# %% [markdown]
# # ***Instalação***

# %%
# %pip install dodfminer -q

# %% [markdown]
# # ***Importação***
#
# A classe do **dodfminer** responsável pela **extração das entidades nomeadas** dos atos do DODF é a ***ActsExtractor***

# %%
from dodfminer import ActsExtractor, ContentExtractor

# %% [markdown]
# # ***Extração***
#
# A extração de entidades nomeadas suporta os seguintes atos:
#
# ### Atos de Pessoal
#
# *   aposentadoria
# *   reversoes
# *   nomeacao
# *   exoneracao
# *   abono
# *   retificacoes
# *   substituicao
# *   efetivos_nome
# *   efetivos_exo
# *   sem_efeito_aposentadoria
# *   cessoes
# *   sem_efeito_exo_nom
# *   efetivos_ret
# *   comissionados_ret
#
# ### Atos de Contratos
#
# *   aditamento
# *   licitacao
# *   suspensao
# *   anulacao_revogacao
# *   contrato
# *   convenio

# %% [markdown]
# ## ***Extraindo um tipo específico de ato***
#
# Para extrair um tipo específico de ato basta chamar o método ***get_act_obj*** da classe ***ActsExtractor*** passando como parâmetro o caminho para seu arquivo e a **chave do ato**.

# %%
# Extrair texto do pdf
file_pdf = "./DODF 197 19-10-2022 INTEGRA.pdf"
ContentExtractor.extract_text(file_pdf, single=True)

# Extrair entidades do texto
file_txt = "./DODF 197 19-10-2022 INTEGRA.txt"
data_aditamento = ActsExtractor.get_act_obj('nomeacao', file_txt)

# %% [markdown]
# ### ***Retorno***
#
# O retorno do método que extrai entidades de um ato em específico é um objeto que possui o atributo ***data_frame*** que contém as informações que desejamos.

# %%
data_aditamento.data_frame
# Out:
#   Tipo do Ato                                     Nome  \
# 0    Nomeação              EDMILTON OLIVEIRA RODRIGUES
# 1    Nomeação                 CELSO FRANCISCO DE ASSIS
# 2    Nomeação              UANDERSON DA SILVA DE SOUZA
# 3    Nomeação   HELENA SABINO SILVA TORRES DE MESQUITA
# 4    Nomeação               ALTAIR CRESCENCIO DA SILVA
# 5    Nomeação                    OSNI BUENO DE FREITAS
# 6    Nomeação         WELLINGTON SOARES RIBEIRO JUNIOR
# 7    Nomeação                 MARIANA DOS SANTOS SILVA
#
#                       Cargo_efetivo  Matricula  Matricula_siape Simbolo  \
# 0                               NaN        NaN              NaN   CC-05
# 1                               NaN        NaN              NaN  CNE-07
# 2                               NaN        NaN              NaN   CC-05
# 3                               NaN  187.475-6              NaN  CPE-07
# 4                               NaN        NaN              NaN   CC-08
# 5                               NaN        NaN              NaN  CNE-07
# 6                               NaN        NaN              NaN   CC-02
# 7  para exercer o Cargo em Comissao        NaN              NaN  DFA-12
#
#         Cargo_comissionado                                 Hierarquia_lotacao  \
# 0                 Assessor  Diretoria de Projetos, da\nCoordenacao de Form...
# 1        Assessor Especial  Subsecretaria de Desenvolvimento Regional\ne O...
# 2        Apoio Operacional          Superintendencia de Obras, da Presidencia
# 3        Assessor Especial  Assessoria de\nInteligencia e Informacoes Estr...
# 4                 Assessor                                           Gabinete
# 5                  Diretor  Diretoria de Desenvolvimento e\nOrdenamento Te...
# 6         Assessor Tecnico                    Coordenacao de\nDesenvolvimento
# 7   Assessor(a) Tecnico(a)          Nucleo de Assistencia Juridica do Plantao
#
#                                                Orgao  Cargo  \
# 0  Secretaria\nExtraordinaria da Familia do Distr...    NaN
# 1  Secretaria de Estado\nde Governo do Distrito F...    NaN
# 2  Departamento de Estradas de Rodagem do Distrit...    NaN
# 3  Controladoria-Geral do Distrito Federal, sem\n...    NaN
# 4  Administracao\nRegional do Gama do Distrito Fe...    NaN
# 5  Administracao do\nRiacho Fundo II do Distrito ...    NaN
# 6  Administracao Regional do Riacho Fundo II do D...    NaN
# 7             Defensoria Publica do Distrito Federal    NaN
#
#    Numero_dodf_resultado_final  Fundamento_legal  Carreira  \
# 0                          NaN               NaN       NaN
# 1                          NaN               NaN       NaN
# 2                          NaN               NaN       NaN
# 3                          NaN               NaN       NaN
# 4                          NaN               NaN       NaN
# 5                          NaN               NaN       NaN
# 6                          NaN               NaN       NaN
# 7                          NaN               NaN       NaN
#
#                 DODF_Fonte_Arquivo DODF_Fonte_Data DODF_Fonte_Numero
# 0  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197
# 1  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197
# 2  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197
# 3  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197
# 4  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197
# 5  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197
# 6  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197
# 7  DODF 197 19-10-2022 INTEGRA.pdf      19/10/2022               197

# %% [markdown]
# ## ***Extraindo todos os atos***
#
# Se você tem interesse em vários tipos de ato o método ***get_all_obj*** da classe ***ActsExtractor*** pode ser utilizado, dessa vez passando como parâmetro somente o caminho para seu arquivo.

# %%
### Passe o caminho pro seu arquivo
file_json = "./DODF 076 26-04-2022.json"

data_all = ActsExtractor.get_all_obj(file_json)
# Out:
# Foram encontrados 33 atos de contrato/convênio
# Foram encontrados 5 atos de aditamento
# Foram encontrados 3 atos de licitação
# Foram encontrados 2 atos de suspensão
# Foram encontrados 0 atos de anulação/revogação
# Foram encontrados 27 atos de contrato
# Foram encontrados 6 atos de convenio

# %% [markdown]
# ### ***Retorno***
#
# Dessa vez o retorno é um pouco diferente. Agora você tem um **dicionário** com chaves que representam cada um dos atos. Se precisa dos atos de Aviso de Licitação basta acessar com ***data_all['licitacao'].data_frame***, ou os atos de Extrato de Convênio com ***data_all['convenio'].data_frame***.

# %%
data_all['licitacao'].data_frame
# Out:
#   numero_dodf                          titulo  \
# 0          76              AVISO DE LICITAÇÃO
# 1          76              AVISO DE LICITAÇÃO
# 2          76  AVISO DE ABERTURA DE LICITAÇÃO
#
#                                                 text MODALIDADE_LICITACAO  \
# 0  AVISO DE LICITAÇÃO PREGÃO ELETRÔNICO Nº 51/202...    PREGÃO ELETRÔNICO
# 1  AVISO DE LICITAÇÃO PREGÃO ELETRÔNICO Nº 52/202...    PREGÃO ELETRÔNICO
# 2  AVISO DE ABERTURA DE LICITAÇÃO O Presidente da...    Pregão Eletrônico
#
#   NUM_LICITACAO                                      OBJ_LICITACAO  \
# 0       51/2022  Registro de Preços para eventual aquisição de ...
# 1       52/2022  contratação de empresa especializada para mini...
# 2           NaN  Contratação de empresa especializada em serviç...
#
#   VALOR_ESTIMADO DATA_ABERTURA                PROCESSO  \
# 0     790.889,26    11/05/2022  00040-00004956/2022-55
# 1      21.140,00    16/05/2022  00063-00002654/2021-11
# 2      11.450,40           NaN                     NaN
#
#                     SISTEMA_COMPRAS                  ORGAO_LICITANTE
# 0  www.comprasgovernamentais.gov.br                              NaN
# 1  www.comprasgovernamentais.gov.br  Fundação Hemocentro de Brasília
# 2                               NaN                              NaN

# %%
data_all['contrato'].data_frame
# Out:
#    numero_dodf                                             titulo  \
# 0           76           EXTRATO DO CONTRATO DE RATEIO Nº 03/2022
# 1           76  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 2           76                                EXTRATO DE CONTRATO
# 3           76                                EXTRATO DE CONTRATO
# 4           76                EXTRATO DO CONTRATO BRB Nº 168/2022
# 5           76                EXTRATO DO CONTRATO BRB Nº 171/2022
# 6           76                  EXTRATO DO CONTRATO Nº 43923/2021
# 7           76                  EXTRATO DO CONTRATO Nº 45788/2021
# 8           76                  EXTRATO DO CONTRATO Nº 46202/2021
# 9           76                  EXTRATO DO CONTRATO Nº 46205/2021
# 10          76                                CONTRATO Nº 08/2022
# 11          76                                CONTRATO Nº 10/2022
# 12          76                     EXTRATO DO CONTRATO Nº 10/2022
# 13          76                                EXTRATO DE CONTRATO
# 14          76                                           CONTRATO
# 15          76  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 16          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 14/2022, ...
# 17          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 15/2022, ...
# 18          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 16/2022, ...
# 19          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 17/2022, ...
# 20          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 18/2022, ...
# 21          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 19/2022, ...
# 22          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 20/2022, ...
# 23          76  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 21/2022, ...
# 24          76                     EXTRATO DO CONTRATO Nº 01/2022
# 25          76                     EXTRATO DO CONTRATO Nº 03/2022
# 26          76                     EXTRATO DO CONTRATO Nº 06/2022
#
#                                                  text  NUM_AJUSTE  \
# 0   EXTRATO DO CONTRATO DE RATEIO Nº 03/2022 Objet...     03/2022
# 1   EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...     02/2022
# 2   EXTRATO DE CONTRATO O BRB – Banco de Brasília ...         NaN
# 3   EXTRATO DE CONTRATO O BRB – Banco de Brasília ...         NaN
# 4   EXTRATO DO CONTRATO BRB Nº 168/2022 Contratada...    168/2022
# 5   EXTRATO DO CONTRATO BRB Nº 171/2022 Contratada...    171/2022
# 6   EXTRATO DO CONTRATO Nº 43923/2021 Processo: 04...  43923/2021
# 7   EXTRATO DO CONTRATO Nº 45788/2021 Processo: 04...  45788/2021
# 8   EXTRATO DO CONTRATO Nº 46202/2021 Processo: 04...  46202/2021
# 9   EXTRATO DO CONTRATO Nº 46205/2021 Processo: 04...  46205/2021
# 10  CONTRATO Nº 08/2022 Contratante: FUNDAÇÃO HEMO...     08/2022
# 11  CONTRATO Nº 10/2022 Contratante: FUNDAÇÃO HEMO...     10/2022
# 12  EXTRATO DO CONTRATO Nº 10/2022 Processo: 00054...     10/2022
# 13  EXTRATO DE CONTRATO CONTRATO SIMPLIFICADO DE S...         NaN
# 14  CONTRATO Espécie: Contrato nº 02/2022 - CEB IP...         NaN
# 15  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...     03/2022
# 16  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 14/2022, ...     14/2022
# 17  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 15/2022, ...     15/2022
# 18  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 16/2022, ...     16/2022
# 19  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 17/2022, ...     17/2022
# 20  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 18/2022, ...     18/2022
# 21  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 19/2022, ...     19/2022
# 22  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 20/2022, ...     20/2022
# 23  CONTRATO DE PRESTAÇÃO DE SERVIÇOS Nº 21/2022, ...     21/2022
# 24  EXTRATO DO CONTRATO Nº 01/2022 Processo: 00401...     01/2022
# 25  EXTRATO DO CONTRATO Nº 03/2022 Processo: 00401...     03/2022
# 26  EXTRATO DO CONTRATO Nº 06/2022 Processo: 00401...     06/2022
#
#                                            OBJ_AJUSTE  \
# 0   [Constitui o objeto do presente Contrato de Ra...
# 1   Prestação de serviços de fornecimento e entreg...
# 2                                                 NaN
# 3   O BRB – Banco de Brasília S.A. torna pública a...
# 4                                                 NaN
# 5                                                 NaN
# 6   CREDECIAMENTO DE PESSOAS JURIDICAS PARA PRESTA...
# 7   CREDECIAMENTO DE PESSOAS JURIDICAS PARA PRESTA...
# 8   CREDENCIAMENTO DE PESSOAS JURIDICAS PARA PREST...
# 9   CREDENCIAMENTO DE PESSOAS JURIDICAS PARA PREST...
# 10  Contratação de empresa especializada na presta...
# 11  Contratação de empresa especializada na presta...
# 12  Aquisição de 06 ( seis ) veículos furgão , tip...
# 13  Contratação de empresa especializada em outsou...
# 14  Contratação de Serviços Regulares de Auditoria...
# 15  [Prestação de serviços de manutenção de equipa...
# 16  [O Contrato tem por objeto a prestação de serv...
# 17  [O Contrato tem por objeto a contratação da Ci...
# 18  [O, O Contrato tem por objeto a prestação de s...
# 19  [O Contrato tem por objeto a prestação de serv...
# 20  [O Contrato tem por objeto a contratação artís...
# 21  [O Contrato tem por objeto a prestação de serv...
# 22  [O Contrato tem por objeto a prestação de serv...
# 23  [O Contrato tem por objeto a prestação de serv...
# 24  Prestação de serviços de manutenção de equipam...
# 25  Aquisição de carimbos . Fundamento Legal : Pre...
# 26  Aquisição de material apoio ergonômico para pé...
#
#                             CONTRATANTE_ou_CONCEDENTE  \
# 0   Consórcio Interestadual de Desenvolvimento do ...
# 1                                                 NaN
# 2                                          [BRB, BRB]
# 3                                                 BRB
# 4                                          [BRB, BRB]
# 5                                          [BRB, BRB]
# 6   [INSTITUTO DE ASSIST . À SAÚDE DOS SERV . DO D...
# 7   [INSTITUTO DE ASSIST . À SAÚDE DOS SERV . DO D...
# 8   [INSTITUTO DE ASSIST . À SAÚDE DOS SERV . DO D...
# 9   [INSTITUTO DE ASSIST . À SAÚDE DOS SERV . DO D...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                CEB
# 14                                                CEB
# 15                             [SEAGRI/DF, SEAGRI/DF]
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24             DEFENSORIA PÚBLICA DO DISTRITO FEDERAL
# 25             DEFENSORIA PÚBLICA DO DISTRITO FEDERAL
# 26             DEFENSORIA PÚBLICA DO DISTRITO FEDERAL
#
#    CNPJ_CONTRATANTE_ou_CONCEDENTE  \
# 0              23.791.169/0001-02
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10             86.743.457/0001-01
# 11             86.743.457/0001-01
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            NaN
#
#                         CNPJ_CONTRATADA_ou_CONVENENTE  \
# 0   [00.394.601/0001-26, 00.394.700/0001-08, 06.02...
# 1                                  10.719.671/0001-60
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                 34.782.400/0001-18
# 11                                 13.086.399/0001-17
# 12                                                NaN
# 13                                 31.229.947/0001-00
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#                              CONTRATADA_ou_CONVENENTE  \
# 0         Fundo Estadual de Saúde do Distrito Federal
# 1      ELDEX DISTRIBUIDORA DE JORNAIS E REVISTAS LTDA
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   VIVACE FISIOTERAPIA & amp ; MEDICINA INTEGRADA...
# 7                REACTIVE FISIOTERAPIA INTEGRADA LTDA
# 8              BEM ESTAR CLINICA DE PSICOLOGIA EIRELI
# 9                            CLÍNICA CARDIOLÓGICA S/C
# 10  MEDIC VITALL COMÉRCIO E SERVIÇOS HOSPITALARES ...
# 11              CERTIFIQUE SOLUÇÕES INTEGRADAS EIRELI
# 12             USATEC BSB VEÍCULOS ESPECIAIS LTDA-EPP
# 13  AVANTE DESENVOLVIMENTO DE SOLUCOES TECNOLOGICA...
# 14              CEB Iluminação Pública e Serviços S/A
# 15  [RICARDO ALVES RAMOS DE BRITO EXTINTORES ME, R...
# 16  R.T ESTRELA ASSESSORIA EM GESTÃO E CONSULTORIA...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                     TZ PRODUÇÕES ARTÍSTICAS EIRELI
# 21                                                NaN
# 22                                                NaN
# 23             CARNE DURA PRODUÇÕES ARTÍSTICAS EIRELI
# 24         RICARDO ALVES RAMOS DE BRITO EXTINTORES ME
# 25    HBL CARIMBOS E PLACAS INDUSTRIA E COMERCIO LTDA
# 26                    E2 IMPORTAÇÃO E EXPORTAÇÃO LTDA
#
#                                              VIGENCIA  \
# 0   [O, O presente contrato vigerá até 31/12/2022 ...
# 1   12 ( doze ) meses , a contar da data de assina...
# 2                                            330 dias
# 3                                            330 dias
# 4                             20/04/2022 à 19/04/2027
# 5                             20/04/2022 à 19/04/2027
# 6   [12 ( doze ) mês ( es ) consecutivos, 12 ( doz...
# 7   [12 ( doze ) mês ( es ) consecutivos, 12 ( doz...
# 8   [12 ( doze ) mês ( es ) consecutivos, 12 ( doz...
# 9   [12 ( doze ) mês ( es ) consecutivos, 12 ( doz...
# 10  12 ( doze ) meses , contados da assinatura do ...
# 11  12 ( doze ) meses , contados da assinatura do ...
# 12  12 ( doze ) meses a contar da data de sua assi...
# 13  06 ( seis ) meses , contados da assinatura do ...
# 14                          28 ( vinte e oito ) meses
# 15                                                NaN
# 16  O contrato terá vigência de 256 ( duzentos e c...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  12 ( doze ) meses , improrrogáveis , contados ...
# 25  12 ( doze ) meses , a contar da data de sua as...
# 26  12 ( doze ) meses a contar da data de sua assi...
#
#                                        VALOR  \
# 0                              39.305.595,41
# 1                       [8.687,64, 8.687,64]
# 2                                 370.000,00
# 3                                 650.000,00
# 4                                  43.125,00
# 5                                  42.500,00
# 6                       [5.000,00, 5.000,00]
# 7             [5.000,00, 5.000,00, 5.000,00]
# 8                       [5.000,00, 5.000,00]
# 9                       [5.000,00, 5.000,00]
# 10                                       NaN
# 11                                       NaN
# 12                              2.178.902,82
# 13                                 24.000,00
# 14                                 50.000,00
# 15  [3.919,04, 3.919,04, 1.910,86, 2.008,18]
# 16                  [130.000,00, 130.000,00]
# 17                    [50.000,00, 50.000,00]
# 18                    [25.000,00, 25.000,00]
# 19                      [8.600,00, 8.600,00]
# 20                          [15.000, 15.000]
# 21                                       NaN
# 22                    [15.000,00, 15.000,00]
# 23                    [36.000,00, 36.000,00]
# 24                                  4.130,70
# 25                                  3.600,00
# 26                                 42.245,00
#
#                                              PROCESSO  \
# 0                                                 NaN
# 1                [00014-00000354/2022-28, 20/04/2022]
# 2                             [09/02/2022, 0185/2022]
# 3                             [09/02/2022, 0185/2022]
# 4                                            351/2022
# 5                                            239/2022
# 6              [04001-0000000262/2021-67, 15/04/2021]
# 7                            04001-0000000123/2022-14
# 8                            04001-0000000783/2021-14
# 9                            04001-0000000785/2021-11
# 10                             00063-00001894/2022-71
# 11                             00063-00001896/2022-60
# 12               [00054-00001636/2021-12, 13/04/2022]
# 13                             00093-00000253/2022-97
# 14                                                NaN
# 15  [00070-00002084/2022-89, 20.122.8201.8517.0004...
# 16                                                NaN
# 17                              13.392.6219.2803.0001
# 18                                                NaN
# 19                              13.392.6219.2803.0001
# 20                              13.392.6219.2803.0001
# 21                                                NaN
# 22                                                NaN
# 23                              13.392.6219.2803.0001
# 24  [00401-00011481/2021-16, 33.90.39.20, 29/03/2021]
# 25               [00401-00003722/2022-26, 19/04/2022]
# 26  [00401-00004753/2022-02, 44.90.52.42, 20/04/2022]
#
#                              CODIGO_UO                 PROGRAMA_TRABALHO  \
# 0                                  NaN                               NaN
# 1                                10101             04.122.8203.8517.0109
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# 5                                  NaN                               NaN
# 6                                  NaN                    10122620361957
# 7                                  NaN  [10122620361957, 10122620361957]
# 8                                  NaN                    10122620361957
# 9                                  NaN                    10122620361957
# 10                               23202             10.122.8202.8517.0117
# 11                               23202             10.122.8202.8517.0117
# 12                                 NaN                               NaN
# 13                                 NaN                               NaN
# 14                                 NaN                               NaN
# 15                               14101                               NaN
# 16          [16101, 13392621928310001]                               NaN
# 17                               16101                               NaN
# 18          [16101, 13392621928030001]                               NaN
# 19                               16101                               NaN
# 20                               16101                               NaN
# 21          [16101, 13392621928030001]                               NaN
# 22  [16101, 13392621928030001, 339036]                               NaN
# 23                               16101                               NaN
# 24                               48101             03.122.8211.8517.0138
# 25                               48101             03.122.8211.8517.0138
# 26                               48101             03.122.8211.8517.0138
#
#         NATUREZA_DESPESA           FONTE_RECURSO  \
# 0                    NaN                     NaN
# 1              3.3.90.39                     100
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
# 5                    NaN                     NaN
# 6                    NaN               220000000
# 7                    NaN  [220000000, 220000000]
# 8                    NaN               220000000
# 9                    NaN               220000000
# 10  [33.90.30, 33.90.39]                     138
# 11  [33.90.30, 33.90.39]                     138
# 12              44.90.52              0100000000
# 13                   NaN                     NaN
# 14                   NaN                     NaN
# 15                339039                     100
# 16                339039                     100
# 17                339039                     100
# 18                339039                     100
# 19              33.90.39                     100
# 20                339039                     100
# 21                339039                     100
# 22                   NaN                     100
# 23                339039                     100
# 24                   NaN                     100
# 25                   NaN                     100
# 26                   NaN                     100
#
#                     NOTA_EMPENHO   NOME_RESPONSAVEL      DATA_ASSINATURA
# 0                            NaN                NaN                  NaN
# 1                    2022NE00121                NaN                  NaN
# 2                            NaN                NaN                  NaN
# 3                            NaN                NaN                  NaN
# 4                            NaN  Bruno Costa Nunes                  NaN
# 5                            NaN  Bruno Costa Nunes                  NaN
# 6                   2022NE0/0255                NaN                  NaN
# 7   [2022NE0/0249, 2022NE0/0142]                NaN           29/07/2021
# 8                   2022NE0/0260                NaN           30/08/2021
# 9                   2022NE0/0256                NaN           09/09/2021
# 10                   2022NE00276                NaN                  NaN
# 11                   2022NE00278                NaN                  NaN
# 12                     2022NE179                NaN                  NaN
# 13                           NaN                NaN  20 de abril de 2022
# 14                           NaN                NaN                  NaN
# 15    [2022NE00109, 2022NE00110]                NaN                  NaN
# 16                   2022NE00338                NaN  20 de abril de 2022
# 17                           NaN                NaN  20 de abril de 2022
# 18                   2022NE00360                NaN  20 de abril de 2022
# 19                           NaN                NaN  20 de abril de 2022
# 20                           NaN                NaN  20 de abril de 2022
# 21                           NaN                NaN  20 de abril de 2022
# 22                           NaN                NaN  20 de abril de 2022
# 23                           NaN                NaN  21 de abril de 2022
# 24                           NaN                NaN                  NaN
# 25                           NaN                NaN                  NaN
# 26                  02/2022-DPDF                NaN                  NaN

# %% [markdown]
# # ***Utilizando outro Modelo de Extração de Entidades com o DODFMiner***
#
# Caso você venha a ter dados de treinamento mais atualizados ou em maior quantidade, deseja que o modelo seja treinado com mais épocas ou até mesmo com parâmetros diferentes, basta passar seu **pipeline com o modelo treinado** como **parâmetro** para a extração do dodfminer.

# %% [markdown]
# ## ***Como usar o pipeline do sklearn para treinar seu modelo***
#
# Como exemplo vamos utilizar o mesmo modelo usado no dodfminer, o ***CRF*** do ***sklearn_crfsuite***.

# %% [markdown]
# ### ***Imports***
#
# Quais são as bibliotecas necessárias para a utilização

# %%
#pipeline imports
import pandas as pd
import nltk

#Elementos do pipeline precisam herdar de TransformerMixin, sendo o ultimo (mais da direita) o Modelo que herda de BaseEstimator
from sklearn.base import TransformerMixin, BaseEstimator

#Pipeline precisa ser do sklearn.pipeline
from sklearn.pipeline import Pipeline

#Modelo usado no DODFMiner
from sklearn_crfsuite import CRF

# %% [markdown]
# ### ***Classes TransformerMixin***
#
# Todo o **pré-processamento**, **extração de características (*feature extraction*)** e **tokenização** devem ser feitos em classes que herdam de ***TransformerMixin*** da biblioteca ***sklearn***.
#
# Alguns métodos como ***fit*** e ***transform*** precisam ser sobrescritos nessas classes para o funcionamento correto do **Pipeline**.

# %% [markdown]
# ### ***Classe de Pré-Processamento***
#
# A classe ***Processing*** é **obrigatória** no pipeline e é responsável pelo **pré-processamento** (se houver) e ***tokenização*** do input do modelo.

# %%
class Processing(TransformerMixin):
  def __init__(self):
    pass

  def tokenize(self, sentence):
    text = nltk.word_tokenize(sentence)
    return text

  def fit(self, X, y = None):
    return self

  def transform(self, X, y = None):
    transformed = []
    for x in X:
      tokens = self.tokenize(x)
      transformed.append(tokens)
    return transformed

# %% [markdown]
# ### ***Classe de Feature Extraction***
#
# ***Feature extraction*** é algo comum em modelos CRF, e como estamos nos baseando no DODFMiner que utiliza esse modelo vamos também implementá-la aqui, mas vale lembrar que **não é obrigatória** caso utilize um modelo diferente.

# %%
class FeatureExtractor(TransformerMixin):
  def __init__(self):
    pass

  def get_features(self, sentence):
    sent_features = []
    for i in range(len(sentence)):
      word_feat = {
        # Palavra atual
        'word': sentence[i].lower(),
        'capital_letter': sentence[i][0].isupper(),
        'all_capital': sentence[i].isupper(),
        'isdigit': sentence[i].isdigit(),
        # Uma palavra antes
        'word_before': '' if i == 0 else sentence[i-1].lower(),
        'word_before_isdigit': '' if i == 0 else sentence[i-1].isdigit(),
        'word_before_isupper': '' if i == 0 else sentence[i-1].isupper(),
        'word_before_istitle': '' if i == 0 else sentence[i-1].istitle(),
        # Uma palavra depois
        'word_after': '' if i+1 >= len(sentence) else sentence[i+1].lower(),
        'word_after_isdigit': '' if i+1 >= len(sentence) else sentence[i+1].isdigit(),
        'word_after_isupper': '' if i+1 >= len(sentence) else sentence[i+1].isupper(),
        'word_after_istitle': '' if i+1 >= len(sentence) else sentence[i+1].istitle(),

        'BOS': i == 0,
        'EOS': i == len(sentence)-1
      }
      sent_features.append(word_feat)
    return sent_features

  def fit(self, X, y = None):
    return self

  def transform(self, X, y = None):
    transformed = []
    for x in X:
      features = self.get_features(x)
      transformed.append(features)
    return transformed

# %% [markdown]
# ### ***Classe BaseEstimator***
#
# Essa classe é **obrigatória** e é nela que o modelo entra. Precisa herdar de ***BaseEstimator*** da biblioteca ***sklearn*** e os métodos ***predict***, ***fit*** e ***transform*** também precisam ser sobrescritos para o funcionamento correto do **Pipeline**.

# %%
class Model(BaseEstimator):

    def __init__(self):
        self.crf = CRF(
          algorithm = 'lbfgs',
          c1=0.35,
          c2=0.2,
          max_iterations=60,
          all_possible_transitions=True
        )

    def transform(self, X, y = None):
      return X

    def fit(self, X, y):
        self.crf.fit(X, y)
        return self

    def predict(self, x):
        pred = self.crf.predict(x)
        return pred

# %% [markdown]
# ### ***Criação do Pipeline***
#
# As classes descritas acima são o que constituem o **pipeline** que é passado para o **dodfminer**. Utilizamos a classe ***Pipeline*** da biblioteca ***sklearn*** para construí-lo. A classe do modelo que herda de ***BaseEstimator*** sempre deve ser a mais à direita na construção do objeto.
#
# Cada uma das classes passadas como parâmetro para o pipeline possuem **chaves**, que são utilizadas pra acessar cada uma delas. A classe ***Processing*** **obrigatóriamente** deve ser passada com a chave ***'pre-processing'***, e a do modelo com a chave ***'model'***.

# %%
pipeline_custom = Pipeline([('pre-processing', Processing()), ('feature-extraction', FeatureExtractor()), ('model', Model())])

# %% [markdown]
# ### ***Treinamento***
#
# Com o objeto do pipeline montado podemos treinar o modelo. Prepare os seus dados de treino X, y e chame o método ***fit***.

# %% [markdown]
# #### ***Preparando os dados de treino***

# %%
df_aditamento_contratual = pd.read_csv('./treino_aditamento_contratual.csv')

# %%
df_aditamento_contratual.head(3)
# Out:
#    Unnamed: 0                            ato           dodf  \
# 0           0  EXTRATO_ADITAMENTO_CONTRATUAL  12_22.11.2018
# 1           1  EXTRATO_ADITAMENTO_CONTRATUAL  12_22.11.2018
# 2           2  EXTRATO_ADITAMENTO_CONTRATUAL  12_22.11.2018
#
#                                         treated_text         PROCESSO  \
# 0  EXTRATO DO SEGUNDO TERMO ADITIVO AO CONTRATO P...  0050-00473/2016
# 1  EXTRATO TERCEIRO TERMO ADITIVO DO CONTRATO DE ...  0530001247/2015
# 2  EXTRATO SEGUNDO TERMO ADITIVO DO CONTRATO DE P...  053-043005/2016
#
#   NUM_AJUSTE                                        CONTRATANTE  \
# 0    25/2018  SECRETARIA DE ESTADO DA SEGURANCA PUBLICA E DA...
# 1    58/2015                                                NaN
# 2    48/2016                                                NaN
#
#                                          OBJ_ADITIVO NUM_ADITIVO  \
# 0  O presente Termo Aditivo tem por objeto a pror...     SEGUNDO
# 1  Prorrogar o prazo de vigencia do contrato por ...    TERCEIRO
# 2  O presente termo aditivo objetiva: Prorrogar o...     SEGUNDO
#
#   NOME_RESPONSAVEL            DATA_ESCRITO  CODIGO_SIGGO  \
# 0              NaN  01 de novembro de 2018           NaN
# 1              NaN              06/11/2018           NaN
# 2              NaN              14/11/2018           NaN
#
#                                                  IOB
# 0  O O B-NUM_ADITIVO O O O O O O O O O B-NUM_AJUS...
# 1  O B-NUM_ADITIVO O O O O O O O O O O O O O O O ...
# 2  O B-NUM_ADITIVO O O O O O O O O O B-NUM_AJUSTE...

# %%
X = df_aditamento_contratual['treated_text'].to_list()
y = df_aditamento_contratual['IOB'].to_list()
y = [iob.split() for iob in y]

# %% [markdown]
# #### ***Treino***

# %%
pipeline_custom.fit(X, y)
# Out:
# Pipeline(steps=[('pre-processing',
#                  <__main__.Processing object at 0x7f4cff452e80>),
#                 ('feature-extraction',
#                  <__main__.FeatureExtractor object at 0x7f4cff452e50>),
#                 ('model', Model())])

# %% [markdown]
# ## ***Extração com o pipeline***
#
# Vamos utilizar a nossa classe ***ActsExtractor*** junto com o nosso pipeline para extrair as entidades nomeadas. Para isso passamos um parâmetro a mais no método de extração, que é o pipeline.

# %%
### Passe o caminho pro seu arquivo
data_aditamento_custom = ActsExtractor.get_act_obj('aditamento', file_json, pipeline = pipeline_custom)
# Out:
# Foram encontrados 5 atos de aditamento

# %% [markdown]
# Podemos comparar o resultado dos dois modelos com a extração que fizemos anteriormente e verificar as diferenças.

# %%
data_aditamento_custom.data_frame
# Out:
#   numero_dodf                                             titulo  \
# 0          76             EXTRATO DE CONTRATO (1º TERMO ADITIVO)
# 1          76             EXTRATO DE CONTRATO (1º TERMO ADITIVO)
# 2          76  EXTRATO DO SEGUNDO TERMO ADITIVO AO CONTRATO N...
# 3          76  EXTRATO DO QUINTO TERMO ADITIVO AO CONTRATO Nº...
# 4          76  EXTRATO DO PRIMEIRO TERMO ADITIVO AO CONTRATO ...
#
#                                                 text  \
# 0  EXTRATO DE CONTRATO (1º TERMO ADITIVO) Process...
# 1  EXTRATO DE CONTRATO (1º TERMO ADITIVO) Process...
# 2  EXTRATO DO SEGUNDO TERMO ADITIVO AO CONTRATO N...
# 3  EXTRATO DO QUINTO TERMO ADITIVO AO CONTRATO Nº...
# 4  EXTRATO DO PRIMEIRO TERMO ADITIVO AO CONTRATO ...
#
#                                     NUM_ADITIVO  \
# 0                              1º TERMO ADITIVO
# 1                              1º TERMO ADITIVO
# 2                         SEGUNDO TERMO ADITIVO
# 3  [QUINTO TERMO ADITIVO, Quinto Termo Aditivo]
# 4                        PRIMEIRO TERMO ADITIVO
#
#                                          PROCESSO  \
# 0                          00001-00004093/2021-56
# 1                          00001-00015205/2021-02
# 2            [00040-00005988/2020-14, 19/04/2022]
# 3             [121.0000.5989/2017-55, 20/04/2022]
# 4  [00054-00116386/2020-33, 44.90.51, 20/04/2022]
#
#                                          OBJ_ADITIVO  NUM_AJUSTE  \
# 0                                                NaN         NaN
# 1  alteração do Contrato-PG nº 46/2021-NPLC , fir...         NaN
# 2  Prorrogar o prazo de vigência do CONTRATO por ...  43189/2021
# 3  Prorrogação do contrato nº 06/2018 , em confor...         NaN
# 4  A alteração qualitativa do item malha de aço ,...     29/2021
#
#                                          CONTRATANTE
# 0                                                NaN
# 1                                                NaN
# 2  SECRETARIA DE ESTADO DE ECONOMIA DO DISTRITO F...
# 3  Companhia de Planejamento do Distrito Federal ...
# 4                                            DF/PMDF

# %%
data_all["aditamento"].data_frame
# Out:
#   numero_dodf                                             titulo  \
# 0          76             EXTRATO DE CONTRATO (1º TERMO ADITIVO)
# 1          76             EXTRATO DE CONTRATO (1º TERMO ADITIVO)
# 2          76  EXTRATO DO SEGUNDO TERMO ADITIVO AO CONTRATO N...
# 3          76  EXTRATO DO QUINTO TERMO ADITIVO AO CONTRATO Nº...
# 4          76  EXTRATO DO PRIMEIRO TERMO ADITIVO AO CONTRATO ...
#
#                                                 text  \
# 0  EXTRATO DE CONTRATO (1º TERMO ADITIVO) Process...
# 1  EXTRATO DE CONTRATO (1º TERMO ADITIVO) Process...
# 2  EXTRATO DO SEGUNDO TERMO ADITIVO AO CONTRATO N...
# 3  EXTRATO DO QUINTO TERMO ADITIVO AO CONTRATO Nº...
# 4  EXTRATO DO PRIMEIRO TERMO ADITIVO AO CONTRATO ...
#
#                                     NUM_ADITIVO  \
# 0                              1º TERMO ADITIVO
# 1                              1º TERMO ADITIVO
# 2                         SEGUNDO TERMO ADITIVO
# 3  [QUINTO TERMO ADITIVO, Quinto Termo Aditivo]
# 4                        PRIMEIRO TERMO ADITIVO
#
#                                PROCESSO  \
# 0                00001-00004093/2021-56
# 1                00001-00015205/2021-02
# 2  [00040-00005988/2020-14, 19/04/2022]
# 3   [121.0000.5989/2017-55, 20/04/2022]
# 4  [00054-00116386/2020-33, 20/04/2022]
#
#                                          CONTRATANTE  \
# 0             Câmara Legislativa do Distrito Federal
# 1             Câmara Legislativa do Distrito Federal
# 2  SECRETARIA DE ESTADO DE ECONOMIA DO DISTRITO F...
# 3  Companhia de Planejamento do Distrito Federal ...
# 4                                                NaN
#
#                                          OBJ_ADITIVO  NUM_AJUSTE
# 0  acréscimo de 20 ( vinte ) unidades do item úni...         NaN
# 1  alteração do Contrato-PG nº 46/2021-NPLC , fir...         NaN
# 2  Prorrogar o prazo de vigência do CONTRATO por ...  43189/2021
# 3  Prorrogação do contrato nº 06/2018 , em confor...     06/2018
# 4  A alteração qualitativa do item malha de aço ,...     29/2021
