# %%
# !pip3 install dodfminer
# Out:
# ...
#   Using cached dodfminer-1.3.2-py3-none-any.whl (18.0 MB)
# ...
#   Using cached joblib-0.16.0-py3-none-any.whl (300 kB)
# ...
# Processing c:\users\khalil\appdata\local\pip\cache\wheels\e2\62\1e\926d1ebe7b1e733c78d627fd288d01b83feaf67efc06e0e4c3\gdown-3.12.2-py3-none-any.whl
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.17.0
#     Uninstalling joblib-0.17.0:
#       Successfully uninstalled joblib-0.17.0
# ...

# %%
from dodfminer import ContentExtractor

# %%
ContentExtractor.extract_text("data/DODF 030 12-02-2019 INTEGRA.pdf", block=True)
# Out:
# [(144.84640502929688,
#   190.43650817871094,
#   671.6583862304688,
#   208.86129760742188,
#   'ANO XLVIII EDICAO No- 30\nBRASILIA - DF, TERCA-FEIRA, 12 DE FEVEREIRO DE 2019'),
#  (202.99237060546875,
#   614.2850952148438,
#   257.645751953125,
#   628.7542724609375,
#   'SECAO I'),
#  (141.144287109375,
#   241.34384155273438,
#   401.49853515625,
#   261.69134521484375,
#   'SUMARIO\nSECAO I\nPAG.\nSECAO II\nPAG.\nSECAO III\nPAG.'),
#  (56.702911376953125,
#   269.6023254394531,
#   386.8976745605469,
#   278.4285888671875,
#   'Poder Legislativo................................................................................... . 1 29'),
#  (56.70294189453125,
#   286.3395690917969,
#   344.85040283203125,
#   295.16583251953125,
#   'Poder Executivo .................................................................................... . 2 10'),
#  (56.70294189453125,
#   303.0768127441406,
#   344.850341796875,
#   311.90313720703125,
# ...
