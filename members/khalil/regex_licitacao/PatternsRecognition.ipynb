# %% [markdown]
# # KneDle: Licitações e Contratos
# ## Data Exploration: "AVISO DE VENCEDOR"

# %%
import re
import docx
from sklearn.feature_extraction.text import CountVectorizer
import operator
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Khalil\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %% [markdown]
# ### Exploring collected data from: <https://www.dodf.df.gov.br/>

# %%
texto = [getText('abetura.docx').lower()]
texto
# Out:
# ['padrões abertura de edital\nexemplos:\n\naviso de abertura de licitação pregão eletrônico nº 04/2021 processo: 00050-00000250/2021-04. tipo: menor preço. modo de disputa: aberto. objeto: registro de preços para eventual aquisição de equipamentos relacionados à tecnologia da informação e comunicação (tic), mais especificamente, 12 (doze) servidores de rack para a sspdf. valor estimado: sigiloso. prazos: de entrega: não superior a 15 dias, contados da assinatura do contrato ou do recebimento da nota de empenho. do contrato: 120 (cento e vinte) dias a partir da data da assinatura. data da sessão pública: 17/03/2021 às 10:00 horas no www.gov.br/compras. uasg 450107. edital também está disponível no http://www.ssp.df.gov.br/licitacoes/. brasília/df,04 de março de 2021 amilcar ubiratan urach vieira\n\naviso de licitação aviso de abertura de licitação exclusiva pregão eletrônico nº 10/2021 processo: 00001-00033436/2020-17. objeto: contratação de empresa especializada para o fornecimento de medicamentos e materiais hospitalares, para atendimento do setor de assistência à saúde da câmara legislativa do distrito federal (sas/cldf) de acordo com as especificações e quantitativos constantes do termo de referência – anexo i do edital. valor estimado: r$ 30.000,00.data/hora da sessão pública: 14/04/2021, às 14h30min. local: internet, no endereço www.comprasnet.gov.br. tipo: maior desconto. o edital encontra-se nos endereços: www.comprasnet.gov.br (uasg 974004) e www.cl.df.gov.br, no linkportal da transparência. maiores informações (61) 3348-8650 ou pelo e-mail: cpl@cl.df.gov.br. lana marta gonçalves pires pregoeira\n\naviso de abertura pregão eletrônico srp nº 06/2021 - (uasg 450432) objeto: registro de preços para eventual aquisição de gêneros alimentícios perecíveis - filé de peixe congelado de tilápia-, para o programa de alimentação escolar do distrito federal (pae-df) conforme condições, quantidades e exigências estabelecidas no edital e seus anexos. total de itens: 08- valor total estimado: r$ 19.900.737,72 (dezenove milhões, novecentos mil setecentos e trinta e sete reais e setenta e dois centavos). processo nº 00080-00198062/2020-14-cadastro das propostas: a partir de 12/01/2021. abertura das propostas: 22/01/2021, às 10h, horário de brasília. o edital estará disponível nos endereços eletrônicos: www.comprasgovernamentais.gov.br e http://www.se.df.gov.br/pregao-eletronico-sistema-de-registro-de-precos/. brasília/df, 11 de janeiro de 2021 regina rodrigues porto pregoeira\n\naviso de abertura pregão eletrônicowi nº 02/2021 processo: 00001-00035338/2020-14. objeto: contratação por meio de execução indireta, de serviços de bombeiro civil, apoio administrativo na área de segurança contra incêndio, pânico, abandono de edificações, primeiros socorros, treinamento de bombeiros voluntários, desenvolvimento e implantação de política prevencionista (ppci), para atender o edifício e áreas da câmara legislativa do distrito federal - cldf. valor estimado: r$ $ 2.076.076,08. data/hora da sessão pública: 20/01/2021, às 14:00. local: internet, no endereço www.comprasnet.gov.br. tipo: menor preço. o edital encontra-se nos endereços: www.comprasnet.gov.br (uasg 974004) e www.cl.df.gov.br, no link transparência. maiores informações (61) 3348-8650 ou licitacao@cl.df.gov.br. daniel luchine ishihara pregoeiro\n\naviso de abertura de licitação pregão eletrônico nº 56/2020 processo: 00050-00028990/2020-16. tipo: menor preço. modo de disputa: aberto. objeto: registro de preços para aquisição de nobreaks e de dispositivo de proteção contra surto (dps) para proteção das câmeras de videomonitoramento no distrito federal da sspdf. valor total estimado: r$ sigiloso. dotação: uo 24.101 – ssp/df. prazos: de entrega: não superior a 30 dias corridos contados da assinatura do contrato ou do recebimento da nota de empenho. vigência do contrato: 180 (cento e oitenta) dias a contar de sua assinatura. data da sessão pública: dia 09/03/2021, às 10h00min no https://www.go ...

# %% [markdown]
# ### BoW: 1-Gram and n-Gram Analysis

# %%
vectorizer = CountVectorizer(stop_words=nltk.corpus.stopwords.words('portuguese'))
X = vectorizer.fit_transform(texto)
words = vectorizer.get_feature_names() #Words
countX = X.toarray()[0]
counting = {}
for pind in range(0, len(countX)):
    counting[words[pind]] = countX[pind]
counting = sorted(counting.items(), key=operator.itemgetter(1),reverse=True)

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(5, 5),token_pattern=r'\b\w+\b', min_df=1, stop_words=nltk.corpus.stopwords.words('portuguese'))
X2 = bigram_vectorizer.fit_transform(texto)
words2 = bigram_vectorizer.get_feature_names() #Words
countX2 = X.toarray()[0]
counting2 = {}
for pind in range(0, len(countX2)):
    counting2[words2[pind]] = countX2[pind]
counting2 = sorted(counting2.items(), key=operator.itemgetter(1),reverse=True)

# %% [markdown]
# ### Visually Selection of Key terms

# %%
counting
# Out:
# [('2021', 46),
#  ('df', 40),
#  ('abertura', 38),
#  ('licitação', 38),
#  ('br', 34),
#  ('data', 33),
#  ('valor', 33),
#  ('aviso', 32),
#  ('gov', 32),
#  ('estimado', 29),
#  ('processo', 29),
#  ('www', 28),
#  ('edital', 25),
#  ('nº', 23),
#  ('brasília', 22),
#  ('objeto', 22),
#  ('2020', 17),
#  ('tipo', 17),
#  ('03', 15),
#  ('pública', 15),
#  ('04', 14),
#  ('preço', 14),
#  ('sessão', 14),
#  ('10', 13),
#  ('uasg', 13),
#  ('compras', 12),
#  ('distrito', 12),
#  ('federal', 12),
#  ('hora', 12),
#  ('menor', 12),
#  ('anexos', 11),
#  ('contratação', 11),
#  ('eletrônico', 11),
#  ('horas', 11),
#  ('pregão', 11),
#  ('propostas', 11),
#  ('recebimento', 11),
#  ('00', 10),
#  ('23', 10),
#  ('serviços', 10),
#  ('terracap', 10),
#  ('março', 9),
#  ('realização', 9),
#  ('aquisição', 8),
#  ('comissão', 8),
#  ('dia', 8),
#  ('endereço', 8),
#  ('limite', 8),
#  ('norte', 8),
#  ('centavos', 7),
#  ('contrato', 7),
#  ('encontra', 7),
#  ('horário', 7),
#  ('mil', 7),
#  ('presidente', 7),
#  ('reais', 7),
#  ('registro', 7),
#  ('setor', 7),
#  ('30', 6),
#  ('assinatura', 6),
#  ('certame', 6),
#  ('cl', 6),
#  ('comprasnet', 6),
#  ('condições', 6),
#  ('dias', 6),
#  ('informações', 6),
#  ('local', 6),
#  ('obras', 6),
#  ('preços', 6),
#  ('sítio', 6),
#  ('01', 5),
#  ('14', 5),
#  ('90', 5),
#  ('bens', 5),
#  ('conforme', 5),
#  ('empresa', 5),
#  ('especializada', 5),
#  ('especificações', 5),
#  ('estabelecidas', 5),
#  ('execução', 5),
#  ('exigências', 5),
#  ('http', 5),
#  ('prazos', 5),
#  ('público', 5),
#  ('quatro', 5),
#  ('sde', 5),
#  ('sigiloso', 5),
#  ('torna', 5),
#  ('total', 5),
#  ('vinte', 5),
#  ('09', 4),
#  ('12', 4),
#  ('13', 4),
#  ('29', 4),
#  ('926334', 4),
#  ('94', 4),
#  ('acordo', 4),
#  ('administrativo', 4),
#  ('anexo', 4),
#  ('cento', 4),
#  ('compra', 4),
#  ('cplic', 4),
#  ('desenvolvimento', 4),
#  ('disponível', 4),
#  ('endereços', 4),
#  ('fundação', 4),
#  ('hemocentro', 4),
#  ('item', 4),
#  ('licitações', 4),
#  ('militar', 4),
#  ('modalidade', 4),
#  ('nove', 4),
#  ('noventa', 4),
#  ('número', 4),
#  ('polícia', 4),
#  ('sete', 4),
#  ('ssp', 4),
#  ('termos', 4),
#  ('00001', 3),
#  ('00050', 3),
#  ('00111', 3),
#  ('14h30min', 3),
#  ('16', 3),
#  ('17', 3),
#  ('19', 3),
#  ('22', 3),
#  ('298', 3),
#  ('3348', 3),
#  ('450107', 3),
#  ('61', 3),
#  ('8650', 3),
#  ('974004', 3),
#  ('aberto', 3),
#  ('amilcar', 3),
#  ('asa', 3),
#  ('atribuições', 3),
#  ('bloco', 3),
#  ('cinco', 3),
#  ('civil', 3),
#  ('comunica', 3),
#  ('confere', 3),
#  ('contados', 3),
#  ('câmara', 3),
#  ('despesa', 3),
#  ('diraf', 3),
#  ('disputa', 3),
#  ('doze', 3),
#  ('empenho', 3),
#  ('entrega', 3),
#  ('equipamentos', 3),
#  ('especial', 3),
#  ('eventual', 3),
#  ('faria', 3),
#  ('glauber', 3),
#  ('global', 3),
#  ('gratuitamente', 3),
#  ('interessados', 3),
#  ('internet', 3),
#  ('legislativa', 3),
#  ('licitacoes', 3),
#  ('mail', 3),
#  ('maiores', 3),
#  ('milhões', 3),
#  ('modo', 3),
#  ('necessários', 3),
#  ('nota', 3),
#  ('partir', 3),
#  ('portaria', 3),
#  ('pregoeira', 3),
#  ('programa', 3),
#  ('projeto', 3),
#  ('quadra', 3),
#  ('quantidades', 3),
#  ('regime', 3),
#  ('retirada', 3),
#  ('sede', 3),
#  ('seguinte', 3),
#  ('setenta', 3),
#  ('seção', 3),
#  ('sitio', 3),
#  ('sspdf', 3),
#  ('superior', 3),
#  ('tabela', 3),
#  ('teodoro', 3),
#  ('termo', 3),
#  ('transparência', 3),
#  ('ubiratan', 3),
#  ('urach', 3),
#  ('uso', 3),
#  ('vieira', 3),
#  ('área', 3),
#  ('00000250', 2),
#  ('00003665', 2),
#  ('00054', 2),
#  ('00063', 2),
#  ('00116386', 2),
#  ('02', 2),
#  ('045', 2),
#  ('076', 2),
#  ('079', 2),
#  ('08', 2),
#  ('11', 2),
#  ('112', 2),
#  ('120', 2),
#  ('14º', 2),
#  ('15', 2),
#  ('20', 2),
#  ('2016', 2),
#  ('28', 2),
#  ('303', 2),
#  ('3190', 2),
#  ('33', 2),
#  ('34', 2),
#  ('51', 2),
#  ('52', 2),
#  ('5557', 2),
#  ('56', 2),
#  ('70710', 2),
#  ('814', 2),
#  ('900', 2),
#  ('908', 2),
#  ('926016', 2),
#  ('acima', 2),
#  ('ambiental', 2),
#  ('apoio', 2),
#  ('arquitetura', 2),
#  ('art', 2),
#  ('assay', 2),
#  ('batalhão', 2),
#  ('bid', 2),
#  ('básico', 2),
#  ('cep', 2),
#  ('cldf', 2),
#  ('comunicação', 2),
#  ('conjunto', 2),
#  ('constantes', 2),
#  ('construção', 2),
#  ('contra', 2),
#  ('convocatório', 2),
#  ('corpo', 2),
#  ('cpl', 2),
#  ('cujo', 2),
#  ('cópia', 2),
#  ('demais', 2),
#  ('departamento', 2),
#  ('despesas', 2),
#  ('diferenciado', 2),
#  ('disponibilizado', 2),
#  ('econômico', 2),
#  ('edifícios', 2),
#  ('elemento', 2),
#  ('elencados', 2),
#  ('enes', 2),
#  ('engenharia', 2),
#  ('epígrafe', 2),
#  ('especificamente', 2),
#  ('fhb', 2),
#  ('finanças', 2),
#  ('garagem', 2),
#  ('gmail', 2),
#  ('governamentais', 2),
#  ('guarda', 2),
#  ('hospitalar', 2),
#  ('impacto', 2),
#  ('implantação', 2),
#  ('indireta', 2),
#  ('informação', 2),
#  ('infraestrutura', 2),
#  ('instrumento', 2),
#  ('insumos', 2),
#  ('lei', 2),
#  ('link', 2),
#  ('lobão', 2),
#  ('logística', 2),
#  ('meio', 2),
#  ('mma', 2),
#  ('monocamada', 2),
#  ('monocyte', 2),
#  ('monolayer', 2),
#  ('monócitos', 2),
#  ('médico', 2),
#  ('nacional', 2),
#  ('nova', 2),
#  ('obra', 2),
#  ('oitenta', 2),
#  ('oitocentos', 2),
#  ('ordenador', 2),
#  ('planaltina', 2),
#  ('pm', 2),
#  ('presencial', 2),
#  ('processada', 2),
#  ('procidades', 2),
#  ('proteção', 2),
#  ('página', 2),
#  ('quarenta', 2),
#  ('quatorze', 2),
#  ('rack', 2),
#  ('referência', 2),
#  ('relacionados', 2),
#  ('servidores', 2),
#  ('smhn', 2),
#  ('sob', 2),
#  ('splpmdf', 2),
#  ('stéfano', 2),
#  ('sítios', 2),
#  ('tecnologia', 2),
#  ('tic', 2),
#  ('treinamento', 2),
#  ('trinta', 2),
#  ('técnica', 2),
#  ('vigência', 2),
#  ('áreas', 2),
#  ('000', 1),
#  ('00000777', 1),
#  ('00001142', 1),
#  ('00001725', 1),
#  ('00007689', 1),
#  ('0001', 1),
#  ('00010995', 1),
#  ('00028990', 1),
#  ('00033436', 1),
#  ('00035338', 1),
#  ('00080', 1),
#  ('001', 1),
#  ('00198062', 1),
#  ('002', 1),
#  ('00370', 1),
#  ('05', 1),
#  ('06', 1),
#  ('07', 1),
#  ('085', 1),
#  ('101', 1),
#  ('1076', 1),
#  ('10h', 1),
#  ('10h00min', 1),
#  ('136', 1),
#  ('180', 1),
#  ('2012', 1),
#  ('24', 1),
#  ('2º', 1),
#  ('324', 1),
#  ('36', 1),
#  ('407', 1),
#  ('41', 1),
#  ('43', 1),
#  ('450432', 1),
#  ('47', 1),
#  ('488', 1),
#  ('502', 1),
#  ('5021', 1),
#  ('6207', 1),
#  ('65', 1),
#  ('661', 1),
#  ('70', 1),
#  ('72', 1),
#  ('737', 1),
#  ('96', 1),
#  ('aba', 1),
#  ('abaixo', 1),
#  ('abandono', 1),
#  ('abril', 1),
#  ('acerca', 1),
#  ('acesso', 1),
#  ('ades', 1),
#  ('ajustamento', 1),
#  ('alimentação', 1),
#  ('alimentícios', 1),
#  ('andar', 1),
#  ('assistência', 1),
#  ('atender', 1),
#  ('atendimento', 1),
#  ('backup', 1),
#  ('banco', 1),
#  ('bem', 1),
#  ('bombeiro', 1),
#  ('bombeiros', 1),
#  ('cadastro', 1),
#  ('cerqueira', 1),
#  ('cinquenta', 1),
#  ('clube', 1),
#  ('comercial', 1),
#  ('comprasgovernamentais', 1),
#  ('concorrência', 1),
#  ('conduta', 1),
#  ('congelado', 1),
#  ('contar', 1),
#  ('contemplando', 1),
#  ('contidas', 1),
#  ('coordenador', 1),
#  ('corridos', 1),
#  ('cumprimento', 1),
#  ('câmeras', 1),
#  ('dados', 1),
#  ('daniel', 1),
#  ('demanda', 1),
#  ('denominado', 1),
#  ('desconto', 1),
#  ('desta', 1),
#  ('deverão', 1),
#  ('dezenove', 1),
#  ('dezesseis', 1),
#  ('diferentes', 1),
#  ('dispositivo', 1),
#  ('diário', 1),
#  ('dois', 1),
#  ('dotação', 1),
#  ('dps', 1),
#  ('edificações', 1),
#  ('edifício', 1),
#  ('eia', 1),
#  ('eletronico', 1),
#  ('eletrônicos', 1),
#  ('eletrônicowi', 1),
#  ('elétrica', 1),
#  ('empreitada', 1),
#  ('energia', 1),
#  ('escolar', 1),
#  ('escopo', 1),
#  ('estará', 1),
#  ('estudo', 1),
#  ('exclusiva', 1),
#  ('exclusivamente', 1),
#  ('exemplos', 1),
#  ('feira', 1),
#  ('fevereiro', 1),
#  ('filé', 1),
#  ('financiamento', 1),
#  ('fonte', 1),
#  ('forma', 1),
#  ('fornecidas', 1),
#  ('fornecimento', 1),
#  ('funcionamento', 1),
#  ('garantia', 1),
#  ('gonçalves', 1),
#  ('gêneros', 1),
#  ('habitacional', 1),
#  ('hospitalares', 1),
#  ('https', 1),
#  ('ibram', 1),
#  ('incêndio', 1),
#  ('indicados', 1),
#  ('instalação', 1),
#  ('instalações', 1),
#  ('instruções', 1),
#  ('interamericano', 1),
#  ('ishihara', 1),
#  ('itens', 1),
#  ('janeiro', 1),
#  ('junior', 1),
#  ('jóquei', 1),
#  ('lana', 1),
#  ('licitacao', 1),
#  ('linkportal', 1),
#  ('lpn', 1),
#  ('luchine', 1),
#  ('maior', 1),
#  ('marta', 1),
#  ('materiais', 1),
#  ('medicamentos', 1),
#  ('melhoria', 1),
#  ('meses', 1),
#  ('milhão', 1),
#  ('modernização', 1),
#  ('nailde', 1),
#  ('nascimento', 1),
#  ('natureza', 1),
#  ('nobreaks', 1),
#  ('novecentos', 1),
#  ('oficial', 1),
#  ('oliveira', 1),
#  ('organizacionais', 1),
#  ('outras', 1),
#  ('padrões', 1),
#  ('pae', 1),
#  ('parcelamento', 1),
#  ('parque', 1),
#  ('peixe', 1),
#  ('perecíveis', 1),
#  ('pires', 1),
#  ('pnb', 1),
#  ('política', 1),
#  ('portal', 1),
#  ('porto', 1),
#  ('posto', 1),
#  ('ppci', 1),
#  ('precos', 1),
#  ('pregao', 1),
#  ('pregoeiro', 1),
#  ('prestação', 1),
#  ('prevencionista', 1),
#  ('primeiros', 1),
#  ('principal', 1),
#  ('processoi', 1),
#  ('pt', 1),
#  ('pânico', 1),
#  ('qn', 1),
#  ('quantitativos', 1),
#  ('quatrocentos', 1),
#  ('quinta', 1),
#  ('ra', 1),
#  ('recepcionistas', 1),
#  ('referido', 1),
#  ('regina', 1),
#  ('relatório', 1),
#  ('republicação', 1),
#  ('respectivo', 1),
#  ('retirados', 1),
#  ('rima', 1),
#  ('rodrigues', 1),
#  ('samambaia', 1),
#  ('sas', 1),
#  ('saúde', 1),
#  ('segmentos', 1),
#  ('segurança', 1),
#  ('seis', 1),
#  ('ser', 1),
#  ('setecentos', 1),
#  ('silveira', 1),
#  ('sistema', 1),
#  ('site', 1),
#  ('socorros', 1),
#  ('solo', 1),
#  ('solução', 1),
#  ('srp', 1),
#  ('suporte', 1),
#  ('surto', 1),
#  ('tac', 1),
#  ('tilápia', 1),
#  ('trabalho', 1),
#  ('trezentos', 1),
#  ('técnicas', 1),
#  ('uo', 1),
#  ('valter', 1),
#  ('videomonitoramento', 1),
#  ('voluntários', 1),
#  ('xii', 1)]

# %%
counting2
# Out:
# [('076 076 08 data hora', 46),
#  ('61 3348 8650 licitacao cl', 40),
#  ('2 076 076 08 data', 38),
#  ('aviso abertura pregão eletrônicowi nº', 38),
#  ('2021 processo 00001 00010995 2020', 34),
#  ('450107 edital disponível http www', 33),
#  ('dezenove milhões novecentos mil setecentos', 33),
#  ('2021 10h horário brasília edital', 32),
#  ('anexo i edital demais anexos', 32),
#  ('abertura licitação uasg 926334 processo', 29),
#  ('comissão tabela comissão licitação compra', 29),
#  ('df 23 fevereiro 2021 amilcar', 28),
#  ('926016 informações 3190 5557 mail', 25),
#  ('brasília df 22 março 2021', 23),
#  ('2021 processo 00001 00033436 2020', 22),
#  ('brasília df 23 março 2021', 22),
#  ('07 2021 processo 00001 00010995', 17),
#  ('demais anexos elencados item 28', 17),
#  ('001 2012 ibram terracap valor', 15),
#  ('compras www pm df gov', 15),
#  ('00111 00000777 2021 03 modalidade', 14),
#  ('comercial norte quadra 02 bloco', 14),
#  ('coordenador aviso abertura pregão eletrônico', 14),
#  ('01 2021 processo 00054 00116386', 13),
#  ('despesa 4 4 90 51', 13),
#  ('23 03 2021 edital encontra', 12),
#  ('814 94 sete milhões setenta', 12),
#  ('acerca referido certame brasília df', 12),
#  ('anexos total itens 08 valor', 12),
#  ('br compras uasg 450107 edital', 12),
#  ('2020 65 modalidade número pregão', 11),
#  ('324 16 cento doze mil', 11),
#  ('96 data hora sessão pública', 11),
#  ('apoio administrativo meio recepcionistas posto', 11),
#  ('cl df gov br linkportal', 11),
#  ('compras serviços brasília df 04', 11),
#  ('conforme especificações técnicas abaixo fornecidas', 11),
#  ('00 data hora sessão pública', 10),
#  ('079 814 94 sete milhões', 10),
#  ('convocatório valor estimado r 7', 10),
#  ('data sessão pública aviso abertura', 10),
#  ('bloco c n 900 2º', 9),
#  ('conforme especificações condições exigências estabelecidas', 9),
#  ('2020 processo 00050 00028990 2020', 8),
#  ('23 03 2021 10 00', 8),
#  ('61 3348 8650 mail cpl', 8),
#  ('abertura 20 04 2021 10', 8),
#  ('aviso licitação nova data regime', 8),
#  ('br uasg 974004 www cl', 8),
#  ('2021 processo 00054 00116386 2020', 7),
#  ('33 departamento logística finanças polícia', 7),
#  ('abertura 16 04 2021 10', 7),
#  ('apoio administrativo área segurança contra', 7),
#  ('br daniel luchine ishihara pregoeiro', 7),
#  ('cldf acordo especificações quantitativos constantes', 7),
#  ('conforme condições quantidades exigências estabelecidas', 7),
#  ('contados assinatura contrato recebimento nota', 7),
#  ('cplic aviso abertura licitação processo', 7),
#  ('09 30 local internet endereço', 6),
#  ('2021 10 00 horas retirada', 6),
#  ('2021 stéfano enes lobão ordenador', 6),
#  ('2021 valter cerqueira junior presidente', 6),
#  ('23 março 2021 glauber teodoro', 6),
#  ('29 045 94 vinte nove', 6),
#  ('6207 5021 0001 modernização melhoria', 6),
#  ('assinatura contrato recebimento nota empenho', 6),
#  ('batalhão polícia militar distrito federal', 6),
#  ('brasília df elemento despesa 3', 6),
#  ('comissão aviso abertura licitação nº', 6),
#  ('data horário indicados sede desta', 6),
#  ('00063 00003665 2020 29 valor', 5),
#  ('04 2021 10 horas retirada', 5),
#  ('14h30min horário brasília df elemento', 5),
#  ('2021 abertura propostas 22 01', 5),
#  ('2º andar asa norte brasília', 5),
#  ('aberto objeto registro preços eventual', 5),
#  ('abertura licitação processo modalidade número', 5),
#  ('abertura licitação processo tipo objeto', 5),
#  ('abertura licitação processo valor estimado', 5),
#  ('abertura pregão eletrônicowi nº 02', 5),
#  ('abertura propostas aviso abertura pregão', 5),
#  ('aquisição gêneros alimentícios perecíveis filé', 5),
#  ('civil apoio administrativo área segurança', 5),
#  ('comprasgovernamentais gov br http www', 5),
#  ('condições especificações constantes termo referência', 5),
#  ('contratação meio execução indireta serviços', 5),
#  ('cujo objeto contratação empresa especializada', 5),
#  ('demanda necessários funcionamento diferentes segmentos', 5),
#  ('denominado setor habitacional jóquei clube', 5),
#  ('df 11 janeiro 2021 regina', 5),
#  ('01 2021 abertura propostas 22', 4),
#  ('03 2021 edital encontra disponibilizado', 4),
#  ('03 conjunto bloco 03 asa', 4),
#  ('085 51 milhão quatrocentos sete', 4),
#  ('16 04 2021 10 horas', 4),
#  ('16 cento doze mil trezentos', 4),
#  ('2016 data hora abertura 20', 4),
#  ('2020 14 objeto contratação meio', 4),
#  ('2020 56 valor estimado contratação', 4),
#  ('2021 procidades df natureza despesa', 4),
#  ('23 03 2021 aviso abertura', 4),
#  ('4 4 90 51 obras', 4),
#  ('51 milhão quatrocentos sete mil', 4),
#  ('70710 908 brasília df sessão', 4),
#  ('abertura 23 03 2021 10', 4),
#  ('alimentação escolar distrito federal pae', 4),
#  ('anexos processo 00063 00003665 2020', 4),
#  ('aviso abertura licitação processo modalidade', 4),
#  ('aviso licitação aviso abertura licitação', 4),
#  ('br l 1076 sde df', 4),
#  ('br licitacoes brasília df 04', 4),
#  ('brasília df 04 março 2021', 4),
#  ('brasília df 11 janeiro 2021', 4),
#  ('brasília df 23 fevereiro 2021', 4),
#  ('certame epígrafe cujo objeto contratação', 4),
#  ('corpo guarda administrativo garagem sede', 4),
#  ('data hora abertura 23 03', 4),
#  ('data sessão pública 17 03', 4),
#  ('00 horas www gov br', 3),
#  ('00003665 2020 29 valor r', 3),
#  ('00033436 2020 17 objeto contratação', 3),
#  ('04 2021 14h30min horário brasília', 3),
#  ('04 2021 uasg 926334 fundação', 3),
#  ('04 março 2021 amilcar ubiratan', 3),
#  ('04 tipo menor preço modo', 3),
#  ('076 08 data hora sessão', 3),
#  ('09 03 2021 10h00min https', 3),
#  ('10 00 horas sítio compras', 3),
#  ('101 ssp df prazos entrega', 3),
#  ('12 doze servidores rack sspdf', 3),
#  ('14 objeto contratação meio execução', 3),
#  ('17 03 2021 10 00', 3),
#  ('19 900 737 72 dezenove', 3),
#  ('2020 41 objeto contratação empresa', 3),
#  ('2021 04 tipo menor preço', 3),
#  ('2021 10 horas retirada edital', 3),
#  ('2021 aviso abertura licitação processo', 3),
#  ('2021 tipo menor preço objeto', 3),
#  ('2021 uasg 926334 fundação hemocentro', 3),
#  ('23 março 2021 stéfano enes', 3),
#  ('298 2020 diraf comunica realização', 3),
#  ('30 dias corridos contados assinatura', 3),
#  ('4 90 52 cópia edital', 3),
#  ('51 obras instalações fonte 136', 3),
#  ('7 079 814 94 sete', 3),
#  ('737 72 dezenove milhões novecentos', 3),
#  ('90 30 4 4 90', 3),
#  ('abandono edificações primeiros socorros treinamento', 3),
#  ('abertura edital exemplos aviso abertura', 3),
#  ('abertura licitação exclusiva pregão eletrônico', 3),
#  ('abertura licitação presidente comissão licitação', 3),
#  ('abertura pregão eletrônico objeto valor', 3),
#  ('abril 2021 10 30 horas', 3),
#  ('ambiental rima parcelamento solo denominado', 3),
#  ('amilcar ubiratan urach vieira aviso', 3),
#  ('anexos anexo i edital demais', 3),
#  ('aviso abertura licitação nº 04', 3),
#  ('aviso abertura licitação pregão eletrônico', 3),
#  ('aviso abertura pregão eletrônico nº', 3),
#  ('aviso abertura pregão eletrônico srp', 3),
#  ('bens serviços obras cplic terracap', 3),
#  ('bid procidades programa desenvolvimento econômico', 3),
#  ('br http www df gov', 3),
#  ('br link portal transparência maiores', 3),
#  ('br uasg 450107 edital disponível', 3),
#  ('brasília acordo condições quantidades exigências', 3),
#  ('centavos tipo menor preço data', 3),
#  ('certame processo 00111 00007689 2020', 3),
#  ('cl df gov br lana', 3),
#  ('compras governamentais termos edital aviso', 3),
#  ('compras pt br uasg 450107', 3),
#  ('comprasnet gov br tipo menor', 3),
#  ('comprasnet gov br uasg 974004', 3),
#  ('constantes termo referência anexo i', 3),
#  ('contra surto dps proteção câmeras', 3),
#  ('contratação nº 01 2021 processo', 3),
#  ('contrato 120 cento vinte dias', 3),
#  ('cpl cl df gov br', 3),
#  ('cplic terracap uso atribuições confere', 3),
#  ('câmara legislativa distrito federal sas', 3),
#  ('data hora abertura aviso abertura', 3),
#  ('data hora sessão pública 14', 3),
#  ('data horário realização licitação aviso', 3),
#  ('data limite recebimento propostas dia', 3),
#  ('data regime diferenciado contratação nº', 3),
#  ('desconto edital encontra endereços www', 3),
#  ('despesas aviso licitação nova data', 3),
#  ('desta sde endereço setor comercial', 3),
#  ('deverão ser retirados conforme instruções', 3),
#  ('df 04 março 2021 glauber', 3),
#  ('df 23 março 2021 stéfano', 3),
#  ('00 horas retirada edital anexos', 2),
#  ('00000250 2021 04 tipo menor', 2),
#  ('00007689 2020 43 modalidade número', 2),
#  ('0001 modernização melhoria infraestrutura áreas', 2),
#  ('00035338 2020 14 objeto contratação', 2),
#  ('00080 00198062 2020 14 cadastro', 2),
#  ('00111 00001725 2020 65 modalidade', 2),
#  ('002 2021 sde df tipo', 2),
#  ('00370 00001142 2020 56 valor', 2),
#  ('01 2021 10h horário brasília', 2),
#  ('03 2021 10h00min https www', 2),
#  ('03 2021 aviso abertura licitação', 2),
#  ('03 asa norte cep 70710', 2),
#  ('04 2021 14h30min local internet', 2),
#  ('04 2021 processo 00050 00000250', 2),
#  ('045 94 vinte nove mil', 2),
#  ('06 2021 uasg 450432 objeto', 2),
#  ('08 valor total estimado r', 2),
#  ('09 abril 2021 10 30', 2),
#  ('1 407 085 51 milhão', 2),
#  ('10 00 horas retirada edital', 2),
#  ('10 00 horas www gov', 2),
#  ('112 324 16 cento doze', 2),
#  ('112 96 data hora sessão', 2),
#  ('12 01 2021 abertura propostas', 2),
#  ('12 03 2021 09 30', 2),
#  ('14 00 local internet endereço', 2),
#  ('14 cadastro propostas partir 12', 2),
#  ('14h30min local internet endereço www', 2),
#  ('14º batalhão polícia militar distrito', 2),
#  ('15 dias contados assinatura contrato', 2),
#  ('2016 data hora abertura 16', 2),
#  ('2020 33 departamento logística finanças', 2),
#  ('2020 diraf comunica realização seguinte', 2),
#  ('2020 republicação tipo menor preço', 2),
#  ('2021 03 modalidade número licitação', 2),
#  ('2021 09 30 local internet', 2),
#  ('2021 14h30min horário brasília df', 2),
#  ('2021 amilcar ubiratan urach vieira', 2),
#  ('2021 processo 00001 00035338 2020', 2),
#  ('2021 regina rodrigues porto pregoeira', 2),
#  ('22 01 2021 10h horário', 2),
#  ('24 101 ssp df prazos', 2),
#  ('3 90 30 4 4', 2),
#  ('30 000 00 data hora', 2),
#  ('30 4 4 90 52', 2),
#  ('3190 5557 mail splpmdf gmail', 2),
#  ('3348 8650 cpl cl df', 2),
#  ('3348 8650 mail cpl cl', 2),
#  ('36 trinta seis meses financiamento', 2),
#  ('4 4 90 52 cópia', 2),
#  ('41 objeto contratação empresa especializada', 2),
#  ('450432 objeto registro preços eventual', 2),
#  ('502 samambaia ra xii distrito', 2),
#  ('52 cópia edital encontra sítios', 2),
#  ('65 modalidade número pregão eletrônico', 2),
#  ('70 diário oficial distrito federal', 2),
#  ('90 52 cópia edital encontra', 2),
#  ('908 brasília df sessão pública', 2),
#  ('926334 processo valor data limite', 2),
#  ('94 sete milhões setenta nove', 2),
#  ('abertura aviso abertura licitação uasg', 2),
#  ('abertura certame epígrafe cujo objeto', 2),
#  ('abertura licitação acima data horário', 2),
#  ('abertura licitação processo objeto valor', 2),
#  ('acima http ssp df gov', 2),
#  ('acordo especificações quantitativos constantes termo', 2),
#  ('alimentícios perecíveis filé peixe congelado', 2),
#  ('amilcar ubiratan urach vieira coordenador', 2),
#  ('anexo i edital valor estimado', 2),
#  ('anexos deverão ser retirados conforme', 2),
#  ('aquisição bens equipamentos serviços conforme', 2),
#  ('aquisição solução backup dados contemplando', 2),
#  ('arquitetura engenharia civil execução obra', 2),
#  ('asa norte cep 70710 908', 2),
#  ('assay mma fundação hemocentro brasília', 2),
#  ('assinatura data sessão pública 17', 2),
#  ('atender edifício áreas câmara legislativa', 2),
#  ('atribuições confere portaria nº 298', 2),
#  ('aviso abertura pregão eletrônico objeto', 2),
#  ('aviso licitação processo valor estimado', 2),
#  ('banco interamericano desenvolvimento bid processoi', 2),
#  ('bem acesso outras informações acerca', 2),
#  ('br compras pt br uasg', 2),
#  ('br lana marta gonçalves pires', 2),
#  ('br link transparência maiores informações', 2),
#  ('br linkportal transparência maiores informações', 2),
#  ('br nailde oliveira nascimento silveira', 2),
#  ('br pregao eletronico sistema registro', 2),
#  ('br página principal aba licitações', 2),
#  ('br seção licitações compras serviços', 2),
#  ('brasília comissão especial licitação sde', 2),
#  ('brasília df edital anexos deverão', 2),
#  ('brasília edital estará disponível endereços', 2),
#  ('brasília pnb cumprimento termo ajustamento', 2),
#  ('básico anexos anexo i edital', 2),
#  ('cep 70710 908 brasília df', 2),
#  ('cerqueira junior presidente comissão tabela', 2),
#  ('cl df gov br nailde', 2),
#  ('comissão tabela aviso abertura licitação', 2),
#  ('compra bens serviços obras cplic', 2),
#  ('compras serviços brasília df 22', 2),
#  ('compras sítio www fhb df', 2),
#  ('comunicação tic especificamente 12 doze', 2),
#  ('concorrência lpn nº 002 2021', 2),
#  ('confere portaria nº 298 2020', 2),
#  ('conjunto bloco 03 asa norte', 2),
#  ('contar assinatura data sessão pública', 2),
#  ('contrato recebimento nota empenho vigência', 2),
#  ('câmeras videomonitoramento distrito federal sspdf', 2),
#  ('cópia edital encontra sítios www', 2),
#  ('data hora abertura 16 04', 2),
#  ('data hora sessão pública 12', 2),
#  ('data horário realização licitação 09', 2),
#  ('data limite recebimento propostas aviso', 2),
#  ('data sessão pública aviso licitação', 2),
#  ('desenvolvimento bid processoi n º', 2),
#  ('desenvolvimento econômico página 70 diário', 2),
#  ('desenvolvimento implantação política prevencionista ppci', 2),
#  ('df 10 março 2021 valter', 2),
#  ('df bid procidades programa desenvolvimento', 2),
#  ('00 horas dia 23 03', 1),
#  ('00 horas sítio compras governamentais', 1),
#  ('00 local internet endereço www', 1),
#  ('000 00 data hora sessão', 1),
#  ('00000777 2021 03 modalidade número', 1),
#  ('00001 00010995 2020 41 objeto', 1),
#  ('00001 00033436 2020 17 objeto', 1),
#  ('00001 00035338 2020 14 objeto', 1),
#  ('00001142 2020 56 valor estimado', 1),
#  ('00001725 2020 65 modalidade número', 1),
#  ('00010995 2020 41 objeto contratação', 1),
#  ('00028990 2020 16 tipo menor', 1),
#  ('00050 00000250 2021 04 tipo', 1),
#  ('00050 00028990 2020 16 tipo', 1),
#  ('00054 00116386 2020 33 departamento', 1),
#  ('00111 00007689 2020 43 modalidade', 1),
#  ('00116386 2020 33 departamento logística', 1),
#  ('00198062 2020 14 cadastro propostas', 1),
#  ('01 2021 14 00 local', 1),
#  ('02 2021 processo 00001 00035338', 1),
#  ('02 bloco c n 900', 1),
#  ('03 2021 09 30 local', 1),
#  ('03 2021 10 00 horas', 1),
#  ('03 modalidade número licitação presencial', 1),
#  ('04 março 2021 glauber teodoro', 1),
#  ('05 2021 tipo menor preço', 1),
#  ('08 data hora sessão pública', 1),
#  ('09 2021 tipo menor preço', 1),
#  ('10 00 horas dia 23', 1),
#  ('10 2021 processo 00001 00033436', 1),
#  ('10 30 horas horário brasília', 1),
#  ('10 horas retirada edital anexos', 1),
#  ('10 março 2021 valter cerqueira', 1),
#  ('1076 sde df bid procidades', 1),
#  ('10h horário brasília edital estará', 1),
#  ('10h00min https www gov br', 1),
#  ('11 janeiro 2021 regina rodrigues', 1),
#  ('11 março 2021 procidades df', 1),
#  ('120 cento vinte dias partir', 1),
#  ('13 303 2016 data hora', 1),
#  ('13 planaltina df conforme especificações', 1),
#  ('136 data horário realização licitação', 1),
#  ('14 04 2021 14h30min local', 1),
#  ('14 2020 republicação tipo menor', 1),
#  ('16 tipo menor preço modo', 1),
#  ('17 objeto contratação empresa especializada', 1),
#  ('180 cento oitenta dias contar', 1),
#  ('19 04 2021 14h30min horário', 1),
#  ('20 01 2021 14 00', 1),
#  ('20 04 2021 10 horas', 1),
#  ('2012 ibram terracap valor estimado', 1),
#  ('2020 14 cadastro propostas partir', 1),
#  ('2020 16 tipo menor preço', 1),
#  ('2020 17 objeto contratação empresa', 1),
#  ('2020 29 valor r 29', 1),
#  ('2020 43 modalidade número licitação', 1),
#  ('2021 10 00 horas sítio', 1),
#  ('2021 10 00 horas www', 1),
#  ('2021 10 30 horas horário', 1),
#  ('2021 10h00min https www gov', 1),
#  ('2021 14 00 local internet', 1),
#  ('2021 14h30min local internet endereço', 1),
#  ('2021 edital encontra disponibilizado sítio', 1),
#  ('2021 glauber teodoro faria presidente', 1),
#  ('2021 processo 00050 00000250 2021', 1),
#  ('2021 sde df tipo preço', 1),
#  ('2021 uasg 450432 objeto registro', 1),
#  ('22 661 6207 5021 0001', 1),
#  ('22 março 2021 glauber teodoro', 1),
#  ('23 fevereiro 2021 amilcar ubiratan', 1),
#  ('28 instrumento convocatório valor estimado', 1),
#  ('29 valor r 29 045', 1),
#  ('3 3 90 30 4', 1),
#  ('30 horas horário brasília comissão', 1),
#  ('30 local internet endereço www', 1),
#  ('303 2016 data hora abertura', 1),
#  ('3348 8650 licitacao cl df', 1),
#  ('34 lei nº 13 303', 1),
#  ('4 90 51 obras instalações', 1),
#  ('407 085 51 milhão quatrocentos', 1),
#  ('43 modalidade número licitação presencial', 1),
#  ('450107 edital disponível endereço acima', 1),
#  ('47 quinta feira 11 março', 1),
#  ('488 112 96 data hora', 1),
#  ('5021 0001 modernização melhoria infraestrutura', 1),
#  ('5557 mail splpmdf gmail brasília', 1),
#  ('56 2020 processo 00050 00028990', 1),
#  ('56 valor estimado contratação r', 1),
#  ('61 3348 8650 cpl cl', 1),
#  ('661 6207 5021 0001 modernização', 1),
#  ('72 dezenove milhões novecentos mil', 1),
#  ('8650 cpl cl df gov', 1),
#  ('8650 licitacao cl df gov', 1),
#  ('8650 mail cpl cl df', 1),
#  ('90 51 obras instalações fonte', 1),
#  ('900 2º andar asa norte', 1),
#  ('900 737 72 dezenove milhões', 1),
#  ('926334 fundação hemocentro brasília torna', 1),
#  ('94 vinte nove mil quarenta', 1),
#  ('974004 www cl df gov', 1),
#  ('aba licitações bem acesso outras', 1),
#  ('abaixo fornecidas parque nacional brasília', 1),
#  ('aberto objeto registro preços aquisição', 1),
#  ('abertura aviso abertura licitação processo', 1),
#  ('abertura licitação nº 04 2021', 1),
#  ('abertura licitação pregão eletrônico nº', 1),
#  ('abertura licitação pública nacional projeto', 1),
#  ('abertura pregão eletrônico nº 07', 1),
#  ('abertura pregão eletrônico processo objeto', 1),
#  ('abertura pregão eletrônico srp nº', 1),
#  ('abertura propostas 22 01 2021', 1),
#  ('acesso outras informações acerca referido', 1),
#  ('acima data horário indicados sede', 1),
#  ('acordo condições especificações constantes termo', 1),
#  ('acordo condições quantidades exigências estabelecidas', 1),
#  ('ades concorrência lpn nº 002', 1),
#  ('administrativo garagem sede 14º batalhão', 1),
#  ('administrativo meio recepcionistas posto sob', 1),
#  ('administrativo área segurança contra incêndio', 1),
#  ('ajustamento conduta tac nº 001', 1),
#  ('ambiental eia respectivo relatório impacto', 1),
#  ('andar asa norte brasília df', 1),
#  ('anexos elencados item 28 instrumento', 1),
#  ('anexos gratuitamente sitio terracap www', 1),
#  ('aquisição equipamentos relacionados tecnologia informação', 1),
#  ('aquisição insumos necessários realização técnica', 1),
#  ('aquisição nobreaks dispositivo proteção contra', 1),
#  ('art 34 lei nº 13', 1),
#  ('asa norte brasília df edital', 1),
#  ('assinatura data sessão pública dia', 1),
#  ('assistência saúde câmara legislativa distrito', 1),
#  ('atendimento setor assistência saúde câmara', 1),
#  ('aviso abertura licitação exclusiva pregão', 1),
#  ('aviso abertura licitação presidente comissão', 1),
#  ('aviso abertura licitação processo objeto', 1),
#  ('aviso abertura licitação processo tipo', 1),
#  ('aviso abertura licitação processo valor', 1),
#  ('aviso abertura licitação pública nacional', 1),
#  ('aviso abertura licitação uasg 926334', 1),
#  ('aviso abertura pregão eletrônico processo', 1),
#  ('backup dados contemplando instalação treinamento', 1),
#  ('bens equipamentos serviços conforme especificações', 1),
#  ('bens serviços obras aviso abertura', 1),
#  ('bid processoi n º 00370', 1),
#  ('bloco 03 asa norte cep', 1),
#  ('bombeiro civil apoio administrativo área', 1),
#  ('bombeiros voluntários desenvolvimento implantação política', 1),
#  ('br compras sítio www fhb', 1),
#  ('br compras www pm df', 1),
#  ('br endereço setor médico hospitalar', 1),
#  ('br licitacoes brasília df 23', 1),
#  ('br tipo maior desconto edital', 1),
#  ('br tipo menor preço edital', 1),
#  ('br tipo menor preço global', 1),
#  ('br uasg 926016 informações 3190', 1),
#  ('brasília df 10 março 2021', 1),
#  ('brasília df sessão pública processada', 1),
#  ('brasília torna público realização licitação', 1),
#  ('c n 900 2º andar', 1),
#  ('cadastro propostas partir 12 01', 1),
#  ('centavos data hora abertura 23', 1),
#  ('centavos data limite recebimento propostas', 1),
#  ('centavos processo nº 00080 00198062', 1),
#  ('centavos programa trabalho 22 661', 1),
#  ('cento doze mil trezentos vinte', 1),
#  ('cento oitenta dias contar assinatura', 1),
#  ('cento vinte dias partir data', 1),
#  ('certame brasília df 10 março', 1),
#  ('certame processo 00111 00000777 2021', 1),
#  ('certame processo 00111 00001725 2020', 1),
#  ('cinco reais cinquenta centavos programa', 1),
#  ('cinco reais noventa quatro centavos', 1),
#  ('cinquenta centavos programa trabalho 22', 1),
#  ('civil execução obra construção edifícios', 1),
#  ('cl df gov br daniel', 1),
#  ('cl df gov br link', 1),
#  ('cldf valor estimado r 2', 1),
#  ('clube valor estimado r valor', 1),
#  ('comissão especial licitação sde torna', 1),
#  ('comissão licitação compra bens serviços', 1),
#  ('compra bens serviços obras aviso', 1),
#  ('compras serviços brasília df 23', 1),
#  ('compras uasg 450107 edital disponível', 1),
#  ('comprasnet gov br tipo maior', 1),
#  ('comunica realização seguinte certame processo', 1),
#  ('condições exigências estabelecidas projeto básico', 1),
#  ('condições quantidades exigências estabelecidas edital', 1),
#  ('conduta tac nº 001 2012', 1),
#  ('conforme instruções contidas exclusivamente endereço', 1),
#  ('congelado tilápia programa alimentação escolar', 1),
#  ('construção edifícios corpo guarda administrativo', 1),
#  ('contemplando instalação treinamento garantia suporte', 1),
#  ('contidas exclusivamente endereço eletrônico site', 1),
#  ('contra incêndio pânico abandono edificações', 1),
#  ('contratação data horário realização licitação', 1),
#  ('contratação empresa especializada arquitetura engenharia', 1),
#  ('contratação empresa especializada execução obras', 1),
#  ('contratação empresa especializada fornecimento medicamentos', 1),
#  ('contratação empresa especializada prestação serviços', 1),
#  ('contratação escopo estudo impacto ambiental', 1),
#  ('contratação r 1 407 085', 1),
#  ('contrato 180 cento oitenta dias', 1),
#  ('contrato data sessão pública aviso', 1),
#  ('contrato recebimento nota empenho contrato', 1),
#  ('corridos contados assinatura contrato recebimento', 1),
#  ('cumprimento termo ajustamento conduta tac', 1),
#  ('câmara legislativa distrito federal acordo', 1),
#  ('câmara legislativa distrito federal cldf', 1),
#  ('dados contemplando instalação treinamento garantia', 1),
#  ('daniel luchine ishihara pregoeiro aviso', 1),
#  ('data assinatura data sessão pública', 1),
#  ('data hora abertura 20 04', 1),
#  ('data hora sessão pública 20', 1),
#  ('data hora sessão pública local', 1),
#  ('data limite recebimento propostas 10', 1),
#  ('data sessão pública dia 09', 1),
#  ('departamento logística finanças polícia militar', 1),
#  ('desenvolvimento econômico distrito federal ades', 1),
#  ('despesa 3 3 90 30', 1),
#  ('despesas tabela aviso abertura licitação', 1),
#  ('dezesseis centavos data hora abertura', 1),
#  ('df 04 março 2021 amilcar', 1),
#  ('df 22 março 2021 glauber', 1),
#  ('df 23 março 2021 glauber', 1)]

# %%
termosimportantes = ['aviso de declaração de vencedor', 'após verificada a aceitabilidade', 'aceitabilidade', 'aviso', 'convocatório', 'licitatório', 'vencedor', 'vencedora']
