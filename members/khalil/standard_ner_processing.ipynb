# %%
import sklearn_crfsuite
from sklearn_crfsuite import metrics
import pandas
import glob
import xml.etree.ElementTree as ET
import nltk
import math
import numpy
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ---
# # 1. Extraindo trechos anotados dos XMLs

# %% [markdown]
# ### 1.1. Adiquirindo a raiz de cada XML

# %%
glob_path = 'xml_batch1/*.xml' # Caminho até os XMLs
roots = []
for xml in glob.glob(glob_path):
    tree = ET.parse(xml)
    roots.append(tree.getroot())

# %% [markdown]
# ### 1.2. Iremos agora iterar sobre a raiz de cada arquivo buscando pelas relações contidas nelas. Em seguida iremos usar as relações para compor cada linha do CSV.
# Antes é importante entender a estrutura XML da anotação de uma relação:
# ```xml
# <relation id="R1">
#     <infon key="type">Ato_Tornado_Sem_Efeito_Exo_Nom</infon>
#     <infon key="annotator">tatiana_franco</infon>
#     <infon key="updated_at">2020-12-22T02:09:50Z</infon>
#     <node refid="4192" role=""/>
#     <node refid="4193" role=""/>
#     <node refid="4194" role=""/>
#     <node refid="4195" role=""/>
#     <node refid="4196" role=""/>
#     <node refid="4197" role=""/>
#     <node refid="4198" role=""/>
#     <node refid="4199" role=""/>
#     <node refid="118512" role=""/>
#     <node refid="118513" role=""/>
#     <node refid="118514" role=""/>
# </relation>
# ```
# > Cada nó(node) representa um anotação. Basta recuperar o *refid* de cada nó e procurar pelo ID de sua respectiva anotação.
#
# > Utilize a tag *infon* com *key=type* para identificar o ato anotado
#
# ```xml
# <annotation id="4192">
#     <infon key="type">tipo_documento</infon>
#     <infon key="identifier"></infon>
#     <infon key="annotator">lindeberg</infon>
#     <infon key="updated_at">2020-12-22T00:41:28Z</infon>
#     <location offset="385761" length="7"/>
#     <text>Decreto</text>
# </annotation>
# ```
# > Novamente utilize *infon* com *key=type* para identificar qual o tipo de anotação e a tag *text* para resgatar o texto da anotação

# %%
# Esse bloco deve demorar de alguns segundos a 1 minuto
atos_csv_dict = {}

for root in roots: # Intera sobre as raizes
    for relation in root.findall(".//relation"):                            # Intera sobre as relações.
        row_act = {}
        type_relation = relation.find('.//infon[@key="type"]').text
        for node in relation.findall('node'):                               # Intera sobre os nós(anotações) da relação.
            ref_id = node.get('refid')
            annotation = root.find(f'.//annotation[@id="{ref_id}"]')        # Encontra anotação.
            type_annotation = annotation.find('.//infon[@key="type"]').text # Encontra tipo da anotação.
            text_annotation = annotation.find('text').text                  # Encontra texto da anotação.
            row_act[type_annotation] = text_annotation
        
        if type_relation not in atos_csv_dict:                              # Checa se a tabela já existe, caso contrário, cria uma.
            atos_csv_dict[type_relation] = pandas.DataFrame()
            
        atos_csv_dict[type_relation] = atos_csv_dict[type_relation].append(row_act, ignore_index=True)

# %% [markdown]
# Como resultado final temos um dicionario de CSVs. Cada chave do dicionário é referente a um ato e aponta para seu respectivo dataframe.
#
# ---

# %% [markdown]
# # 2. Exploração e validação da integridade dos dados

# %% [markdown]
# ### 2.2. Vamos checar agora quantos atos temos e se os Dataframes estão coerentes.

# %%
print(atos_csv_dict.keys())
print("Quantidade de atos: " + str(len(atos_csv_dict.keys())))
# Out:
# dict_keys(['Ato_Retificacao_Comissionado', 'Ato_Tornado_Sem_Efeito_Exo_Nom', 'Ato_Exoneracao_Comissionado', 'Ato_Nomeacao_Comissionado', 'Ato_Nomeacao_Efetivo', 'Ato_Abono_Permanencia', 'Ato_Substituicao', 'Ato_Tornado_Sem_Efeito_Apo', 'Ato_Retificacao_Efetivo', 'Ato_Cessao', 'Ato_Reversao', 'Ato_Exoneracao_Efetivo'])
# Quantidade de atos: 12

# %% [markdown]
# ### 2.3. Temos todos os 12 atos presentes no dicionário. Checaremos agora o tamanho e os campos de cada dataframe.

# %%
for key in atos_csv_dict.keys():
    print("Ato: " + key)
    print("Campos: ", end='')
    print(atos_csv_dict[key].columns)
    print("Tamanho: " + str(len(atos_csv_dict[key])))
    print('----------------')
# Out:
# Ato: Ato_Retificacao_Comissionado
# Campos: Index(['Ato_Retificacao_Comissionado', 'data_dodf', 'informacao_corrigida',
#        'informacao_errada', 'nome', 'numero_documento', 'numero_dodf',
#        'pagina_dodf', 'tipo_documento', 'data_documento', 'tipo_ato',
#        'lotacao', 'matricula', 'a_pedido_ou_nao'],
#       dtype='object')
# Tamanho: 50
# ----------------
# Ato: Ato_Tornado_Sem_Efeito_Exo_Nom
# Campos: Index(['Ato_Tornado_Sem_Efeito_Exo_Nom', 'cargo_comissionado',
#        'data_documento', 'data_dodf', 'hierarquia_lotacao', 'nome',
#        'numero_dodf', 'orgao', 'pagina_dodf', 'simbolo', 'tipo_documento',
#        'matricula', 'cargo_efetivo', 'motivo', 'matricula_SIAPE', 'lotacao'],
#       dtype='object')
# Tamanho: 54
# ----------------
# Ato: Ato_Exoneracao_Comissionado
# Campos: Index(['Ato_Exoneracao_Comissionado', 'cargo_comissionado',
#        'hierarquia_lotacao', 'motivo', 'nome', 'orgao', 'simbolo',
#        'a_pedido_ou_nao', 'vigencia', 'cargo_efetivo', 'matricula',
#        'matricula_SIAPE', 'data', 'carreira', 'Ato_Nomeacao_Comissionado'],
#       dtype='object')
# Tamanho: 755
# ----------------
# Ato: Ato_Nomeacao_Comissionado
# Campos: Index(['Ato_Nomeacao_Comissionado', 'cargo_comissionado', 'cargo_efetivo',
#        'hierarquia_lotacao', 'matricula', 'nome', 'orgao', 'simbolo',
#        'Ato_Retificacao_Comissionado', 'data_documento', 'data_dodf',
#        'informacao_corrigida', 'informacao_errada', 'numero_dodf',
#        'pagina_dodf', 'tipo_ato', 'tipo_documento',
#        'Ato_Tornado_Sem_Efeito_Exo_Nom', 'motivo',
#        'Ato_Exoneracao_Comissionado', 'matricula_SIAPE',
#        'Ato_Retificacao_Efetivo', 'carreira'],
#       dtype='object')
# Tamanho: 7687
# ----------------
# Ato: Ato_Nomeacao_Efetivo
# Campos: Index(['Ato_Nomeacao_Efetivo', 'candidato', 'cargo',
#        'data_dodf_edital_normativo', 'data_dodf_resultado_final',
#        'edital_normativo', 'edital_resultado_final',
#        'numero_dodf_edital_normativo', 'numero_dodf_resultado_final', 'orgao',
#        'nome', 'carreira', 'data_edital_normativo',
#        'data_edital_resultado_final'],
#       dtype='object')
# Tamanho: 7
# ----------------
# Ato: Ato_Abono_Permanencia
# Campos: Index(['Ato_Abono_Permanencia', 'cargo_efetivo', 'fundamento_legal', 'lotacao',
#        'matricula', 'nome', 'processo_SEI', 'vigencia', 'classe', 'padrao',
#        'quadro', 'matricula_SIAPE', 'matricula_siape'],
#       dtype='object')
# Tamanho: 33
# ----------------
# Ato: Ato_Substituicao
# Campos: Index(['Ato_Substituicao', 'cargo_objeto_susbtituicao', 'cargo_substituto',
#        'data_final', 'data_inicial', 'hierarquia_lotacao',
#        'matricula_substituido', 'matricula_substituto', 'motivo',
#        'nome_substituido', 'nome_substituto', 'orgao',
#        'simbolo_objeto_substituicao', 'simbolo_substituto', 'matricula_SIAPE',
#        'matricula_siape'],
#       dtype='object')
# Tamanho: 310
# ----------------
# Ato: Ato_Tornado_Sem_Efeito_Apo
# Campos: Index(['Ato_Tornado_Sem_Efeito_Apo', 'cargo_efetivo', 'data_documento',
#        'data_dodf', 'fundamento_legal', 'matricula', 'nome', 'numero_dodf',
#        'pagina_dodf', 'processo_SEI', 'tipo_documento'],
#       dtype='object')
# Tamanho: 2
# ----------------
# Ato: Ato_Retificacao_Efetivo
# Campos: Index(['Ato_Retificacao_Efetivo', 'cargo_efetivo', 'data_documento',
#        'data_dodf', 'informacao_corrigida', 'informacao_errada', 'matricula',
#        'nome', 'numero_dodf', 'pagina_dodf', 'tipo_ato', 'tipo_documento',
#        'matricula_SIAPE', 'numero_documento', 'classe', 'padrao',
#        'Ato_Retificacao_Comissionado', 'lotacao'],
#       dtype='object')
# Tamanho: 128
# ----------------
# Ato: Ato_Cessao
# Campos: Index(['Ato_Cessao', 'cargo_efetivo', 'cargo_orgao_cessionario',
#        'fundamento_legal', 'matricula', 'nome', 'orgao_cedente',
#        'orgao_cessionario', 'processo_SEI', 'hierarquia_lotacao', 'onus',
#        'simbolo', 'vigencia'],
#       dtype='object')
# Tamanho: 60
# ----------------
# Ato: Ato_Reversao
# Campos: Index(['Ato_Reversao', 'cargo_efetivo', 'fundamento_legal', 'matricula',
#        'motivo', 'nome', 'quadro', 'vigencia'],
#       dtype='object')
# Tamanho: 8
# ----------------
# Ato: Ato_Exoneracao_Efetivo
# Campos: Index(['Ato_Exoneracao_Efetivo', 'a_pedido_ou_nao', 'cargo_efetivo',
#        'fundamento_legal', 'matricula', 'nome', 'processo_SEI', 'vigencia',
#        'carreira', 'classe', 'orgao', 'padrao', 'quadro', 'cargo_comissionado',
#        'hierarquia_lotacao'],
#       dtype='object')
# Tamanho: 79
# ----------------

# %% [markdown]
# ### 2.4. Extraido as tabelas dos atos precisamos agora executar uma limpeza nas tebelas.
#
# > ATENÇÃO: ESSE TRATAMENTO DE DADOS SERVE SOMENTE PARA NOMEAÇÃO. CADA ATO DEVE TER SEU PRÓPRIO TRATAMENTO.
#
# > TRATAMENTO INDIVIDUAIS SERÃO ADICIONADOS NO FUTURO.

# %%
nomeacao_df = atos_csv_dict['Ato_Nomeacao_Comissionado']

nomeacao_fields = ['nome', 'cargo_efetivo', 'matricula', 'matricula_SIAPE', 'simbolo', 'cargo_comissionado', 'hierarquia_lotacao', 'orgao', 'Ato_Nomeacao_Comissionado']

# Nessa linha todas as colunas que não pertencem a nomecao são extraidas para uma segunda lista. (Compreensão de listas).
nomeacao_non_fields = [column for column in nomeacao_df.columns if column not in nomeacao_fields]

# Exclusão de todas as linhas que possuam algum valor nos campos que não pertecem a nomeacao.
nomeacao_df = nomeacao_df[nomeacao_df[nomeacao_non_fields].isna().any(axis=1)]

# Exclusão de todas as colunas que não pertecem a nomeação.
nomeacao_df = nomeacao_df.drop(columns=nomeacao_non_fields)

# Exclusão das linhas que não possuem anotação de atos.
nomeacao_df = nomeacao_df.dropna(subset=['Ato_Nomeacao_Comissionado'])

atos_csv_dict['Ato_Nomeacao_Comissionado'] = nomeacao_df
atos_csv_dict['Ato_Nomeacao_Comissionado']
# Out:
#                               Ato_Nomeacao_Comissionado  \
# 0     NOMEAR o TC QOPM JOAQUIM SINESIO MARQUES, matr...
# 1     NOMEAR o MAJ QOPM DOUGLAS CAMPOS MACHADO, matr...
# 2     NOMEAR BRUNA KAROLLYNE DIAS NASCIMENTO para ex...
# 3     NOMEAR ANA DONIZETE DE ASSIS para exercer o Ca...
# 4     NOMEAR CHARLES DOUGLAS PROTAZIO SOUSA para exe...
# ...                                                 ...
# 7682  NOMEAR ALESSANDRA NAZARE LEANDRO TAVARES, Tecn...
# 7683  NOMEAR JOSE MOREIRA DANTAS, matricula 1.440.73...
# 7684  NOMEAR JANAINA MESSIAS GOMES, Auxiliar de Enfe...
# 7685  NOMEAR MARCELO AUGUSTO SOARES DE LIMA, Carreir...
# 7686  NOMEAR SUSIVANE MARTINS NEVES ROSA, Auxiliar d...
#
#                                      cargo_comissionado  \
# 0                                              Assessor
# 1                                              Assessor
# 2                                              Assessor
# 3                                               Gerente
# 4                                              Assessor
# ...                                                 ...
# 7682             Chefe do Nucleo de Apoio \nOperacional
# 7683                                            Gerente
# 7684   Chefe do Nucleo de Apoio e Remo-\ncao de Paci...
# 7685  Chefe do Nucleo \nde Citopatologia e Anatomia ...
# 7686  Chefe do Nucleo do \nTrabalhador da Industria,...
#
#                              cargo_efetivo  \
# 0                                  TC QOPM
# 1                                 MAJ QOPM
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 7682                Tecnico Administrativo
# 7683                                   NaN
# 7684                Auxiliar de Enfermagem
# 7685  Carreira Medica (Anatomia Patologia)
# 7686                Auxiliar de Enfermagem
#
#                                      hierarquia_lotacao    matricula  \
# 0     Assessoria Tecnica, \nda Governadoria do Distr...     50.114-X
# 1                          Subsecretaria Administrativa     50.708-3
# 2                  Subsecretaria de Administracao Geral          NaN
# 3     Gerencia de Execucao de Obras, Conservacao e M...          NaN
# 4     Diretoria Social, da Administracao Regional de...          NaN
# ...                                                 ...          ...
# 7682  Gerencia do Centro de Saude no 04, da Diretori...  1.442.814-8
# 7683  Gerencia de Saude da Familia 1, da Diretoria R...  1.440.738-0
# 7684  Gerencia de Enfermagem, da Diretoria do Hospit...  1.436.679-7
# 7685  Gerencia de Diagnose e Terapia, da Diretoria d...    190.079-X
# 7686  Gerencia de Programas de Saude do Traba-\nlhad...  1.433.819-X
#
#                                     nome  \
# 0                JOAQUIM SINESIO MARQUES
# 1                 DOUGLAS CAMPOS MACHADO
# 2        BRUNA KAROLLYNE DIAS NASCIMENTO
# 3                  ANA DONIZETE DE ASSIS
# 4         CHARLES DOUGLAS PROTAZIO SOUSA
# ...                                  ...
# 7682   ALESSANDRA NAZARE LEANDRO TAVARES
# 7683                 JOSE MOREIRA DANTAS
# 7684               JANAINA MESSIAS GOMES
# 7685      MARCELO AUGUSTO SOARES DE LIMA
# 7686         SUSIVANE MARTINS NEVES ROSA
#
#                                                   orgao simbolo  \
# 0                                 19 de janeiro de 2009  CNE-06
# 1                    Casa \nMilitar do Distrito Federal  DFA-12
# 2     Secretaria de Estado \nde Publicidade Instituc...  DFA-14
# 3                      Governadoria do Distrito Federal  DFG-14
# 4                      Governadoria do Distrito Federal  DFA-11
# ...                                                 ...     ...
# 7682  \nSecretaria de Estado de Saude do Distrito Fe...  DFG-07
# 7683  Secretaria de Estado de Saude do Distrito Federal  DFG-12
# 7684  Secretaria de \nEstado de Saude do Distrito Fe...  DFG-07
# 7685  Secretaria de Estado de Saude do Distrito Federal  DFG-07
# 7686  Secretaria de Estado de Saude do Distrito Federal  DFG-09
#
#      matricula_SIAPE
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 7682             NaN
# 7683             NaN
# 7684             NaN
# 7685             NaN
# 7686             NaN
#
# [619 rows x 9 columns]

# %% [markdown]
# Um problema comum em todos os atos é a existência de valores *nan* no campo de texto do ato. Sem esse campo não é possível executar a etapa de criação de labels. Podemos assim realizar um laço que retirar todas as linhas que possuem esse campo com valor de *nan*.

# %%
for key in atos_csv_dict.keys():
    atos_csv_dict[key] = atos_csv_dict[key].dropna(subset=[key])

# %% [markdown]
# ---
# # 3. Criação dos labels IOB

# %% [markdown]
# ### 3.1. Definiremos agora uma função *generate_labels* que recebe uma linha do csv do ato e adiciona o label de IOB.
# > No formato IOB o caracter 'B' representa o início de uma entidade o 'I' uma parte de uma entidade q já tenha sido iniciada e 'O' um token que não possui label.
# > Dessa forma adiciona-se o tipo da entidade em seguida do label identificado 'B-entidade'...'I-entidade'

# %%
# Altere aqui a forma de tokenizar as sentenças.
def tokenize(sentence):
    return nltk.word_tokenize(sentence)
#     tokenizer = nltk.RegexpTokenizer(r"\w+")
#     new_words = tokenizer.tokenize(sentence)
#     return new_words

def find_entity(row, token):
    for column in row.keys()[1:]:
        if row[column] is not numpy.nan and token == tokenize(row[column])[0]:
            return column
    
    return None

# Atualizar no futuro para qualquer ato.
# Aparentemente esse algoritmo está O(n*m) onde n é a quantidade de tokens e m a quantidade de colunas do df.
def generate_IOB_labels(row, key):
    labels = []
    entity_started = False
    for token in tokenize(row[key]):                         # Intera sobre cada token da anotação do ato.
        if not entity_started:                               # Caso uma entidade ainda n tenha sido identificada nos tokens.
            entity = find_entity(row, token)                 # Busca o token atual no primeiro token de todos os campos do df.
            if entity is not None:                           # Se foi encontrado o token no inicio de alguma entidade ele inicia a comparação token a token com a entidade.
                entity_started = True
                token_index = 1
                labels.append('B-' + entity)
            else:
                labels.append('O')
        else:                                                # Caso uma entidade já tenha sido identificada
            if token_index < len(tokenize(row[entity])) and token == tokenize(row[entity])[token_index]: # Checa se o próximo token pertence à entidade e se o tamanho da entidade chegou ao fim.
                labels.append('I-' + entity)                 # Se a entidade ainda possui tokens e a comparação foi bem sucedida adicione o label I.
                token_index += 1
                if token_index >= len(tokenize(row[entity])):
                    entity_started = False
            else:                                            # Se o token n for igual ou a entidade chegou ao fim.
                entity_started = False
                labels.append('O')
                
    return labels

# %% [markdown]
# ### 3.2. Agora, com as funções de geração label prontas iremos criar uma lista de strings representando os labels para adicionar ao df de cada ato.

# %%
for key in atos_csv_dict.keys():
    labels_row = []
    for index, row in atos_csv_dict[key].iterrows():
        try:
            labels_row.append(' '.join(generate_IOB_labels(row, key)))
        except Exception as e:
            print(row)
            raise e
        
    atos_csv_dict[key].insert(len(atos_csv_dict[key].columns), 'labels_IOB', labels_row, False)

# %% [markdown]
# ---
# # 4. Criação das features e treinamento do CRF à moda José

# %% [markdown]
# > Faremos duas funções para gerar as features para o algoritmo CRF.

# %%
def extract_features(sentence):
  sentence_features = []
  for j in range(len(sentence)):
    word_feat = {
            'word': sentence[j].lower(),
            'capital_letter': sentence[j][0].isupper(),
            'all_capital': sentence[j].isupper(),
            'isdigit': sentence[j].isdigit(),
            'word_before': sentence[j].lower() if j==0 else sentence[j-1].lower(),
            'word_after:': sentence[j].lower() if j+1>=len(sentence) else sentence[j+1].lower(),
            'BOS': j==0,
            'EOS': j==len(sentence)-1
    }
    sentence_features.append(word_feat)
  return sentence_features

def separate_cols(arq, key):
    x = []
    y = []
    for index, row in arq.iterrows():
        x.append(extract_features(tokenize(row[key])))
        y.append(row['labels_IOB'].split())
    return x, y

# %% [markdown]
# > Aqui criaremos os dados usando 70% pra treinamento e 30% teste. Isso é feito para cada ato e ao final é apresentado a tebela do F1-Score

# %%
training_ratio = 0.7  

for key in atos_csv_dict.keys():
    print("------------------------------------------------------------------------------------")
    print("Ato:" + key)
    print("Tamanho: " + str(len(atos_csv_dict[key])))
    x, y = separate_cols(atos_csv_dict[key], key)
    train_x = x[:math.floor(training_ratio*len(atos_csv_dict[key]))]
    train_y = y[:math.floor(training_ratio*len(atos_csv_dict[key]))]
    test_x = x[math.floor(training_ratio*len(atos_csv_dict[key])):]
    test_y = y[math.floor(training_ratio*len(atos_csv_dict[key])):]

    len(atos_csv_dict[key]), len(train_x), len(train_y), len(test_x), len(test_y)

    model = sklearn_crfsuite.CRF(
        algorithm = 'l2sgd', 
        c2=1,
        max_iterations=100, 
        all_possible_transitions=True,
        verbose=False
    )

    model.fit(train_x, train_y)
    y_pred = model.predict(test_x)

    labels = list(model.classes_)
    labels.remove('O')

    f1 = metrics.flat_f1_score(test_y, y_pred, 
                          average='weighted', labels=labels)
    print(f1)
    print(metrics.flat_classification_report(
        test_y, y_pred, labels=labels, digits=3
    ))
# Out:
# ------------------------------------------------------------------------------------
# Ato:Ato_Retificacao_Comissionado
# Tamanho: 50
# 0.3182178318515615
#                         precision    recall  f1-score   support
#
#       B-tipo_documento      0.923     0.800     0.857        15
#     B-numero_documento      0.000     0.000     0.000         3
#                 B-nome      0.000     0.000     0.000         7
#                 I-nome      0.000     0.000     0.000        28
#          B-numero_dodf      0.800     0.923     0.857        13
#            B-data_dodf      0.000     0.000     0.000        15
#            I-data_dodf      0.000     0.000     0.000        61
#          B-pagina_dodf      0.000     0.000     0.000        15
# B-informacao_corrigida      0.857     0.154     0.261        39
# I-informacao_corrigida      0.904     0.314     0.466       239
#       B-data_documento      0.393     0.733     0.512        15
#       I-data_documento      0.389     0.733     0.509        60
#             B-tipo_ato      0.857     0.429     0.571        14
#              B-lotacao      0.000     0.000     0.000         5
#              I-lotacao      0.000     0.000     0.000        28
#       I-tipo_documento      1.000     1.000     1.000         4
#            B-matricula      0.000     0.000     0.000         1
#    B-informacao_errada      0.000     0.000     0.000         2
#    I-informacao_errada      0.000     0.000     0.000        34
#             I-tipo_ato      0.000     0.000     0.000         2
#          I-pagina_dodf      0.000     0.000     0.000        15
#
#              micro avg      0.550     0.276     0.368       615
#              macro avg      0.292     0.242     0.240       615
#           weighted avg      0.519     0.276     0.318       615
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Tornado_Sem_Efeito_Exo_Nom
# Tamanho: 54
# 0.7171368820376088
#                       precision    recall  f1-score   support
#
#     B-tipo_documento      1.000     1.000     1.000        17
#     B-data_documento      0.550     0.647     0.595        17
#     I-data_documento      0.557     0.647     0.599        68
#        B-numero_dodf      1.000     0.941     0.970        17
#          B-data_dodf      0.571     0.471     0.516        17
#          I-data_dodf      0.571     0.478     0.520        67
#        B-pagina_dodf      0.267     0.235     0.250        17
#        I-pagina_dodf      0.000     0.000     0.000        15
#               B-nome      1.000     1.000     1.000        17
#               I-nome      1.000     1.000     1.000        51
#            B-simbolo      1.000     1.000     1.000        17
# B-cargo_comissionado      1.000     0.824     0.903        17
# B-hierarquia_lotacao      0.312     1.000     0.476         5
# I-hierarquia_lotacao      0.182     1.000     0.308        51
#              B-orgao      1.000     0.938     0.968        16
#              I-orgao      1.000     0.964     0.982       111
#          B-matricula      0.000     0.000     0.000         1
# I-cargo_comissionado      1.000     0.400     0.571        10
#      B-cargo_efetivo      0.000     0.000     0.000         0
#      I-cargo_efetivo      0.000     0.000     0.000         0
#             B-motivo      0.000     0.000     0.000         0
#             I-motivo      0.000     0.000     0.000         0
#    B-matricula_SIAPE      0.000     0.000     0.000         0
#
#            micro avg      0.560     0.778     0.651       531
#            macro avg      0.522     0.545     0.507       531
#         weighted avg      0.722     0.778     0.717       531
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Exoneracao_Comissionado
# Tamanho: 755
# 0.9160427204893626
#                       precision    recall  f1-score   support
#
#             B-motivo      0.730     0.730     0.730        37
#             I-motivo      0.865     1.000     0.928       192
#               B-nome      0.987     0.987     0.987       227
#               I-nome      0.987     1.000     0.993       679
#            B-simbolo      0.969     0.995     0.982       221
# B-cargo_comissionado      0.922     0.934     0.928       227
# B-hierarquia_lotacao      0.841     0.841     0.841       227
# I-hierarquia_lotacao      0.932     0.965     0.949      3981
#              B-orgao      0.802     0.858     0.829       212
#              I-orgao      0.820     0.995     0.899      1734
# I-cargo_comissionado      0.965     0.536     0.689       459
#    B-a_pedido_ou_nao      0.857     1.000     0.923        72
#    I-a_pedido_ou_nao      1.000     1.000     1.000        51
#           B-vigencia      1.000     1.000     1.000        33
#           I-vigencia      1.000     1.000     1.000       132
#      B-cargo_efetivo      0.500     0.333     0.400        27
#      I-cargo_efetivo      0.407     0.393     0.400        84
#          B-matricula      0.927     0.981     0.953        52
#            I-simbolo      0.500     1.000     0.667         9
#    B-matricula_SIAPE      0.000     0.000     0.000         3
#          I-matricula      0.000     0.000     0.000         0
#               B-data      0.000     0.000     0.000         0
#
#            micro avg      0.900     0.939     0.919      8659
#            macro avg      0.728     0.752     0.732      8659
#         weighted avg      0.904     0.939     0.916      8659
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Nomeacao_Comissionado
# Tamanho: 619
# 0.8912461320026498
#                       precision    recall  f1-score   support
#
#      B-cargo_efetivo      0.643     0.500     0.563        18
#      I-cargo_efetivo      0.786     0.623     0.695        53
#               B-nome      0.973     0.973     0.973       185
#               I-nome      0.981     1.000     0.991       524
#          B-matricula      1.000     1.000     1.000        48
#            B-simbolo      0.952     1.000     0.975       178
# B-cargo_comissionado      0.946     0.957     0.951       184
# B-hierarquia_lotacao      0.931     0.885     0.907       182
# I-hierarquia_lotacao      0.890     0.943     0.916      2937
#              B-orgao      0.616     0.693     0.652       153
#              I-orgao      0.741     0.862     0.797       950
#            I-simbolo      0.917     0.917     0.917        24
# I-cargo_comissionado      0.962     0.669     0.789       266
#          I-matricula      1.000     1.000     1.000         1
#    B-matricula_SIAPE      0.000     0.000     0.000         5
#
#            micro avg      0.872     0.912     0.892      5708
#            macro avg      0.822     0.801     0.808      5708
#         weighted avg      0.876     0.912     0.891      5708
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Nomeacao_Efetivo
# Tamanho: 7
# 0.0
#                                 precision    recall  f1-score   support
#
#             B-edital_normativo      0.000     0.000     0.000         2
#             I-edital_normativo      0.000     0.000     0.000         2
# B-numero_dodf_edital_normativo      0.000     0.000     0.000         3
#   B-data_dodf_edital_normativo      0.000     0.000     0.000         3
#   I-data_dodf_edital_normativo      0.000     0.000     0.000        12
#  B-numero_dodf_resultado_final      0.000     0.000     0.000         3
#    B-data_dodf_resultado_final      0.000     0.000     0.000         3
#    I-data_dodf_resultado_final      0.000     0.000     0.000        12
#                        B-cargo      0.000     0.000     0.000         3
#                        B-orgao      0.000     0.000     0.000         0
#                        I-orgao      0.000     0.000     0.000         0
#                    B-candidato      0.000     0.000     0.000         3
#                    I-candidato      0.000     0.000     0.000        12
#       B-edital_resultado_final      0.000     0.000     0.000         3
#       I-edital_resultado_final      0.000     0.000     0.000         1
#                         B-nome      0.000     0.000     0.000         0
#                         I-nome      0.000     0.000     0.000         0
#                     B-carreira      0.000     0.000     0.000         3
#        B-data_edital_normativo      0.000     0.000     0.000         2
#        I-data_edital_normativo      0.000     0.000     0.000         8
#  B-data_edital_resultado_final      0.000     0.000     0.000         3
#  I-data_edital_resultado_final      0.000     0.000     0.000        12
#                        I-cargo      0.000     0.000     0.000        11
#
#                      micro avg      0.000     0.000     0.000       101
#                      macro avg      0.000     0.000     0.000       101
#                   weighted avg      0.000     0.000     0.000       101
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Abono_Permanencia
# Tamanho: 33
# 0.5258530871461387
#                     precision    recall  f1-score   support
#
#             B-nome      0.000     0.000     0.000         6
#             I-nome      0.750     0.158     0.261        19
#    B-cargo_efetivo      0.000     0.000     0.000         7
#    I-cargo_efetivo      0.000     0.000     0.000        23
#        B-matricula      1.000     0.200     0.333        10
#          B-lotacao      0.000     0.000     0.000         0
#          I-lotacao      0.000     0.000     0.000         0
#         B-vigencia      1.000     0.261     0.414        23
#         I-vigencia      1.000     0.357     0.526        56
# B-fundamento_legal      1.000     0.350     0.519        20
# I-fundamento_legal      0.490     1.000     0.657       405
#     B-processo_SEI      0.000     0.000     0.000        10
#        I-matricula      0.000     0.000     0.000         0
#     I-processo_SEI      0.000     0.000     0.000         0
#           B-classe      0.000     0.000     0.000         3
#           B-padrao      0.000     0.000     0.000         3
#           B-quadro      0.000     0.000     0.000         4
#           I-quadro      0.000     0.000     0.000        20
#  B-matricula_SIAPE      0.000     0.000     0.000         1
#  B-matricula_siape      0.000     0.000     0.000         0
#           I-classe      0.000     0.000     0.000         3
#           I-padrao      0.000     0.000     0.000         3
#
#          micro avg      0.512     0.719     0.598       616
#          macro avg      0.238     0.106     0.123       616
#       weighted avg      0.522     0.719     0.526       616
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Substituicao
# Tamanho: 308
# 0.7503202767617403
#                                precision    recall  f1-score   support
#
#             B-nome_substituto      0.960     0.774     0.857        93
#             I-nome_substituto      0.974     0.786     0.870       281
#        B-matricula_substituto      0.488     0.911     0.636        90
#            B-cargo_substituto      0.789     0.300     0.435       100
#          B-simbolo_substituto      1.000     0.067     0.125        30
#            B-nome_substituido      0.771     0.871     0.818        93
#            I-nome_substituido      0.780     0.929     0.848       282
#       B-matricula_substituido      0.833     0.055     0.103        91
#   B-cargo_objeto_susbtituicao      0.790     0.667     0.723        96
#   I-cargo_objeto_susbtituicao      0.709     0.695     0.702       256
# B-simbolo_objeto_substituicao      0.786     0.885     0.832        87
#          B-hierarquia_lotacao      0.731     0.487     0.585        78
#          I-hierarquia_lotacao      0.921     0.736     0.818       821
#                       B-orgao      0.759     0.774     0.766        53
#                       I-orgao      0.808     0.784     0.796       333
#                B-data_inicial      0.844     0.890     0.866        91
#                  B-data_final      0.926     0.967     0.946        91
#                      B-motivo      1.000     0.946     0.972        92
#                      I-motivo      0.943     0.982     0.962       168
#            I-cargo_substituto      0.743     0.308     0.435       273
#                I-data_inicial      0.611     0.647     0.629        34
#                  I-data_final      0.964     0.947     0.955       113
# I-simbolo_objeto_substituicao      0.857     1.000     0.923         6
#       I-matricula_substituido      1.000     0.333     0.500         6
#        I-matricula_substituto      0.000     0.000     0.000         4
#             B-matricula_SIAPE      0.000     0.000     0.000        21
#             B-matricula_siape      0.000     0.000     0.000         8
#          I-simbolo_substituto      0.000     0.000     0.000         1
#
#                     micro avg      0.833     0.720     0.773      3692
#                     macro avg      0.714     0.598     0.611      3692
#                  weighted avg      0.836     0.720     0.750      3692
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Tornado_Sem_Efeito_Apo
# Tamanho: 2
# 0.0
#                     precision    recall  f1-score   support
#
#   B-tipo_documento      0.000     0.000     0.000         1
#   I-tipo_documento      0.000     0.000     0.000         0
#   B-data_documento      0.000     0.000     0.000         1
#   I-data_documento      0.000     0.000     0.000         0
#      B-numero_dodf      0.000     0.000     0.000         1
#        B-data_dodf      0.000     0.000     0.000         1
#        I-data_dodf      0.000     0.000     0.000         0
#      B-pagina_dodf      0.000     0.000     0.000         1
#             B-nome      0.000     0.000     0.000         1
#             I-nome      0.000     0.000     0.000         3
#        B-matricula      0.000     0.000     0.000         1
#    B-cargo_efetivo      0.000     0.000     0.000         0
#    I-cargo_efetivo      0.000     0.000     0.000         0
# B-fundamento_legal      0.000     0.000     0.000         0
# I-fundamento_legal      0.000     0.000     0.000         0
#     B-processo_SEI      0.000     0.000     0.000         1
#
#          micro avg      0.000     0.000     0.000        11
#          macro avg      0.000     0.000     0.000        11
#       weighted avg      0.000     0.000     0.000        11
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Retificacao_Efetivo
# Tamanho: 127
# 0.1755780943667227
#                         precision    recall  f1-score   support
#
#       B-tipo_documento      0.810     0.500     0.618        34
#       I-tipo_documento      0.805     0.971     0.880        34
#       B-data_documento      0.421     0.432     0.427        37
#       I-data_documento      0.419     0.765     0.542        85
#          B-numero_dodf      0.638     0.882     0.741        34
#            B-data_dodf      0.375     0.079     0.130        38
#            I-data_dodf      0.316     0.174     0.224        69
#             B-tipo_ato      1.000     0.025     0.049        40
#                 B-nome      1.000     0.212     0.350        33
#                 I-nome      1.000     0.196     0.328        97
#            B-matricula      0.861     0.861     0.861        36
#        B-cargo_efetivo      0.000     0.000     0.000         2
#    B-informacao_errada      0.000     0.000     0.000        19
#    I-informacao_errada      0.000     0.000     0.000       155
# B-informacao_corrigida      0.000     0.000     0.000        84
# I-informacao_corrigida      0.565     0.022     0.043       586
#          B-pagina_dodf      0.000     0.000     0.000        33
#        I-cargo_efetivo      0.000     0.000     0.000         8
#      B-matricula_SIAPE      0.000     0.000     0.000         0
#             I-tipo_ato      0.000     0.000     0.000         3
#     B-numero_documento      0.000     0.000     0.000        10
#            I-matricula      0.000     0.000     0.000         0
#          I-pagina_dodf      0.000     0.000     0.000        38
#               B-classe      0.000     0.000     0.000         1
#               I-classe      0.000     0.000     0.000         1
#               B-padrao      0.000     0.000     0.000         1
#               I-padrao      0.000     0.000     0.000         1
#
#              micro avg      0.484     0.167     0.248      1479
#              macro avg      0.304     0.190     0.192      1479
#           weighted avg      0.471     0.167     0.176      1479
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Cessao
# Tamanho: 60
# 0.7002810545756809
#                            precision    recall  f1-score   support
#
#            B-processo_SEI      0.889     1.000     0.941         8
#           B-orgao_cedente      0.585     0.857     0.696        28
#           I-orgao_cedente      0.475     0.897     0.621       204
#           B-cargo_efetivo      1.000     0.889     0.941        18
#           I-cargo_efetivo      1.000     0.928     0.962        69
#                    B-nome      1.000     0.972     0.986        36
#                    I-nome      0.990     0.990     0.990       104
#               B-matricula      1.000     0.944     0.971        18
# B-cargo_orgao_cessionario      1.000     0.833     0.909        18
# I-cargo_orgao_cessionario      0.565     0.722     0.634        54
#       B-orgao_cessionario      0.000     0.000     0.000         4
#       I-orgao_cessionario      0.000     0.000     0.000        26
#        B-fundamento_legal      0.000     0.000     0.000        18
#        I-fundamento_legal      0.860     1.000     0.925       332
#                 B-simbolo      1.000     0.944     0.971        18
#      B-hierarquia_lotacao      1.000     0.143     0.250         7
#      I-hierarquia_lotacao      1.000     0.197     0.329        61
#                    B-onus      0.938     0.779     0.851        77
#                    I-onus      0.944     0.782     0.855        87
#                B-vigencia      0.000     0.000     0.000       101
#                I-vigencia      0.000     0.000     0.000        40
#               I-matricula      0.000     0.000     0.000         0
#
#                 micro avg      0.557     0.748     0.638      1328
#                 macro avg      0.648     0.585     0.583      1328
#              weighted avg      0.707     0.748     0.700      1328
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Reversao
# Tamanho: 8
# 0.870309001343484
#                     precision    recall  f1-score   support
#
#           B-quadro      0.000     0.000     0.000         0
#         B-vigencia      1.000     1.000     1.000         3
#         I-vigencia      1.000     1.000     1.000        12
#    B-cargo_efetivo      1.000     0.750     0.857        12
#        B-matricula      0.000     0.000     0.000         3
#           I-quadro      0.000     0.000     0.000         0
# B-fundamento_legal      1.000     1.000     1.000         3
# I-fundamento_legal      1.000     1.000     1.000        63
#           B-motivo      1.000     1.000     1.000         3
#           I-motivo      1.000     1.000     1.000        21
#    I-cargo_efetivo      0.667     0.800     0.727        15
#             B-nome      0.000     0.000     0.000         3
#             I-nome      0.000     0.000     0.000         7
#
#          micro avg      0.857     0.869     0.863       145
#          macro avg      0.590     0.581     0.583       145
#       weighted avg      0.876     0.869     0.870       145
#
# ------------------------------------------------------------------------------------
# Ato:Ato_Exoneracao_Efetivo
# Tamanho: 79
# 0.8941650380754
#                     precision    recall  f1-score   support
#
#  B-a_pedido_ou_nao      1.000     1.000     1.000        48
#  I-a_pedido_ou_nao      1.000     1.000     1.000        24
#             B-nome      1.000     1.000     1.000        24
#             I-nome      1.000     1.000     1.000        84
#        B-matricula      1.000     1.000     1.000        24
#    B-cargo_efetivo      1.000     1.000     1.000        15
#    I-cargo_efetivo      0.879     1.000     0.935        87
# B-fundamento_legal      1.000     1.000     1.000        24
# I-fundamento_legal      1.000     1.000     1.000       168
#     B-processo_SEI      0.857     0.857     0.857        21
#         B-vigencia      0.000     0.000     0.000         9
#         I-vigencia      0.000     0.000     0.000        36
#         B-carreira      1.000     0.600     0.750        15
#         I-carreira      1.000     1.000     1.000        18
#           B-classe      1.000     1.000     1.000        15
#           B-padrao      0.889     1.000     0.941        24
#           B-quadro      1.000     1.000     1.000        12
#           I-quadro      1.000     1.000     1.000        60
#            B-orgao      1.000     1.000     1.000        12
#            I-orgao      0.519     1.000     0.683        84
#        I-matricula      1.000     1.000     1.000         3
#
#          micro avg      0.887     0.933     0.909       807
#          macro avg      0.864     0.879     0.865       807
#       weighted avg      0.874     0.933     0.894       807
