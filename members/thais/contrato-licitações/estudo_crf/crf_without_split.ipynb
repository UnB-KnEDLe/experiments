# %% [markdown]
# ## CRF model with cross validation
#
# Modelo CRF para ato de aviso de licitação (com dados rotulados manualmente)

# %%
# !pip install sklearn_crfsuite
# !pip install nltk

import pandas as pd
import sklearn_crfsuite
import nltk
from nltk.tokenize import word_tokenize

# %%
path_data_train = pd.read_parquet('./result/test.parquet')
path_data_test = pd.read_parquet('./result/test.parquet')

data_train = pd.DataFrame(path_data_train)
data_test = pd.DataFrame(path_data_test)

# %%
data_test.head()
# Out:
#   ORGAO_LICITANTE NUM_LICITACAO  \
# 0            None        249/00
# 1            None    1.437/2008
# 2            None        5/2003
# 3            None       50/2015
# 4            None      964/2008
#
#                                        OBJ_LICITACAO MODALIDADE_LICITACAO  \
# 0  AQUISIÇÃO DE MATERIAL DE CONSUMO ; MATERIAL PA...              CONVITE
# 1  Contratação de empresa para prestação de servi...    PREGÃO ELETRÔNICO
# 2  Aquisição de material de consumo ( limpeza, co...         CONCORRENCIA
# 3  Aquisição de material consumo Termoplástico Te...    PREGÃO ELETRÔNICO
# 4  Contratação de firma especializada em confecçã...    PREGÃO ELETRÔNICO
#
#            PROCESSO           DATA_ABERTURA               TIPO_OBJ  \
# 0              None                24/07/00              AQUISIÇÃO
# 1  053.001.258/2008   16 de janeiro de 2009  prestação de serviços
# 2              None              10.03.2003                   None
# 3   113.013360/2015   27 de janeiro de 2016              Aquisição
# 4  220.000.570/2008  11 de setembro de 2008            Contratação
#
#   VALOR_ESTIMADO CODIGO_SISTEMA_COMPRAS               SISTEMA_COMPRAS  \
# 0           None                   None  http://www fazenda df gov.br
# 1           None                   None         www.compras.df.gov.br
# 2           None                   None         www.fazenda.df.gov.br
# 3           None                   None                          None
# 4           None                   None         www.compras.df.gov.br
#
#                                         treated_text  \
# 0  CONVITE Nº 249/00 Objeto: AQUISIÇÃO DE MATERIA...
# 1  AVISO DE LICITAÇÃO PREGÃO ELETRÔNICO Nº 1.437/...
# 2  AVISOS DE LICITAÇÃO CONCORRENCIA N.º 5/2003-Su...
# 3  AVISO DE LICITAÇÃ NOVA DATA PREGÃO ELETRÔNICO ...
# 4  PREGÃO ELETRÔNICO Nº 964/2008. Objeto: Contrat...
#
#                                                  IOB
# 0  B-MODALIDADE_LICITACAO O B-NUM_LICITACAO I-NUM...
# 1  O O O B-MODALIDADE_LICITACAO I-MODALIDADE_LICI...
# 2  O O O B-MODALIDADE_LICITACAO O O B-NUM_LICITAC...
# 3  O O O O O B-MODALIDADE_LICITACAO I-MODALIDADE_...
# 4  B-MODALIDADE_LICITACAO I-MODALIDADE_LICITACAO ...

# %% [markdown]
# Load csv with text and labels

# %%
# tratando dados de treino
 
from nltk.tokenize import RegexpTokenizer

TOKENIZER = nltk.RegexpTokenizer(r"\w+").tokenize

x_train = []
y_train = []
for row in range(len(data_train)):
    if pd.notna(data_train['treated_text'][row]):
        x_train.append(TOKENIZER(data_train['treated_text'][row]))
        y_train.append(data_train['IOB'][row].split())
len(x_train), len(y_train)
# Out:
# (71, 71)

# %%
# tratando dados de teste

from nltk.tokenize import RegexpTokenizer

TOKENIZER = nltk.RegexpTokenizer(r"\w+").tokenize

x_test = []
y_test = []
for row in range(len(data_test)):
    if pd.notna(data_test['treated_text'][row]):
        x_test.append(TOKENIZER(data_test['treated_text'][row]))
        y_test.append(data_test['IOB'][row].split())
len(x_test), len(y_test)
# Out:
# (71, 71)

# %% [markdown]
# Create dictionary feature for each word in each sequence in x

# %%
def get_features(sentence):
    """Create features for each word in act.
    Create a list of dict of words features to be used in the predictor module.
    Args:
        act (list): List of words in an act.
    Returns:
        A list with a dictionary of features for each of the words.
    """
    sent_features = []
    for i in range(len(sentence)):
        word_feat = {
            'word': sentence[i].lower(),
            'word[-3:]': sentence[i][-3:],
            'word[-2:]': sentence[i][-2:],
            'capital_letter': sentence[i][0].isupper(),
            'word_istitle': sentence[i].istitle(),
            'all_capital': sentence[i].isupper(),
            'word_isdigit': sentence[i].isdigit(),
            # Uma palavra antes
            'word_before': '' if i == 0 else sentence[i-1].lower(),
            'word_before_isdigit': '' if i == 0 else sentence[i-1].isdigit(),
            'word_before_isupper': '' if i == 0 else sentence[i-1].isupper(),
            'word_before_istitle': '' if i == 0 else sentence[i-1].istitle(),
            # Duas palavras antes
            'word_before2': '' if i in [0, 1] else sentence[i-2].lower(),
            'word_before_isdigit2': '' if i in [0, 1] else sentence[i-1].isdigit(),
            'word_before_isupper2': '' if i in [0, 1] else sentence[i-1].isupper(),
            'word_before_istitle2': '' if i in [0, 1] else sentence[i-1].istitle(),
            # Uma palavra depois
            'word_after': '' if i+1 >= len(sentence) else sentence[i+1].lower(),
            'word_after_isdigit': '' if i+1 >= len(sentence) else sentence[i+1].isdigit(),
            'word_after_isupper': '' if i+1 >= len(sentence) else sentence[i+1].isupper(),
            'word_after_istitle': '' if i+1 >= len(sentence) else sentence[i+1].istitle(),
            # Duas palavras depois
            'word_after2': '' if i+2 >= len(sentence) else sentence[i+2].lower(),
            'word_after_isdigit2': '' if i+2 >= len(sentence) else sentence[i+2].isdigit(),
            'word_after_isupper2': '' if i+2 >= len(sentence) else sentence[i+2].isupper(),
            'word_after_istitle2': '' if i+2 >= len(sentence) else sentence[i+2].istitle(),
            # 'word_before': '' if i == 0 else sentence[i-1].lower(),
            # 'word_before_isdigit': '' if i == 0 else sentence[i-1].isdigit(),
            # 'word_before_isupper': '' if i == 0 else sentence[i-1].isupper(),
            # 'word_before_istitle': '' if i == 0 else sentence[i-1].istitle(),
            # 'word_after:': '' if i+1 >= len(sentence) else sentence[i+1].lower(),
            # 'word_after_isdigit:': '' if i+1 >= len(sentence) else sentence[i+1].isdigit(),
            # 'word_after_isupper:': '' if i+1 >= len(sentence) else sentence[i+1].isupper(),
            # 'word_after_istitle:': '' if i+1 >= len(sentence) else sentence[i+1].istitle(),
            'BOS': i == 0,
            'EOS': i == len(sentence)-1
        }
        sent_features.append(word_feat)
    return sent_features

# %%
for i in range(len(x_train)):
    x_train[i] = get_features(x_train[i])

for i in range(len(x_test)):
    x_test[i] = get_features(x_test[i])

# %% [markdown]
# Separate train and test splits (in order)

# %%
x_train[0]
# Out:
# [{'word': 'convite',
#   'word[-3:]': 'ITE',
#   'word[-2:]': 'TE',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': '',
#   'word_before_isdigit': '',
#   'word_before_isupper': '',
#   'word_before_istitle': '',
#   'word_before2': '',
#   'word_before_isdigit2': '',
#   'word_before_isupper2': '',
#   'word_before_istitle2': '',
#   'word_after': 'nº',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': '249',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': True,
#   'EOS': False},
#  {'word': 'nº',
#   'word[-3:]': 'Nº',
#   'word[-2:]': 'Nº',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'convite',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': '',
#   'word_before_isdigit2': '',
#   'word_before_isupper2': '',
#   'word_before_istitle2': '',
#   'word_after': '249',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': '00',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': '249',
#   'word[-3:]': '249',
#   'word[-2:]': '49',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': 'nº',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'convite',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': '00',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'objeto',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': '00',
#   'word[-3:]': '00',
#   'word[-2:]': '00',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': '249',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'nº',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'objeto',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'aquisição',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'objeto',
#   'word[-3:]': 'eto',
#   'word[-2:]': 'to',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': '00',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': '249',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'aquisição',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'aquisição',
#   'word[-3:]': 'ÇÃO',
#   'word[-2:]': 'ÃO',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'objeto',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': '00',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'material',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'DE',
#   'word[-2:]': 'DE',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'aquisição',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'objeto',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'material',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'material',
#   'word[-3:]': 'IAL',
#   'word[-2:]': 'AL',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'aquisição',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'consumo',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'DE',
#   'word[-2:]': 'DE',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'material',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'consumo',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'material',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'consumo',
#   'word[-3:]': 'UMO',
#   'word[-2:]': 'MO',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'material',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'material',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'para',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'material',
#   'word[-3:]': 'IAL',
#   'word[-2:]': 'AL',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'consumo',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'para',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'expediente',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'para',
#   'word[-3:]': 'ARA',
#   'word[-2:]': 'RA',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'material',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'consumo',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'expediente',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'e',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'expediente',
#   'word[-3:]': 'NTE',
#   'word[-2:]': 'TE',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'para',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'material',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'e',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': True,
#   'word_after2': 'ensino',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'e',
#   'word[-3:]': 'E',
#   'word[-2:]': 'E',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'expediente',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'para',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'ensino',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'e',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'ensino',
#   'word[-3:]': 'INO',
#   'word[-2:]': 'NO',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'e',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': True,
#   'word_before2': 'expediente',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': True,
#   'word_after': 'e',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': True,
#   'word_after2': 'peças',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'e',
#   'word[-3:]': 'E',
#   'word[-2:]': 'E',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'ensino',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'e',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'peças',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'e',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'peças',
#   'word[-3:]': 'ÇAS',
#   'word[-2:]': 'AS',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'e',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': True,
#   'word_before2': 'ensino',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': True,
#   'word_after': 'e',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': True,
#   'word_after2': 'acessórios',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'e',
#   'word[-3:]': 'E',
#   'word[-2:]': 'E',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'peças',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'e',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'acessórios',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'para',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'acessórios',
#   'word[-3:]': 'IOS',
#   'word[-2:]': 'OS',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'e',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': True,
#   'word_before2': 'peças',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': True,
#   'word_after': 'para',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'móveis',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'para',
#   'word[-3:]': 'ARA',
#   'word[-2:]': 'RA',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'acessórios',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'e',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'móveis',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'e',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'móveis',
#   'word[-3:]': 'EIS',
#   'word[-2:]': 'IS',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'para',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'acessórios',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'e',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': True,
#   'word_after2': 'equipamentosipamentos',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'e',
#   'word[-3:]': 'E',
#   'word[-2:]': 'E',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'móveis',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'para',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'equipamentosipamentos',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'bobina',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'equipamentosipamentos',
#   'word[-3:]': 'TOS',
#   'word[-2:]': 'OS',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'e',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': True,
#   'word_before2': 'móveis',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': True,
#   'word_after': 'bobina',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'toner',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'bobina',
#   'word[-3:]': 'ina',
#   'word[-2:]': 'na',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'equipamentosipamentos',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'e',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'toner',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'revelador',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'toner',
#   'word[-3:]': 'ner',
#   'word[-2:]': 'er',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'bobina',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'equipamentosipamentos',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'revelador',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'disco',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'revelador',
#   'word[-3:]': 'dor',
#   'word[-2:]': 'or',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'toner',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'bobina',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'disco',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'zip',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'disco',
#   'word[-3:]': 'sco',
#   'word[-2:]': 'co',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'revelador',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'toner',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'zip',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'drive',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'zip',
#   'word[-3:]': 'zip',
#   'word[-2:]': 'ip',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'disco',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'revelador',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'drive',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'ete',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'drive',
#   'word[-3:]': 'ive',
#   'word[-2:]': 've',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'zip',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'disco',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'ete',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'grupos',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'ete',
#   'word[-3:]': 'ete',
#   'word[-2:]': 'te',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'drive',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'zip',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'grupos',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': '14',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'grupos',
#   'word[-3:]': 'pos',
#   'word[-2:]': 'os',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'ete',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'drive',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': '14',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'e',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': '14',
#   'word[-3:]': '14',
#   'word[-2:]': '14',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': 'grupos',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'ete',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'e',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': '20',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'e',
#   'word[-3:]': 'e',
#   'word[-2:]': 'e',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': '14',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'grupos',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': '20',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'abertura',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': '20',
#   'word[-3:]': '20',
#   'word[-2:]': '20',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': 'e',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': '14',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'abertura',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': '24',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'abertura',
#   'word[-3:]': 'ura',
#   'word[-2:]': 'ra',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': '20',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'e',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': '24',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': '07',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': '24',
#   'word[-3:]': '24',
#   'word[-2:]': '24',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': 'abertura',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': '20',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': '07',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': '00',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': '07',
#   'word[-3:]': '07',
#   'word[-2:]': '07',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': '24',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'abertura',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': '00',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'às',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': '00',
#   'word[-3:]': '00',
#   'word[-2:]': '00',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': '07',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': '24',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'às',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': '14',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'às',
#   'word[-3:]': 'às',
#   'word[-2:]': 'às',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': '00',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': '07',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': '14',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': '00',
#   'word_after_isdigit2': True,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': '14',
#   'word[-3:]': '14',
#   'word[-2:]': '14',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': 'às',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': '00',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': '00',
#   'word_after_isdigit': True,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'o',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': '00',
#   'word[-3:]': '00',
#   'word[-2:]': '00',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': True,
#   'word_before': '14',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'às',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'o',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': True,
#   'word_after2': 'respectivo',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'o',
#   'word[-3:]': 'O',
#   'word[-2:]': 'O',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': '00',
#   'word_before_isdigit': True,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': '14',
#   'word_before_isdigit2': True,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'respectivo',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'ato',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'respectivo',
#   'word[-3:]': 'ivo',
#   'word[-2:]': 'vo',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'o',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': True,
#   'word_before2': '00',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': True,
#   'word_after': 'ato',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'convocatório',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'ato',
#   'word[-3:]': 'Ato',
#   'word[-2:]': 'to',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'respectivo',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'o',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'convocatório',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'poderá',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'convocatório',
#   'word[-3:]': 'rio',
#   'word[-2:]': 'io',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'ato',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'respectivo',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'poderá',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'ser',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'poderá',
#   'word[-3:]': 'erá',
#   'word[-2:]': 'rá',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'convocatório',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'ato',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'ser',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'retirado',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'ser',
#   'word[-3:]': 'ser',
#   'word[-2:]': 'er',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'poderá',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'convocatório',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'retirado',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'mediante',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'retirado',
#   'word[-3:]': 'ado',
#   'word[-2:]': 'do',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'ser',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'poderá',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'mediante',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'a',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'mediante',
#   'word[-3:]': 'nte',
#   'word[-2:]': 'te',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'retirado',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'ser',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'a',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'apresentação',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'a',
#   'word[-3:]': 'a',
#   'word[-2:]': 'a',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'mediante',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'retirado',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'apresentação',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'do',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'apresentação',
#   'word[-3:]': 'ção',
#   'word[-2:]': 'ão',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'a',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'mediante',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'do',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'certificado',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'do',
#   'word[-3:]': 'do',
#   'word[-2:]': 'do',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'apresentação',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'a',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'certificado',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'certificado',
#   'word[-3:]': 'ado',
#   'word[-2:]': 'do',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'do',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'apresentação',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'registro',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'certificado',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'do',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'registro',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'cadastral',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'registro',
#   'word[-3:]': 'tro',
#   'word[-2:]': 'ro',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'certificado',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'cadastral',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'crc',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'cadastral',
#   'word[-3:]': 'ral',
#   'word[-2:]': 'al',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'registro',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'crc',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'emitido',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'crc',
#   'word[-3:]': 'CRC',
#   'word[-2:]': 'RC',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'cadastral',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'registro',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'emitido',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'pelo',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'emitido',
#   'word[-3:]': 'ido',
#   'word[-2:]': 'do',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'crc',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'cadastral',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'pelo',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'núcleo',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'pelo',
#   'word[-3:]': 'elo',
#   'word[-2:]': 'lo',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'emitido',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'crc',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'núcleo',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'núcleo',
#   'word[-3:]': 'leo',
#   'word[-2:]': 'eo',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'pelo',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'emitido',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'cadastro',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'núcleo',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'pelo',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'cadastro',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'cadastro',
#   'word[-3:]': 'tro',
#   'word[-2:]': 'ro',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'núcleo',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'fomecedores',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'cadastro',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'fomecedores',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'da',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'fomecedores',
#   'word[-3:]': 'res',
#   'word[-2:]': 'es',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'cadastro',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'da',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'central',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'da',
#   'word[-3:]': 'da',
#   'word[-2:]': 'da',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'fomecedores',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'central',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'central',
#   'word[-3:]': 'ral',
#   'word[-2:]': 'al',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'da',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'fomecedores',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'compras',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'central',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'da',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'compras',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'sefp',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': True,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'compras',
#   'word[-3:]': 'ras',
#   'word[-2:]': 'as',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'central',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'sefp',
#   'word_after_isdigit': False,
#   'word_after_isupper': True,
#   'word_after_istitle': False,
#   'word_after2': 'ou',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'sefp',
#   'word[-3:]': 'EFP',
#   'word[-2:]': 'FP',
#   'capital_letter': True,
#   'word_istitle': False,
#   'all_capital': True,
#   'word_isdigit': False,
#   'word_before': 'compras',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'ou',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'certificado',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'ou',
#   'word[-3:]': 'ou',
#   'word[-2:]': 'ou',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'sefp',
#   'word_before_isdigit': False,
#   'word_before_isupper': True,
#   'word_before_istitle': False,
#   'word_before2': 'compras',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': True,
#   'word_before_istitle2': False,
#   'word_after': 'certificado',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'equivalente',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'certificado',
#   'word[-3:]': 'ado',
#   'word[-2:]': 'do',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'ou',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'sefp',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
# ...
#   'word_after': 'possíveis',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'alterações',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'possíveis',
#   'word[-3:]': 'eis',
#   'word[-2:]': 'is',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'à',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'federal',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'alterações',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'e',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'alterações',
#   'word[-3:]': 'ões',
#   'word[-2:]': 'es',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'possíveis',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'à',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'e',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'no',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'e',
#   'word[-3:]': 'e',
#   'word[-2:]': 'e',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'alterações',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'possíveis',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'no',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'dia',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'no',
#   'word[-3:]': 'no',
#   'word[-2:]': 'no',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'e',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'alterações',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'dia',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'da',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'dia',
#   'word[-3:]': 'dia',
#   'word[-2:]': 'ia',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'no',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'e',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'da',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'abertura',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'da',
#   'word[-3:]': 'da',
#   'word[-2:]': 'da',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'dia',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'no',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'abertura',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'do',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'abertura',
#   'word[-3:]': 'ura',
#   'word[-2:]': 'ra',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'da',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'dia',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'do',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'envelope',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'do',
#   'word[-3:]': 'do',
#   'word[-2:]': 'do',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'abertura',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'da',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'envelope',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'contendo',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'envelope',
#   'word[-3:]': 'ope',
#   'word[-2:]': 'pe',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'do',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'abertura',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'contendo',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'a',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'contendo',
#   'word[-3:]': 'ndo',
#   'word[-2:]': 'do',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'envelope',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'do',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'a',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'proposta',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'a',
#   'word[-3:]': 'a',
#   'word[-2:]': 'a',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'contendo',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'envelope',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'proposta',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'proposta',
#   'word[-3:]': 'sta',
#   'word[-2:]': 'ta',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'a',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'contendo',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'preços',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'proposta',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'a',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'preços',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'trazer',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'preços',
#   'word[-3:]': 'ços',
#   'word[-2:]': 'os',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'proposta',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'trazer',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'o',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'trazer',
#   'word[-3:]': 'zer',
#   'word[-2:]': 'er',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'preços',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'o',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'certificado',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'o',
#   'word[-3:]': 'o',
#   'word[-2:]': 'o',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'trazer',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'preços',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'certificado',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'de',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'certificado',
#   'word[-3:]': 'ado',
#   'word[-2:]': 'do',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'o',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'trazer',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'de',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'registro',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'de',
#   'word[-3:]': 'de',
#   'word[-2:]': 'de',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'certificado',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'o',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'registro',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'cadastral',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': True,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'registro',
#   'word[-3:]': 'tro',
#   'word[-2:]': 'ro',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'de',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'certificado',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'cadastral',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': True,
#   'word_after2': 'ou',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'cadastral',
#   'word[-3:]': 'ral',
#   'word[-2:]': 'al',
#   'capital_letter': True,
#   'word_istitle': True,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'registro',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'de',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'ou',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'certificado',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'ou',
#   'word[-3:]': 'ou',
#   'word[-2:]': 'ou',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'cadastral',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': True,
#   'word_before2': 'registro',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': True,
#   'word_after': 'certificado',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': 'equivalente',
#   'word_after_isdigit2': False,
#   'word_after_isupper2': False,
#   'word_after_istitle2': False,
#   'BOS': False,
#   'EOS': False},
#  {'word': 'certificado',
#   'word[-3:]': 'ado',
#   'word[-2:]': 'do',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'ou',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'cadastral',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': 'equivalente',
#   'word_after_isdigit': False,
#   'word_after_isupper': False,
#   'word_after_istitle': False,
#   'word_after2': '',
#   'word_after_isdigit2': '',
#   'word_after_isupper2': '',
#   'word_after_istitle2': '',
#   'BOS': False,
#   'EOS': False},
#  {'word': 'equivalente',
#   'word[-3:]': 'nte',
#   'word[-2:]': 'te',
#   'capital_letter': False,
#   'word_istitle': False,
#   'all_capital': False,
#   'word_isdigit': False,
#   'word_before': 'certificado',
#   'word_before_isdigit': False,
#   'word_before_isupper': False,
#   'word_before_istitle': False,
#   'word_before2': 'ou',
#   'word_before_isdigit2': False,
#   'word_before_isupper2': False,
#   'word_before_istitle2': False,
#   'word_after': '',
#   'word_after_isdigit': '',
#   'word_after_isupper': '',
#   'word_after_istitle': '',
#   'word_after2': '',
#   'word_after_isdigit2': '',
#   'word_after_isupper2': '',
#   'word_after_istitle2': '',
#   'BOS': False,
#   'EOS': True}]

# %%
# !pip install scipy
import sklearn_crfsuite
from sklearn_crfsuite import metrics
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV


crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=100, 
    all_possible_transitions=True
)

params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

rs = RandomizedSearchCV(crf, params_space, 
                        cv=5, 
                        verbose=1, 
                        n_jobs=-1, 
                        n_iter=50)
rs.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  5.2min finished
# RandomizedSearchCV(cv=5,
#                    estimator=CRF(algorithm='lbfgs',
#                                  all_possible_transitions=True,
#                                  keep_tempfiles=None, max_iterations=100),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'c1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f5e14f50430>,
#                                         'c2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f5e15a5f550>},
#                    verbose=1)

# %%
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.31932097048088937, 'c2': 0.009530356867673853}
# best CV score: 0.8764664602201394
# model size: 0.15M

# %%
# !pip install matplotlib
# import matplotlib.pyplot as plt
# from sklearn.model_selection import RandomizedSearchCV
# plt.style.use('ggplot')

# _x = rs.cv_results_['param_c1']
# _y = rs.cv_results_['param_c2']
# _c = rs.cv_results_['mean_test_score']

# fig = plt.figure()
# fig.set_size_inches(12, 12)
# ax = plt.gca()
# ax.set_yscale('log')
# ax.set_xscale('log')
# ax.set_xlabel('C1')
# ax.set_ylabel('C2')
# ax.set_title("Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".format(
#     min(_c), max(_c)
# ))

# ax.scatter(_x, _y, c=_c, s=60, alpha=0.9, edgecolors=[0,0,0])

# print("Dark blue => {:0.4}, dark red => {:0.4}".format(min(_c), max(_c)))

# %%
crf = rs.best_estimator_

classes = list(crf.classes_)
classes.remove('O')

y_pred = crf.predict(x_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=classes, digits=3
))
# Out:
# /home/thais/Documentos/Knedle/experiments/members/thais/contrato-licitações/estudo_crf/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass labels=['B-MODALIDADE_LICITACAO', 'B-NUM_LICITACAO', 'I-NUM_LICITACAO', 'B-OBJ_LICITACAO', 'I-OBJ_LICITACAO', 'B-DATA_ABERTURA', 'I-DATA_ABERTURA', 'B-SISTEMA_COMPRAS', 'I-SISTEMA_COMPRAS', 'I-MODALIDADE_LICITACAO', 'B-PROCESSO', 'I-PROCESSO', 'B-CODIGO_SISTEMA_COMPRAS', 'B-VALOR_ESTIMADO', 'I-VALOR_ESTIMADO', 'I-CODIGO_SISTEMA_COMPRAS', 'B-TIPO_OBJ', 'B-ORGAO_LICITANTE', 'I-ORGAO_LICITANTE'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
#                           precision    recall  f1-score   support
#
#   B-MODALIDADE_LICITACAO      1.000     1.000     1.000        72
#          B-NUM_LICITACAO      0.988     0.988     0.988        80
#          I-NUM_LICITACAO      0.973     1.000     0.986        73
#          B-OBJ_LICITACAO      1.000     1.000     1.000        70
#          I-OBJ_LICITACAO      0.984     1.000     0.992      2053
#          B-DATA_ABERTURA      1.000     0.947     0.973        75
#          I-DATA_ABERTURA      0.985     1.000     0.993       200
#        B-SISTEMA_COMPRAS      1.000     0.983     0.992        60
#        I-SISTEMA_COMPRAS      1.000     1.000     1.000       185
#   I-MODALIDADE_LICITACAO      1.000     1.000     1.000        73
#               B-PROCESSO      1.000     1.000     1.000        59
#               I-PROCESSO      1.000     1.000     1.000       160
# B-CODIGO_SISTEMA_COMPRAS      1.000     1.000     1.000        12
#         B-VALOR_ESTIMADO      1.000     0.952     0.976        21
#         I-VALOR_ESTIMADO      1.000     1.000     1.000        46
# I-CODIGO_SISTEMA_COMPRAS      1.000     1.000     1.000         8
#               B-TIPO_OBJ      1.000     1.000     1.000         1
#        B-ORGAO_LICITANTE      1.000     1.000     1.000        14
#        I-ORGAO_LICITANTE      1.000     1.000     1.000        67
#
#                micro avg      0.988     0.998     0.993      3329
#                macro avg      0.996     0.993     0.995      3329
#             weighted avg      0.988     0.998     0.993      3329

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))
        

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# I-OBJ_LICITACAO -> I-OBJ_LICITACAO 5.779369
# O      -> O       5.336256
# I-PROCESSO -> I-PROCESSO 5.218414
# B-CODIGO_SISTEMA_COMPRAS -> I-CODIGO_SISTEMA_COMPRAS 4.716489
# I-SISTEMA_COMPRAS -> I-SISTEMA_COMPRAS 4.555286
# I-VALOR_ESTIMADO -> I-VALOR_ESTIMADO 4.056591
# I-DATA_ABERTURA -> I-DATA_ABERTURA 3.951341
# B-VALOR_ESTIMADO -> I-VALOR_ESTIMADO 3.747090
# B-NUM_LICITACAO -> I-NUM_LICITACAO 3.729454
# I-ORGAO_LICITANTE -> I-ORGAO_LICITANTE 3.462145
# B-MODALIDADE_LICITACAO -> I-MODALIDADE_LICITACAO 3.349387
# I-MODALIDADE_LICITACAO -> I-MODALIDADE_LICITACAO 3.263376
# B-PROCESSO -> I-PROCESSO 3.170532
# B-DATA_ABERTURA -> I-DATA_ABERTURA 2.972631
# B-ORGAO_LICITANTE -> I-ORGAO_LICITANTE 2.635686
# B-SISTEMA_COMPRAS -> I-SISTEMA_COMPRAS 2.431726
# B-OBJ_LICITACAO -> I-OBJ_LICITACAO 2.410537
# O      -> B-SISTEMA_COMPRAS 2.211252
# O      -> B-DATA_ABERTURA 2.204350
# O      -> B-NUM_LICITACAO 1.926168
#
# Top unlikely transitions:
# B-DATA_ABERTURA -> B-DATA_ABERTURA -0.673903
# B-VALOR_ESTIMADO -> B-VALOR_ESTIMADO -0.707180
# B-DATA_ABERTURA -> I-PROCESSO -0.759962
# B-PROCESSO -> B-PROCESSO -0.914312
# I-OBJ_LICITACAO -> I-DATA_ABERTURA -1.011432
# O      -> I-CODIGO_SISTEMA_COMPRAS -1.054439
# B-PROCESSO -> I-VALOR_ESTIMADO -1.199060
# B-NUM_LICITACAO -> I-PROCESSO -1.229090
# I-OBJ_LICITACAO -> B-DATA_ABERTURA -1.328250
# B-NUM_LICITACAO -> I-VALOR_ESTIMADO -1.367358
# O      -> I-SISTEMA_COMPRAS -1.375570
# B-PROCESSO -> I-DATA_ABERTURA -1.427101
# I-OBJ_LICITACAO -> B-OBJ_LICITACAO -1.497203
# B-NUM_LICITACAO -> I-DATA_ABERTURA -1.523373
# O      -> I-MODALIDADE_LICITACAO -1.589835
# O      -> I-VALOR_ESTIMADO -1.603975
# O      -> I-ORGAO_LICITANTE -1.931352
# O      -> I-PROCESSO -2.446360
# O      -> I-DATA_ABERTURA -3.214015
# O      -> I-OBJ_LICITACAO -3.259148

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))    

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
# 6.654827 B-CODIGO_SISTEMA_COMPRAS word_before:uasg
# 4.227421 O        word:objeto
# 3.829761 O        word:200
# 3.796002 O        word_before2:gov
# 3.664366 O        word_before:2008
# 3.545483 B-VALOR_ESTIMADO word_after:851
# 3.464869 B-OBJ_LICITACAO word_before:objeto
# 3.380213 I-NUM_LICITACAO word_before2:nº
# 3.372236 O        word_after2:reais
# 3.324524 B-NUM_LICITACAO word_after2:2000
# 3.266243 B-PROCESSO word:060
# 3.266243 B-PROCESSO word[-3:]:060
# 3.243848 O        word:valor
# 3.109380 B-MODALIDADE_LICITACAO word_before:licitação
# 3.108587 B-ORGAO_LICITANTE word:administração
# 3.097680 O        word:data
# 2.981170 I-DATA_ABERTURA word_after2:às
# 2.948488 I-SISTEMA_COMPRAS word_before:http
# 2.861517 O        word[-2:]:um
# 2.824516 B-VALOR_ESTIMADO word_before:01
# 2.798009 B-DATA_ABERTURA word_before:abertura
# 2.778711 B-DATA_ABERTURA word_after2:cópia
# 2.772327 B-ORGAO_LICITANTE word_before:a
# 2.758218 I-CODIGO_SISTEMA_COMPRAS word_before:uasg
# 2.721328 I-MODALIDADE_LICITACAO word_after2:57
# 2.709039 B-MODALIDADE_LICITACAO word[-3:]:GÃO
# 2.672437 O        word_after:00
# 2.610435 B-NUM_LICITACAO word_before:nº
# 2.580493 I-SISTEMA_COMPRAS word_before:e
# 2.564700 B-MODALIDADE_LICITACAO word_after:nº
#
# Top negative:
# -1.123394 O        word_after2:00
# -1.141681 O        word_before2:r
# -1.199952 I-PROCESSO word[-2:]:88
# -1.211332 I-VALOR_ESTIMADO capital_letter
# -1.223622 O        word_after:convite
# -1.239291 O        word_before2:processo
# -1.260291 O        word_before2:eletrônico
# -1.279301 O        word_before2:objeto
# -1.283298 O        word_before:processos
# -1.351544 O        word_after:200
# -1.370040 O        word:concorrência
# -1.448878 O        word_before2:2
# -1.472044 O        word_after:torna
# -1.495135 I-NUM_LICITACAO word_after_isdigit
# -1.520138 B-DATA_ABERTURA word_after2:2018
# -1.526753 O        word_after2:público
# -1.621659 O        word_isdigit
# -1.629523 I-PROCESSO word_after:2006
# -1.693201 O        word:contratação
# -1.694240 O        word[-2:]:TE
# -1.694618 O        word_after2:partir
# -1.722880 O        word[-2:]:60
# -1.753780 O        word_after2:2º
# -1.834498 O        word_after2:14
# -1.864440 O        word[-3:]:010
# -1.873774 O        word_after:abertura
# -1.968448 O        word_after:nº
# -2.066478 O        word_after2:º
# -2.123998 O        word[-2:]:40
# -2.879576 O        word[-3:]:003
