# %%
import pandas as pd

# %% [markdown]
# #### Dataset - Abertura/Aviso de licitação (ABER_LIC01)
#
# Contém 435 atos. Nesse dataset encontram-se os dados de 200x até 2020. Contém muitos dados de atos de abertura/aviso recentes (2018 e 2020)
#
# Localizaçã:
# https://github.com/UnB-KnEDLe/experiments.git - members/ian/deep-learning/acts_parquet/lic_435_acts_200x_2018_2020_iob.parquet

# %%
#trocar o caminho do arquivo em sua máquina
ABER_LIC01 = pd.read_parquet(r'C:\Users\72118423187\desenvolvimento\github\experiments\members\ian\deep-learning\acts_parquet\lic_435_acts_200x_2018_2020_iob.parquet')

print('Tamanho:', ABER_LIC01.shape[0])
# Out:
# Tamanho: 435

# %%
ABER_LIC01
# Out:
#                                        ORGAO_LICITANTE NUM_LICITACAO  \
# 0    demais orgaos participantes do Sistema de Regi...      001/2020
# 1                                             METRO-DF       03/2019
# 2    Secretaria de Estado de Seguranca Publica do D...       31/2019
# 3                                                 None      301/2019
# 4                                                 None      116/2018
# ..                                                 ...           ...
# 430                                               None      442/2004
# 431                                               None      451/2004
# 432                                               None      024/2002
# 433                                               None      005/2002
# 434               COMPANHIA ENERGÉTICA DE BRASÍLIA CEB       31/2000
#
#                                          OBJ_LICITACAO  \
# 0    Registro de Precos visando a eventual aquisica...
# ...

# %%
#ABER_LIC01.head()

# %% [markdown]
# #### Dataset - Abertura/Aviso de licitação (ABER_LIC02)
# Contém 234 atos. Foi anotado pela equipe de contratos. Prefira criar os modelos com o dataset (ABER_LIC01), por já contemplar os dados de ABER_LIC02
#
# Localização:
# https://github.com/UnB-KnEDLe/experiments.git - members/ian/deep-learning/acts_parquet/aviso_licitacao_all_entities_iob.parquet

# %%
#trocar o caminho do arquivo em sua máquina
ABER_LIC02 = pd.read_parquet(r'C:\Users\72118423187\desenvolvimento\github\experiments\members\ian\deep-learning\acts_parquet\aviso_licitacao_all_entities_iob.parquet')

print('Tamanho:', ABER_LIC02.shape[0])
# Out:
# Tamanho: 234

# %% [markdown]
# #### Dataset - TODOS os atos de  licitação (ALL_ACTS)
# ###### ATOS = (ABERTURA/AVISO, EXTRATO_CONTRATO, SUSPENCAO, REVOGACAO, EXTRATO_ADITAMENTO)
# Contém 1.168 registros de atos no período de 20xx. *** verificar se esse dataset é anterior ao dataset disponibilizado pelo Prof. vinícius (contratos_idato.csv)
#
# Localização:
# https://github.com/UnB-KnEDLe/experiments.git - members/ian/deep-learning/acts_parquet/all_acts_entities.parquet

# %%
ALL_ACTS = pd.read_parquet(r'C:\Users\72118423187\desenvolvimento\github\experiments\members\ian\deep-learning\acts_parquet\all_acts_entities.parquet')


print('Total de atos:', ALL_ACTS.shape[0])

print('\n')
print('Qtd de atos por categoria: ', ALL_ACTS.groupby(['ato'])['ato'].count())
# Out:
# Total de atos: 1168
#
#
# Qtd de atos por categoria:  ato
# aviso_de_aditamento_contratual              463
# aviso_de_licitacao                          235
# aviso_de_revogacao_anulacao_de_licitacao     16
# aviso_de_suspensao_de_licitacao              12
# extrato_de_contrato_ou_convenio             442
# Name: ato, dtype: int64

# %%
# QTD de entidades em cada ato 
pd.set_option('display.max_columns', None)
ALL_ACTS.groupby(['ato']).count()
# Out:
#                                           arquivo_rast  text  dodf  \
# ato
# aviso_de_aditamento_contratual                     463   463   463
# aviso_de_licitacao                                 235   235   235
# aviso_de_revogacao_anulacao_de_licitacao            16    16    16
# aviso_de_suspensao_de_licitacao                     12    12    12
# extrato_de_contrato_ou_convenio                    442   442   442
#
#                                           treated_text  PROCESSO  NUM_AJUSTE  \
# ato
# aviso_de_aditamento_contratual                     463         0           0
# aviso_de_licitacao                                 235       173           0
# aviso_de_revogacao_anulacao_de_licitacao            16         0           0
# aviso_de_suspensao_de_licitacao                     12         0           0
# extrato_de_contrato_ou_convenio                    442       431         431
#
#                                           CONTRATANTE  CONTRATADA  OBJ_AJUSTE  \
# ato
# ...

# %%
#Exemplo: filtrando aviso_de_aditamento_contratual - Entidades que não estão no dataset processo_gdf, data_escrito, nome_responsavel
ALL_ACTS[ALL_ACTS['ato']=='aviso_de_aditamento_contratual'][['ato', 'treated_text', 'NUM_ADITIVO', 'NUM_CONTRATO', 'CONTRATANTE', 'OBJ_ADITIVO' ]]
# Out:
#                                  ato  \
# 10    aviso_de_aditamento_contratual
# 11    aviso_de_aditamento_contratual
# 14    aviso_de_aditamento_contratual
# 25    aviso_de_aditamento_contratual
# 27    aviso_de_aditamento_contratual
# ...                              ...
# 1163  aviso_de_aditamento_contratual
# 1164  aviso_de_aditamento_contratual
# 1165  aviso_de_aditamento_contratual
# 1166  aviso_de_aditamento_contratual
# 1167  aviso_de_aditamento_contratual
#
#                                            treated_text  \
# 10    HI TERMO ADITIVO AO CONTRATO BRB 2016/100 Cont...
# 11    Espécie: Segundo Termo Aditivo ao Contrato 000...
# 14    EXTRATO DO PRIMEIRO TERMO ADITIVO AO CONTRATO ...
# 25    EXTRATO DO SEGUNDO TERMO ADITIVO AO CONTRATO N...
# 27    EXTRATO DO QUINTO TERMO ADITIVO AO CONTRATO Nº...
# ...                                                 ...
# 1163  EXTRATO DE INSTRUMENTO CONTRATUAL PROCESSO: 11...
# 1164  PROCESSO: 112.003.048/2016. ESPÉCIE: SEXTO TER...
# ...
