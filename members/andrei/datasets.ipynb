# %%
import pandas as pd

# %% [markdown]
# #### Dataset - Abertura/Aviso de licitação (ABER_LIC01)
#
# Contém 435 atos. Nesse dataset encontram-se os dados de 200x até 2020. Contém muitos dados de atos de abertura/aviso recentes (2018 e 2020)
#
# Localizaçã:
# https://github.com/UnB-KnEDLe/experiments.git - members/ian/deep-learning/acts_parquet/lic_435_acts_200x_2018_2020_iob.parquet

# %%
#trocar o caminho do arquivo em sua máquina
ABER_LIC01 = pd.read_parquet(r'C:\Users\72118423187\desenvolvimento\github\experiments\members\ian\deep-learning\acts_parquet\lic_435_acts_200x_2018_2020_iob.parquet')

print('Tamanho:', ABER_LIC01.shape[0])
# Out:
# Tamanho: 435

# %% [markdown]
# #### Dataset - Abertura/Aviso de licitação (ABER_LIC02)
# Contém 234 atos. Foi anotado pela equipe de contratos. Prefira criar os modelos com o dataset (ABER_LIC01), por já contemplar os dados de ABER_LIC02
#
# Localização:
# https://github.com/UnB-KnEDLe/experiments.git - members/ian/deep-learning/acts_parquet/aviso_licitacao_all_entities_iob.parquet

# %%
#trocar o caminho do arquivo em sua máquina
ABER_LIC02 = pd.read_parquet(r'C:\Users\72118423187\desenvolvimento\github\experiments\members\ian\deep-learning\acts_parquet\aviso_licitacao_all_entities_iob.parquet')

print('Tamanho:', ABER_LIC02.shape[0])
# Out:
# Tamanho: 234

# %% [markdown]
# #### Dataset - TODOS os atos de  licitação (ALL_ACTS)
# ###### ATOS = (ABERTURA/AVISO, EXTRATO_CONTRATO, SUSPENCAO, REVOGACAO, EXTRATO_ADITAMENTO)
# Contém 1.894 registros de atos no período de 20xx até 2020. Contém os atos anotados via labelbox + atos anotados pelos alunos do Prof. Vinícius do período de 2018 até 2022  (arquivo referência - contratos_idato.csv)
#
# Localização:
# https://github.com/UnB-KnEDLe/experiments.git - members/ian/atos_licitacao_contratos/all_acts_200x_2018_2020.parquet

# %%
#trocar o caminho do arquivo em sua máquina
ALL_ACTS = pd.read_parquet(r'C:\Users\72118423187\desenvolvimento\github\experiments\members\ian\atos_licitacao_contratos\all_acts_200x_2018_2020.parquet')
print('Total de atos:', ALL_ACTS.shape[0])

print('\n')
print('Qtd de atos por categoria: ', ALL_ACTS.groupby(['ato'])['ato'].count())
# Out:
# Total de atos: 1894
#
#
# Qtd de atos por categoria:  ato
# AVISO_ANUL_REV_LICITACAO          34
# AVISO_LICITACAO                  436
# AVISO_SUSPENSAO_LICITACAO         25
# EXTRATO_ADITAMENTO_CONTRATUAL    833
# EXTRATO_CONTRATO                 119
# EXTRATO_CONTRATO_CONVENIO        442
# EXTRATO_CONVENIO                   5
# Name: ato, dtype: int64

# %%
#Exemplo de filtragem por ato (EXTRATO_ADITAMENTO_CONTRATUAL) e seleção de colunas
ALL_ACTS[ALL_ACTS['ato']=='EXTRATO_ADITAMENTO_CONTRATUAL'][['ato', 'CONTRATANTE', 'OBJ_ADITIVO', 'NUM_ADITIVO'  ]]
# Out:
#                                 ato  \
# 10    EXTRATO_ADITAMENTO_CONTRATUAL
# 11    EXTRATO_ADITAMENTO_CONTRATUAL
# 14    EXTRATO_ADITAMENTO_CONTRATUAL
# 25    EXTRATO_ADITAMENTO_CONTRATUAL
# 27    EXTRATO_ADITAMENTO_CONTRATUAL
# ...                             ...
# 1881  EXTRATO_ADITAMENTO_CONTRATUAL
# 1883  EXTRATO_ADITAMENTO_CONTRATUAL
# 1884  EXTRATO_ADITAMENTO_CONTRATUAL
# 1885  EXTRATO_ADITAMENTO_CONTRATUAL
# 1892  EXTRATO_ADITAMENTO_CONTRATUAL
#
#                                             CONTRATANTE  \
# 10                           BRB BANCO DE BRASÍLIA S.A.
# 11                                 CEB Distribuição S/A
# 14                                                DF/ST
# 25               DEFENSORIA PÚBLICA DO DISTRITO FEDERAL
# 27                                                CBMDF
# ...                                                 ...
# 1881           ADMINISTRACAO REGIONAL DO RIACHO FUNDO I
# 1883  DEPARTAMENTO DE ESTRADAS DE RODAGEM DO DISTRIT...
# 1884  DEPARTAMENTO DE ESTRADAS DE RODAGEM DO DISTRIT...
# 1885  COMPANHIA IMOBILIARIA DE BRASILIA TERRACAP TER...
# 1892  COMPANHIA URBANIZADORA DA NOVA CAPITAL DO BRAS...
#
#                                             OBJ_ADITIVO  \
# 10    prorrogação do contrato, a partir de 17/05/201...
# 11    Prorrogação rogação do prazo de vigência por 0...
# 14    Prorrogar, por 60 (sessenta) dias, o prazo de ...
# 25    Prorrogar por mais 12 (doze) meses o prazo de ...
# 27    alteração contratual com vistas a incluir no e...
# ...                                                 ...
# 1881  O presente Termo Aditivo tem por objeto prorro...
# 1883  Incluir a Fonte 248 CIDE, CIDE, no item IV Fon...
# 1884  Prorrogar a vigencia do Contrato no 002/2017 D...
# 1885  Aditar o referido contrato, que tem por objeto...
# 1892  Prorrogacao do prazo de vigencia, bem como o r...
#
#                  NUM_ADITIVO
# 10          HI TERMO ADITIVO
# 11     Segundo Termo Aditivo
# 14    PRIMEIRO TERMO ADITIVO
# 25     SEGUNDO TERMO ADITIVO
# 27      QUINTO TERMO ADITIVO
# ...                      ...
# 1881                 SEGUNDO
# 1883                       3
# 1884                       3
# 1885                      2o
# 1892                TERCEIRO
#
# [833 rows x 4 columns]

# %%
# QTD de entidades em cada ato 
pd.set_option('display.max_columns', None)
ALL_ACTS.groupby(['ato']).count()
# Out:
#                                arquivo_rast  text  dodf  treated_text  \
# ato
# AVISO_ANUL_REV_LICITACAO                 16    16    34            34
# AVISO_LICITACAO                         235   235   436           436
# AVISO_SUSPENSAO_LICITACAO                12    12    25            25
# EXTRATO_ADITAMENTO_CONTRATUAL           463   463   833           833
# EXTRATO_CONTRATO                          0     0   119           119
# EXTRATO_CONTRATO_CONVENIO               442   442   442           442
# EXTRATO_CONVENIO                          0     0     5             5
#
#                                PROCESSO  NUM_AJUSTE  CONTRATANTE  CONTRATADA  \
# ato
# AVISO_ANUL_REV_LICITACAO             16           0            0           0
# AVISO_LICITACAO                     369           0            0           0
# AVISO_SUSPENSAO_LICITACAO             8           0            0           0
# EXTRATO_ADITAMENTO_CONTRATUAL       333         367          806           0
# EXTRATO_CONTRATO                    119         118          118         119
# EXTRATO_CONTRATO_CONVENIO           431         431          403         413
# EXTRATO_CONVENIO                      4           4            0           0
#
#                                OBJ_AJUSTE  VIGENCIA  VALOR   PT  \
# ato
# AVISO_ANUL_REV_LICITACAO                0         0      0    0
# AVISO_LICITACAO                         0         0      0    0
# AVISO_SUSPENSAO_LICITACAO               0         0      0    0
# EXTRATO_ADITAMENTO_CONTRATUAL           0         0      0    0
# EXTRATO_CONTRATO                      117       111    107   71
# EXTRATO_CONTRATO_CONVENIO             440       406    348  251
# EXTRATO_CONVENIO                        5         5      3    2
#
#                                DATA_ASSINATURA  CODIGO_UO   ND   NE  \
# ato
# AVISO_ANUL_REV_LICITACAO                     0          0    0    0
# AVISO_LICITACAO                              0          0    0    0
# AVISO_SUSPENSAO_LICITACAO                    0          0    0    0
# EXTRATO_ADITAMENTO_CONTRATUAL                0          0    0    0
# EXTRATO_CONTRATO                           101         56   65   69
# EXTRATO_CONTRATO_CONVENIO                  380        178  198  199
# EXTRATO_CONVENIO                             3          2    2    0
#
#                                FUND_DISPENSA  ORGAO_LICITANTE  NUM_LICITACAO  \
# ato
# AVISO_ANUL_REV_LICITACAO                   0               18             34
# AVISO_LICITACAO                            0              161            429
# AVISO_SUSPENSAO_LICITACAO                  0               17             22
# EXTRATO_ADITAMENTO_CONTRATUAL              0                0              0
# EXTRATO_CONTRATO                           0                0              0
# EXTRATO_CONTRATO_CONVENIO                 30                1            124
# EXTRATO_CONVENIO                           0                0              0
#
#                                OBJ_LICITACAO  MODALIDADE_LICITACAO  \
# ato
# AVISO_ANUL_REV_LICITACAO                   0                    33
# AVISO_LICITACAO                          434                   428
# AVISO_SUSPENSAO_LICITACAO                 10                    20
# EXTRATO_ADITAMENTO_CONTRATUAL              0                     0
# EXTRATO_CONTRATO                           0                     0
# EXTRATO_CONTRATO_CONVENIO                  0                     0
# EXTRATO_CONVENIO                           0                     0
#
#                                DATA_ABERTURA  TIPO_OBJ  VALOR_ESTIMADO  \
# ato
# AVISO_ANUL_REV_LICITACAO                   0         0               0
# AVISO_LICITACAO                          398       414             219
# AVISO_SUSPENSAO_LICITACAO                  0         0               0
# EXTRATO_ADITAMENTO_CONTRATUAL              0         0               0
# EXTRATO_CONTRATO                           0         0               0
# EXTRATO_CONTRATO_CONVENIO                  0         0               0
# EXTRATO_CONVENIO                           0         0               0
#
#                                CODIGO_SISTEMA_COMPRAS  NUM_CONTRATO  \
# ato
# AVISO_ANUL_REV_LICITACAO                            0             0
# AVISO_LICITACAO                                   184             0
# AVISO_SUSPENSAO_LICITACAO                           0             0
# EXTRATO_ADITAMENTO_CONTRATUAL                       0           455
# EXTRATO_CONTRATO                                    0             0
# EXTRATO_CONTRATO_CONVENIO                           0             0
# EXTRATO_CONVENIO                                    0             0
#
#                                OBJ_ADITIVO  NUM_ADITIVO  \
# ato
# AVISO_ANUL_REV_LICITACAO                 0            0
# AVISO_LICITACAO                          0            0
# AVISO_SUSPENSAO_LICITACAO                0            0
# EXTRATO_ADITAMENTO_CONTRATUAL          819          775
# EXTRATO_CONTRATO                         0            0
# EXTRATO_CONTRATO_CONVENIO                0            0
# EXTRATO_CONVENIO                         0            0
#
#                                IDENT_REVOGACAO_ANULACAO  IDENT_DISPENSA  \
# ato
# AVISO_ANUL_REV_LICITACAO                             16               0
# AVISO_LICITACAO                                       0               0
# AVISO_SUSPENSAO_LICITACAO                             0               0
# EXTRATO_ADITAMENTO_CONTRATUAL                         0               0
# EXTRATO_CONTRATO                                      0               0
# EXTRATO_CONTRATO_CONVENIO                             0              24
# EXTRATO_CONVENIO                                      0               0
#
#                                SISTEMA_COMPRAS  CONVENENTE  DECISAO_TCDF  \
# ato
# AVISO_ANUL_REV_LICITACAO                     0           0             0
# AVISO_LICITACAO                            347           0             0
# AVISO_SUSPENSAO_LICITACAO                    0           0             5
# EXTRATO_ADITAMENTO_CONTRATUAL                0           0             0
# EXTRATO_CONTRATO                             0           0             0
# EXTRATO_CONTRATO_CONVENIO                    0          17             0
# EXTRATO_CONVENIO                             0           5             0
#
#                                PRAZO_SUSPENSAO  OG_ATA  NOME_RESPONSAVEL  \
# ato
# AVISO_ANUL_REV_LICITACAO                     0       0                18
# AVISO_LICITACAO                              0       0               193
# AVISO_SUSPENSAO_LICITACAO                    2       0                13
# EXTRATO_ADITAMENTO_CONTRATUAL                0       0                 3
# EXTRATO_CONTRATO                             0       0                 0
# EXTRATO_CONTRATO_CONVENIO                    0       1                 0
# EXTRATO_CONVENIO                             0       0                 0
#
#                                DATA_ESCRITO  FONTE_RECURSO  CNPJ_CONTRATADA  \
# ato
# AVISO_ANUL_REV_LICITACAO                  1              0                0
# AVISO_LICITACAO                           0              0                0
# AVISO_SUSPENSAO_LICITACAO                 0              0                0
# EXTRATO_ADITAMENTO_CONTRATUAL           341              0                0
# EXTRATO_CONTRATO                          0             68               41
# EXTRATO_CONTRATO_CONVENIO                 0              0                0
# EXTRATO_CONVENIO                          0              2                0
#
#                                CONCEDENTE  CNPJ_CONVENENTE  \
# ato
# AVISO_ANUL_REV_LICITACAO                0                0
# AVISO_LICITACAO                         0                0
# AVISO_SUSPENSAO_LICITACAO               0                0
# EXTRATO_ADITAMENTO_CONTRATUAL           0                0
# EXTRATO_CONTRATO                        0                0
# EXTRATO_CONTRATO_CONVENIO               0                0
# EXTRATO_CONVENIO                        5                3
#
#                                IDENTIFICACAO_OCORRENCIA  CNPJ_CONTRATANTE  \
# ato
# AVISO_ANUL_REV_LICITACAO                             18                 0
# AVISO_LICITACAO                                       0                 0
# AVISO_SUSPENSAO_LICITACAO                             0                 0
# EXTRATO_ADITAMENTO_CONTRATUAL                         0                 0
# EXTRATO_CONTRATO                                      0                19
# EXTRATO_CONTRATO_CONVENIO                             0                 0
# EXTRATO_CONVENIO                                      0                 0
#
#                                CNPJ_CONCEDENTE
# ato
# AVISO_ANUL_REV_LICITACAO                     0
# AVISO_LICITACAO                              0
# AVISO_SUSPENSAO_LICITACAO                    0
# EXTRATO_ADITAMENTO_CONTRATUAL                0
# EXTRATO_CONTRATO                             0
# EXTRATO_CONTRATO_CONVENIO                    0
# EXTRATO_CONVENIO                             1
