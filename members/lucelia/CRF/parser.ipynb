# %%
# Read in the file
#with open('/home/82068895153/POS/skweak/data/BERT/train.tsv', 'r') as file :
#with open('/home/82068895153/POS/skweak/data/Ontonotes/ner_train.txt', 'r') as file :
with open('/home/82068895153/POS/skweak/data/wiki/wikigold.conll.txt', 'r') as file :
  filedata = list(file.readlines())

# %%
filedata[0:8]
# Out:
# ['is O\\\n',
#  'the O\\\n',
#  'tenth O\\\n',
#  'album O\\\n',
#  'from O\\\n',
#  'Japanese I-MISC\\\n',
#  'Punk O\\\n',
#  'Techno O\\\n']

# %%
#linha = filedata[0]
linha = filedata
p=linha.split(' ')[0]
#p=linha.split('\t')[0]
p=linha.split('\\\n')[0]
p

# %%
texto=''
# for each line in the input file
for linha in filedata[0]:
	#read replace the string and write to output file
    p=linha.split(' ')[0]
    #p=linha.split('\n')[0]
    #p=linha.split('\t')[0]
    texto=texto + p + '\n'
texto[0]
# Out:
# 'i'

# %%
# Write the file out again
with open('/home/82068895153/POS/skweak/data/BERT/train_out.txt', 'wt') as fileout:
  fileout.write(texto)

# %%
# Read in the file
with open('/home/82068895153/POS/skweak/data/BERT/train_out.txt', 'r') as file :
  filedataout = file.readlines()

# %%
filedataout

# %%
# Read in the file
with open('/home/82068895153/POS/skweak/data/conll2003_dataset/train.txt', 'r') as file :
  filedata = file.readlines()

# %%
linha = filedata[6]
linha

# %%
texto=''
setenca=''
# for each line in the input file

#message = 'Python is a fun programming language'

# check the index of 'fun'
#print(linha.find('.'))


for linha in filedata:
	#read the string and write to output file
    pos = linha.find('.')
    if pos > 0:
        p=''.join(linha[:pos])
        texto=texto + p 
    setenca = setenca + texto + '\n'
texto[0:10]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18744/3802629960.py in <module>
#      15         p=''.join(linha[:pos])
#      16         texto=texto + p
# ---> 17     setenca = setenca + texto + '\n'
#      18 texto[0:10]
#
# KeyboardInterrupt:

# %%
lista_sentenca = []
sentenca = ''
for linha in filedata: 
   if linha.find('.') > 0:
       print (linha)
       lista_sentenca.append(sentenca) 
       sentenca = ''  
   sentenca = sentenca + linha + ' '
   print(sentenca)
# Out:
#  ( ( O O
#  Australia NNP B-NP B-LOC
#  ) ) O O
#  71 CD B-NP O
#  78 CD I-NP O
#  71 CD I-NP O
#  , , O O
#
#  Martin NNP B-NP B-PER
#  Gates NNP I-NP I-PER
#  71 CD I-NP O
#  77 CD I-NP O
#  72 CD I-NP O
#  , , O O
#  Bradley NNP B-NP B-PER
#  Hughes NNP I-NP I-PER
#  ( ( O O
#  Australia NNP B-NP B-LOC
#  ) ) O O
#  73 CD B-NP O
#  75 CD I-NP O
#  72 CD I-NP O
#  , , O O
#
#  Peter NNP B-NP B-PER
#  Hedblom NNP I-NP I-PER
#  ( ( O O
#  Sweden NNP B-NP B-LOC
#  ) ) O O
#  70 CD B-NP O
#  75 CD I-NP O
#  75 CD I-NP O
#  , , O O
#  Retief NNP B-NP B-PER
#  Goosen NNP I-NP I-PER
#  ( ( O O
#  South NNP B-NP B-LOC
#
#  Africa NNP B-NP B-LOC
#  ) ) O O
#  71 CD B-NP O
#  74 CD B-NP O
#  75 CD I-NP O
#  , , O O
#  David NNP B-NP B-PER
#  Gilford NNP I-NP I-PER
#  69 CD I-NP O
#  74 CD B-NP O
#  77 CD I-NP O
#  . . O O
#
#  -DOCSTART- -X- -X- O
#
#  SOCCER NN B-NP O
#  - : O O
#  ENGLISH JJ B-NP B-MISC
#  SOCCER NNP I-NP O
#  RESULTS NNS I-NP O
#  . . O O
#
#  LONDON NNP B-NP B-LOC
# ...

# %%
# Write the file out again
with open('/home/82068895153/POS/skweak/data/conll2003_dataset/train_lu.txt', 'wt') as fileout:
  fileout.write(sentenca)

# %%
#Abre o Ontonotes 
with open('/home/82068895153/POS/skweak/data/Ontonotes/ner_train_1.txt', 'r') as file:
    sentences = list(file.readlines())

# %%
sentences[0]

# %%
for linha in sentences[i][1]:
        #lista_sentenca.replace(PERSON,PER)

# %%
def preprocess(sentences):
    l_sentences = []
    l1_ = []
    for token in sentences[5:]:
        cls = token.split()    
        if len(cls) != 0:
            l1_.append(cls)
        else:
            l_sentences.append(l1_)
            l1_ = []
    return l_sentences

# %%
texto = preprocess(sentences)
texto
#texto[0][1]

# %%
def replace(texto, i):
    lista_sentenca = []
    print(texto)
    print('antes do for')
    for linha in texto[i][1]:
        #lista_sentenca.replace(PERSON,PER)
        print(linha)
    return lista_sentenca

# %%
def sentReplace(sent):
    return [replace(sent, i) for i in range(len(sent))]

# %%
texto = [sentReplace(s) for s in texto]
