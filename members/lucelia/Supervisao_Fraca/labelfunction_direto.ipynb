# %% [markdown]
# # Código para aplicação das LB direto no dado para rotulação

# %% [markdown]
# ## Preparando o test da base ouro para aplicar as labels functions

# %%
import pandas as pd
import nltk
import scipy.stats
import sklearn

# %%
#apenas para testar o iob com spacy
#cria um novo dataset com as 2000 primeiras linhas
#csv_reader = pd.read_csv("/home/lucelia_vieira/Experimentos/ner/CSVs/REL_EXTRATO_CONTRATO_COMPLETO.csv", nrows=200)

# %%
#df = ["EXTRATO DO CONTRATO No 11/2019 PROCESSO: 00390-00003006/2019-92. ESPECIE: Contrato de Aquisicao de Bens pelo Distrito Federal no 11/2019. PARTES: Secretaria de Estado de Desenvolvimento Urbano e Habitacao do Distrito Federal - SEDUH/DF e INDUSTRIA DE AGUA MINERAL IBIA LTDA. DO OBJETO: Aquisicao de agua potavel de mesa sem gas e garrafao retornavel, destinados ao atendimento desta pasta, conforme demais especiGcacoes e condicoes estabelecidas no Termo de Referencia Anexo I do Edital de Pregao Eletronico no 0058/2018 - SCG/SEPLAG, da Proposta da empresa INDUSTRIA DE AGUA MINERAL IBIA LTDA de 11/06/2018 e da Lei no 8.666, de 21 de junho de 1993, que passam a integrar o presente Termo. DO VALOR: R$ 11.661,00 (onze mil, seiscentos e sessenta e um reais) conforme Nota de Empenho no 2019NE00180, emitida em 18/07/2019. Dotacao Orcamentaria P.T 15.122.6001.8517.0131 - Natureza da Despesa: 3390.30 - Fonte de Recursos: 100. DO PRAZO DE VIGENCIA: O Contrato tera vigencia de 06 (seis) meses a contar do dia 07/08/2019. DATA DE ASSINATURA: 22/07/2019. SIGNATARIOS: Pelo Distrito Federal: Mateus Leandro de Oliveira, na qualidade de Secretario de Estado. Pela Contratada: Eduardo Barros de Queiroz Rodrigues, na qualidade de Socio Administrador.", "EXTRATO DO CONTRATO Nº 06/2021 Processo: 00139-00001275/2021-00. Partes: DF - ADMINISTRAÇÃO REGIONAL DO CRUZEIRO X COMERCIAL DE ALIMENTOS PARK SUL. Objeto: O presente contrato tem por objeto a contratação de empresa especializada na área de alimentação para confecção e fornecimento de 50 KG DE BOLO CONFEITADO TIPO ANIVERSÁRIO COM MASSA PÃO DE LÓ COM RECHEIO DE BABA DE MOÇA, BEIJINHO OU DOCE DE LEITE E COBERTURA DE CHANTILLY DECORADO COM ACABAMENTO, no evento de comemoração ao aniversário de 62 anos do Cruzeiro no dia 30/11/2021. Valor do Contrato: R$ 2.000,00 (Dois Mil Reais). Dotação orçamentária: Unidade Orçamentária: 190113. Programa de Trabalho: 13.392.6219.3678.0136 . Natureza da Despesa: 339039. Fonte de Recursos: 120. Nota de Empenho: 2021NE00259. Valor do Empenho Inicial: R$ 2.000,00 (Dois Mil Reais), emitida em 26/11/2021 sob o evento 400091, na Modalidade 1   Ordinário. Fundamento Legal: Art. 24 da Lei nº 8.666/1993. Data da Assinatura: 29/11/2021. Signatários: Pelo DISTRITO FEDERAL: LUIZ EDUARDO GOMES DE PAULA PESSOA, na qualidade de Administrador Regional do Cruzeiro; pela COMERCIAL DE ALIMENTOS PARK SUL: GIVANILDES DE AGUIAR MORAIS, na qualidade de Gerente Geral."]

# %%
#Carrega o dataset de teste para aplicacao das LB
df_sk_1 = pd.read_csv('./CSVs/Extrato_Contrato_Split_4_x_test_texto.csv', dtype=str)
df_sk_1
# Out:
#     Unnamed: 0                                              Texto
# 0            0  EXTRATO DO CONTRATO DE AQUISIÇÃO DE PRODUTOS D...
# 1            1  EXTRATO DE CONTRATO Espécie : Contrato de Pres...
# 2            2  EXTRATO CONTRATUAL Processo : 00072-00000404/ ...
# 3            3  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 4            4  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# ..         ...                                                ...
# 303        303  EXTRATO DO CONTRATO PARA AQUISIÇÃO DE BENS Nº ...
# 304        304  EXTRATO DO CONTRATO DE EXECUÇÃO DE OBRAS PARA ...
# 305        305  EXTRATO DO CONTRATO Nº 45.926/2022 Processo : ...
# 306        306  EXTRATO DO CONTRATO Nº 45832/2022 Processo : 0...
# 307        307  EXTRATO DO CONTRATO Nº 45927/2022 Processo : 0...
#
# [308 rows x 2 columns]

# %%
#criando novo dataframe somente com os textos
df_sk = df_sk_1['Texto'].reset_index(drop=True)
df_sk
# Out:
# 0      EXTRATO DO CONTRATO DE AQUISIÇÃO DE PRODUTOS D...
# 1      EXTRATO DE CONTRATO Espécie : Contrato de Pres...
# 2      EXTRATO CONTRATUAL Processo : 00072-00000404/ ...
# 3      EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 4      EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
#                              ...
# 303    EXTRATO DO CONTRATO PARA AQUISIÇÃO DE BENS Nº ...
# 304    EXTRATO DO CONTRATO DE EXECUÇÃO DE OBRAS PARA ...
# 305    EXTRATO DO CONTRATO Nº 45.926/2022 Processo : ...
# 306    EXTRATO DO CONTRATO Nº 45832/2022 Processo : 0...
# 307    EXTRATO DO CONTRATO Nº 45927/2022 Processo : 0...
# Name: Texto, Length: 308, dtype: object

# %%
len(df_sk)
# Out:
# 308

# %%
# CODIGO DE APLICACAO DA SUPERVISAO FRACA
import dodfSkweak_v1_2
skw = dodfSkweak_v1_2.SkweakContratos(df_sk)
skw.apply_label_functions()
skw.train_HMM_Dodf()
#data_label=skw.get_hmm_dataframe()
# Out:
# Starting iteration 1
# Finished E-step with 308 documents
# Starting iteration 2
#          1      -16392.3927             +nan
# Finished E-step with 308 documents
# Starting iteration 3
#          2      -15982.8106        +409.5821
# Finished E-step with 308 documents
# Starting iteration 4
#          3      -15968.5001         +14.3105
# Finished E-step with 308 documents
#          4      -15964.2510          +4.2491
# Write to ./data/reuters_small.spacy...done

# %%
# converting to CSV file
#data_label.to_csv("./CSVs/base_rotulada_supervisao_fraca.csv")

# %%
corpus = skw.get_IOB()

# %%
len(corpus)
# Out:
# 308

# %%
termos_skweak = []
debug=set()
labels_skweak = []
for ato in corpus:
    x = []
    y = []
    for termo in ato:
        termo_label = termo.split()
        x.append(termo_label[0])
        y.append(termo_label[1])
        debug.add(termo_label[1])
    termos_skweak.append(x)
    labels_skweak.append(y)

# %%
debug
# Out:
# {'B-data_assinatura_contrato',
#  'B-natureza_despesa',
#  'B-nota_empenho',
#  'B-numero_contrato',
#  'B-processo_gdf',
#  'B-programa_trabalho',
#  'B-unidade_orcamentaria',
#  'B-valor_contrato',
#  'I-data_assinatura_contrato',
#  'I-natureza_despesa',
#  'I-nota_empenho',
#  'I-numero_contrato',
#  'I-processo_gdf',
#  'I-programa_trabalho',
#  'I-unidade_orcamentaria',
#  'O'}

# %%
len(termos_skweak)
# Out:
# 308

# %%
list_termos_skweak = []
for i in termos_skweak:
   if not isinstance(i, list):
      list_termos_skweak .append(i)
   else:
      for j in i:
       list_termos_skweak .append(j)

len(list_termos_skweak )
# Out:
# 72026

# %%
list_termos_skweak
# Out:
# ['EXTRATO',
#  'DO',
#  'CONTRATO',
#  'DE',
#  'AQUISIÇÃO',
#  'DE',
#  'PRODUTOS',
#  'DA',
#  'AGRICULTURA',
#  'FAMILIAR',
#  'Nº',
#  '15/2021',
#  'Processo',
#  ':',
#  '00070-00002253/',
#  '2021-08',
#  '.',
#  'Partes',
#  ':',
#  'SEAGRI',
#  '/',
#  'DF',
#  'e',
#  'COOPERATIVA',
#  'DE',
#  'SERVIÇOS',
#  'AMBIENTAIS',
#  ',',
#  'AGRICULTURA',
#  'FAMILIAR',
#  ',',
#  'SOCIEDADE',
#  ',',
#  'CULTURA',
#  'E',
#  'SAÚDE',
#  '-',
#  'COOPERBRASILIA',
#  '.',
#  'Objeto',
#  ':',
#  'O',
#  'presente',
#  'contrato',
#  'tem',
#  'por',
#  'objeto',
#  'aquisição',
#  ',',
#  'por',
#  'dispensa',
#  'de',
#  'licitação',
#  ',',
#  'de',
#  '2.822',
#  '(',
#  'dois',
#  'mil',
#  'oitocentos',
#  'e',
#  'vinte',
#  'e',
#  'dois',
#  ')',
#  'cestas',
#  'de',
#  'alimentos',
#  ',',
#  'compostas',
#  'por',
#  'frutas',
#  ',',
#  'verduras',
#  'e',
#  'legumes',
#  'produzidos',
#  'por',
#  'agricultores',
#  'familiares',
#  'rurais',
#  'e',
#  'urbanos',
#  'e',
#  'pelos',
#  'demais',
#  'beneficiários',
#  'e',
#  'organizações',
#  'que',
#  'se',
#  'enquadrem',
#  'nas',
#  'disposições',
#  'da',
#  'Lei',
#  'Federal',
#  'nº',
#  '11.326',
#  ',',
#  'de',
#  '24',
#  'de',
#  'julho',
#  'de',
#  '2006',
#  ',',
#  'para',
#  'atender',
#  'a',
#  'demanda',
#  'da',
#  'CONTRATANTE',
#  ',',
#  'conforme',
#  'condições',
#  'definidas',
#  'no',
#  'Chamamento',
#  'Público',
#  'nº',
#  '01/2021',
#  'e',
#  'seus',
#  'anexos',
#  ',',
#  'os',
#  'quais',
#  'ficam',
#  'fazendo',
#  'parte',
#  'integrante',
#  'do',
#  'presente',
#  'contrato',
#  ',',
#  'independentemente',
#  'de',
#  'anexação',
#  'ou',
#  'transcrição',
#  '.',
#  'Valor',
#  ':',
#  'O',
#  'valor',
#  'total',
#  'do',
#  'Contrato',
#  'é',
#  'de',
#  'R$',
#  '89.316,30',
#  '(',
#  'oitenta',
#  'e',
#  'nove',
#  'mil',
#  'trezentos',
#  'e',
#  'dezesseis',
#  'reais',
#  'e',
#  'trinta',
#  'centavos',
#  ')',
#  '.',
#  'O',
#  'empenho',
#  'é',
#  'de',
#  'R$',
#  '89.316,30',
#  '(',
#  'oitenta',
#  'e',
#  'nove',
#  'mil',
#  'trezentos',
#  'e',
#  'dezesseis',
#  'reais',
#  'e',
#  'trinta',
#  'centavos',
#  ')',
#  ',',
#  'conforme',
#  'Nota',
#  'de',
#  'Empenho',
#  'nº',
#  '2021NE00235',
#  'emitida',
#  'em',
#  '18/05/2021',
#  ',',
#  'sob',
#  'o',
#  'evento',
#  'Nº',
#  '400091',
#  ',',
#  'na',
#  'modalidade',
#  'global',
#  ',',
#  'Unidade',
#  'Orçamentária',
#  ':',
#  '14101',
#  ',',
#  'Programa',
#  'de',
#  'Trabalho',
#  ':',
#  '20306620141150002',
#  ',',
#  'Natureza',
#  'da',
#  'Despesa',
#  '339032',
#  ',',
#  'Fonte',
#  'de',
#  'Recurso',
#  ':',
#  '100',
#  '.',
#  'Prazo',
#  'de',
#  'Vigência',
#  ':',
#  'O',
#  'contrato',
#  'terá',
#  'vigência',
#  'desde',
#  'a',
#  'sua',
#  'assinatura',
#  'por',
#  'até',
#  '12',
#  'meses',
#  '.',
#  'Data',
#  'de',
#  'assinatura',
#  ':',
#  '27/05/2021',
#  '.',
#  'Signatários',
#  ':',
#  'Pela',
#  'SEAGRI',
#  '/',
#  'DF',
#  ':',
#  'CANDIDO',
#  'TELES',
#  'DE',
#  'ARAUJO',
#  ',',
#  'na',
#  'qualidade',
#  'de',
#  'Secretário',
#  'de',
#  'Estado',
#  '.',
#  'Pela',
#  'Contratada',
#  ':',
#  'JOSÉ',
#  'VANTUIL',
#  'GONÇALVES',
#  'DA',
#  'CRUZ',
#  ',',
#  'na',
#  'qualidade',
#  'de',
#  'Presidente',
#  '.',
#  'CENTRAIS',
#  'DE',
#  'ABASTECIMENTO',
#  'DO',
#  'DISTRITO',
#  'FEDERAL',
#  'EXTRATO',
#  'DE',
#  'CONTRATO',
#  'Espécie',
#  ':',
#  'Contrato',
#  'de',
#  'Prestação',
#  'de',
#  'Serviços',
#  'nº',
#  '08/2021',
#  'que',
#  'entre',
#  'si',
#  'celebram',
#  'as',
#  'Centrais',
#  'de',
#  'Abastecimento',
#  'do',
#  'Distrito',
#  'Federal',
#  'S.A.',
#  'e',
#  'a',
#  'Porto',
#  'Seguro',
#  'Companhia',
#  'de',
#  'Seguro',
#  'Gerais',
#  '.',
#  'Objeto',
#  ':',
#  'Contratação',
#  'de',
#  'empresa',
#  'especializada',
#  'em',
#  'serviços',
#  'de',
#  'seguro',
#  'automotivo',
#  'para',
#  'a',
#  'frota',
#  'de',
#  'veículos',
#  'pertencente',
#  'da',
#  'EMATER',
#  'cedidos',
#  'à',
#  'CEASA',
#  '/',
#  'DF',
#  '.',
#  'Processo',
#  '0007100001538/',
#  '2019-71',
#  '.',
#  'Data',
#  'de',
#  'Assinatura',
#  ':',
#  '17',
#  'de',
#  'maio',
#  'de',
#  '2021',
#  '.',
#  'Prazo',
#  'de',
#  'vigência',
#  ':',
#  'A',
#  'cobertura',
#  'da',
#  'apólice',
#  'de',
#  'seguro',
#  'abrangerá',
#  'o',
#  'período',
#  'de',
#  'trezentos',
#  'e',
#  'sessenta',
#  'e',
#  'cinco',
#  'dias',
#  'corridos',
#  ',',
#  'a',
#  'contar',
#  'da',
#  'assinatura',
#  'do',
#  'contrato',
#  '.',
#  'Valor',
#  ':',
#  'R$',
#  '2.999,71',
#  '(',
#  'dois',
#  'mil',
#  'novecentos',
#  'e',
#  'noventa',
#  'e',
#  'nove',
#  'reais',
#  'e',
#  'setenta',
#  'e',
#  'um',
#  'centavos',
#  ')',
#  '.',
#  'Assinaturas',
#  ':',
#  'pela',
#  'CEASA',
#  '/',
#  'DF',
#  ':',
#  'Sebastião',
#  'Marcio',
#  'Lopes',
#  'de',
#  'Andrade',
#  ';',
#  'pela',
#  'contratada',
#  ':',
#  'Neide',
#  'De',
#  'Oliveira',
#  'Souza',
#  'e',
#  'Roberto',
#  'de',
#  'Souza',
#  'Dias',
#  '(',
#  'Representantes',
#  'Legais',
#  ')',
#  '.',
#  'EXTRATO',
#  'CONTRATUAL',
#  'Processo',
#  ':',
#  '00072-00000404/',
#  '2021-29',
#  '.',
#  'Instrumento',
#  ':',
#  'Contrato',
#  'nº',
#  '09/',
#  '2021-GCONV',
#  'Contratação',
#  'de',
#  'Empresa',
#  'Especializada',
#  'para',
#  'Conservação',
#  '/',
#  'Manutenção',
#  'dos',
#  'Banheiros',
#  'da',
#  'EMATER',
#  '/',
#  'DF',
#  'Sede',
#  '.',
#  'Partes',
#  ':',
#  'EMPRESA',
#  'DE',
#  'ASSISTÊNCIA',
#  'TÉCNICA',
#  'E',
#  'EXTENSÃO',
#  'RURAL',
#  'DO',
#  'DISTRITO',
#  'FEDERAL',
#  '-',
#  'EMATER',
#  '/',
#  'DF',
#  'e',
#  'a',
#  'Empresa',
#  'BERNARDO',
#  'DE',
#  'SÁ',
#  'CONSTRUTORA',
#  ',',
#  'INCORPORADORA',
#  'E',
#  'EMPREENDIMENTOS',
#  'IMOBILIÁRIOS',
#  'EIRELI',
#  '.',
#  'Objeto',
#  ':',
#  'Contratação',
#  'de',
#  'empresa',
#  'especializada',
#  'para',
#  'conservação',
#  '/',
#  'manutenção',
#  'dos',
#  'banheiros',
#  'da',
#  'EMATER',
#  'sede',
#  ',',
#  'composto',
#  'por',
#  'serviços',
#  'essenciais',
#  'para',
#  'manutenção',
#  '.',
#  'Os',
#  'banheiros',
#  'estão',
#  'localizados',
#  'na',
#  'STN',
#  '-',
#  'Asa',
#  'Norte',
#  ',',
#  'Brasília',
#  '/',
#  'DF',
#  ',',
#  '70770-915',
#  '.',
#  'O',
#  'Serviço',
#  'terá',
#  'uma',
#  'área',
#  '30,00',
#  'm²',
#  '.',
#  'Dotação',
#  'Orçamentária',
#  ':',
#  'Unidade',
#  'Orçamentária',
#  ':',
#  '14203',
#  ';',
#  'Programa',
#  'de',
#  'Trabalho',
#  ':',
#  '20.122.8201.2396.5409',
#  '(',
#  'EPI',
#  ')',
#  ';',
#  'Projeto',
#  '/',
#  'Atividade',
#  '/',
#  'Denominação',
#  ':',
#  'CONSERVAÇÃO',
#  'DAS',
#  'ESTRUTURAS',
#  'FÍSICAS',
#  'DA',
#  'SEDE',
#  'DA',
#  'EMATER',
#  ';',
#  'Natureza',
#  'da',
#  'Despesa',
#  ':',
#  '33.90.39',
#  ';',
#  'Fonte',
#  'de',
#  'Recurso',
#  ':',
#  '100',
#  ';',
#  'Valor',
#  'Total',
#  ':',
#  'R$',
#  '44.081,61',
#  '(',
#  'quarenta',
#  'e',
#  'quatro',
#  'mil',
#  'e',
#  'oitenta',
#  'e',
#  'um',
#  'reais',
#  'e',
#  'sessenta',
#  'e',
#  'um',
#  'centavos',
#  ')',
#  '.',
#  'Fundamento',
#  'Legal',
#  ':',
#  'A',
#  'presente',
#  'contratação',
#  'será',
#  'feita',
#  'por',
#  'meio',
#  'da',
#  'modalidade',
#  'direta',
#  ',',
#  'por',
#  'dispensa',
#  'de',
#  'licitação',
#  ',',
#  'por',
#  'força',
#  'do',
#  'inciso',
#  'II',
#  'do',
#  'art.',
#  '06',
#  'do',
#  'Regulamento',
#  'de',
#  'Licitações',
#  'e',
#  'Contratos',
#  'da',
#  'EMATER',
#  '/',
#  'DF',
#  ',',
#  'combinado',
#  'com',
#  'a',
#  'Lei',
#  'nº',
#  '13.303',
#  ',',
#  'de',
#  '30',
#  'de',
#  'junho',
#  'de',
#  '2016',
#  ',',
#  'que',
#  'dispõe',
#  'sobre',
#  'o',
#  'estatuto',
#  'jurídico',
#  'das',
#  'empresas',
#  'públicas',
#  ',',
#  'bem',
#  'como',
#  'o',
#  'Termo',
#  'de',
#  'Referência',
#  'e',
#  'da',
#  'proposta',
#  'comercial',
#  '.',
#  'Assinatura',
#  ':',
#  '26/05/2021',
#  '.',
#  'Vigência',
#  ':',
#  '12',
#  '(',
#  'doze',
#  ')',
#  'meses',
#  'a',
#  'contar',
#  'da',
#  'assinatura',
#  '.',
#  'Signatários',
#  ':',
#  'P',
#  '/',
#  'EMATER-DF',
#  ':',
#  'Denise',
#  'Andrade',
#  'da',
#  'Fonseca',
#  ',',
#  'Presidente',
#  '.',
#  'P',
#  '/',
#  'Contratada',
#  ':',
#  'Bernardo',
#  'José',
#  'de',
#  'Sá',
#  'Filho',
#  '.',
#  'EXTRATO',
#  'DO',
#  'CONTRATO',
#  'DE',
#  'PRESTAÇÃO',
#  'DE',
#  'SERVIÇOS',
#  'Nº',
#  '07/2021',
#  'Processo',
#  ':',
#  '00020-00010200/',
#  '2019-14',
#  '.',
#  'PARTES',
#  ':',
#  'PROCURADORIA-GERAL',
#  'DO',
#  'DISTRITO',
#  'FEDERAL',
#  'E',
#  'J3',
#  'TECNOLOGIA',
#  'E',
#  'INFRAESTRUTURA',
#  'DE',
#  'REDES',
#  'EIRELI',
#  '.',
#  '(',
#  'CNPJ',
#  'nº',
#  '17.886.222/',
#  '0001-56',
#  ')',
#  '.',
#  'Edital',
#  'de',
#  'Pregão',
#  'Eletrônico',
#  'nº',
#  '07/',
#  '2021-PGDF',
#  '.',
#  'OBJETO',
#  ':',
#  'Contratação',
#  'de',
#  'empresa',
#  'especializada',
#  'em',
#  'sistema',
#  'de',
#  'detecção',
#  'e',
#  'alarme',
#  'contra',
#  'incêndio',
#  ',',
#  'para',
#  'prestação',
#  'de',
#  'serviços',
#  'técnicos',
#  'e',
#  'profissionais',
#  ',',
#  'incluindo',
#  'o',
#  'fornecimento',
#  'dos',
#  'materiais',
#  'necessários',
#  ',',
#  'visando',
#  'à',
#  'Recuperação',
#  'do',
#  'Sistema',
#  'de',
#  'Detecção',
#  'e',
#  'Alarme',
#  'Contra',
#  'Incêndio',
#  ',',
#  'existente',
#  'no',
#  'prédio',
#  'da',
#  'Procuradoria-Geral',
#  'do',
#  'Distrito',
#  'Federal',
#  '.',
#  'ASSINATURA',
#  ':',
#  '25/05/2021',
#  '.',
#  'VIGÊNCIA',
#  ':',
#  'O',
#  'contrato',
#  'terá',
#  'vigência',
#  'de',
#  '90',
#  '(',
#  'noventa',
#  ')',
#  'dias',
#  'a',
#  'contar',
#  'de',
#  'sua',
#  'assinatura',
#  ',',
#  'com',
#  'eficácia',
#  'a',
#  'partir',
#  'de',
#  'sua',
#  'publicação',
#  ',',
#  'compreendendo',
#  'os',
#  'prazos',
#  'de',
#  'entrega',
#  ',',
#  'dos',
#  'procedimentos',
#  'de',
#  'recebimento',
#  'fixados',
#  'e',
#  'pagamento',
#  '.',
#  'NOTA',
#  'DE',
#  'EMPENHO',
#  ':',
#  'Os',
#  'empenho',
#  'iniciais',
#  'são',
#  'de',
#  'R$',
#  '15.548,74',
#  '(',
#  'quinze',
#  'mil',
#  'quinhentos',
#  'e',
#  'quarenta',
#  'e',
#  'oito',
#  'reais',
#  'e',
#  'setenta',
#  'e',
#  'quatro',
#  'centavos',
#  ')',
#  ',',
#  'conforme',
#  'Nota',
#  'de',
#  'Empenho',
#  'nº',
#  '2021NE00143',
#  ';',
#  'R$',
#  '878,78',
#  '(',
#  'oitocentos',
#  'e',
#  'setenta',
#  'e',
#  'oito',
#  'reais',
#  'e',
#  'setenta',
#  'e',
#  'oito',
#  'centavos',
#  ')',
#  ',',
#  'conforme',
#  'Nota',
#  'de',
#  'Empenho',
#  'nº',
#  '2021NE00144',
#  ';',
#  'R$',
#  '930,00',
#  '(',
#  'novecentos',
#  'e',
#  'trinta',
#  'reais',
#  ')',
#  ',',
#  'conforme',
#  'Nota',
#  'de',
#  'Empenho',
#  'nº',
#  '2021NE00145',
#  ';',
#  'R$',
#  '37.482,38',
#  '(',
#  'trinta',
#  'e',
#  'sete',
#  'mil',
#  'quatrocentos',
#  'e',
#  'oitenta',
#  'e',
#  'dois',
#  'reais',
#  'e',
#  'trinta',
#  'e',
#  'oito',
#  'centavos',
#  ')',
#  ',',
#  'conforme',
#  'Nota',
#  'de',
#  'Empenho',
#  'nº',
#  '2021NE00146',
#  'e',
#  'R$',
#  '34.450,00',
#  '(',
#  'trinta',
#  'e',
#  'quatro',
#  'mil',
#  'quatrocentos',
#  'e',
#  'cinquenta',
#  'reais',
#  ')',
#  ',',
#  'conforme',
#  'Nota',
#  'de',
#  'Empenho',
#  'nº',
#  '2021NE00147',
#  ',',
#  'emitidas',
#  'em',
#  '10/05/2021',
#  ',',
#  'sob',
#  'o',
#  'evento',
#  'nº',
#  '400091',
#  ',',
#  'na',
#  'modalidade',
#  'Ordinário',
#  '.',
#  'COBERTURA',
#  ...]

# %%
#apenas para conferencia
df = pd.DataFrame(list_termos_skweak, columns=['Texto']) 
df.to_csv('/home/lucelia_vieira/Experimentos/ner/CSVs/list_termos_skweak.csv')

# %%
list_labels_skweak = []
for i in labels_skweak:
   if not isinstance(i, list):
      list_labels_skweak.append(i)
   else:
      for j in i:
        list_labels_skweak.append(j)

len(list_labels_skweak)
# Out:
# 72026

# %% [markdown]
# ## Preparando o test da base ouro para fazer a validação

# %%
#Carrega o dataset de teste da base ouro para aplicar a validação
df_gold_labels= pd.read_csv('./CSVs/Extrato_Contrato_Split_4_y_test.csv', dtype=str)
df_gold_labels
# Out:
#       Unnamed: 0 Texto
# 0              0     O
# 1              1     O
# 2              2     O
# 3              3     O
# 4              4     O
# ...          ...   ...
# 71877      71877     O
# 71878      71878     O
# 71879      71879     O
# 71880      71880     O
# 71881      71881     O
#
# [71882 rows x 2 columns]

# %%
#criando novo dataframe somente com os labels
df_gold_label = df_gold_labels['Texto'].reset_index(drop=True)
df_gold_label
# Out:
# 0        O
# 1        O
# 2        O
# 3        O
# 4        O
#         ..
# 71877    O
# 71878    O
# 71879    O
# 71880    O
# 71881    O
# Name: Texto, Length: 71882, dtype: object

# %%
len(df_gold_labels)
# Out:
# 71882

# %%
#Carrega o dataset de teste da base ouro para aplicar a validação
df_gold_ato= pd.read_csv('./CSVs/Extrato_Contrato_Split_4_x_test.csv', dtype=str)
df_gold_ato
# Out:
#       Unnamed: 0      Texto
# 0              0    EXTRATO
# 1              1         DO
# 2              2   CONTRATO
# 3              3         DE
# 4              4  AQUISIÇÃO
# ...          ...        ...
# 71877      71877         de
# 71878      71878    Atacado
# 71879      71879          e
# 71880      71880    Governo
# 71881      71881          .
#
# [71882 rows x 2 columns]

# %%
#criando novo dataframe somente com os labels
df_gold_ato = df_gold_ato['Texto'].reset_index(drop=True)
df_gold_ato
# Out:
# 0          EXTRATO
# 1               DO
# 2         CONTRATO
# 3               DE
# 4        AQUISIÇÃO
#            ...
# 71877           de
# 71878      Atacado
# 71879            e
# 71880      Governo
# 71881            .
# Name: Texto, Length: 71882, dtype: object

# %%
resultados = []
for sk_ato , gold_ato in zip(list_termos_skweak, df_gold_ato):
    tupla=(sk_ato , gold_ato) 
    resultados.append(tupla)
#print(resultados)
for item in resultados:
    print(item)
# Out:
# ('EXTRATO', 'EXTRATO')
# ('DO', 'DO')
# ('CONTRATO', 'CONTRATO')
# ('DE', 'DE')
# ('AQUISIÇÃO', 'AQUISIÇÃO')
# ('DE', 'DE')
# ('PRODUTOS', 'PRODUTOS')
# ('DA', 'DA')
# ('AGRICULTURA', 'AGRICULTURA')
# ('FAMILIAR', 'FAMILIAR')
# ('Nº', 'Nº')
# ('15/2021', '15/2021')
# ('Processo', 'Processo')
# (':', ':')
# ('00070-00002253/', '00070-00002253/')
# ('2021-08', '2021-08')
# ('.', '.')
# ('Partes', 'Partes')
# (':', ':')
# ('SEAGRI', 'SEAGRI')
# ('/', '/')
# ('DF', 'DF')
# ('e', 'e')
# ('COOPERATIVA', 'COOPERATIVA')
# ('DE', 'DE')
# ('SERVIÇOS', 'SERVIÇOS')
# ('AMBIENTAIS', 'AMBIENTAIS')
# (',', ',')
# ('AGRICULTURA', 'AGRICULTURA')
# ('FAMILIAR', 'FAMILIAR')
# (',', ',')
# ('SOCIEDADE', 'SOCIEDADE')
# (',', ',')
# ('CULTURA', 'CULTURA')
# ('E', 'E')
# ('SAÚDE', 'SAÚDE')
# ('-', '-')
# ('COOPERBRASILIA', 'COOPERBRASILIA')
# ('.', '.')
# ('Objeto', 'Objeto')
# (':', ':')
# ('O', 'O')
# ('presente', 'presente')
# ('contrato', 'contrato')
# ('tem', 'tem')
# ('por', 'por')
# ('objeto', 'objeto')
# ('aquisição', 'aquisição')
# (',', ',')
# ('por', 'por')
# ('dispensa', 'dispensa')
# ('de', 'de')
# ('licitação', 'licitação')
# (',', ',')
# ('de', 'de')
# ('2.822', '2.822')
# ('(', '(')
# ('dois', 'dois')
# ('mil', 'mil')
# ('oitocentos', 'oitocentos')
# ('e', 'e')
# ('vinte', 'vinte')
# ('e', 'e')
# ('dois', 'dois')
# (')', ')')
# ('cestas', 'cestas')
# ('de', 'de')
# ('alimentos', 'alimentos')
# (',', ',')
# ('compostas', 'compostas')
# ('por', 'por')
# ('frutas', 'frutas')
# (',', ',')
# ('verduras', 'verduras')
# ('e', 'e')
# ('legumes', 'legumes')
# ('produzidos', 'produzidos')
# ('por', 'por')
# ('agricultores', 'agricultores')
# ('familiares', 'familiares')
# ('rurais', 'rurais')
# ('e', 'e')
# ('urbanos', 'urbanos')
# ('e', 'e')
# ('pelos', 'pelos')
# ('demais', 'demais')
# ('beneficiários', 'beneficiários')
# ('e', 'e')
# ('organizações', 'organizações')
# ('que', 'que')
# ('se', 'se')
# ('enquadrem', 'enquadrem')
# ('nas', 'nas')
# ('disposições', 'disposições')
# ('da', 'da')
# ('Lei', 'Lei')
# ('Federal', 'Federal')
# ('nº', 'nº')
# ('11.326', '11.326')
# (',', ',')
# ('de', 'de')
# ('24', '24')
# ('de', 'de')
# ('julho', 'julho')
# ('de', 'de')
# ('2006', '2006')
# (',', ',')
# ('para', 'para')
# ('atender', 'atender')
# ('a', 'a')
# ('demanda', 'demanda')
# ('da', 'da')
# ('CONTRATANTE', 'CONTRATANTE')
# (',', ',')
# ('conforme', 'conforme')
# ('condições', 'condições')
# ('definidas', 'definidas')
# ('no', 'no')
# ('Chamamento', 'Chamamento')
# ('Público', 'Público')
# ('nº', 'nº')
# ('01/2021', '01/2021')
# ('e', 'e')
# ('seus', 'seus')
# ('anexos', 'anexos')
# (',', ',')
# ('os', 'os')
# ('quais', 'quais')
# ('ficam', 'ficam')
# ('fazendo', 'fazendo')
# ('parte', 'parte')
# ('integrante', 'integrante')
# ('do', 'do')
# ('presente', 'presente')
# ('contrato', 'contrato')
# (',', ',')
# ('independentemente', 'independentemente')
# ('de', 'de')
# ('anexação', 'anexação')
# ('ou', 'ou')
# ('transcrição', 'transcrição')
# ('.', '.')
# ('Valor', 'Valor')
# (':', ':')
# ('O', 'O')
# ('valor', 'valor')
# ('total', 'total')
# ('do', 'do')
# ('Contrato', 'Contrato')
# ('é', 'é')
# ('de', 'de')
# ('R$', 'R$')
# ('89.316,30', '89.316,30')
# ('(', '(')
# ('oitenta', 'oitenta')
# ('e', 'e')
# ('nove', 'nove')
# ('mil', 'mil')
# ('trezentos', 'trezentos')
# ('e', 'e')
# ('dezesseis', 'dezesseis')
# ('reais', 'reais')
# ('e', 'e')
# ('trinta', 'trinta')
# ('centavos', 'centavos')
# (')', ')')
# ('.', '.')
# ('O', 'O')
# ('empenho', 'empenho')
# ('é', 'é')
# ('de', 'de')
# ('R$', 'R$')
# ('89.316,30', '89.316,30')
# ('(', '(')
# ('oitenta', 'oitenta')
# ('e', 'e')
# ('nove', 'nove')
# ('mil', 'mil')
# ('trezentos', 'trezentos')
# ('e', 'e')
# ('dezesseis', 'dezesseis')
# ('reais', 'reais')
# ('e', 'e')
# ('trinta', 'trinta')
# ('centavos', 'centavos')
# (')', ')')
# (',', ',')
# ('conforme', 'conforme')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('nº', 'nº')
# ('2021NE00235', '2021NE00235')
# ('emitida', 'emitida')
# ('em', 'em')
# ('18/05/2021', '18/05/2021')
# (',', ',')
# ('sob', 'sob')
# ('o', 'o')
# ('evento', 'evento')
# ('Nº', 'Nº')
# ('400091', '400091')
# (',', ',')
# ('na', 'na')
# ('modalidade', 'modalidade')
# ('global', 'global')
# (',', ',')
# ('Unidade', 'Unidade')
# ('Orçamentária', 'Orçamentária')
# (':', ':')
# ('14101', '14101')
# (',', ',')
# ('Programa', 'Programa')
# ('de', 'de')
# ('Trabalho', 'Trabalho')
# (':', ':')
# ('20306620141150002', '20306620141150002')
# (',', ',')
# ('Natureza', 'Natureza')
# ('da', 'da')
# ('Despesa', 'Despesa')
# ('339032', '339032')
# (',', ',')
# ('Fonte', 'Fonte')
# ('de', 'de')
# ('Recurso', 'Recurso')
# (':', ':')
# ('100', '100')
# ('.', '.')
# ('Prazo', 'Prazo')
# ('de', 'de')
# ('Vigência', 'Vigência')
# (':', ':')
# ('O', 'O')
# ('contrato', 'contrato')
# ('terá', 'terá')
# ('vigência', 'vigência')
# ('desde', 'desde')
# ('a', 'a')
# ('sua', 'sua')
# ('assinatura', 'assinatura')
# ('por', 'por')
# ('até', 'até')
# ('12', '12')
# ('meses', 'meses')
# ('.', '.')
# ('Data', 'Data')
# ('de', 'de')
# ('assinatura', 'assinatura')
# (':', ':')
# ('27/05/2021', '27/05/2021')
# ('.', '.')
# ('Signatários', 'Signatários')
# (':', ':')
# ('Pela', 'Pela')
# ('SEAGRI', 'SEAGRI')
# ('/', '/')
# ('DF', 'DF')
# (':', ':')
# ('CANDIDO', 'CANDIDO')
# ('TELES', 'TELES')
# ('DE', 'DE')
# ('ARAUJO', 'ARAUJO')
# (',', ',')
# ('na', 'na')
# ('qualidade', 'qualidade')
# ('de', 'de')
# ('Secretário', 'Secretário')
# ('de', 'de')
# ('Estado', 'Estado')
# ('.', '.')
# ('Pela', 'Pela')
# ('Contratada', 'Contratada')
# (':', ':')
# ('JOSÉ', 'JOSÉ')
# ('VANTUIL', 'VANTUIL')
# ('GONÇALVES', 'GONÇALVES')
# ('DA', 'DA')
# ('CRUZ', 'CRUZ')
# (',', ',')
# ('na', 'na')
# ('qualidade', 'qualidade')
# ('de', 'de')
# ('Presidente', 'Presidente')
# ('.', '.')
# ('CENTRAIS', 'CENTRAIS')
# ('DE', 'DE')
# ('ABASTECIMENTO', 'ABASTECIMENTO')
# ('DO', 'DO')
# ('DISTRITO', 'DISTRITO')
# ('FEDERAL', 'FEDERAL')
# ('EXTRATO', 'EXTRATO')
# ('DE', 'DE')
# ('CONTRATO', 'CONTRATO')
# ('Espécie', 'Espécie')
# (':', ':')
# ('Contrato', 'Contrato')
# ('de', 'de')
# ('Prestação', 'Prestação')
# ('de', 'de')
# ('Serviços', 'Serviços')
# ('nº', 'nº')
# ('08/2021', '08/2021')
# ('que', 'que')
# ('entre', 'entre')
# ('si', 'si')
# ('celebram', 'celebram')
# ('as', 'as')
# ('Centrais', 'Centrais')
# ('de', 'de')
# ('Abastecimento', 'Abastecimento')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('S.A.', 'S.A.')
# ('e', 'e')
# ('a', 'a')
# ('Porto', 'Porto')
# ('Seguro', 'Seguro')
# ('Companhia', 'Companhia')
# ('de', 'de')
# ('Seguro', 'Seguro')
# ('Gerais', 'Gerais')
# ('.', '.')
# ('Objeto', 'Objeto')
# (':', ':')
# ('Contratação', 'Contratação')
# ('de', 'de')
# ('empresa', 'empresa')
# ('especializada', 'especializada')
# ('em', 'em')
# ('serviços', 'serviços')
# ('de', 'de')
# ('seguro', 'seguro')
# ('automotivo', 'automotivo')
# ('para', 'para')
# ('a', 'a')
# ('frota', 'frota')
# ('de', 'de')
# ('veículos', 'veículos')
# ('pertencente', 'pertencente')
# ('da', 'da')
# ('EMATER', 'EMATER')
# ('cedidos', 'cedidos')
# ('à', 'à')
# ('CEASA', 'CEASA')
# ('/', '/')
# ('DF', 'DF')
# ('.', '.')
# ('Processo', 'Processo')
# ('0007100001538/', '0007100001538/')
# ('2019-71', '2019-71')
# ('.', '.')
# ('Data', 'Data')
# ('de', 'de')
# ('Assinatura', 'Assinatura')
# (':', ':')
# ('17', '17')
# ('de', 'de')
# ('maio', 'maio')
# ('de', 'de')
# ('2021', '2021')
# ('.', '.')
# ('Prazo', 'Prazo')
# ('de', 'de')
# ('vigência', 'vigência')
# (':', ':')
# ('A', 'A')
# ('cobertura', 'cobertura')
# ('da', 'da')
# ('apólice', 'apólice')
# ('de', 'de')
# ('seguro', 'seguro')
# ('abrangerá', 'abrangerá')
# ('o', 'o')
# ('período', 'período')
# ('de', 'de')
# ('trezentos', 'trezentos')
# ('e', 'e')
# ('sessenta', 'sessenta')
# ('e', 'e')
# ('cinco', 'cinco')
# ('dias', 'dias')
# ('corridos', 'corridos')
# (',', ',')
# ('a', 'a')
# ('contar', 'contar')
# ('da', 'da')
# ('assinatura', 'assinatura')
# ('do', 'do')
# ('contrato', 'contrato')
# ('.', '.')
# ('Valor', 'Valor')
# (':', ':')
# ('R$', 'R$')
# ('2.999,71', '2.999,71')
# ('(', '(')
# ('dois', 'dois')
# ('mil', 'mil')
# ('novecentos', 'novecentos')
# ('e', 'e')
# ('noventa', 'noventa')
# ('e', 'e')
# ('nove', 'nove')
# ('reais', 'reais')
# ('e', 'e')
# ('setenta', 'setenta')
# ('e', 'e')
# ('um', 'um')
# ('centavos', 'centavos')
# (')', ')')
# ('.', '.')
# ('Assinaturas', 'Assinaturas')
# (':', ':')
# ('pela', 'pela')
# ('CEASA', 'CEASA')
# ('/', '/')
# ('DF', 'DF')
# (':', ':')
# ('Sebastião', 'Sebastião')
# ('Marcio', 'Marcio')
# ('Lopes', 'Lopes')
# ('de', 'de')
# ('Andrade', 'Andrade')
# (';', ';')
# ('pela', 'pela')
# ('contratada', 'contratada')
# (':', ':')
# ('Neide', 'Neide')
# ('De', 'De')
# ('Oliveira', 'Oliveira')
# ('Souza', 'Souza')
# ('e', 'e')
# ('Roberto', 'Roberto')
# ('de', 'de')
# ('Souza', 'Souza')
# ('Dias', 'Dias')
# ('(', '(')
# ('Representantes', 'Representantes')
# ('Legais', 'Legais')
# (')', ')')
# ('.', '.')
# ('EXTRATO', 'EXTRATO')
# ('CONTRATUAL', 'CONTRATUAL')
# ('Processo', 'Processo')
# (':', ':')
# ('00072-00000404/', '00072-00000404/')
# ('2021-29', '2021-29')
# ('.', '.')
# ('Instrumento', 'Instrumento')
# (':', ':')
# ('Contrato', 'Contrato')
# ('nº', 'nº')
# ('09/', '09/')
# ('2021-GCONV', '2021-GCONV')
# ('Contratação', 'Contratação')
# ('de', 'de')
# ('Empresa', 'Empresa')
# ('Especializada', 'Especializada')
# ('para', 'para')
# ('Conservação', 'Conservação')
# ('/', '/')
# ('Manutenção', 'Manutenção')
# ('dos', 'dos')
# ('Banheiros', 'Banheiros')
# ('da', 'da')
# ('EMATER', 'EMATER')
# ('/', '/')
# ('DF', 'DF')
# ('Sede', 'Sede')
# ('.', '.')
# ('Partes', 'Partes')
# (':', ':')
# ('EMPRESA', 'EMPRESA')
# ('DE', 'DE')
# ('ASSISTÊNCIA', 'ASSISTÊNCIA')
# ('TÉCNICA', 'TÉCNICA')
# ('E', 'E')
# ('EXTENSÃO', 'EXTENSÃO')
# ('RURAL', 'RURAL')
# ('DO', 'DO')
# ('DISTRITO', 'DISTRITO')
# ('FEDERAL', 'FEDERAL')
# ('-', '-')
# ('EMATER', 'EMATER')
# ('/', '/')
# ('DF', 'DF')
# ('e', 'e')
# ('a', 'a')
# ('Empresa', 'Empresa')
# ('BERNARDO', 'BERNARDO')
# ('DE', 'DE')
# ('SÁ', 'SÁ')
# ('CONSTRUTORA', 'CONSTRUTORA')
# (',', ',')
# ('INCORPORADORA', 'INCORPORADORA')
# ('E', 'E')
# ('EMPREENDIMENTOS', 'EMPREENDIMENTOS')
# ('IMOBILIÁRIOS', 'IMOBILIÁRIOS')
# ('EIRELI', 'EIRELI')
# ('.', '.')
# ('Objeto', 'Objeto')
# (':', ':')
# ('Contratação', 'Contratação')
# ('de', 'de')
# ('empresa', 'empresa')
# ('especializada', 'especializada')
# ('para', 'para')
# ('conservação', 'conservação')
# ('/', '/')
# ('manutenção', 'manutenção')
# ('dos', 'dos')
# ('banheiros', 'banheiros')
# ('da', 'da')
# ('EMATER', 'EMATER')
# ('sede', 'sede')
# (',', ',')
# ('composto', 'composto')
# ('por', 'por')
# ('serviços', 'serviços')
# ('essenciais', 'essenciais')
# ('para', 'para')
# ('manutenção', 'manutenção')
# ('.', '.')
# ('Os', 'Os')
# ('banheiros', 'banheiros')
# ('estão', 'estão')
# ('localizados', 'localizados')
# ('na', 'na')
# ('STN', 'STN')
# ('-', '-')
# ('Asa', 'Asa')
# ('Norte', 'Norte')
# (',', ',')
# ('Brasília', 'Brasília')
# ('/', '/')
# ('DF', 'DF')
# (',', ',')
# ('70770-915', '70770-915')
# ('.', '.')
# ('O', 'O')
# ('Serviço', 'Serviço')
# ('terá', 'terá')
# ('uma', 'uma')
# ('área', 'área')
# ('30,00', '30,00')
# ('m²', 'm²')
# ('.', '.')
# ('Dotação', 'Dotação')
# ('Orçamentária', 'Orçamentária')
# (':', ':')
# ('Unidade', 'Unidade')
# ('Orçamentária', 'Orçamentária')
# (':', ':')
# ('14203', '14203')
# (';', ';')
# ('Programa', 'Programa')
# ('de', 'de')
# ('Trabalho', 'Trabalho')
# (':', ':')
# ('20.122.8201.2396.5409', '20.122.8201.2396.5409')
# ('(', '(')
# ('EPI', 'EPI')
# (')', ')')
# (';', ';')
# ('Projeto', 'Projeto')
# ('/', '/')
# ('Atividade', 'Atividade')
# ('/', '/')
# ('Denominação', 'Denominação')
# (':', ':')
# ('CONSERVAÇÃO', 'CONSERVAÇÃO')
# ('DAS', 'DAS')
# ('ESTRUTURAS', 'ESTRUTURAS')
# ('FÍSICAS', 'FÍSICAS')
# ('DA', 'DA')
# ('SEDE', 'SEDE')
# ('DA', 'DA')
# ('EMATER', 'EMATER')
# (';', ';')
# ('Natureza', 'Natureza')
# ('da', 'da')
# ('Despesa', 'Despesa')
# (':', ':')
# ('33.90.39', '33.90.39')
# (';', ';')
# ('Fonte', 'Fonte')
# ('de', 'de')
# ('Recurso', 'Recurso')
# (':', ':')
# ('100', '100')
# (';', ';')
# ('Valor', 'Valor')
# ('Total', 'Total')
# (':', ':')
# ('R$', 'R$')
# ('44.081,61', '44.081,61')
# ('(', '(')
# ('quarenta', 'quarenta')
# ('e', 'e')
# ('quatro', 'quatro')
# ('mil', 'mil')
# ('e', 'e')
# ('oitenta', 'oitenta')
# ('e', 'e')
# ('um', 'um')
# ('reais', 'reais')
# ('e', 'e')
# ('sessenta', 'sessenta')
# ('e', 'e')
# ('um', 'um')
# ('centavos', 'centavos')
# (')', ')')
# ('.', '.')
# ('Fundamento', 'Fundamento')
# ('Legal', 'Legal')
# (':', ':')
# ('A', 'A')
# ('presente', 'presente')
# ('contratação', 'contratação')
# ('será', 'será')
# ('feita', 'feita')
# ('por', 'por')
# ('meio', 'meio')
# ('da', 'da')
# ('modalidade', 'modalidade')
# ('direta', 'direta')
# (',', ',')
# ('por', 'por')
# ('dispensa', 'dispensa')
# ('de', 'de')
# ('licitação', 'licitação')
# (',', ',')
# ('por', 'por')
# ('força', 'força')
# ('do', 'do')
# ('inciso', 'inciso')
# ('II', 'II')
# ('do', 'do')
# ('art.', 'art.')
# ('06', '06')
# ('do', 'do')
# ('Regulamento', 'Regulamento')
# ('de', 'de')
# ('Licitações', 'Licitações')
# ('e', 'e')
# ('Contratos', 'Contratos')
# ('da', 'da')
# ('EMATER', 'EMATER')
# ('/', '/')
# ('DF', 'DF')
# (',', ',')
# ('combinado', 'combinado')
# ('com', 'com')
# ('a', 'a')
# ('Lei', 'Lei')
# ('nº', 'nº')
# ('13.303', '13.303')
# (',', ',')
# ('de', 'de')
# ('30', '30')
# ('de', 'de')
# ('junho', 'junho')
# ('de', 'de')
# ('2016', '2016')
# (',', ',')
# ('que', 'que')
# ('dispõe', 'dispõe')
# ('sobre', 'sobre')
# ('o', 'o')
# ('estatuto', 'estatuto')
# ('jurídico', 'jurídico')
# ('das', 'das')
# ('empresas', 'empresas')
# ('públicas', 'públicas')
# (',', ',')
# ('bem', 'bem')
# ('como', 'como')
# ('o', 'o')
# ('Termo', 'Termo')
# ('de', 'de')
# ('Referência', 'Referência')
# ('e', 'e')
# ('da', 'da')
# ('proposta', 'proposta')
# ('comercial', 'comercial')
# ('.', '.')
# ('Assinatura', 'Assinatura')
# (':', ':')
# ('26/05/2021', '26/05/2021')
# ('.', '.')
# ('Vigência', 'Vigência')
# (':', ':')
# ('12', '12')
# ('(', '(')
# ('doze', 'doze')
# (')', ')')
# ('meses', 'meses')
# ('a', 'a')
# ('contar', 'contar')
# ('da', 'da')
# ('assinatura', 'assinatura')
# ('.', '.')
# ('Signatários', 'Signatários')
# (':', ':')
# ('P', 'P')
# ('/', '/')
# ('EMATER-DF', 'EMATER-DF')
# (':', ':')
# ('Denise', 'Denise')
# ('Andrade', 'Andrade')
# ('da', 'da')
# ('Fonseca', 'Fonseca')
# (',', ',')
# ('Presidente', 'Presidente')
# ('.', '.')
# ('P', 'P')
# ('/', '/')
# ('Contratada', 'Contratada')
# (':', ':')
# ('Bernardo', 'Bernardo')
# ('José', 'José')
# ('de', 'de')
# ('Sá', 'Sá')
# ('Filho', 'Filho')
# ('.', '.')
# ('EXTRATO', 'EXTRATO')
# ('DO', 'DO')
# ('CONTRATO', 'CONTRATO')
# ('DE', 'DE')
# ('PRESTAÇÃO', 'PRESTAÇÃO')
# ('DE', 'DE')
# ('SERVIÇOS', 'SERVIÇOS')
# ('Nº', 'Nº')
# ('07/2021', '07/2021')
# ('Processo', 'Processo')
# (':', ':')
# ('00020-00010200/', '00020-00010200/')
# ('2019-14', '2019-14')
# ('.', '.')
# ('PARTES', 'PARTES')
# (':', ':')
# ('PROCURADORIA-GERAL', 'PROCURADORIA-GERAL')
# ('DO', 'DO')
# ('DISTRITO', 'DISTRITO')
# ('FEDERAL', 'FEDERAL')
# ('E', 'E')
# ('J3', 'J3')
# ('TECNOLOGIA', 'TECNOLOGIA')
# ('E', 'E')
# ('INFRAESTRUTURA', 'INFRAESTRUTURA')
# ('DE', 'DE')
# ('REDES', 'REDES')
# ('EIRELI', 'EIRELI')
# ('.', '.')
# ('(', '(')
# ('CNPJ', 'CNPJ')
# ('nº', 'nº')
# ('17.886.222/', '17.886.222/')
# ('0001-56', '0001-56')
# (')', ')')
# ('.', '.')
# ('Edital', 'Edital')
# ('de', 'de')
# ('Pregão', 'Pregão')
# ('Eletrônico', 'Eletrônico')
# ('nº', 'nº')
# ('07/', '07/')
# ('2021-PGDF', '2021-PGDF')
# ('.', '.')
# ('OBJETO', 'OBJETO')
# (':', ':')
# ('Contratação', 'Contratação')
# ('de', 'de')
# ('empresa', 'empresa')
# ('especializada', 'especializada')
# ('em', 'em')
# ('sistema', 'sistema')
# ('de', 'de')
# ('detecção', 'detecção')
# ('e', 'e')
# ('alarme', 'alarme')
# ('contra', 'contra')
# ('incêndio', 'incêndio')
# (',', ',')
# ('para', 'para')
# ('prestação', 'prestação')
# ('de', 'de')
# ('serviços', 'serviços')
# ('técnicos', 'técnicos')
# ('e', 'e')
# ('profissionais', 'profissionais')
# (',', ',')
# ('incluindo', 'incluindo')
# ('o', 'o')
# ('fornecimento', 'fornecimento')
# ('dos', 'dos')
# ('materiais', 'materiais')
# ('necessários', 'necessários')
# (',', ',')
# ('visando', 'visando')
# ('à', 'à')
# ('Recuperação', 'Recuperação')
# ('do', 'do')
# ('Sistema', 'Sistema')
# ('de', 'de')
# ('Detecção', 'Detecção')
# ('e', 'e')
# ('Alarme', 'Alarme')
# ('Contra', 'Contra')
# ('Incêndio', 'Incêndio')
# (',', ',')
# ('existente', 'existente')
# ('no', 'no')
# ('prédio', 'prédio')
# ('da', 'da')
# ('Procuradoria-Geral', 'Procuradoria-Geral')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('.', '.')
# ('ASSINATURA', 'ASSINATURA')
# (':', ':')
# ('25/05/2021', '25/05/2021')
# ('.', '.')
# ('VIGÊNCIA', 'VIGÊNCIA')
# (':', ':')
# ('O', 'O')
# ('contrato', 'contrato')
# ('terá', 'terá')
# ('vigência', 'vigência')
# ('de', 'de')
# ('90', '90')
# ('(', '(')
# ('noventa', 'noventa')
# (')', ')')
# ('dias', 'dias')
# ('a', 'a')
# ('contar', 'contar')
# ('de', 'de')
# ('sua', 'sua')
# ('assinatura', 'assinatura')
# (',', ',')
# ('com', 'com')
# ('eficácia', 'eficácia')
# ('a', 'a')
# ('partir', 'partir')
# ('de', 'de')
# ('sua', 'sua')
# ('publicação', 'publicação')
# (',', ',')
# ('compreendendo', 'compreendendo')
# ('os', 'os')
# ('prazos', 'prazos')
# ('de', 'de')
# ('entrega', 'entrega')
# (',', ',')
# ('dos', 'dos')
# ('procedimentos', 'procedimentos')
# ('de', 'de')
# ('recebimento', 'recebimento')
# ('fixados', 'fixados')
# ('e', 'e')
# ('pagamento', 'pagamento')
# ('.', '.')
# ('NOTA', 'NOTA')
# ('DE', 'DE')
# ('EMPENHO', 'EMPENHO')
# (':', ':')
# ('Os', 'Os')
# ('empenho', 'empenho')
# ('iniciais', 'iniciais')
# ('são', 'são')
# ('de', 'de')
# ('R$', 'R$')
# ('15.548,74', '15.548,74')
# ('(', '(')
# ('quinze', 'quinze')
# ('mil', 'mil')
# ('quinhentos', 'quinhentos')
# ('e', 'e')
# ('quarenta', 'quarenta')
# ('e', 'e')
# ('oito', 'oito')
# ('reais', 'reais')
# ('e', 'e')
# ('setenta', 'setenta')
# ('e', 'e')
# ('quatro', 'quatro')
# ('centavos', 'centavos')
# (')', ')')
# (',', ',')
# ('conforme', 'conforme')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('nº', 'nº')
# ('2021NE00143', '2021NE00143')
# (';', ';')
# ('R$', 'R$')
# ('878,78', '878,78')
# ('(', '(')
# ('oitocentos', 'oitocentos')
# ('e', 'e')
# ('setenta', 'setenta')
# ('e', 'e')
# ('oito', 'oito')
# ('reais', 'reais')
# ('e', 'e')
# ('setenta', 'setenta')
# ('e', 'e')
# ('oito', 'oito')
# ('centavos', 'centavos')
# (')', ')')
# (',', ',')
# ('conforme', 'conforme')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('nº', 'nº')
# ('2021NE00144', '2021NE00144')
# (';', ';')
# ('R$', 'R$')
# ('930,00', '930,00')
# ('(', '(')
# ('novecentos', 'novecentos')
# ('e', 'e')
# ('trinta', 'trinta')
# ('reais', 'reais')
# (')', ')')
# (',', ',')
# ('conforme', 'conforme')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('nº', 'nº')
# ('2021NE00145', '2021NE00145')
# (';', ';')
# ('R$', 'R$')
# ('37.482,38', '37.482,38')
# ('(', '(')
# ('trinta', 'trinta')
# ('e', 'e')
# ('sete', 'sete')
# ('mil', 'mil')
# ('quatrocentos', 'quatrocentos')
# ('e', 'e')
# ('oitenta', 'oitenta')
# ('e', 'e')
# ('dois', 'dois')
# ('reais', 'reais')
# ('e', 'e')
# ('trinta', 'trinta')
# ('e', 'e')
# ('oito', 'oito')
# ('centavos', 'centavos')
# (')', ')')
# (',', ',')
# ('conforme', 'conforme')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('nº', 'nº')
# ('2021NE00146', '2021NE00146')
# ('e', 'e')
# ('R$', 'R$')
# ('34.450,00', '34.450,00')
# ('(', '(')
# ('trinta', 'trinta')
# ('e', 'e')
# ('quatro', 'quatro')
# ('mil', 'mil')
# ('quatrocentos', 'quatrocentos')
# ('e', 'e')
# ('cinquenta', 'cinquenta')
# ('reais', 'reais')
# (')', ')')
# (',', ',')
# ('conforme', 'conforme')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('nº', 'nº')
# ('2021NE00147', '2021NE00147')
# (',', ',')
# ('emitidas', 'emitidas')
# ('em', 'em')
# ('10/05/2021', '10/05/2021')
# (',', ',')
# ('sob', 'sob')
# ('o', 'o')
# ('evento', 'evento')
# ('nº', 'nº')
# ('400091', '400091')
# (',', ',')
# ('na', 'na')
# ('modalidade', 'modalidade')
# ('Ordinário', 'Ordinário')
# ('.', '.')
# ('COBERTURA', 'COBERTURA')
# ('ORÇAMENTÁRIA', 'ORÇAMENTÁRIA')
# (':', ':')
# ('A', 'A')
# ('despesa', 'despesa')
# ('correrá', 'correrá')
# ('à', 'à')
# ('conta', 'conta')
# ('da', 'da')
# ('seguinte', 'seguinte')
# ('Dotação', 'Dotação')
# ('Orçamentária', 'Orçamentária')
# (':', ':')
# ('I', 'I')
# ('-', '-')
# ('Unidade', 'Unidade')
# ('Orçamentária', 'Orçamentária')
# (':', ':')
# ('12901', '12901')
# ('-', '-')
# ('Procuradoria-Geral', 'Procuradoria-Geral')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('EXTRATO', 'EXTRATO')
# ('DO', 'DO')
# ('CONTRATO', 'CONTRATO')
# ('DE', 'DE')
# ('PRESTAÇÃO', 'PRESTAÇÃO')
# ('DE', 'DE')
# ('SERVIÇOS', 'SERVIÇOS')
# ('Nº', 'Nº')
# ('05/2021', '05/2021')
# ('Processo', 'Processo')
# (':', ':')
# ('04017-00013410/', '04017-00013410/')
# ('2021-15', '2021-15')
# ('.', '.')
# ('SIGGO', 'SIGGO')
# ('Nº', 'Nº')
# ('044006', '044006')
# ('.', '.')
# ('DAS', 'DAS')
# ('PARTES', 'PARTES')
# (':', ':')
# ('SECRETARIA', 'SECRETARIA')
# ('DE', 'DE')
# ('ESTADO', 'ESTADO')
# ('DE', 'DE')
# ('PROTEÇÃO', 'PROTEÇÃO')
# ('DA', 'DA')
# ('ORDEM', 'ORDEM')
# ('URBANÍSTICA', 'URBANÍSTICA')
# ('DO', 'DO')
# ('DISTRITO', 'DISTRITO')
# ('FEDERAL-DF', 'FEDERAL-DF')
# ('LEGAL', 'LEGAL')
# ('e', 'e')
# ('AMC', 'AMC')
# ('INFORMÁTICA', 'INFORMÁTICA')
# ('LTDA', 'LTDA')
# (',', ',')
# ('CNPJ', 'CNPJ')
# ('Nº', 'Nº')
# ('62.541.735/', '62.541.735/')
# ('0001-80', '0001-80')
# ('.', '.')
# ('DO', 'DO')
# ('OBJETO', 'OBJETO')
# (':', ':')
# ('Contratação', 'Contratação')
# ('emergencial', 'emergencial')
# ('para', 'para')
# ('prestação', 'prestação')
# ('de', 'de')
# ('serviços', 'serviços')
# ('de', 'de')
# ('outsourcing', 'outsourcing')
# ('de', 'de')
# ('impressão', 'impressão')
# ('na', 'na')
# ('modalidade', 'modalidade')
# ('"', '"')
# ('franquia', 'franquia')
# ('de', 'de')
# ('página', 'página')
# ('mais', 'mais')
# ('excedente', 'excedente')
# ('"', '"')
# (',', ',')
# ('contemplando', 'contemplando')
# ('o', 'o')
# ('fornecimento', 'fornecimento')
# ('de', 'de')
# ('equipamentos', 'equipamentos')
# ('e', 'e')
# ('todos', 'todos')
# ('os', 'os')
# ('insumos', 'insumos')
# (',', ',')
# ('exceto', 'exceto')
# ('o', 'o')
# ('papel', 'papel')
# (',', ',')
# ('bem', 'bem')
# ('como', 'como')
# ('serviços', 'serviços')
# ('de', 'de')
# ('instalação', 'instalação')
# (',', ',')
# ('manutenção', 'manutenção')
# (',', ',')
# ('assistência', 'assistência')
# ('técnica', 'técnica')
# ('especializada', 'especializada')
# ('com', 'com')
# ('reposição', 'reposição')
# ('de', 'de')
# ('peças', 'peças')
# ('originais', 'originais')
# (',', ',')
# ('para', 'para')
# ('atender', 'atender')
# ('as', 'as')
# ('necessidades', 'necessidades')
# ('da', 'da')
# ('Secretaria', 'Secretaria')
# ('de', 'de')
# ('Estado', 'Estado')
# ('de', 'de')
# ('Proteção', 'Proteção')
# ('da', 'da')
# ('Ordem', 'Ordem')
# ('Urbanística', 'Urbanística')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('(', '(')
# ('DF', 'DF')
# ('LEGAL', 'LEGAL')
# (')', ')')
# (',', ',')
# ('consoante', 'consoante')
# ('especifica', 'especifica')
# ('o', 'o')
# ('Termo', 'Termo')
# ('de', 'de')
# ('Referência', 'Referência')
# ('03/2021', '03/2021')
# ('(', '(')
# ('63194694', '63194694')
# (')', ')')
# ('e', 'e')
# ('a', 'a')
# ('Proposta', 'Proposta')
# ('(', '(')
# ('65120043', '65120043')
# (')', ')')
# ('que', 'que')
# ('integram', 'integram')
# ('o', 'o')
# ('Contrato', 'Contrato')
# ('.', '.')
# ('DO', 'DO')
# ('VALOR', 'VALOR')
# (':', ':')
# ('O', 'O')
# ('valor', 'valor')
# ('total', 'total')
# ('estimativo', 'estimativo')
# ('do', 'do')
# ('Contrato', 'Contrato')
# ('corresponde', 'corresponde')
# ('a', 'a')
# ('R$', 'R$')
# ('73.831,78', '73.831,78')
# ('(', '(')
# ('setenta', 'setenta')
# ('e', 'e')
# ('três', 'três')
# ('mil', 'mil')
# ('oitocentos', 'oitocentos')
# ('e', 'e')
# ('trinta', 'trinta')
# ('e', 'e')
# ('um', 'um')
# ('reais', 'reais')
# ('e', 'e')
# ('setenta', 'setenta')
# ('e', 'e')
# ('oito', 'oito')
# ('centavos', 'centavos')
# (')', ')')
# (',', ',')
# ('procedente', 'procedente')
# ('do', 'do')
# ('Orçamento', 'Orçamento')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('para', 'para')
# ('o', 'o')
# ('corrente', 'corrente')
# ('exercício', 'exercício')
# (',', ',')
# ('nos', 'nos')
# ('termos', 'termos')
# ('da', 'da')
# ('correspondente', 'correspondente')
# ('Lei', 'Lei')
# ('Orçamentária', 'Orçamentária')
# ('Anual', 'Anual')
# ('.', '.')
# ('DA', 'DA')
# ('DOTAÇÃO', 'DOTAÇÃO')
# ('ORÇAMENTÁRIA', 'ORÇAMENTÁRIA')
# (':', ':')
# ('I', 'I')
# ('Unidade', 'Unidade')
# ('Orçamentária', 'Orçamentária')
# (':', ':')
# ('63101', '63101')
# (';', ';')
# ('II', 'II')
# ('Programa', 'Programa')
# ('de', 'de')
# ('Trabalho', 'Trabalho')
# (':', ':')
# ('04.122.8208.8517.0125', '04.122.8208.8517.0125')
# (';', ';')
# ('III', 'III')
# ('Natureza', 'Natureza')
# ('da', 'da')
# ('Despesa', 'Despesa')
# (':', ':')
# ('33.90.39', '33.90.39')
# (',', ',')
# ('e', 'e')
# ('IV', 'IV')
# ('Fonte', 'Fonte')
# ('de', 'de')
# ('Recursos', 'Recursos')
# (':', ':')
# ('183', '183')
# ('.', '.')
# ('DO', 'DO')
# ('EMPENHO', 'EMPENHO')
# (':', ':')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('nº', 'nº')
# ('2021NE00266', '2021NE00266')
# (',', ',')
# ('emitida', 'emitida')
# ('em', 'em')
# ('9', '9')
# ('de', 'de')
# ('julho', 'julho')
# ('de', 'de')
# ('2021', '2021')
# (',', ',')
# ('sob', 'sob')
# ('o', 'o')
# ('Evento', 'Evento')
# ('nº', 'nº')
# ('400091', '400091')
# (',', ',')
# ('na', 'na')
# ('modalidade', 'modalidade')
# ('Estimativo', 'Estimativo')
# ('.', '.')
# ('DA', 'DA')
# ('VIGÊNCIA', 'VIGÊNCIA')
# (':', ':')
# ('O', 'O')
# ('contrato', 'contrato')
# ('terá', 'terá')
# ('vigência', 'vigência')
# ('de', 'de')
# ('180', '180')
# ('(', '(')
# ('cento', 'cento')
# ('e', 'e')
# ('oitenta', 'oitenta')
# (')', ')')
# ('dias', 'dias')
# (',', ',')
# ('consecutivos', 'consecutivos')
# ('e', 'e')
# ('ininterruptos', 'ininterruptos')
# (',', ',')
# ('a', 'a')
# ('contar', 'contar')
# ('da', 'da')
# ('data', 'data')
# ('de', 'de')
# ('sua', 'sua')
# ('assinatura', 'assinatura')
# (',', ',')
# ('sendo', 'sendo')
# ('vedada', 'vedada')
# ('a', 'a')
# ('sua', 'sua')
# ('prorrogação', 'prorrogação')
# (',', ',')
# ('nos', 'nos')
# ('termos', 'termos')
# ('do', 'do')
# ('art.', 'art.')
# ('24', '24')
# (',', ',')
# ('inciso', 'inciso')
# ('IV', 'IV')
# (',', ',')
# ('da', 'da')
# ('Lei', 'Lei')
# ('nº', 'nº')
# ('8.666/93', '8.666/93')
# (',', ',')
# ('ou', 'ou')
# ('até', 'até')
# ('que', 'que')
# ('se', 'se')
# ('conclua', 'conclua')
# ('o', 'o')
# ('novo', 'novo')
# ('procedimento', 'procedimento')
# ('licitatório', 'licitatório')
# ('em', 'em')
# ('andamento', 'andamento')
# ('sob', 'sob')
# ('o', 'o')
# ('processo', 'processo')
# ('04017-00015539/', '04017-00015539/')
# ('2020-79', '2020-79')
# (',', ',')
# ('impondo-se', 'impondo-se')
# ('a', 'a')
# ('rescisão', 'rescisão')
# ('unilateral', 'unilateral')
# ('do', 'do')
# ('contrato', 'contrato')
# (',', ',')
# ('por', 'por')
# ('parte', 'parte')
# ('da', 'da')
# ('CONTRATANTE', 'CONTRATANTE')
# (',', ',')
# ('tão', 'tão')
# ('logo', 'logo')
# ('seja', 'seja')
# ('concluído', 'concluído')
# ('o', 'o')
# ('mencionado', 'mencionado')
# ('procedimento', 'procedimento')
# ('licitatório', 'licitatório')
# ('.', '.')
# ('DOS', 'DOS')
# ('SIGNATÁRIOS', 'SIGNATÁRIOS')
# (':', ':')
# ('Pelo', 'Pelo')
# ('DISTRITO', 'DISTRITO')
# ('FEDERAL', 'FEDERAL')
# (':', ':')
# ('CRISTIANO', 'CRISTIANO')
# ('MANGUEIRA', 'MANGUEIRA')
# ('DE', 'DE')
# ('SOUZA', 'SOUZA')
# (',', ',')
# ('na', 'na')
# ('qualidade', 'qualidade')
# ('de', 'de')
# ('Secretário', 'Secretário')
# ('de', 'de')
# ('EXTRATO', 'EXTRATO')
# ('CONTRATUAL', 'CONTRATUAL')
# ('Processo', 'Processo')
# ('00112-00036315/', '00112-00036315/')
# ('2019-73', '2019-73')
# ('.', '.')
# ('ESPÉCIE', 'ESPÉCIE')
# (':', ':')
# ('CONTRATO', 'CONTRATO')
# ('DE', 'DE')
# ('EMPREITADA', 'EMPREITADA')
# ('DE', 'DE')
# ('OBRA', 'OBRA')
# ('DE', 'DE')
# ('ENGENHARIA', 'ENGENHARIA')
# ('D.E', 'D.E')
# ('Nº', 'Nº')
# ('067/2021', '067/2021')
# ('DJ', 'DJ')
# ('/', '/')
# ('NOVACAP', 'NOVACAP')
# ('.', '.')
# ('CONTRATANTES', 'CONTRATANTES')
# (':', ':')
# ('NOVACAP', 'NOVACAP')
# ('e', 'e')
# ('ABTEC', 'ABTEC')
# ('ENGENHARIA', 'ENGENHARIA')
# ('LTDA', 'LTDA')
# ('.', '.')
# ('DO', 'DO')
# ('OBJETO', 'OBJETO')
# (':', ':')
# ('Contratação', 'Contratação')
# ('de', 'de')
# ('empresa', 'empresa')
# ('de', 'de')
# ('engenharia', 'engenharia')
# ('para', 'para')
# ('execução', 'execução')
# ('de', 'de')
# ('obra', 'obra')
# ('de', 'de')
# ('recuperação', 'recuperação')
# ('estrutural', 'estrutural')
# ('da', 'da')
# ('passarela', 'passarela')
# ('de', 'de')
# ('pedestres', 'pedestres')
# ('do', 'do')
# ('CONIC', 'CONIC')
# (',', ',')
# ('localizada', 'localizada')
# ('SDS', 'SDS')
# ('-', '-')
# ('Setor', 'Setor')
# ('de', 'de')
# ('Diversões', 'Diversões')
# ('Sul', 'Sul')
# ('-', '-')
# ('Lote', 'Lote')
# ('Único', 'Único')
# ('.', '.')
# ('VALOR', 'VALOR')
# (':', ':')
# ('R$', 'R$')
# ('362.162,17', '362.162,17')
# ('.', '.')
# ('PRAZO', 'PRAZO')
# (':', ':')
# ('Vigência', 'Vigência')
# ('de', 'de')
# ('150', '150')
# ('dias', 'dias')
# ('corridos', 'corridos')
# ('.', '.')
# ('RECURSOS', 'RECURSOS')
# (':', ':')
# ('Nota', 'Nota')
# ('de', 'de')
# ('Empenho', 'Empenho')
# ('n', 'n')
# ('°', '°')
# ('2021NE01550', '2021NE01550')
# (',', ',')
# ('no', 'no')
# ('valor', 'valor')
# ('de', 'de')
# ('R$', 'R$')
# ('362.162,17', '362.162,17')
# (',', ',')
# ('à', 'à')
# ('conta', 'conta')
# ('do', 'do')
# ('Programa', 'Programa')
# ('de', 'de')
# ('Trabalho', 'Trabalho')
# (':', ':')
# ('15.451.6216.1223.0005', '15.451.6216.1223.0005')
# (',', ',')
# ('Natureza', 'Natureza')
# ('da', 'da')
# ('Despesa', 'Despesa')
# (':', ':')
# ('44.90.51', '44.90.51')
# (',', ',')
# ('Fonte', 'Fonte')
# ('de', 'de')
# ('Recurso', 'Recurso')
# (':', ':')
# ('100', '100')
# ('.', '.')
# ('DATA', 'DATA')
# ('DA', 'DA')
# ('ASSINATURA', 'ASSINATURA')
# (':', ':')
# ('01/07/2021', '01/07/2021')
# ('.', '.')
# ('PELA', 'PELA')
# ('NOVACAP', 'NOVACAP')
# (':', ':')
# ('Fernando', 'Fernando')
# ('Rodrigues', 'Rodrigues')
# ('Ferreira', 'Ferreira')
# ('Leite', 'Leite')
# ('e', 'e')
# ('Rubens', 'Rubens')
# ('de', 'de')
# ('Oliveira', 'Oliveira')
# ('Pimentel', 'Pimentel')
# ('Júnior', 'Júnior')
# ('.', '.')
# ('PELA', 'PELA')
# ('CONTRATADA', 'CONTRATADA')
# (':', ':')
# ('Guilherme', 'Guilherme')
# ('Siqueira', 'Siqueira')
# ('Borba', 'Borba')
# ('.', '.')
# ('EXTRATO', 'EXTRATO')
# ('DE', 'DE')
# ('CONTRATO', 'CONTRATO')
# ('Processo', 'Processo')
# (':', ':')
# ('00196-00000212/', '00196-00000212/')
# ('2021-99', '2021-99')
# ('.', '.')
# ('DA', 'DA')
# ('ESPÉCIE', 'ESPÉCIE')
# (':', ':')
# ('Contrato', 'Contrato')
# ('de', 'de')
# ('Aquisição', 'Aquisição')
# ('de', 'de')
# ('Produtos', 'Produtos')
# ('da', 'da')
# ('Agricultura', 'Agricultura')
# ('Familiar', 'Familiar')
# ('nº', 'nº')
# ('44.003/2021', '44.003/2021')
# ('.', '.')
# ('DAS', 'DAS')
# ('PARTES', 'PARTES')
# (':', ':')
# ('Fundação', 'Fundação')
# ('Jardim', 'Jardim')
# ('Zoológico', 'Zoológico')
# ('de', 'de')
# ('Brasília', 'Brasília')
# ('-', '-')
# ('FJZB', 'FJZB')
# ('e', 'e')
# ('Associação', 'Associação')
# ('dos', 'dos')
# ('Produtores', 'Produtores')
# ('Hortifrutigranjeiros', 'Hortifrutigranjeiros')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('e', 'e')
# ('Entorno', 'Entorno')
# ('-', '-')
# ('ASPHOR', 'ASPHOR')
# ('.', '.')
# ('DO', 'DO')
# ('OBJETO', 'OBJETO')
# (':', ':')
# ('Aquisição', 'Aquisição')
# (',', ',')
# ('por', 'por')
# ('dispensa', 'dispensa')
# ('de', 'de')
# ('licitação', 'licitação')
# ('de', 'de')
# ('frutas', 'frutas')
# (',', ',')
# ('verduras', 'verduras')
# ('e', 'e')
# ('legumes', 'legumes')
# ('produzidos', 'produzidos')
# ('por', 'por')
# ('agricultores', 'agricultores')
# ('familiares', 'familiares')
# ('rurais', 'rurais')
# ('e', 'e')
# ('urbanos', 'urbanos')
# ('e', 'e')
# ('pelos', 'pelos')
# ('demais', 'demais')
# ('beneficiários', 'beneficiários')
# ('e', 'e')
# ('organizações', 'organizações')
# ('que', 'que')
# ('se', 'se')
# ('enquadrem', 'enquadrem')
# ('nas', 'nas')
# ('disposições', 'disposições')
# ('da', 'da')
# ('Lei', 'Lei')
# ('Federal', 'Federal')
# ('nº', 'nº')
# ('11.326', '11.326')
# (',', ',')
# ('de', 'de')
# ('24', '24')
# ('de', 'de')
# ('julho', 'julho')
# ('de', 'de')
# ('2006', '2006')
# (',', ',')
# ('para', 'para')
# ('a', 'a')
# ('alimentação', 'alimentação')
# ('dos', 'dos')
# ('animais', 'animais')
# ('mantidos', 'mantidos')
# ('na', 'na')
# ('FJZB', 'FJZB')
# (',', ',')
# ('conforme', 'conforme')
# ('especificações', 'especificações')
# (',', ',')
# ('quantidades', 'quantidades')
# ('e', 'e')
# ('demais', 'demais')
# ('exigências', 'exigências')
# ('da', 'da')
# ('Chamada', 'Chamada')
# ('Pública', 'Pública')
# ('nº', 'nº')
# ('002/2021SEAGRI', '002/2021SEAGRI')
# ('/', '/')
# ('DF', 'DF')
# ('.', '.')
# ('DO', 'DO')
# ('VALOR', 'VALOR')
# (':', ':')
# ('O', 'O')
# ('valor', 'valor')
# ('total', 'total')
# ('do', 'do')
# ('contrato', 'contrato')
# ('é', 'é')
# ('de', 'de')
# ('R$', 'R$')
# ('237.673,60', '237.673,60')
# ('(', '(')
# ('duzentos', 'duzentos')
# ('e', 'e')
# ('trinta', 'trinta')
# ('e', 'e')
# ('sete', 'sete')
# ('mil', 'mil')
# (',', ',')
# ('seiscentos', 'seiscentos')
# ('e', 'e')
# ('setenta', 'setenta')
# ('e', 'e')
# ('três', 'três')
# ('reais', 'reais')
# ('e', 'e')
# ('sessenta', 'sessenta')
# ('centavos', 'centavos')
# (')', ')')
# ('.', '.')
# ('DA', 'DA')
# ('DOTAÇÃO', 'DOTAÇÃO')
# ('ORÇAMENTÁRIA', 'ORÇAMENTÁRIA')
# (':', ':')
# ('PT', 'PT')
# ('18.541.6210.4086.0002', '18.541.6210.4086.0002')
# ('-', '-')
# ('ND', 'ND')
# ('3390.30', '3390.30')
# ('-', '-')
# ('Fonte', 'Fonte')
# ('100', '100')
# ('.', '.')
# ('DA', 'DA')
# ('VIGÊNCIA', 'VIGÊNCIA')
# (':', ':')
# ('12', '12')
# ('(', '(')
# ('doze', 'doze')
# (')', ')')
# ('meses', 'meses')
# ('a', 'a')
# ('contar', 'contar')
# ('da', 'da')
# ('data', 'data')
# ('de', 'de')
# ('assinatura', 'assinatura')
# ('.', '.')
# ('DATA', 'DATA')
# ('DE', 'DE')
# ('ASSINATURA', 'ASSINATURA')
# (':', ':')
# ('25/07/2019', '25/07/2019')
# ('.', '.')
# ('DOS', 'DOS')
# ('SIGNATÁRIOS', 'SIGNATÁRIOS')
# (':', ':')
# ('Pela', 'Pela')
# ('Fundação', 'Fundação')
# (':', ':')
# ('José', 'José')
# ('Carlos', 'Carlos')
# ('Lopes', 'Lopes')
# ('de', 'de')
# ('Oliveira', 'Oliveira')
# (',', ',')
# ('na', 'na')
# ('qualidade', 'qualidade')
# ('de', 'de')
# ('Diretor', 'Diretor')
# ('Presidente', 'Presidente')
# ('-', '-')
# ('Substituto', 'Substituto')
# ('.', '.')
# ('Pela', 'Pela')
# ('Contratada', 'Contratada')
# (':', ':')
# ('Sandra', 'Sandra')
# ('Moreira', 'Moreira')
# ('Padilha', 'Padilha')
# ('Vitoriano', 'Vitoriano')
# (',', ',')
# ('na', 'na')
# ('qualidade', 'qualidade')
# ('de', 'de')
# ('Presidente', 'Presidente')
# ('.', '.')
# ('EXTRATO', 'EXTRATO')
# ('DE', 'DE')
# ('CONTRATO', 'CONTRATO')
# ('Processo', 'Processo')
# (':', ':')
# ('001-000116/2018', '001-000116/2018')
# ('.', '.')
# ('CONTRATO', 'CONTRATO')
# ('CLDF', 'CLDF')
# ('Nº', 'Nº')
# ('22/', '22/')
# ('2021-NPLC', '2021-NPLC')
# (',', ',')
# ('firmado', 'firmado')
# ('entre', 'entre')
# ('a', 'a')
# ('Câmara', 'Câmara')
# ('Legislativa', 'Legislativa')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('e', 'e')
# ('a', 'a')
# ('empresa', 'empresa')
# ('IDEALINE', 'IDEALINE')
# ('TECNOLOGIA', 'TECNOLOGIA')
# ('E', 'E')
# ('SEGURANÇA', 'SEGURANÇA')
# ('LTDA', 'LTDA')
# ('.', '.')
# ('EPP', 'EPP')
# (',', ',')
# ('CNPJ', 'CNPJ')
# ('nº', 'nº')
# ('01.215.897/', '01.215.897/')
# ('0001-33', '0001-33')
# ('.', '.')
# ('Objeto', 'Objeto')
# (':', ':')
# ('Prestação', 'Prestação')
# ('de', 'de')
# ('serviços', 'serviços')
# ('de', 'de')
# ('reparação', 'reparação')
# ('inicial', 'inicial')
# (',', ',')
# ('manutenção', 'manutenção')
# ('preventiva', 'preventiva')
# ('e', 'e')
# ('corretiva', 'corretiva')
# ('do', 'do')
# ('sistema', 'sistema')
# ('de', 'de')
# ('controle', 'controle')
# ('de', 'de')
# ('acesso', 'acesso')
# ('de', 'de')
# ('pessoas', 'pessoas')
# ('e', 'e')
# ('veículos', 'veículos')
# ('do', 'do')
# ('Edifício', 'Edifício')
# ('Sede', 'Sede')
# ('da', 'da')
# ('Câmara', 'Câmara')
# ('Legislativa', 'Legislativa')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('.', '.')
# ('Valor', 'Valor')
# (':', ':')
# ('R$', 'R$')
# ('246.059,97', '246.059,97')
# ('.', '.')
# ('Unidade', 'Unidade')
# ('Gestora', 'Gestora')
# ('010101', '010101')
# (',', ',')
# ('gestão', 'gestão')
# ('00001', '00001')
# (',', ',')
# ('unidade', 'unidade')
# ('orçamentária', 'orçamentária')
# ('01101', '01101')
# (',', ',')
# ('programa', 'programa')
# ('de', 'de')
# ('trabalho', 'trabalho')
# ('01122820485170065', '01122820485170065')
# (',', ',')
# ('fonte', 'fonte')
# ('de', 'de')
# ('recurso', 'recurso')
# ('100000000', '100000000')
# (';', ';')
# ('natureza', 'natureza')
# ('da', 'da')
# ('despesa', 'despesa')
# ('339039', '339039')
# ('.', '.')
# ('Nota', 'Nota')
# ('de', 'de')
# ('empenho', 'empenho')
# (':', ':')
# ('2021NE00326', '2021NE00326')
# (',', ',')
# ('com', 'com')
# ('valor', 'valor')
# ('de', 'de')
# ('R$', 'R$')
# ('153.911,98', '153.911,98')
# (',', ',')
# ('emitida', 'emitida')
# ('em', 'em')
# ('11/06/2021', '11/06/2021')
# ('.', '.')
# ('Unidade', 'Unidade')
# ('Gestora', 'Gestora')
# ('010101', '010101')
# (',', ',')
# ('gestão', 'gestão')
# ('00001', '00001')
# (',', ',')
# ('unidade', 'unidade')
# ('orçamentária', 'orçamentária')
# ('01101', '01101')
# (',', ',')
# ('programa', 'programa')
# ('de', 'de')
# ('trabalho', 'trabalho')
# ('01122820485170065', '01122820485170065')
# (',', ',')
# ('fonte', 'fonte')
# ('de', 'de')
# ('recurso', 'recurso')
# ('100000000', '100000000')
# (';', ';')
# ('natureza', 'natureza')
# ('da', 'da')
# ('despesa', 'despesa')
# ('339030', '339030')
# ('.', '.')
# ('Nota', 'Nota')
# ('de', 'de')
# ('empenho', 'empenho')
# (':', ':')
# ('2021NE00327', '2021NE00327')
# (',', ',')
# ('com', 'com')
# ('valor', 'valor')
# ('de', 'de')
# ('R$', 'R$')
# ('68.326,13', '68.326,13')
# (',', ',')
# ('emitida', 'emitida')
# ('em', 'em')
# ('11/06/2021', '11/06/2021')
# ('.', '.')
# ('Unidade', 'Unidade')
# ('Gestora', 'Gestora')
# ('010101', '010101')
# (',', ',')
# ('gestão', 'gestão')
# ('00001', '00001')
# (',', ',')
# ('unidade', 'unidade')
# ('orçamentária', 'orçamentária')
# ('01101', '01101')
# (',', ',')
# ('programa', 'programa')
# ('de', 'de')
# ('trabalho', 'trabalho')
# ('01126820414710006', '01126820414710006')
# (',', ',')
# ('fonte', 'fonte')
# ('de', 'de')
# ('recurso', 'recurso')
# ('100000000', '100000000')
# (';', ';')
# ('natureza', 'natureza')
# ('da', 'da')
# ('despesa', 'despesa')
# ('449040', '449040')
# ('.', '.')
# ('Nota', 'Nota')
# ('de', 'de')
# ('empenho', 'empenho')
# (':', ':')
# ('2021NE00328', '2021NE00328')
# (',', ',')
# ('com', 'com')
# ('valor', 'valor')
# ('de', 'de')
# ('R$', 'R$')
# ('18.000,00', '18.000,00')
# (',', ',')
# ('emitida', 'emitida')
# ('em', 'em')
# ('11/06/2021', '11/06/2021')
# ('.', '.')
# ('Unidade', 'Unidade')
# ('Gestora', 'Gestora')
# ('010101', '010101')
# (',', ',')
# ('gestão', 'gestão')
# ('00001', '00001')
# (',', ',')
# ('unidade', 'unidade')
# ('orçamentária', 'orçamentária')
# ('01101', '01101')
# (',', ',')
# ('programa', 'programa')
# ('de', 'de')
# ('trabalho', 'trabalho')
# ('01126820425572627', '01126820425572627')
# (',', ',')
# ('fonte', 'fonte')
# ('de', 'de')
# ('recurso', 'recurso')
# ('100000000', '100000000')
# (';', ';')
# ('natureza', 'natureza')
# ('da', 'da')
# ('despesa', 'despesa')
# ('339040', '339040')
# ('.', '.')
# ('Nota', 'Nota')
# ('de', 'de')
# ('empenho', 'empenho')
# (':', ':')
# ('2021NE00329', '2021NE00329')
# (',', ',')
# ('com', 'com')
# ('valor', 'valor')
# ('de', 'de')
# ('R$', 'R$')
# ('5.821,86', '5.821,86')
# (',', ',')
# ('emitida', 'emitida')
# ('em', 'em')
# ('11/06/2021', '11/06/2021')
# ('.', '.')
# ('Vigência', 'Vigência')
# (':', ':')
# ('12', '12')
# ('(', '(')
# ('doze', 'doze')
# (')', ')')
# ('meses', 'meses')
# ('a', 'a')
# ('contar', 'contar')
# ('da', 'da')
# ('data', 'data')
# ('de', 'de')
# ('25/05/2021', '25/05/2021')
# (',', ',')
# ('com', 'com')
# ('eficácia', 'eficácia')
# ('a', 'a')
# ('partir', 'partir')
# ('da', 'da')
# ('data', 'data')
# ('da', 'da')
# ('publicação', 'publicação')
# ('do', 'do')
# ('seu', 'seu')
# ('extrato', 'extrato')
# ('no', 'no')
# ('Diário', 'Diário')
# ('Oficial', 'Oficial')
# ('do', 'do')
# ('Distrito', 'Distrito')
# ('Federal', 'Federal')
# ('.', '.')
# ('Legislação', 'Legislação')
# (':', ':')
# ('Lei', 'Lei')
# ('8.666/93', '8.666/93')
# ('e', 'e')
# ('suas', 'suas')
# ('alterações', 'alterações')
# ('.', '.')
# ('Partes', 'Partes')
# (':', ':')
# ('Pela', 'Pela')
# ('Contratante', 'Contratante')
# (',', ',')
# ('MARLON', 'MARLON')
# ('CARVALHO', 'CARVALHO')
# ('CAMBRAIA', 'CAMBRAIA')
# ('Secretário-Geral', 'Secretário-Geral')
# (',', ',')
# ('e', 'e')
# (',', ',')
# ('pela', 'pela')
# ('Contratada', 'Contratada')
# (',', ',')
# ('ALINE', 'ALINE')
# ("D'ALESSANDRO", "D'ALESSANDRO")
# ('ALVES', 'ALVES')
# ('-', '-')
# ('Representante', 'Representante')
# ('da', 'da')
# ('Empresa', 'Empresa')
# ('.', '.')
# ('FUNDO', 'FUNDO')
# ('DE', 'DE')
# ('ASSISTÊNCIA', 'ASSISTÊNCIA')
# ('À', 'À')
# ('SAÚDE', 'SAÚDE')
# ('DOS', 'DOS')
# ('DEPUTADOS', 'DEPUTADOS')
# ('DISTRITAIS', 'DISTRITAIS')
# ('E', 'E')
# ('SERVIDORES', 'SERVIDORES')
# ('DA', 'DA')
# ('CÂMARA', 'CÂMARA')
# ('LEGISLATIVA', 'LEGISLATIVA')
# ('EXTRATO', 'EXTRATO')
# ('DO', 'DO')
# ('CONTRATO', 'CONTRATO')
# ('DE', 'DE')
# ('RATEIO', 'RATEIO')
# ('N', 'N')
# ('°', '°')
# ('07/2021', '07/2021')
# ('Objeto', 'Objeto')
# (':', ':')
# ('Constitui', 'Constitui')
# ('o', 'o')
# ('objeto', 'objeto')
# ('do', 'do')
# ('presente', 'presente')
# ('Contrato', 'Contrato')
# ('de', 'de')
# ('Rateio', 'Rateio')
# ('a', 'a')
# ('transferência', 'transferência')
# ('de', 'de')
# ('recursos', 'recursos')
# ('financeiros', 'financeiros')
# ('do', 'do')
# ('CONSORCIADO', 'CONSORCIADO')
# ('ao', 'ao')
# ('CONSÓRCIO', 'CONSÓRCIO')
# ('relativo', 'relativo')
# ('a', 'a')
# ('compra', 'compra')
# ('compartilhada', 'compartilhada')
# ('de', 'de')
# ('medicamentos', 'medicamentos')
# (',', ',')
# ('correlatos', 'correlatos')
# (',', ',')
# ('insumos', 'insumos')
# ('e', 'e')
# ('equipamentos', 'equipamentos')
# ('de', 'de')
# ('proteção', 'proteção')
# ('individual', 'individual')
# (',', ',')
# ('no', 'no')
# ('ano', 'ano')
# ('de', 'de')
# ('2021', '2021')
# ('.', '.')
# ('Consórcio', 'Consórcio')
# (':', ':')
# ('Consórcio', 'Consórcio')
# ('Interestadual', 'Interestadual')
# ('de', 'de')
# ('Desenvolvimento', 'Desenvolvimento')
# ('do', 'do')
# ('Brasil', 'Brasil')
# ('Central', 'Central')
# ('-', '-')
# ('BrC', 'BrC')
# (',', ',')
# ('inscrito', 'inscrito')
# ('no', 'no')
# ('CNPJ', 'CNPJ')
# ('/', '/')
# ('MF', 'MF')
# ('sob', 'sob')
# ('o', 'o')
# ('n', 'n')
# ('°', '°')
# ('23.791.169/', '23.791.169/')
# ('0001-02', '0001-02')
# (';', ';')
# ('Consorciado', 'Consorciado')
# (':', ':')
# ('Estado', 'Estado')
# ('de', 'de')
# ('Rondônia', 'Rondônia')
# (',', ',')
# ('inscrito', 'inscrito')
# ('no', 'no')
# ('CNPJ', 'CNPJ')
# ('/', '/')
# ('MF', 'MF')
# ('sob', 'sob')
# ('o', 'o')
# ('n', 'n')
# ('°', '°')
# ('00.394.585/', '00.394.585/')
# ('0001-71', '0001-71')
# (';', ';')
# ('Secretaria', 'Secretaria')
# ('de', 'de')
# ('Estado', 'Estado')
# ('de', 'de')
# ('Saúde', 'Saúde')
# ('de', 'de')
# ('Rondônia', 'Rondônia')
# (',', ',')
# ('inscrita', 'inscrita')
# ('no', 'no')
# ('CNPJ', 'CNPJ')
# ('/', '/')
# ('MF', 'MF')
# ('sob', 'sob')
# ('o', 'o')
# ('n', 'n')
# ('°', '°')
# ('00.733.062/', '00.733.062/')
# ('0001-52', '0001-52')
# (';', ';')
# ('Fundo', 'Fundo')
# ('Estadual', 'Estadual')
# ('de', 'de')
# ('Saúde', 'Saúde')
# ('do', 'do')
# ('Estado', 'Estado')
# ('de', 'de')
# ('Rondônia', 'Rondônia')
# (',', ',')
# ('inscrito', 'inscrito')
# ('no', 'no')
# ('CNPJ', 'CNPJ')
# ('/', '/')
# ('MF', 'MF')
# ('sob', 'sob')
# ('o', 'o')
# ('n', 'n')
# ('°', '°')
# ('00.733.062/', '00.733.062/')
# ('0001-52', '0001-52')
# (';', ';')
# ('Valor', 'Valor')
# ('das', 'das')
# ('Transferências', 'Transferências')
# (':', ':')
# ('O', 'O')
# ('CONSORCIADO', 'CONSORCIADO')
# ('se', 'se')
# ('compromete', 'compromete')
# ('a', 'a')
# ('transferir', 'transferir')
# ('ao', 'ao')
# ('CONSÓRCIO', 'CONSÓRCIO')
# ('o', 'o')
# ('montante', 'montante')
# ('de', 'de')
# ('R$', 'R$')
# ('898.853,80', '898.853,80')
# ('(', '(')
# ('oitocentos', 'oitocentos')
# ('e', 'e')
# ('noventa', 'noventa')
# ('e', 'e')
# ('oito', 'oito')
# ('mil', 'mil')
# (',', ',')
# ('oitocentos', 'oitocentos')
# ('e', 'e')
# ('cinquenta', 'cinquenta')
# ('e', 'e')
# ('três', 'três')
# ('reais', 'reais')
# ('e', 'e')
# ('oitenta', 'oitenta')
# ('centavos', 'centavos')
# (')', ')')
# ('.', '.')
# ('Fundamentação', 'Fundamentação')
# ('Legal', 'Legal')
# (':', ':')
# ('O', 'O')
# ('presente', 'presente')
# ('Contrato', 'Contrato')
# ('de', 'de')
# ('Rateio', 'Rateio')
# ('tem', 'tem')
# ('a', 'a')
# ('sua', 'sua')
# ('fundamentação', 'fundamentação')
# ('jurídica', 'jurídica')
# ('no', 'no')
# ('art.', 'art.')
# ('8º', '8º')
# ('da', 'da')
# ('Lei', 'Lei')
# ('Federal', 'Federal')
# ('nº', 'nº')
# ('11.107', '11.107')
# (',', ',')
# ('de', 'de')
# ('06', '06')
# ('de', 'de')
# ('abril', 'abril')
# ('de', 'de')
# ('2005', '2005')
# (',', ',')
# ('no', 'no')
# ('Decreto', 'Decreto')
# ('Federal', 'Federal')
# ('nº', 'nº')
# ('6.017', '6.017')
# (',', ',')
# ('de', 'de')
# ('17', '17')
# ('de', 'de')
# ('janeiro', 'janeiro')
# ('de', 'de')
# ('2017', '2017')
# (',', ',')
# ('Cláusula', 'Cláusula')
# ('32', '32')
# ('do', 'do')
# ('Protocolo', 'Protocolo')
# ('de', 'de')
# ('Intenções', 'Intenções')
# ('ratificado', 'ratificado')
# ('pelas', 'pelas')
# ('Assembleias', 'Assembleias')
# ('Legislativas', 'Legislativas')
# ('de', 'de')
# ('todos', 'todos')
# ('os', 'os')
# ('entes', 'entes')
# ('consorciados', 'consorciados')
# ('.', '.')
# ('Vigência', 'Vigência')
# ('Contratual', 'Contratual')
# (':', ':')
# ('O', 'O')
# ('presente', 'presente')
# ('contrato', 'contrato')
# ('vigerá', 'vigerá')
# ('até', 'até')
# ('31/12/2021', '31/12/2021')
# (',', ',')
# ('vedada', 'vedada')
# ('a', 'a')
# ('sua', 'sua')
# ('prorrogação', 'prorrogação')
# (',', ',')
# ('sendo', 'sendo')
# (',', ',')
# ('todavia', 'todavia')
# (',', ',')
# ('rescindido', 'rescindido')
# ('automaticamente', 'automaticamente')
# ('no', 'no')
# ('caso', 'caso')
# ('de', 'de')
# ('o', 'o')
# ('CONSORCIADO', 'CONSORCIADO')
# ('deixar', 'deixar')
# ('de', 'de')
# ('integrar', 'integrar')
# ('o', 'o')
# ('Consórcio', 'Consórcio')
# (',', ',')
# ('atendidas', 'atendidas')
# (',', ',')
# ('neste', 'neste')
# ('caso', 'caso')
# (',', ',')
# ('as', 'as')
# ('formalidades', 'formalidades')
# ('estabelecidas', 'estabelecidas')
# ('na', 'na')
# ('legislação', 'legislação')
# ('vigente', 'vigente')
# ('e', 'e')
# ('estatuto', 'estatuto')
# ('.', '.')
# ('Signatários', 'Signatários')
# (':', ':')
# ('Ibaneis', 'Ibaneis')
# ('Rocha', 'Rocha')
# ('Barros', 'Barros')
# ('Júnior', 'Júnior')
# ('-', '-')
# ('Presidente', 'Presidente')
# ('do', 'do')
# ('BrC', 'BrC')
# (';', ';')
# ('Marcos', 'Marcos')
# ('José', 'José')
# ('Rocha', 'Rocha')
# ('dos', 'dos')
# ('Santos', 'Santos')
# ('-', '-')
# ('Governador', 'Governador')
# ('do', 'do')
# ('Estado', 'Estado')
# ('de', 'de')
# ('Rondônia', 'Rondônia')
# (';', ';')
# ('Fernando', 'Fernando')
# ('Rodrigues', 'Rodrigues')
# ('Máximo', 'Máximo')
# ('Secretário', 'Secretário')
# ('de', 'de')
# ('Estado', 'Estado')
# ('de', 'de')
# ('Saúde', 'Saúde')
# ('de', 'de')
# ('Rondônia', 'Rondônia')
# ('.', '.')
# ('EXTRATO', 'EXTRATO')
# ('DO', 'DO')
# ('CONTRATO', 'CONTRATO')
# ('Nº', 'Nº')
# ('043609/2021', '043609/2021')
# ('Processo', 'Processo')
# (':', ':')
# ('00090-00032956/', '00090-00032956/')
# ('2020-05', '2020-05')
# ('.', '.')
# ('DAS', 'DAS')
# ('PARTES', 'PARTES')
# (':', ':')
# ('SEMOB', 'SEMOB')
# ('x', 'x')
# ('P', 'P')
# ('B', 'B')
# ('SISTEMAS', 'SISTEMAS')
# ('DE', 'DE')
# ('SEGURANCA', 'SEGURANCA')
# ('EIRELI', 'EIRELI')
# ('.', '.')
# ('DA', 'DA')
# ('MODALIDADE', 'MODALIDADE')
# (':', ':')
# ('Pregão', 'Pregão')
# ('Eletrônico', 'Eletrônico')
# ('.', '.')
# ('DO', 'DO')
# ('OBJETO', 'OBJETO')
# (':', ':')
# ('prestação', 'prestação')
# ('de', 'de')
# ('serviços', 'serviços')
# ('de', 'de')
# ('manutenção', 'manutenção')
# ('de', 'de')
# ('extintores', 'extintores')
# ('.', '.')
# ('DA', 'DA')
# ('VIGÊNCIA', 'VIGÊNCIA')
# (':', ':')
# ('O', 'O')
# ('presente', 'presente')
# ('Contrato', 'Contrato')
# ('terá', 'terá')
# ('vigência', 'vigência')
# ('de', 'de')
# ('12', '12')
# ('(', '(')
# ('doze', 'doze')
# (')', ')')
# ('meses', 'meses')
# (',', ',')
# ('a', 'a')
# ('partir', 'partir')
# ('da', 'da')
# ('data', 'data')
# ('de', 'de')
# ('sua', 'sua')
# ('assinatura', 'assinatura')
# (',', ',')
# ('podendo', 'podendo')
# ('ser', 'ser')
# ('prorrogado', 'prorrogado')
# ('por', 'por')
# ('iguais', 'iguais')
# ('e', 'e')
# ('sucessivos', 'sucessivos')
# ('períodos', 'períodos')
# ('até', 'até')
# ('o', 'o')
# ('limite', 'limite')
# ('de', 'de')
# ('60', '60')
# ('(', '(')
# ('sessenta', 'sessenta')
# (')', ')')
# ('meses', 'meses')
# (',', ',')
# ('na', 'na')
# ('forma', 'forma')
# ('da', 'da')
# ('legislação', 'legislação')
# ('vigente', 'vigente')
# ('.', '.')
# ('DO', 'DO')
# ('VALOR', 'VALOR')
# (':', ':')
# ('O', 'O')
# ('valor', 'valor')
# ('total', 'total')
# ('do', 'do')
# ('contrato', 'contrato')
# ('é', 'é')
# ('de', 'de')
# ('R$', 'R$')
# ('32.160,80', '32.160,80')
# ('(', '(')
# ('trinta', 'trinta')
# ('e', 'e')
# ('dois', 'dois')
# ('mil', 'mil')
# ('cento', 'cento')
# ('e', 'e')
# ('sessenta', 'sessenta')
# ('reais', 'reais')
# ('e', 'e')
# ('oitenta', 'oitenta')
# ('centavos', 'centavos')
# (')', ')')
# ('.', '.')
# ('DATA', 'DATA')
# ('DA', 'DA')
# ('ASSINATURA', 'ASSINATURA')
# (':', ':')
# ('11/06/2021', '11/06/2021')
# ('.', '.')
# ('DOS', 'DOS')
# ('SIGNATÁRIOS', 'SIGNATÁRIOS')
# (':', ':')
# ('Pela', 'Pela')
# ('Contratante', 'Contratante')
# (',', ',')
# ('VALTER', 'VALTER')
# ('CASIMIRO', 'CASIMIRO')
# ('SILVEIRA', 'SILVEIRA')
# (',', ',')
# ('na', 'na')
# ('qualidade', 'qualidade')
# ('de', 'de')
# ('Secretário', 'Secretário')
# ('de', 'de')
# ('Estado', 'Estado')
# ('de', 'de')
# ('Transporte', 'Transporte')
# ('e', 'e')
# ('Mobilidade', 'Mobilidade')
# (';', ';')
# ('e', 'e')
# ('pela', 'pela')
# ('Contratada', 'Contratada')
# (',', ',')
# ('ANDRÉ', 'ANDRÉ')
# ('PAZ', 'PAZ')
# ('DE', 'DE')
# ('LIMA', 'LIMA')
# (',', ',')
# ('na', 'na')
# ('qualidade', 'qualidade')
# ('de', 'de')
# ('Representante', 'Representante')
# ('Legal', 'Legal')
# ('.', '.')
# ('EXTRATO', 'EXTRATO')
# ('DE', 'DE')
# ('CONTRATO', 'CONTRATO')
# ('CONTRATO', 'CONTRATO')
# ('Nº', 'Nº')
# ('24/2021', '24/2021')
# ('-', '-')
# ('CJU', 'CJU')
# ('/', '/')
# ('CEB-H', 'CEB-H')
# ('Espécie', 'Espécie')
# (':', ':')
# ('Contrato', 'Contrato')
# ('nº', 'nº')
# ('24/2021', '24/2021')
# ('-', '-')
# ('CJU', 'CJU')
# ('/', '/')
# ('CEB-H', 'CEB-H')
# ('.', '.')
# ('Partes', 'Partes')
# (':', ':')
# ('Companhia', 'Companhia')
# ('Energética', 'Energética')
# ('de', 'de')
# ('Brasília', 'Brasília')
# ('-', '-')
# ('CEB', 'CEB')
# ('e', 'e')
# ('Moreira', 'Moreira')
# ('Associados', 'Associados')
# ('Auditores', 'Auditores')
# ('Independentes', 'Independentes')
# ('S', 'S')
# ('/', '/')
# ('S.', 'S.')
# ('Processo', 'Processo')
# ('00093-00000760/', '00093-00000760/')
# ('2020-69', '2020-69')
# (',', ',')
# ('regido', 'regido')
# ('pelo', 'pelo')
# ('CEBLic', 'CEBLic')
# ('Regulamento', 'Regulamento')
# ('de', 'de')
# ('Licitações', 'Licitações')
# ('e', 'e')
# ('Contratos', 'Contratos')
# ('do', 'do')
# ('Grupo', 'Grupo')
# ('CEB', 'CEB')
# ('.', '.')
# ('Data', 'Data')
# ('de', 'de')
# ('assinatura', 'assinatura')
# (':', ':')
# ('18/06/2021', '18/06/2021')
# ('.', '.')
# ('Objeto', 'Objeto')
# (':', ':')
# ('contratação', 'contratação')
# ('de', 'de')
# ('serviços', 'serviços')
# ('planejados', 'planejados')
# ('de', 'de')
# ('auditoria', 'auditoria')
# ('interna', 'interna')
# (',', ',')
# ('a', 'a')
# ('serem', 'serem')
# ('realizados', 'realizados')
# ('por', 'por')
# ('empresa', 'empresa')
# ('com', 'com')
# ('comprovada', 'comprovada')
# ('experiência', 'experiência')
# ('no', 'no')
# ('setor', 'setor')
# ('energético', 'energético')
# (',', ',')
# ('para', 'para')
# ('a', 'a')
# ('realização', 'realização')
# ('de', 'de')
# ('auditorias', 'auditorias')
# ('operacional', 'operacional')
# (',', ',')
# ('de', 'de')
# ('conformidade', 'conformidade')
# (',', ',')
# ('e', 'e')
# ('de', 'de')
# ('procedimentos', 'procedimentos')
# ('contábeis', 'contábeis')
# ('e', 'e')
# ...
# ('cercado', 'de')
# ('por', 'R$')
# ('muro', '975.630,09')
# ('e', '(')
# ('gradil', 'novecentos')
# ('metálico', 'e')
# ('e', 'setenta')
# ('edificação', 'e')
# ('com', 'cinco')
# ('3.914,09', 'mil')
# ('m²', ',')
# ('de', 'seiscentos')
# ('área', 'e')
# ('construída', 'trinta')
# (',', 'reais')
# ('em', 'e')
# ('2', 'nove')
# ('(', 'centavos')
# ('dois', ')')
# (')', ',')
# ('pavimentos', 'e')
# (',', 'nº')
# ('com', '2022NE01303')
# ('rampa', ',')
# ('e', 'no')
# ('escadas', 'valor')
# (',', 'de')
# ('18', 'R$')
# ('(', '7.763.247,12')
# ('dezoito', '(')
# (')', 'sete')
# ('salas', 'milhões')
# ('de', ',')
# ('aula', 'setecentos')
# (',', 'e')
# ('auditório', 'sessenta')
# (',', 'e')
# ('sala', 'três')
# ('de', 'mil')
# ('música', ',')
# (',', 'duzentos')
# ('grêmio', 'e')
# ('estudantil', 'quarenta')
# (',', 'e')
# ('biblioteca', 'sete')
# (',', 'reais')
# ('sala', 'e')
# ('de', 'doze')
# ('artes', 'centavos')
# ('plásticas', ')')
# (',', ',')
# ('sala', 'emitidas')
# ('multiuso', 'em')
# (',', '10/03/2022')
# ('sala', '.')
# ('multimídia', 'Evento')
# (',', ':')
# ('salas', '400091')
# ('de', '.')
# ('apoio', 'Modalidade')
# ('pedagógico', ':')
# (',', 'Global')
# ('cozinha', '.')
# ('industrial', 'Valor')
# ('e', 'total')
# ('refeitório', 'do')
# (',', 'Contrato')
# ('vestiários', ':')
# ('e', 'R$')
# ('sanitários', '11.963.826,74')
# (',', '(')
# ('salas', 'onze')
# ('administrativas', 'milhões')
# (',', ',')
# ('pátio', 'novecentos')
# ('coberto', 'e')
# ('e', 'sessenta')
# ('laboratórios', 'e')
# ('.', 'três')
# ('Também', 'mil')
# ('serão', ',')
# ('edificados', 'oitocentos')
# ('castelo', 'e')
# ('d', 'vinte')
# ('água', 'e')
# (',', 'seis')
# ('central', 'reais')
# ('de', 'e')
# ('glp', 'setenta')
# (',', 'e')
# ('bicicletário', 'quatro')
# (',', 'centavos')
# ('guarita', ')')
# (',', '.')
# ('estacionamento', 'Vigência')
# (',', ':')
# ('e', '1460')
# ('uma', '(')
# ('quadra', 'um')
# ('coberta', 'mil')
# ('com', 'e')
# ('719,64', 'quatrocentos')
# ('m²', 'e')
# ('que', 'sessenta')
# ('também', ')')
# ('abriga', 'dias')
# ('vestiários', 'corridos')
# ('e', ',')
# ('depósito', 'contados')
# ('.', 'a')
# ('Unidade', 'partir')
# ('Orçamentária', 'da')
# (':', 'data')
# ('18101', 'da')
# ('.', 'assinatura')
# ('Programa', 'do')
# ('de', 'Contrato')
# ('Trabalho', '.')
# (':', 'Assinatura')
# ('12.368.6221.3982.0001', ':')
# ('.', '17/03/2022')
# ('Natureza', '.')
# ('da', 'Assinantes')
# ('Despesa', ':')
# (':', 'Pela')
# ('4.4.90.51', 'SEEDF')
# ('.', ':')
# ('Fontes', 'HÉLVIA')
# ('de', 'MIRIDAN')
# ('Recursos', 'PARANAGUÁ')
# (':', 'FRAGA')
# ('103', '.')
# ('e', 'Pela')
# ('177021399', 'SOLLAR')
# ('.', 'ENGENHARIA')
# ('Notas', 'LTDA')
# ('de', '.')
# ('Empenho', ':')
# (':', 'MARDEN')
# ('nº', 'FREDERICO')
# ('2022NE01302', 'TOMÁS')
# (',', 'DA')
# ('no', 'SILVA')
# ('valor', '.')
# ('de', 'EXTRATO')
# ('R$', 'DO')
# ('975.630,09', 'CONTRATO')
# ('(', 'Nº')
# ('novecentos', '45.926/2022')
# ('e', 'Processo')
# ('setenta', ':')
# ('e', '00370-00002021/')
# ('cinco', '2021-11')
# ('mil', '.')
# (',', 'Partes')
# ('seiscentos', ':')
# ('e', 'Secretaria')
# ('trinta', 'de')
# ('reais', 'Estado')
# ('e', 'Desenvolvimento')
# ('nove', 'Econômico')
# ('centavos', 'do')
# (')', 'Distrito')
# (',', 'Federal')
# ('e', 'e')
# ('nº', 'a')
# ('2022NE01303', 'empresa')
# (',', 'Mondi')
# ('no', 'Comércio')
# ('valor', 'e')
# ('de', 'Representação')
# ('R$', 'de')
# ('7.763.247,12', 'Móveis')
# ('(', 'LTDA')
# ('sete', ',')
# ('milhões', 'inscrita')
# (',', 'no')
# ('setecentos', 'CNPJ')
# ('e', '/')
# ('sessenta', 'MF')
# ('e', 'sob')
# ('três', 'o')
# ('mil', 'n')
# (',', '°')
# ('duzentos', '37.110.556/0001')
# ('e', '-')
# ('quarenta', '40')
# ('e', 'Objeto')
# ('sete', ':')
# ('reais', 'Contratação')
# ('e', 'de')
# ('doze', 'empresa')
# ('centavos', 'especializada')
# (')', 'em')
# (',', 'serviços')
# ('emitidas', 'de')
# ('em', 'mudança')
# ('10/03/2022', 'para')
# ('.', 'prestação')
# ('Evento', 'de')
# (':', 'serviços')
# ('400091', 'de')
# ('.', 'desmontagem')
# ('Modalidade', 'e')
# (':', 'embalagem')
# ('Global', 'na')
# ('.', 'origem')
# ('Valor', ',')
# ('total', 'transporte')
# ('do', ',')
# ('Contrato', 'montagem')
# (':', 'e')
# ('R$', 'organização')
# ('11.963.826,74', 'no')
# ('(', 'destino')
# ('onze', ',')
# ('milhões', 'dos')
# (',', 'mobiliários')
# ('novecentos', ',')
# ('e', 'eletrodomésticos')
# ('sessenta', ',')
# ('e', 'eletrônicos')
# ('três', ',')
# ('mil', 'almoxarifado')
# (',', ',')
# ('oitocentos', 'documentos')
# ('e', ';')
# ('vinte', 'e')
# ('e', 'acondicionamento')
# ('seis', 'e')
# ('reais', 'montagem')
# ('e', 'de')
# ('setenta', '03')
# ('e', '(')
# ('quatro', 'três')
# ('centavos', ')')
# (')', 'arquivos')
# ('.', 'deslizantes')
# ('Vigência', 'para')
# (':', 'atender')
# ('1460', 'a')
# ('(', 'Secretaria')
# ('um', 'de')
# ('mil', 'Estado')
# ('e', 'de')
# ('quatrocentos', 'Desenvolvimento')
# ('e', 'Econômico')
# ('sessenta', 'do')
# (')', 'Distrito')
# ('dias', 'Federal')
# ('corridos', '-')
# (',', 'SDE')
# ('contados', '/')
# ('a', 'DF')
# ('partir', '.')
# ('da', 'Valor')
# ('data', ':')
# ('da', 'R$')
# ('assinatura', '47.948,95')
# ('do', '(')
# ('Contrato', 'quarenta')
# ('.', 'e')
# ('Assinatura', 'sete')
# (':', 'ml')
# ('17/03/2022', 'novecentos')
# ('.', 'e')
# ('Assinantes', 'quarenta')
# (':', 'e')
# ('Pela', 'oito')
# ('SEEDF', 'reais')
# (':', 'e')
# ('HÉLVIA', 'noventa')
# ('MIRIDAN', 'e')
# ('PARANAGUÁ', 'cinco')
# ('FRAGA', 'centavos')
# ('.', ')')
# ('Pela', '.')
# ('SOLLAR', 'Programa')
# ('ENGENHARIA', 'de')
# ('LTDA', 'Trabalho')
# ('.', ':')
# (':', '04122820785170062')
# ('MARDEN', ',')
# ('FREDERICO', 'Fonte')
# ('TOMÁS', ':')
# ('DA', '100')
# ('SILVA', ',')
# ('.', 'Natureza')
# ('EXTRATO', 'de')
# ('DO', 'Despesa')
# ('CONTRATO', ':')
# ('Nº', '339039')
# ('45.926/2022', '.')
# ('Processo', 'Nota')
# (':', 'de')
# ('00370-00002021/', 'Empenho')
# ('2021-11', ':')
# ('.', '2022NE00039')
# ('Partes', '.')
# (':', 'Unidade')
# ('Secretaria', 'Orçamentária')
# ('de', ':')
# ('Estado', '20101')
# ('Desenvolvimento', '.')
# ('Econômico', 'Data')
# ('do', 'de')
# ('Distrito', 'Assinatura')
# ('Federal', ':')
# ('e', '15/03/2022')
# ('a', '.')
# ('empresa', 'Signatários')
# ('Mondi', ':')
# ('Comércio', 'Pelo')
# ('e', 'Contratante')
# ('Representação', ':')
# ('de', 'JESUÍNO')
# ('Móveis', 'JESUS')
# ('LTDA', 'DE')
# (',', 'PEREIRA')
# ('inscrita', 'LEMES')
# ('no', ',')
# ('CNPJ', 'na')
# ('/', 'qualidade')
# ('MF', 'de')
# ('sob', 'Secretário')
# ('o', 'de')
# ('n', 'Estado')
# ('°', 'e')
# ('37.110.556/0001', 'pela')
# ('-', 'Contratada')
# ('40', ':')
# ('Objeto', 'Rafael')
# (':', 'Coelho')
# ('Contratação', 'Monteiro')
# ('de', ',')
# ('empresa', 'na')
# ('especializada', 'qualidade')
# ('em', 'de')
# ('serviços', 'representante')
# ('de', 'legal')
# ('mudança', '.')
# ('para', 'EXTRATO')
# ('prestação', 'DO')
# ('de', 'CONTRATO')
# ('serviços', 'Nº')
# ('de', '45832/2022')
# ('desmontagem', 'Processo')
# ('e', ':')
# ('embalagem', '00431-00000747/')
# ('na', '2022-66')
# ('origem', '.')
# (',', 'DAS')
# ('transporte', 'PARTES')
# (',', ':')
# ('montagem', 'SECRETARIA')
# ('e', 'DE')
# ('organização', 'ESTADO')
# ('no', 'DE')
# ('destino', 'DESENVOLVIMENTO')
# (',', 'SOCIAL')
# ('dos', 'DO')
# ('mobiliários', 'DISTRITO')
# (',', 'FEDERAL')
# ('eletrodomésticos', 'x')
# (',', 'OURO')
# ('eletrônicos', 'GÁS')
# (',', 'LTDA')
# ('almoxarifado', '.')
# (',', 'DA')
# ('documentos', 'MODALIDADE')
# (';', ':')
# ('e', 'Pregão')
# ('acondicionamento', 'Eletrônico')
# ('e', 'nº')
# ('montagem', '86/2021')
# ('de', '.')
# ('03', 'DO')
# ('(', 'OBJETO')
# ('três', ':')
# (')', 'O')
# ('arquivos', 'Contrato')
# ('deslizantes', 'tem')
# ('para', 'por')
# ('atender', 'objeto')
# ('a', 'a')
# ('Secretaria', 'aquisição')
# ('de', 'de')
# ('Estado', 'gás')
# ('de', 'liquefeito')
# ('Desenvolvimento', 'de')
# ('Econômico', 'petróleo')
# ('do', '-')
# ('Distrito', 'GLP')
# ('Federal', ',')
# ('-', 'consoante')
# ('SDE', 'especifica')
# ('/', 'o')
# ('DF', 'Edital')
# ('.', 'de')
# ('Valor', 'Pregão')
# (':', 'Eletrônico')
# ('R$', 'nº')
# ('47.948,95', '86/2021')
# ('(', '(')
# ('quarenta', '77731875')
# ('e', ')')
# ('sete', ',')
# ('ml', 'a')
# ('novecentos', 'Ata')
# ('e', 'de')
# ('quarenta', 'Registro')
# ('e', 'de')
# ('oito', 'Preços')
# ('reais', 'nº')
# ('e', '140/2021')
# ('noventa', '(')
# ('e', '77731988')
# ('cinco', ')')
# ('centavos', 'que')
# (')', 'passam')
# ('.', 'a')
# ('Programa', 'integrar')
# ('de', 'o')
# ('Trabalho', 'presente')
# (':', 'Termo')
# ('04122820785170062', '.')
# (',', 'DO')
# ('Fonte', 'VALOR')
# (':', ':')
# ('100', 'O')
# (',', 'valor')
# ('Natureza', 'total')
# ('de', 'do')
# ('Despesa', 'Contrato')
# (':', 'é')
# ('339039', 'de')
# ('.', 'R$')
# ('Nota', '22.636,80')
# ('de', '(')
# ('Empenho', 'vinte')
# (':', 'e')
# ('2022NE00039', 'dois')
# ('.', 'mil')
# ('Unidade', 'seiscentos')
# ('Orçamentária', 'e')
# (':', 'trinta')
# ('20101', 'e')
# ('.', 'seis')
# ('Data', 'reais')
# ('de', 'e')
# ('Assinatura', 'oitenta')
# (':', 'centavos')
# ('15/03/2022', ')')
# ('.', '.')
# ('Signatários', 'DA')
# (':', 'DOTAÇÃO')
# ('Pelo', 'ORÇAMENTÁRIA')
# ('Contratante', ':')
# (':', 'UO')
# ('JESUÍNO', ':')
# ('JESUS', '17.101')
# ('DE', ';')
# ('PEREIRA', 'PT')
# ('LEMES', ':')
# (',', '08.122.8228.8517.0139')
# ('na', ',')
# ('qualidade', 'ND')
# ('de', '33.90.30.04')
# ('Secretário', ';')
# ('de', 'Fonte')
# ('Estado', ':')
# ('e', '100')
# ('pela', ',')
# ('Contratada', 'conforme')
# (':', 'Nota')
# ('Rafael', 'de')
# ('Coelho', 'Empenho')
# ('Monteiro', 'nº')
# (',', '2022NE00103')
# ('na', ',')
# ('qualidade', 'no')
# ('de', 'valor')
# ('representante', 'de')
# ('legal', 'R$')
# ('.', '22.636,80')
# ('EXTRATO', '(')
# ('DO', 'vinte')
# ('CONTRATO', 'e')
# ('Nº', 'dois')
# ('45832/2022', 'mil')
# ('Processo', 'seiscentos')
# (':', 'e')
# ('00431-00000747/', 'trinta')
# ('2022-66', 'e')
# ('.', 'seis')
# ('DAS', 'reais')
# ('PARTES', 'e')
# (':', 'oitenta')
# ('SECRETARIA', 'centavos')
# ('DE', ')')
# ('ESTADO', ',')
# ('DE', 'na')
# ('DESENVOLVIMENTO', 'modalidade')
# ('SOCIAL', '03-Global')
# ('DO', ',')
# ('DISTRITO', 'emitida')
# ('FEDERAL', 'em')
# ('x', '22/02/2022')
# ('OURO', '.')
# ('GÁS', 'DA')
# ('LTDA', 'VIGÊNCIA')
# ('.', ':')
# ('DA', 'O')
# ('MODALIDADE', 'contrato')
# (':', 'terá')
# ('Pregão', 'vigência')
# ('Eletrônico', 'de')
# ('nº', '90')
# ('86/2021', '(')
# ('.', 'noventa')
# ('DO', ')')
# ('OBJETO', 'dias')
# (':', 'a')
# ('O', 'contar')
# ('Contrato', 'da')
# ('tem', 'data')
# ('por', 'de')
# ('objeto', 'sua')
# ('a', 'assinatura')
# ('aquisição', '.')
# ('de', 'DATA')
# ('gás', 'DE')
# ('liquefeito', 'ASSINATURA')
# ('de', ':')
# ('petróleo', '04/03/2022')
# ('-', '.')
# ('GLP', 'SIGNATÁRIOS')
# (',', ':')
# ('consoante', 'Pela')
# ('especifica', 'CONTRATANTE')
# ('o', ':')
# ('Edital', 'THIAGO')
# ('de', 'VINÍCIUS')
# ('Pregão', 'PINHEIRO')
# ('Eletrônico', 'DA')
# ('nº', 'SILVA')
# ('86/2021', ',')
# ('(', 'na')
# ('77731875', 'qualidade')
# (')', 'de')
# (',', 'Secretário-Executivo')
# ('a', 'de')
# ('Ata', 'Desenvolvimento')
# ('de', 'Social')
# ('Registro', 'da')
# ('de', 'Secretaria')
# ('Preços', 'de')
# ('nº', 'Estado')
# ('140/2021', 'de')
# ('(', 'Desenvolvimento')
# ('77731988', 'Social')
# (')', 'do')
# ('que', 'Distrito')
# ('passam', 'Federal')
# ('a', ',')
# ('integrar', 'e')
# ('o', 'pela')
# ('presente', 'CONTRATADA')
# ('Termo', ':')
# ('.', 'BRUNA')
# ('DO', 'MARIA')
# ('VALOR', 'OLIVEIRA')
# (':', 'ARAÚJO')
# ('O', ',')
# ('valor', 'na')
# ('total', 'qualidade')
# ('do', 'de')
# ('Contrato', 'Procuradora')
# ('é', '.')
# ('de', 'EXTRATO')
# ('R$', 'DO')
# ('22.636,80', 'CONTRATO')
# ('(', 'Nº')
# ('vinte', '45927/2022')
# ('e', 'Processo')
# ('dois', ':')
# ('mil', '00431-00024978/')
# ('seiscentos', '2021-84')
# ('e', '.')
# ('trinta', 'DAS')
# ('e', 'PARTES')
# ('seis', ':')
# ('reais', 'SECRETARIA')
# ('e', 'DE')
# ('oitenta', 'ESTADO')
# ('centavos', 'DE')
# (')', 'DESENVOLVIMENTO')
# ('.', 'SOCIAL')
# ('DA', 'DO')
# ('DOTAÇÃO', 'DISTRITO')
# ('ORÇAMENTÁRIA', 'FEDERAL')
# (':', 'x')
# ('UO', 'BANCO')
# (':', 'DE')
# ('17.101', 'BRASÍLIA')
# (';', 'S.A')
# ('PT', 'BRB')
# (':', '.')
# ('08.122.8228.8517.0139', 'DA')
# (',', 'MODALIDADE')
# ('ND', ':')
# ('33.90.30.04', 'Dispensa')
# (';', 'de')
# ('Fonte', 'Licitação')
# (':', ',')
# ('100', 'baseada')
# (',', 'no')
# ('conforme', 'artigo')
# ('Nota', '24')
# ('de', ',')
# ('Empenho', 'inc')
# ('nº', '.')
# ('2022NE00103', 'VIII')
# (',', ',')
# ('no', 'da')
# ('valor', 'lei')
# ('de', 'nº')
# ('R$', '8.666/1993')
# ('22.636,80', '.')
# ('(', 'DO')
# ('vinte', 'OBJETO')
# ('e', ':')
# ('dois', 'O')
# ('mil', 'CONTRATO')
# ('seiscentos', 'tem')
# ('e', 'por')
# ('trinta', 'objeto')
# ('e', 'a')
# ('seis', 'Contratação')
# ('reais', 'de')
# ('e', 'agente')
# ('oitenta', 'bancário')
# ('centavos', 'para')
# (')', 'operacionalização')
# (',', 'dos')
# ('na', 'pagamentos')
# ('modalidade', 'de')
# ('03-Global', 'benefícios')
# (',', 'socioassistenciais')
# ('emitida', 'da')
# ('em', 'Secretaria')
# ('22/02/2022', 'de')
# ('.', 'Estado')
# ('DA', 'de')
# ('VIGÊNCIA', 'Desenvolvimento')
# (':', 'Social')
# ('O', '(')
# ('contrato', 'SEDES')
# ('terá', ')')
# ('vigência', ',')
# ('de', 'consoante')
# ('90', 'especificações')
# ('(', 'constantes')
# ('noventa', 'no')
# (')', 'Termo')
# ('dias', 'de')
# ('a', 'Referência')
# ('contar', '-')
# ('da', 'SEDES')
# ('data', '/')
# ('de', 'SEEDS')
# ('sua', '/')
# ('assinatura', 'SUBSAS')
# ('.', '/')
# ('DATA', 'UNIBS')
# ('DE', '(')
# ('ASSINATURA', '81419724')
# (':', ')')
# ('04/03/2022', 'que')
# ('.', 'passa')
# ('SIGNATÁRIOS', 'a')
# (':', 'integrar')
# ('Pela', 'o')
# ('CONTRATANTE', 'presente')
# (':', 'Termo')
# ('THIAGO', ',')
# ('VINÍCIUS', 'independente')
# ('PINHEIRO', 'de')
# ('DA', 'transcrição')
# ('SILVA', '.')
# (',', 'DO')
# ('na', 'VALOR')
# ('qualidade', ':')
# ('de', 'O')
# ('Secretário-Executivo', 'valor')
# ('de', 'total')
# ('Desenvolvimento', 'do')
# ('Social', 'Contrato')
# ('da', 'é')
# ('Secretaria', 'de')
# ('de', 'R$')
# ('Estado', '547.811,64')
# ('de', '(')
# ('Desenvolvimento', 'quinhentos')
# ('Social', 'e')
# ('do', 'quarenta')
# ('Distrito', 'e')
# ('Federal', 'sete')
# (',', 'mil')
# ('e', 'oitocentos')
# ('pela', 'e')
# ('CONTRATADA', 'onze')
# (':', 'reais')
# ('BRUNA', 'e')
# ('MARIA', 'sessenta')
# ('OLIVEIRA', 'e')
# ('ARAÚJO', 'quatro')
# (',', 'centavos')
# ('na', ')')
# ('qualidade', '.')
# ('de', 'DA')
# ('Procuradora', 'DOTAÇÃO')
# ('.', 'ORÇAMENTÁRIA')
# ('EXTRATO', ':')
# ('DO', 'UO')
# ('CONTRATO', ':')
# ('Nº', '17.101')
# ('45927/2022', ';')
# ('Processo', 'PT')
# (':', ':')
# ('00431-00024978/', '08.244.6228.4232.0002')
# ('2021-84', ',')
# ('.', 'ND')
# ('DAS', '33.90.39.81')
# ('PARTES', ';')
# (':', 'Fonte')
# ('SECRETARIA', ':')
# ('DE', '100')
# ('ESTADO', ',')
# ('DE', 'conforme')
# ('DESENVOLVIMENTO', 'Nota')
# ('SOCIAL', 'de')
# ('DO', 'Empenho')
# ('DISTRITO', 'nº')
# ('FEDERAL', '2022NE00130')
# ('x', ',')
# ('BANCO', 'no')
# ('DE', 'valor')
# ('BRASÍLIA', 'de')
# ('S.A', 'R$')
# ('BRB', '547.811,64')
# ('.', '(')
# ('DA', 'quinhentos')
# ('MODALIDADE', 'e')
# (':', 'quarenta')
# ('Dispensa', 'e')
# ('de', 'sete')
# ('Licitação', 'mil')
# (',', 'oitocentos')
# ('baseada', 'e')
# ('no', 'onze')
# ('artigo', 'reais')
# ('24', 'e')
# (',', 'sessenta')
# ('inc', 'e')
# ('.', 'quatro')
# ('VIII', 'centavos')
# (',', ')')
# ('da', ',')
# ('lei', 'na')
# ('nº', 'modalidade')
# ('8.666/1993', '02-Estimativo')
# ('.', ',')
# ('DO', 'emitida')
# ('OBJETO', 'em')
# (':', '09/03/2022')
# ('O', '.')
# ('CONTRATO', 'DA')
# ('tem', 'VIGÊNCIA')
# ('por', ':')
# ('objeto', 'O')
# ('a', 'contrato')
# ('Contratação', 'terá')
# ('de', 'vigência')
# ('agente', 'de')
# ('bancário', '12')
# ('para', '(')
# ('operacionalização', 'doze')
# ('dos', ')')
# ('pagamentos', 'meses')
# ('de', ',')
# ('benefícios', 'a')
# ('socioassistenciais', 'contar')
# ('da', 'da')
# ('Secretaria', 'data')
# ('de', 'de')
# ('Estado', 'sua')
# ('de', 'assinatura')
# ('Desenvolvimento', ',')
# ('Social', 'prorrogáveis')
# ('(', 'por')
# ('SEDES', 'iguais')
# (')', 'e')
# (',', 'sucessivos')
# ('consoante', 'períodos')
# ('especificações', ',')
# ('constantes', 'limitada')
# ('no', 'a')
# ('Termo', 'sessenta')
# ('de', 'meses')
# ('Referência', ',')
# ('-', 'na')
# ('SEDES', 'forma')
# ('/', 'do')
# ('SEEDS', 'artigo')
# ('/', '57')
# ('SUBSAS', ',')
# ('/', 'inciso')
# ('UNIBS', 'II')
# ('(', 'da')
# ('81419724', 'Lei')
# (')', 'nº')
# ('que', '8.666/1993')
# ('passa', '.')
# ('a', 'DATA')
# ('integrar', 'DE')
# ('o', 'ASSINATURA')
# ('presente', ':')
# ('Termo', '11/03/2022')
# (',', '.')
# ('independente', 'SIGNATÁRIOS')
# ('de', ':')
# ('transcrição', 'Pela')
# ('.', 'CONTRATANTE')
# ('DO', ':')
# ('VALOR', 'THIAGO')
# (':', 'VINÍCIUS')
# ('O', 'PINHEIRO')
# ('valor', 'DA')
# ('total', 'SILVA')
# ('do', ',')
# ('Contrato', 'na')
# ('é', 'qualidade')
# ('de', 'de')
# ('R$', 'Secretário-Executivo')
# ('547.811,64', 'de')
# ('(', 'Desenvolvimento')
# ('quinhentos', 'Social')
# ('e', 'da')
# ('quarenta', 'Secretaria')
# ('e', 'de')
# ('sete', 'Estado')
# ('mil', 'de')
# ('oitocentos', 'Desenvolvimento')
# ('e', 'Social')
# ('onze', 'do')
# ('reais', 'Distrito')
# ('e', 'Federal')
# ('sessenta', ',')
# ('e', 'e')
# ('quatro', 'pela')
# ('centavos', 'CONTRATADA')
# (')', ':')
# ('.', 'EUGENIA')
# ('DA', 'REGINA')
# ('DOTAÇÃO', 'DE')
# ('ORÇAMENTÁRIA', 'MELO')
# (':', ',')
# ('UO', 'na')
# (':', 'qualidade')
# ('17.101', 'de')
# (';', 'Diretora')
# ('PT', 'Executiva')
# (':', 'de')
# ('08.244.6228.4232.0002', 'Atacado')
# (',', 'e')
# ('ND', 'Governo')
# ('33.90.39.81', '.')

# %%
#labels_skweak = labels
numero_contrato = 0
numero_contrato_total = 0
B_numero_contrato = 0
numero_contrato_gold=[]
obj_sk=[]


data_assinatura_contrato = 0
data_assinatura_contrato_total = 0
B_data_assinatura_contrato = 0
data_assinatura_contrato_gold = []

unidade_orcamentaria = 0
unidade_orcamentaria_total = 0
B_unidade_orcamentaria = 0
unidade_orcamentaria_gold = []
teste=[]

programa_trabalho = 0
programa_trabalho_total = 0
B_programa_trabalho = 0
programa_trabalho_gold = []

for text_sk, label_skweak, text_gold,  label_gold in zip(termos_skweak, labels_skweak, atos, labels):
    for text_skw, termo_skweak, text_ato, termo_gold in zip(text_sk, label_skweak, text_gold,  label_gold ):
       #print("termo gold", termo_gold)
       #print("termo swkeak", termo_skweak) 
       if termo_gold == "B-numero_contrato":
           numero_contrato_total+=1
           B_numero_contrato=termo_gold
           if termo_gold == termo_skweak:
               numero_contrato+=1
           else:
               numero_contrato_gold.append(text_ato)

       elif termo_gold == "B-data_assinatura_contrato":
                
            data_assinatura_contrato_total+=1
            B_data_assinatura_contrato=termo_gold
            if termo_gold == termo_skweak:
                data_assinatura_contrato+=1
            else:
                data_assinatura_contrato_gold.append(text_ato)

       elif termo_gold == "B-unidade_orcamentaria":
                
            unidade_orcamentaria_total+=1
            B_unidade_orcamentaria=termo_gold
            if termo_gold == termo_skweak:
                unidade_orcamentaria+=1
                
            else:
                unidade_orcamentaria_gold.append(text_ato) 
                 
       elif termo_gold == "B-programa_trabalho":
                
            programa_trabalho_total+=1
            B_programa_trabalho=termo_gold
            if termo_gold == termo_skweak:
                programa_trabalho+=1
            else:
                programa_trabalho_gold.append(text_ato)                
print("Tipo da entidade           Total Entidade Gold                 Total Entidade Skweak")                
print("B-numero_contrato","       ",numero_contrato_total,"            ",numero_contrato,"      ","       ",numero_contrato_gold)
print("B-data_assinatura_contrato" ,data_assinatura_contrato_total,"   ",data_assinatura_contrato,"      ",data_assinatura_contrato_gold)
print("B-unidade_orcamentaria","  ",unidade_orcamentaria_total, "      ",unidade_orcamentaria,"          ",unidade_orcamentaria_gold)
print( "B-programa_trabalho","    ", programa_trabalho_total, "        ",programa_trabalho,"             ",programa_trabalho_gold)

#print(programa_trabalho_gold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [140], in <cell line: 25>()
#      22 B_programa_trabalho = 0
#      23 programa_trabalho_gold = []
# ---> 25 for text_sk, label_skweak, text_gold,  label_gold in zip(termos_skweak, labels_skweak, atos, labels):
#      26     for text_skw, termo_skweak, text_ato, termo_gold in zip(text_sk, label_skweak, text_gold,  label_gold ):
#      27        #print("termo gold", termo_gold)
#      28        #print("termo swkeak", termo_skweak)
#      29        if termo_gold == "B-numero_contrato":
#
# NameError: name 'atos' is not defined

# %%
#print(labels_skweak[1])
#print(labels[1])
#print("ato_skweak", ato_skweak[8])
#print("ato gold ", ato_gold[8])
#print("termo skweak", termo_skweak[0])
#print("termo gold",termo_gold[0])

# %%
#supervisão fraca
x=termos_skweak
y=labels_skweak

# %%
len(x)
# Out:
# 15

# %%
#gold
x1=atos
y1=labels

# %%
len(x1)
# Out:
# 16

# %%
#Split da Supervisão Fraca
from sklearn.model_selection import train_test_split
# 80% treino, 20% teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, shuffle=False)
print( 'x_train',len(x_train),'\n','x_test',len(x_test),'\n','total atos',len(x))
# Out:
# x_train 978
#  x_test 245
#  total atos 1223

# %%
#Split da base ouro
from sklearn.model_selection import train_test_split
# 80% treino, 20% teste
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=None, shuffle=False)
#random_state: the seed number to be passed to the shuffle operation, thus making the experiment reproducible.
x_train_gold, x_test_gold, y_train_gold, y_test_gold = train_test_split(x1, y1, test_size=0.2, random_state=42, shuffle=False)
print( 'x_train_gold',len(x_train_gold),'\n','x_test_gold',len(x_test_gold),'\n','total atos',len(x))
# Out:
# x_train_gold 978
#  x_test_gold 245
#  total atos 1223

# %% [markdown]
# CRF

# %%
def get_features(sentence):
        """Create features for each word in act.
        Create a list of dict of words features to be used in the predictor module.
        Args:
            act (list): List of words in an act.
        Returns:
            A list with a dictionary of features for each of the words.
        """
        sent_features = []
        for i in range(len(sentence)):
            word_feat = {
                'word': sentence[i].lower(),
                'capital_letter': sentence[i][0].isupper(),
                'all_capital': sentence[i].isupper(),
                'isdigit': sentence[i].isdigit(),
                'word_before': sentence[i].lower() if i == 0 else sentence[i-1].lower(),
                'word_after:': sentence[i].lower() if i+1 >= len(sentence) else sentence[i+1].lower(),
                'BOS': i == 0,
                'EOS': i == len(sentence)-1
            }
            sent_features.append(word_feat)
        return sent_features
    
for i in range(len(x_train)):
    x[i] = get_features(x_train[i])

# %%
import sklearn_crfsuite
from sklearn_crfsuite import metrics


crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=10,
    c2=0.1,
    max_iterations=100,
    #max_iterations=50,
    
    all_possible_transitions=False,
    all_possible_states=True
)

#crf.fit(x_train, y_train)

try:
    #crf.fit(x_train[:200], y_train[:200])
    crf.fit(x_train, y_train)
except AttributeError:
    pass

# %%
crf.classes_
# Out:
# ['O',
#  'B-numero_contrato',
#  'B-processo_gdf',
#  'I-processo_gdf',
#  'B-data_assinatura_contrato',
#  'B-unidade_orcamentaria',
#  'B-programa_trabalho',
#  'B-natureza_despesa',
#  'B-nota_empenho',
#  'B-valor_contrato',
#  'I-data_assinatura_contrato']

# %%
#Rotulação baseada no modelo treinado com supervisão fraca
classes = list(crf.classes_)
classes.remove('O')

y_pred = crf.predict(x_test_gold)
metrics.flat_f1_score(y_test_gold, y_pred, average='weighted', labels=classes)
# Out:
# /home/lucelia_vieira/Experimentos/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1492: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(
# 0.6905628269618073

# %%
print(metrics.flat_classification_report(
    #y_test[:200], y_pred[:200], labels=classes, digits=3))
    y_test_gold, y_pred, labels=classes, digits=3))
# Out:
# /home/lucelia_vieira/Experimentos/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucelia_vieira/Experimentos/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                             precision    recall  f1-score   support
#
#          B-numero_contrato      0.582     0.391     0.468       253
#             B-processo_gdf      0.947     0.991     0.969       233
#             I-processo_gdf      0.971     1.000     0.985       202
# B-data_assinatura_contrato      0.118     0.084     0.098       154
#     B-unidade_orcamentaria      0.329     0.385     0.355       122
#        B-programa_trabalho      0.958     0.972     0.965       211
#         B-natureza_despesa      0.880     0.880     0.880       133
#             B-nota_empenho      0.974     0.921     0.947       202
#           B-valor_contrato      0.703     0.563     0.625       311
#        I-programa_trabalho      0.143     0.444     0.216         9
#         I-natureza_despesa      0.000     0.000     0.000         0
#             I-nota_empenho      0.000     0.000     0.000         0
#          I-numero_contrato      0.500     0.083     0.143        12
# I-data_assinatura_contrato      0.000     0.000     0.000        56
#     I-unidade_orcamentaria      0.000     0.000     0.000         1
#
#                  micro avg      0.712     0.674     0.693      1899
#                  macro avg      0.474     0.448     0.443      1899
#               weighted avg      0.718     0.674     0.691      1899
# /home/lucelia_vieira/Experimentos/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucelia_vieira/Experimentos/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucelia_vieira/Experimentos/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucelia_vieira/Experimentos/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# CODIGO DE APLICACAO DO MODELO CRF TREINADO

import dodfCRF
#crf = dodfCRF.CRFContratos()
#crf.init_model_from_path("contratosFINAL.pkl")
#crfIOB = crf.model_predict(dados)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [45], in <cell line: 3>()
#       1 # CODIGO DE APLICACAO DO MODELO CRF TREINADO
# ----> 3 import dodfCRF
#
# ModuleNotFoundError: No module named 'dodfCRF'
