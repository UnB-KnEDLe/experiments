# %% [markdown]
# # Código para aplicação das LB direto no dado para rotulação

# %% [markdown]
# ## Preparando o test da base ouro para aplicar as labels functions

# %%
import pandas as pd
import nltk
import scipy.stats
import sklearn
import sklearn_crfsuite
from sklearn_crfsuite import metrics

# %%
#apenas para testar o iob com spacy
#cria um novo dataset com as 2000 primeiras linhas
#csv_reader = pd.read_csv("/home/lucelia_vieira/Experimentos/ner/CSVs/REL_EXTRATO_CONTRATO_COMPLETO.csv", nrows=200)

# %%
#df = ["EXTRATO DO CONTRATO No 11/2019 PROCESSO: 00390-00003006/2019-92. ESPECIE: Contrato de Aquisicao de Bens pelo Distrito Federal no 11/2019. PARTES: Secretaria de Estado de Desenvolvimento Urbano e Habitacao do Distrito Federal - SEDUH/DF e INDUSTRIA DE AGUA MINERAL IBIA LTDA. DO OBJETO: Aquisicao de agua potavel de mesa sem gas e garrafao retornavel, destinados ao atendimento desta pasta, conforme demais especiGcacoes e condicoes estabelecidas no Termo de Referencia Anexo I do Edital de Pregao Eletronico no 0058/2018 - SCG/SEPLAG, da Proposta da empresa INDUSTRIA DE AGUA MINERAL IBIA LTDA de 11/06/2018 e da Lei no 8.666, de 21 de junho de 1993, que passam a integrar o presente Termo. DO VALOR: R$ 11.661,00 (onze mil, seiscentos e sessenta e um reais) conforme Nota de Empenho no 2019NE00180, emitida em 18/07/2019. Dotacao Orcamentaria P.T 15.122.6001.8517.0131 - Natureza da Despesa: 3390.30 - Fonte de Recursos: 100. DO PRAZO DE VIGENCIA: O Contrato tera vigencia de 06 (seis) meses a contar do dia 07/08/2019. DATA DE ASSINATURA: 22/07/2019. SIGNATARIOS: Pelo Distrito Federal: Mateus Leandro de Oliveira, na qualidade de Secretario de Estado. Pela Contratada: Eduardo Barros de Queiroz Rodrigues, na qualidade de Socio Administrador.", "EXTRATO DO CONTRATO Nº 06/2021 Processo: 00139-00001275/2021-00. Partes: DF - ADMINISTRAÇÃO REGIONAL DO CRUZEIRO X COMERCIAL DE ALIMENTOS PARK SUL. Objeto: O presente contrato tem por objeto a contratação de empresa especializada na área de alimentação para confecção e fornecimento de 50 KG DE BOLO CONFEITADO TIPO ANIVERSÁRIO COM MASSA PÃO DE LÓ COM RECHEIO DE BABA DE MOÇA, BEIJINHO OU DOCE DE LEITE E COBERTURA DE CHANTILLY DECORADO COM ACABAMENTO, no evento de comemoração ao aniversário de 62 anos do Cruzeiro no dia 30/11/2021. Valor do Contrato: R$ 2.000,00 (Dois Mil Reais). Dotação orçamentária: Unidade Orçamentária: 190113. Programa de Trabalho: 13.392.6219.3678.0136 . Natureza da Despesa: 339039. Fonte de Recursos: 120. Nota de Empenho: 2021NE00259. Valor do Empenho Inicial: R$ 2.000,00 (Dois Mil Reais), emitida em 26/11/2021 sob o evento 400091, na Modalidade 1   Ordinário. Fundamento Legal: Art. 24 da Lei nº 8.666/1993. Data da Assinatura: 29/11/2021. Signatários: Pelo DISTRITO FEDERAL: LUIZ EDUARDO GOMES DE PAULA PESSOA, na qualidade de Administrador Regional do Cruzeiro; pela COMERCIAL DE ALIMENTOS PARK SUL: GIVANILDES DE AGUIAR MORAIS, na qualidade de Gerente Geral."]

# %%
#Carrega o dataset de teste para aplicacao das LB
df_sk_1 = pd.read_csv('./CSVs/Extrato_Contrato_Split_V1_0_x_test_texto.csv', dtype=str)
df_sk_1
# Out:
#     Unnamed: 0                                              Texto
# 0            0  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 1            1  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 2            2  EXTRATO DO CONTRATO Nº 09/2022 Contratante : T...
# 3            3  EXTRATO DO CONTRATO Nº 43845/2021 Processo : 0...
# 4            4  EXTRATO DO CONTRATO DE CONCESSÃO DE DIREITO RE...
# ..         ...                                                ...
# 303        303  EXTRATO DO CONTRATO Nº 44178/2021 Processo : 0...
# 304        304  EXTRATO DO CONTRATO Nº 158/2021 Processo : 001...
# 305        305  EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 306        306  EXTRATO DO CONTRATO Nº 173/2021 Processo : 001...
# 307        307  EXTRATO DO CONTRATO Nº 43721/2021 Processo : 0...
#
# [308 rows x 2 columns]

# %%
#criando novo dataframe somente com os textos
df_sk = df_sk_1['Texto'].reset_index(drop=True)
df_sk
# Out:
# 0      EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 1      EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 2      EXTRATO DO CONTRATO Nº 09/2022 Contratante : T...
# 3      EXTRATO DO CONTRATO Nº 43845/2021 Processo : 0...
# 4      EXTRATO DO CONTRATO DE CONCESSÃO DE DIREITO RE...
#                              ...
# 303    EXTRATO DO CONTRATO Nº 44178/2021 Processo : 0...
# 304    EXTRATO DO CONTRATO Nº 158/2021 Processo : 001...
# 305    EXTRATO DO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...
# 306    EXTRATO DO CONTRATO Nº 173/2021 Processo : 001...
# 307    EXTRATO DO CONTRATO Nº 43721/2021 Processo : 0...
# Name: Texto, Length: 308, dtype: object

# %%
#len(df_sk)

# %%
# CODIGO DE APLICACAO DA SUPERVISAO FRACA CONTRATO
import dodfSkweak_v1_2
skw = dodfSkweak_v1_2.SkweakContratos(df_sk)
skw.apply_label_functions()
skw.train_HMM_Dodf()
#data_label=skw.get_hmm_dataframe()
# Out:
# Starting iteration 1
# Finished E-step with 308 documents
# Starting iteration 2
#          1      -16729.5736             +nan
# Finished E-step with 308 documents
# Starting iteration 3
#          2      -16279.1909        +450.3827
# Finished E-step with 308 documents
# Starting iteration 4
#          3      -16262.2250         +16.9659
# Finished E-step with 308 documents
#          4      -16256.9731          +5.2519
# Write to ./data/reuters_small.spacy...done

# %%
# CODIGO DE APLICACAO DA SUPERVISAO FRACA CONTRATO
import dodfSkweak_Aditamento
skw = dodfSkweak_Aditamento.SkweakAditamento(df_sk)
skw.apply_label_functions()
skw.train_HMM_Dodf()
#data_label=skw.get_hmm_dataframe()
# Out:
# Starting iteration 1
# Finished E-step with 308 documents
# Starting iteration 2
#          1       -7312.5160             +nan
# Finished E-step with 308 documents
# Starting iteration 3
#          2       -6999.1928        +313.3232
# Finished E-step with 308 documents
# Starting iteration 4
#          3       -6994.2591          +4.9337
# Finished E-step with 308 documents
#          4       -6993.1373          +1.1218
# Write to ./data/aditamento.spacy...done

# %%
# converting to CSV file
#data_label.to_csv("./CSVs/base_rotulada_supervisao_fraca.csv")

# %%
corpus = skw.get_IOB()

# %%
corpus
# Out:
# [['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'DE O',
#   'PRESTAÇÃO O',
#   'DE O',
#   'SERVIÇOS O',
#   'Nº O',
#   '25/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '00094-00005321/ B-processo_gdf',
#   '2019-81 I-processo_gdf',
#   '. O',
#   'PARTES O',
#   ': O',
#   'SERVIÇO O',
#   'DE O',
#   'LIMPEZA O',
#   'URBANA O',
#   'DO O',
#   'DISTRITO O',
#   'FEDERAL O',
#   '- O',
#   'SLU O',
#   '/ O',
#   'DF O',
#   'e O',
#   'a O',
#   'empresa O',
#   'CONÁGUA O',
#   'AMBIENTAL O',
#   'LTDA O',
#   ', O',
#   'inscrita O',
#   'no O',
#   'CNPJ O',
#   '/ O',
#   'MF O',
#   'sob O',
#   'o O',
#   'nº O',
#   '01.615.998/ O',
#   '0001-00 O',
#   '. O',
#   'OBJETO O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'prestação O',
#   'de O',
#   'serviços O',
#   'de O',
#   'laboratório O',
#   'acreditado O',
#   'pelo O',
#   'INMETRO O',
#   'para O',
#   'avaliar O',
#   'os O',
#   'parâmetros O',
#   'e O',
#   'indicadores O',
#   'da O',
#   'eficácia O',
#   'do O',
#   'tratamento O',
#   'do O',
#   'efluente O',
#   'na O',
#   'Usina O',
#   'de O',
#   'Tratamento O',
#   'de O',
#   'Chorume O',
#   '- O',
#   'UTC O',
#   ', O',
#   'localizada O',
#   'no O',
#   'Aterro O',
#   'Sanitário O',
#   'de O',
#   'Brasília O',
#   '- O',
#   'ASB O',
#   ', O',
#   'conforme O',
#   'especificações O',
#   'e O',
#   'condições O',
#   'estabelecidas O',
#   'no O',
#   'Edital O',
#   'e O',
#   'seus O',
#   'Anexos O',
#   ', O',
#   'consoante O',
#   'especifica O',
#   'o O',
#   'Edital O',
#   'de O',
#   'Licitação O',
#   'do O',
#   'Pregão O',
#   'Eletrônico O',
#   'nº O',
#   '15/2021 O',
#   'CPL O',
#   '/ O',
#   'SLU-DF O',
#   'e O',
#   'da O',
#   'Proposta O',
#   'de O',
#   'Preços O',
#   ', O',
#   'que O',
#   'passam O',
#   'a O',
#   'integrar O',
#   'o O',
#   'presente O',
#   'Termo O',
#   'sem O',
#   'necessidade O',
#   'de O',
#   'transcrição O',
#   'na O',
#   'íntegra O',
#   '. O',
#   'FUNDAMENTAÇÃO O',
#   'LEGAL O',
#   ': O',
#   'O O',
#   'presente O',
#   'Contrato O',
#   'obedece O',
#   'aos O',
#   'termos O',
#   'do O',
#   'Edital O',
#   'de O',
#   'Licitação O',
#   'do O',
#   'Pregão O',
#   'Eletrônico O',
#   'nº O',
#   '15/2021 O',
#   'CPL O',
#   '/ O',
#   'SLU-DF O',
#   ', O',
#   'da O',
#   'Proposta O',
#   'de O',
#   'Preços O',
#   'e O',
#   'da O',
#   'Lei O',
#   'nº O',
#   '8.666 O',
#   ', O',
#   'de O',
#   '21.06.93 O',
#   '. O',
#   'VALOR O',
#   ': O',
#   'O O',
#   'valor O',
#   'total O',
#   'do O',
#   'Contrato O',
#   'é O',
#   'de O',
#   'R$ O',
#   '84.240,00 O',
#   '( O',
#   'oitenta O',
#   'e O',
#   'quatro O',
#   'mil O',
#   'e O',
#   'duzentos O',
#   'e O',
#   'quarenta O',
#   'reais O',
#   ') O',
#   ', O',
#   'devendo O',
#   'a O',
#   'importância O',
#   'ser O',
#   'atendida O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotações O',
#   'orçamentárias O',
#   'consignadas O',
#   'no O',
#   'orçamento O',
#   'corrente O',
#   'Lei O',
#   'Orçamentária O',
#   'Anual O',
#   'nº O',
#   '6.778 O',
#   'de O',
#   '06/01/2021 O',
#   ', O',
#   'enquanto O',
#   'a O',
#   'parcela O',
#   'remanescente O',
#   'será O',
#   'custeada O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotações O',
#   'a O',
#   'serem O',
#   'alocadas O',
#   'no(s O',
#   ') O',
#   'orçamento(s O',
#   ') O',
#   'seguinte(s O',
#   ') O',
#   '. O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   '; O',
#   'UO O',
#   ': O',
#   '22214 O',
#   '; O',
#   'PT O',
#   ': O',
#   '15.452.6209.2079.6118 O',
#   '; O',
#   'NATUREZA O',
#   'DA O',
#   'DESPESA O',
#   ': O',
#   '33.90. O',
#   '39-51 O',
#   '; O',
#   'FONTE O',
#   'DE O',
#   'RECURSOS O',
#   ': O',
#   '100 O',
#   '. O',
#   'DATA O',
#   'DE O',
#   'ASSINATURA O',
#   ': O',
#   '05 B-data_assinatura_contrato',
#   'de I-data_assinatura_contrato',
#   'novembro I-data_assinatura_contrato',
#   'de I-data_assinatura_contrato',
#   '2021 I-data_assinatura_contrato',
#   '. O',
#   'DA O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'contrato O',
#   'terá O',
#   'vigência O',
#   'de O',
#   '12 O',
#   '( O',
#   'doze O',
#   ') O',
#   'meses O',
#   ', O',
#   'de O',
#   'acordo O',
#   'com O',
#   'o O',
#   'item O',
#   '17.1 O',
#   '. O',
#   'do O',
#   'Termo O',
#   'de O',
#   'Referência O',
#   'a O',
#   'contar O',
#   'da O',
#   'data O',
#   'de O',
#   'sua O',
#   'assinatura O',
#   ', O',
#   'persistindo O',
#   'as O',
#   'obrigações O',
#   'decorrentes O',
#   'da O',
#   'garantia O',
#   ', O',
#   'quando O',
#   'houver O',
#   ', O',
#   'sendo O',
#   'seu O',
#   'extrato O',
#   'publicado O',
#   'no O',
#   'DODF O',
#   '. O',
#   'SIGNATÁRIOS O',
#   ': O',
#   'pelo O',
#   'SLU O',
#   '/ O',
#   'DF O',
#   ', O',
#   'SILVIO O',
#   'DE O',
#   'MORAIS O',
#   'VIEIRA O',
#   ', O',
#   'Diretor-Presidente O',
#   'e O',
#   'DARLEY O',
#   'BRAZ O',
#   'DE O',
#   'QUEIROZ O',
#   ', O',
#   'Diretor O',
#   'de O',
#   'Administração O',
#   'e O',
#   'Finanças O',
#   'e O',
#   ', O',
#   'pela O',
#   'CONTRATADA O',
#   ': O',
#   'WILMA O',
#   'MARIA O',
#   'COELHO O',
#   ', O',
#   'Representante O',
#   'Legal O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'DE O',
#   'PRESTAÇÃO O',
#   'DE O',
#   'SERVIÇOS O',
#   'Nº O',
#   '67/2021 B-numero_contrato',
#   '- O',
#   'SIGGO O',
#   'Nº O',
#   '045035 O',
#   'Processo O',
#   ': O',
#   '0417-000507/2017 B-processo_gdf',
#   '. O',
#   'PARTES O',
#   ': O',
#   'DISTRITO O',
#   'FEDERAL O',
#   '/ O',
#   'SECRETARIA O',
#   'DE O',
#   'ESTADO O',
#   'DE O',
#   'JUSTIÇA O',
#   'E O',
#   'CIDADANIA O',
#   'X O',
#   'DOUGLAS O',
#   'CORDEIRO O',
#   'EIRELI O',
#   '. O',
#   'OBJETO O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'aquisição O',
#   'de O',
#   'equipamentos O',
#   'de O',
#   'saúde O',
#   'para O',
#   'qualificar O',
#   'os O',
#   'atendimentos O',
#   'realizados O',
#   'aos O',
#   'adolescentes O',
#   'do O',
#   'sistema O',
#   'socioeducativo O',
#   'que O',
#   'se O',
#   'encontram O',
#   'nas O',
#   'Unidades O',
#   'de O',
#   'Atendimento O',
#   'Inicial O',
#   ', O',
#   'Unidades O',
#   'de O',
#   'Internação O',
#   'e O',
#   'Unidade O',
#   'de O',
#   'Internação O',
#   'Provisória O',
#   ', O',
#   'a O',
#   'saber O',
#   ': O',
#   'VENOSCÓPIO O',
#   '( O',
#   'localizador O',
#   'de O',
#   'veias O',
#   ') O',
#   ', O',
#   'Marca O',
#   '/ O',
#   'Modelo O',
#   ': O',
#   'DUAN O',
#   '/ O',
#   'IV O',
#   'PLUS O',
#   '. O',
#   'VALOR O',
#   'DO O',
#   'CONTRATO O',
#   ': O',
#   'O O',
#   'valor O',
#   'total O',
#   'do O',
#   'Contrato O',
#   'é O',
#   'de O',
#   'R$ O',
#   '12.881,99 O',
#   '( O',
#   'doze O',
#   'mil O',
#   'oitocentos O',
#   'e O',
#   'oitenta O',
#   'e O',
#   'um O',
#   'reais O',
#   'e O',
#   'noventa O',
#   'e O',
#   'nove O',
#   'centavos O',
#   ') O',
#   ', O',
#   'devendo O',
#   'a O',
#   'importância O',
#   'ser O',
#   'atendida O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotações O',
#   'orçamentárias O',
#   'consignadas O',
#   'no O',
#   'orçamento O',
#   'corrente O',
#   'Lei O',
#   'Orçamentária O',
#   'nº O',
#   '6.778 O',
#   ', O',
#   'de O',
#   '06 O',
#   'de O',
#   'Janeiro O',
#   'de O',
#   '2021 O',
#   '. O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   ': O',
#   'Unidade O',
#   'Orçamentária O',
#   ': O',
#   '44.101 O',
#   ', O',
#   'sob O',
#   'o O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   '14.243.6211.2461.0004 O',
#   '- O',
#   'Apoio O',
#   'às O',
#   'Ações O',
#   'Intersetoriais O',
#   'de O',
#   'Proteção O',
#   'Especial O',
#   'de O',
#   'Crianças O',
#   'e O',
#   'Adolescentes O',
#   '- O',
#   'FDCA O',
#   'Fonte O',
#   'de O',
#   'Recursos O',
#   ': O',
#   '100 O',
#   ', O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   ': O',
#   '44.90.52 O',
#   '. O',
#   'O O',
#   'empenho O',
#   'é O',
#   'de O',
#   'R$ O',
#   '12.881,99 O',
#   '( O',
#   'doze O',
#   'mil O',
#   'oitocentos O',
#   'e O',
#   'oitenta O',
#   'e O',
#   'um O',
#   'reais O',
#   'e O',
#   'noventa O',
#   'e O',
#   'nove O',
#   'centavos O',
#   ') O',
#   ', O',
#   'conforme O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   'nº O',
#   '2021NE01213 O',
#   ', O',
#   'emitida O',
#   'em O',
#   '29/10/2021 O',
#   ', O',
#   'sob O',
#   'o O',
#   'evento O',
#   'nº O',
#   '400091 O',
#   ', O',
#   'na O',
#   'modalidade O',
#   'Ordinário O',
#   '. O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'contrato O',
#   'terá O',
#   'vigência O',
#   '6 O',
#   '( O',
#   'seis O',
#   ') O',
#   'meses O',
#   ', O',
#   'contados O',
#   'a O',
#   'partir O',
#   'da O',
#   'data O',
#   'de O',
#   'sua O',
#   'assinatura O',
#   '. O',
#   'DATA O',
#   'DE O',
#   'ASSINATURA O',
#   ': O',
#   '08/11/2021 B-data_assinatura_contrato',
#   '. O',
#   'SIGNATÁRIOS O',
#   ': O',
#   'Pelo O',
#   'DISTRITO O',
#   'FEDERAL O',
#   ': O',
#   'JAIME O',
#   'SANTANA O',
#   'DE O',
#   'SOUSA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Secretário-Executivo O',
#   'de O',
#   'Estado O',
#   '. O',
#   'Pela O',
#   'CONTRATADA O',
#   ': O',
#   'DOUGLAS O',
#   'CORDEIRO O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Responsável O',
#   'Legal O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '09/2022 B-numero_contrato',
#   'Contratante O',
#   ': O',
#   'Tribunal O',
#   'de O',
#   'Contas O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   '- O',
#   'CNPJ O',
#   'Nº O',
#   '00.534.560/ O',
#   '0001-26 O',
#   '- O',
#   'Contratada O',
#   ': O',
#   'SOLETRA O',
#   'LIVROS O',
#   'E O',
#   'BRINQUEDOS O',
#   'LTDA O',
#   '. O',
#   '- O',
#   'CNPJ O',
#   'Nº O',
#   '31.507.729/ O',
#   '0001-82 O',
#   '- O',
#   'Objeto O',
#   ': O',
#   'fornecimento O',
#   'de O',
#   'materiais O',
#   'bibliográficos O',
#   ', O',
#   'durante O',
#   'o O',
#   'exercício O',
#   'de O',
#   '2022 O',
#   ', O',
#   'a O',
#   'fim O',
#   'de O',
#   'atender O',
#   'à O',
#   'demanda O',
#   'da O',
#   'Biblioteca O',
#   'Cyro O',
#   'dos O',
#   'Anjos O',
#   'do O',
#   'TCDF O',
#   '- O',
#   'Processo O',
#   '00600- B-processo_gdf',
#   '00010859/ I-processo_gdf',
#   '2021-91 O',
#   '- O',
#   'Licitação O',
#   ': O',
#   'Pregão O',
#   'Eletrônico O',
#   'n O',
#   '° O',
#   '2/2022 O',
#   ', O',
#   'regido O',
#   'pela O',
#   'Lei O',
#   'nº O',
#   '10.520/2002 O',
#   ', O',
#   'Lei O',
#   'Complementar O',
#   'nº O',
#   '123/2006 O',
#   'e O',
#   ', O',
#   'subsidiariamente O',
#   ', O',
#   'pela O',
#   'Lei O',
#   'nº O',
#   '8.666/1993 O',
#   ', O',
#   'bem O',
#   'como O',
#   'pelas O',
#   'Leis O',
#   'Distritais O',
#   'nº O',
#   '4.611/2011 O',
#   'e O',
#   '4.770/2012 O',
#   ', O',
#   'pelos O',
#   'Decretos O',
#   'Distritais O',
#   'nºs O',
#   '23.460/2002 O',
#   'e O',
#   '35.592/2014 O',
#   ', O',
#   'pelo O',
#   'Decreto O',
#   'Federal O',
#   'nº O',
#   '10.024/2019 O',
#   ', O',
#   'recepcionado O',
#   'pelo O',
#   'Distrito O',
#   'Federal O',
#   'pelo O',
#   'Decreto O',
#   'Distrital O',
#   'nº O',
#   '40.205/2019 O',
#   ', O',
#   'e O',
#   'pelas O',
#   'demais O',
#   'legislações O',
#   'aplicáveis O',
#   'Vigência O',
#   'e O',
#   'Execução O',
#   ': O',
#   'de O',
#   '22/02/2022 O',
#   'a O',
#   '31/12/2022 O',
#   '- O',
#   'Valor O',
#   'Estimado O',
#   ': O',
#   'R$ O',
#   '78.715,00 O',
#   '( O',
#   'setenta O',
#   'e O',
#   'oito O',
#   'mil O',
#   'e O',
#   'setecentos O',
#   'e O',
#   'quinze O',
#   'reais O',
#   ') O',
#   '- O',
#   'Unidade O',
#   'Gestora O',
#   ': O',
#   '20101 O',
#   '- O',
#   'Gestão O',
#   ': O',
#   '1 O',
#   '- O',
#   'Classificação O',
#   'Orçamentária O',
#   ': O',
#   '449052 O',
#   '- O',
#   'EQUIPAMENTOS O',
#   'E O',
#   'MATERIAL O',
#   'PERMANENTE O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   ': O',
#   '01122823185170019 O',
#   '- O',
#   'Fonte O',
#   'de O',
#   'Recursos O',
#   ': O',
#   '100 O',
#   '- O',
#   'ORDINÁRIO O',
#   'NÃO O',
#   'VINCULADO O',
#   '- O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   ': O',
#   '2022NE00194 O',
#   '- O',
#   'Data O',
#   'de O',
#   'Emissão O',
#   'da O',
#   'NE O',
#   ': O',
#   '09/02/2022 O',
#   '- O',
#   'Valor O',
#   'da O',
#   'NE O',
#   ': O',
#   'R$ O',
#   '78.715,00 O',
#   '( O',
#   'setenta O',
#   'e O',
#   'oito O',
#   'mil O',
#   'e O',
#   'setecentos O',
#   'e O',
#   'quinze O',
#   'reais O',
#   ') O',
#   '- O',
#   'Data O',
#   'da O',
#   'Assinatura O',
#   ': O',
#   '22/02/2022 B-data_assinatura_contrato',
#   '- I-data_assinatura_contrato',
#   'Assinam I-data_assinatura_contrato',
#   ': I-data_assinatura_contrato',
#   'pelo I-data_assinatura_contrato',
#   'Contratante I-data_assinatura_contrato',
#   ', O',
#   'PAULO O',
#   'CAVALCANTI O',
#   'DE O',
#   'OLIVEIRA O',
#   '; O',
#   'e O',
#   ', O',
#   'pela O',
#   'Contratada O',
#   ', O',
#   'RENAN O',
#   'MAIA O',
#   'AMARAL O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '43845/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '04001-0000000284/ B-processo_gdf',
#   '2021-27 I-processo_gdf',
#   '. O',
#   'Das O',
#   'Partes O',
#   ': O',
#   'INSTITUTO O',
#   'DE O',
#   'ASSIST O',
#   '. O',
#   'À O',
#   'SAÚDE O',
#   'DOS O',
#   'SERV O',
#   '. O',
#   'DO O',
#   'DF-INAS O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'CONTRATANTE O',
#   ', O',
#   'CLIAOD-CLIN O',
#   '. O',
#   'DE O',
#   'OTORR O',
#   '. O',
#   'E O',
#   'AUDIOLOGIA O',
#   'LTDA O',
#   '. O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'CONTRATADA O',
#   '. O',
#   'DO O',
#   'OBJETO O',
#   ': O',
#   'CREDECIAMENTO O',
#   'DE O',
#   'PESSOAS O',
#   'JURIDICAS O',
#   'PARA O',
#   'PRESTAÇÃO O',
#   'DE O',
#   'SERVIÇOS O',
#   'DE O',
#   'SAÚDE O',
#   'AOS O',
#   'BENEFICIÁRIOS O',
#   'DO O',
#   'PLANO O',
#   'DE O',
#   'ASSISTÊNCIA O',
#   'SUPLEMENTAR O',
#   'À O',
#   'SAÚDE O',
#   '- O',
#   'GDF-SAÚDE-DF O',
#   ', O',
#   'COMPREENDENDO O',
#   'ASSISTÊNCIA O',
#   'MÉDICA O',
#   'E O',
#   'SERVIÇOS O',
#   'AUXILIARES O',
#   'DE O',
#   'DIAGNÓSTICO O',
#   'E O',
#   'TERAPIA O',
#   '; O',
#   'CONFORME O',
#   'CONTRATO O',
#   '. O',
#   'Do O',
#   'Valor O',
#   ': O',
#   'R$ O',
#   '1.482,56 O',
#   '( O',
#   'hum O',
#   'mil O',
#   'e O',
#   'quatrocentos O',
#   'e O',
#   'oitenta O',
#   'e O',
#   'dois O',
#   'reais O',
#   'e O',
#   'cinqüenta O',
#   'e O',
#   'seis O',
#   'centavos O',
#   ') O',
#   'e O',
#   'correrá O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotações O',
#   'orçamentárias O',
#   'consignadas O',
#   'no O',
#   'orçamento O',
#   'corrente O',
#   '- O',
#   'Lei O',
#   'Orçamentária O',
#   'Anual O',
#   '. O',
#   'DA O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   ': O',
#   'A O',
#   'despesa O',
#   'correrá O',
#   'à O',
#   'conta O',
#   'da O',
#   'seguinte O',
#   'Dotação O',
#   'Orçamentária O',
#   ': O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   ': O',
#   'UO:19212 O',
#   '; O',
#   'PROGRAMA O',
#   'DE O',
#   'TRABALHO O',
#   ': O',
#   '10122620361957 O',
#   ', O',
#   'FONTE O',
#   'DE O',
#   'RECURSO O',
#   ': O',
#   '220000000 O',
#   '; O',
#   'UG O',
#   ': O',
#   '140202 O',
#   '; O',
#   'GESTÃO O',
#   ': O',
#   '14202 O',
#   '; O',
#   'EMPENHO O',
#   '2021NE0/0244 O',
#   ', O',
#   'DATADO O',
#   'DE O',
#   ': O',
#   '25/08/2021 O',
#   ', O',
#   'VALOR O',
#   'DO O',
#   'EMPENHO O',
#   ': O',
#   'R$ O',
#   '1.482,56 O',
#   '( O',
#   'hum O',
#   'mil O',
#   'e O',
#   'quatrocentos O',
#   'e O',
#   'oitenta O',
#   'e O',
#   'dois O',
#   'reais O',
#   'e O',
#   'cinqüenta O',
#   'e O',
#   'seis O',
#   'centavos).DO O',
#   'PRAZO O',
#   'EXECUÇÃO O',
#   '/ O',
#   'VIGÊNCIA O',
#   ': O',
#   '12(doze O',
#   ') O',
#   'mês(es O',
#   ') O',
#   'consecutivos O',
#   'e O',
#   '12 O',
#   '( O',
#   'doze O',
#   ') O',
#   'mês(es O',
#   ') O',
#   'consecutivos O',
#   ', O',
#   'respectivamente O',
#   '. O',
#   'Observado O',
#   'o O',
#   'disposto O',
#   'no O',
#   'art. O',
#   '57 O',
#   'da O',
#   'Lei O',
#   'nº O',
#   '8666/93 O',
#   '. O',
#   'DA O',
#   'ASSINATURA:09/04/2021 B-data_assinatura_contrato',
#   '. B-data_assinatura_contrato',
#   'DOS I-data_assinatura_contrato',
#   'SIGNATÁRIOS O',
#   ': O',
#   'Pelo O',
#   'INSTITUTO O',
#   'DE O',
#   'ASSIST O',
#   '. O',
#   'À O',
#   'SAÚDE O',
#   'DOS O',
#   'SERV O',
#   '. O',
#   'DO O',
#   'DF-INAS O',
#   ': O',
#   'NEY O',
#   'FERRAZ O',
#   'JUNIOR O',
#   '- O',
#   'Presidente O',
#   'Interino O',
#   'e O',
#   'pela O',
#   'CONTRATADA O',
#   ': O',
#   'ANA O',
#   'MARIA O',
#   'DE O',
#   'FREITAS O',
#   'MACHADO O',
#   'BRAGA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Representante O',
#   'da O',
#   'Empresa O',
#   '. O',
#   'NEY O',
#   'FERRAZ O',
#   'JUNIOR O',
#   '. O',
#   'Presidente O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'DE O',
#   'CONCESSÃO O',
#   'DE O',
#   'DIREITO O',
#   'REAL O',
#   'DE O',
#   'USO O',
#   'SOBRE O',
#   'IMÓVEL O',
#   'DO O',
#   'DISTRITO O',
#   'FEDERAL O',
#   'Nº O',
#   '24/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '00390-00005880/ B-processo_gdf',
#   '2020-06 I-processo_gdf',
#   '. O',
#   'PARTES O',
#   ': O',
#   'O O',
#   'DISTRITO O',
#   'FEDERAL O',
#   ', O',
#   'por O',
#   'intermédio O',
#   'da O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Desenvolvimento O',
#   'Urbano O',
#   'e O',
#   'Habitação O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'representado O',
#   'por O',
#   'RICARDO O',
#   'AUGUSTO O',
#   'DE O',
#   'NORONHA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Subsecretário O',
#   'da O',
#   'Central O',
#   'de O',
#   'Aprovação O',
#   'de O',
#   'Projetos O',
#   'da O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Desenvolvimento O',
#   'Urbano O',
#   'e O',
#   'Habitação O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'com O',
#   'competência O',
#   'prevista O',
#   'no O',
#   'art. O',
#   '1º O',
#   'do O',
#   'Decreto O',
#   'nº O',
#   '35.224 O',
#   ', O',
#   'de O',
#   '13 O',
#   'de O',
#   'março O',
#   'de O',
#   '2014 O',
#   ', O',
#   'que O',
#   'dá O',
#   'nova O',
#   'redação O',
#   'ao O',
#   'art. O',
#   '29 O',
#   ', O',
#   'aos O',
#   'incisos O',
#   'III O',
#   ', O',
#   'V O',
#   'e O',
#   'ao O',
#   'parágrafo O',
#   '2º O',
#   ', O',
#   'do O',
#   'Decreto O',
#   'nº O',
#   '29.590 O',
#   ', O',
#   'de O',
#   '09 O',
#   'de O',
#   'outubro O',
#   'de O',
#   '2008 O',
#   ', O',
#   'bem O',
#   'como O',
#   'considerando O',
#   'o O',
#   'disposto O',
#   'no O',
#   'art. O',
#   '7º O',
#   'do O',
#   'Decreto O',
#   'nº O',
#   '36.339 O',
#   ', O',
#   'de O',
#   '28 O',
#   'de O',
#   'janeiro O',
#   'de O',
#   '2015 O',
#   ', O',
#   'e O',
#   'COMPANHIA O',
#   'DE O',
#   'DESENVOLVIMENTO O',
#   'HABITACIONAL O',
#   'DO O',
#   'DISTRITO O',
#   'FEDERAL O',
#   '- O',
#   'CODHAB O',
#   '/ O',
#   'DF O',
#   ', O',
#   'CNPJ O',
#   'nº O',
#   '09.335.575/ O',
#   '0001-30 O',
#   'representa O',
#   'neste O',
#   'ato O',
#   'por O',
#   'WELLINGTON O',
#   'LUZ O',
#   'DE O',
#   'SOUZA O',
#   'SILVA O',
#   ', O',
#   'brasileiro O',
#   ', O',
#   'casado O',
#   ', O',
#   'graduado O',
#   'em O',
#   'Tecnologia O',
#   'de O',
#   'Segurança O',
#   'Pública O',
#   ', O',
#   'portador O',
#   'do O',
#   'CPF O',
#   ': O',
#   '2 O',
#   '* O',
#   '6.***.5 O',
#   '* O',
#   '1-68 O',
#   ', O',
#   'residente O',
#   'e O',
#   'domiciliado O',
#   'no O',
#   'SMPW O',
#   'Quadra O',
#   '27 O',
#   ', O',
#   'conjunto O',
#   '03 O',
#   ', O',
#   'lote O',
#   '09 O',
#   '- O',
#   'Brasília O',
#   '-DF O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Diretor O',
#   'Presidente O',
#   '. O',
#   'DO O',
#   'OBJETO O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'Concessão O',
#   'de O',
#   'Direito O',
#   'Real O',
#   'de O',
#   'Uso O',
#   'da O',
#   'área O',
#   'contígua O',
#   'a O',
#   'QUADRA O',
#   '02 O',
#   'CONJUNTO O',
#   'D8 O',
#   'PROJEÇÃO O',
#   'C O',
#   '- O',
#   'SOBRADINHO O',
#   '/ O',
#   'DF O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'matriculado O',
#   'sob O',
#   'o O',
#   'nº O',
#   '10.620 O',
#   ', O',
#   'no O',
#   '7º O',
#   'Ofício O',
#   'de O',
#   'Registro O',
#   'de O',
#   'Imóveis O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'na O',
#   'forma O',
#   'da O',
#   'Lei O',
#   ', O',
#   'de O',
#   'forma O',
#   'não O',
#   'onerosa O',
#   'com O',
#   'fulcro O',
#   'no O',
#   'incisos O',
#   'I O',
#   'e O',
#   'IV O',
#   'do O',
#   'art. O',
#   '4º O',
#   ', O',
#   'da O',
#   'Lei O',
#   'Complementar O',
#   'nº O',
#   '755 O',
#   ', O',
#   'de O',
#   '28 O',
#   'de O',
#   'janeiro O',
#   'de O',
#   '2008 O',
#   ', O',
#   'entre O',
#   'COMPANHIA O',
#   'DE O',
#   'DESENVOLVIMENTO O',
#   'HABITACIONAL O',
#   'DO O',
#   'DISTRITO O',
#   'FEDERAL O',
#   '- O',
#   'CODHAB O',
#   '/ O',
#   'DF O',
#   ', O',
#   'CNPJ O',
#   'nº O',
#   '09.335.575/ O',
#   '0001-30 O',
#   'e O',
#   'o O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'para O',
#   'a O',
#   'utilização O',
#   'de O',
#   '166,32 O',
#   'm² O',
#   'em O',
#   'nível O',
#   'de O',
#   'subsolo O',
#   'para O',
#   'Garagem O',
#   'e O',
#   '2,15 O',
#   'm² O',
#   'em O',
#   'nível O',
#   'de O',
#   'solo O',
#   'para O',
#   'Instalações O',
#   'Técnicas O',
#   'Central O',
#   'de O',
#   'GLP O',
#   'totalizando O',
#   '168,47 O',
#   'm² O',
#   'de O',
#   'área O',
#   'concedida O',
#   ', O',
#   'conforme O',
#   'Atestado O',
#   'de O',
#   'Habilitação O',
#   'nº O',
#   '81/2021 O',
#   '( O',
#   'Documento O',
#   'SEI O',
#   'nº O',
#   '59542671 O',
#   ') O',
#   'e O',
#   'a O',
#   'Justificativa O',
#   'de O',
#   'Inexigibilidade O',
#   'de O',
#   'Licitação O',
#   '( O',
#   'Documento O',
#   'SEI O',
#   'nº O',
#   '67953414 O',
#   ') O',
#   ', O',
#   'que O',
#   'integram O',
#   'o O',
#   'processo O',
#   'administrativo O',
#   'acima O',
#   'referenciado O',
#   '. O',
#   'DA O',
#   'DESTINAÇÃO O',
#   ': O',
#   'As O',
#   'áreas O',
#   'em O',
#   'avanço O',
#   'de O',
#   'Subsolo O',
#   'e O',
#   'Solo O',
#   'objeto O',
#   'do O',
#   'presente O',
#   'Termo O',
#   ', O',
#   'segundo O',
#   'a O',
#   'Justificativa O',
#   'de O',
#   'Inexigibilidade O',
#   'de O',
#   'Licitação O',
#   '( O',
#   'Documento O',
#   'SEI O',
#   'nº O',
#   '67953414 O',
#   ') O',
#   'destina-se O',
#   'exclusivamente O',
#   'para O',
#   'Garagem O',
#   'e O',
#   'Instalações O',
#   'Técnicas O',
#   'Central O',
#   'de O',
#   'GLP O',
#   'e O',
#   'Laje O',
#   'Técnica O',
#   '( O',
#   'fulcro O',
#   'nos O',
#   'incisos O',
#   'I O',
#   'e O',
#   'IV O',
#   'do O',
#   'art. O',
#   '4º O',
#   ', O',
#   'da O',
#   'Lei O',
#   'Complementar O',
#   'n.º O',
#   '755 O',
#   ', O',
#   'de O',
#   '28 O',
#   'de O',
#   'janeiro O',
#   'de O',
#   '2008 O',
#   ') O',
#   'e O',
#   'sua O',
#   'utilização O',
#   'deve O',
#   'ser O',
#   'feita O',
#   'em O',
#   'estrita O',
#   'obediência O',
#   'às O',
#   'respectivas O',
#   'normas O',
#   'urbanísticas O',
#   '. O',
#   'DO O',
#   'VALOR O',
#   ': O',
#   'A O',
#   'área O',
#   'em O',
#   'avanço O',
#   'de O',
#   'Subsolo O',
#   'para O',
#   'garagem O',
#   'e O',
#   'Solo O',
#   'para O',
#   'Instalação O',
#   'Técnica O',
#   'Central O',
#   'de O',
#   'GLP O',
#   'e O',
#   'Varanda O',
#   'são O',
#   'não-onerosas O',
#   'conforme O',
#   'disposto O',
#   'na O',
#   'hipótese O',
#   'prevista O',
#   'nos O',
#   'incisos O',
#   'I O',
#   'e O',
#   'IV O',
#   'do O',
#   'art. O',
#   '4º O',
#   'da O',
#   'Lei O',
#   'Complementar O',
#   'nº O',
#   '755/2008 O',
#   ', O',
#   'de O',
#   '28 O',
#   'de O',
#   'janeiro O',
#   'de O',
#   '2008 O',
#   '. O',
#   'DO O',
#   'PRAZO O',
#   'DE O',
#   'VIGÊNCIA O',
#   ': O',
#   'A O',
#   'Concessão O',
#   'terá O',
#   'vigência O',
#   'de O',
#   '30 O',
#   '( O',
#   'trinta O',
#   ') O',
#   'anos O',
#   ', O',
#   'a O',
#   'contar O',
#   'da O',
#   'data O',
#   'de O',
#   'sua O',
#   'assinatura O',
#   ', O',
#   'podendo O',
#   'ser O',
#   'prorrogada O',
#   'por O',
#   'igual O',
#   'período O',
#   '. O',
#   'DA O',
#   'PUBLICAÇÃO O',
#   'E O',
#   'DO O',
#   'REGISTRO O',
#   ': O',
#   'A O',
#   'eficácia O',
#   'do O',
#   'Contrato O',
#   'fica O',
#   'condicionada O',
#   'à O',
#   'publicação O',
#   'resumida O',
#   'do O',
#   'instrumento O',
#   'pela O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Desenvolvimento O',
#   'Urbano O',
#   'e O',
#   'Habitação O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'na O',
#   'Imprensa O',
#   'Oficial O',
#   ', O',
#   'até O',
#   'o O',
#   'quinto O',
#   'dia O',
#   'útil O',
#   'do O',
#   'mês O',
#   'seguinte O',
#   'ao O',
#   'de O',
#   'sua O',
#   'assinatura O',
#   '. O',
#   'DO O',
#   'FORO O',
#   ': O',
#   'Fica O',
#   'eleito O',
#   'o O',
#   'foro O',
#   'de O',
#   'Brasília O',
#   ', O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'para O',
#   'dirimir O',
#   'quaisquer O',
#   'dúvidas O',
#   'relativas O',
#   'ao O',
#   'cumprimento O',
#   'do O',
#   'presente O',
#   'Contrato O',
#   '. O',
#   'DATA O',
#   'DE O',
#   'ASSINATURA O',
#   ': O',
#   '24 B-data_assinatura_contrato',
#   'de I-data_assinatura_contrato',
#   'agosto I-data_assinatura_contrato',
#   'de I-data_assinatura_contrato',
#   '2021 I-data_assinatura_contrato',
#   '. O',
#   'SIGNATÁRIOS O',
#   ': O',
#   'Pelo O',
#   'Distrito O',
#   'Federal O',
#   ': O',
#   'RICARDO O',
#   'AUGUSTO O',
#   'DE O',
#   'NORONHA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Subsecretário O',
#   'da O',
#   'Central O',
#   'de O',
#   'Aprovação O',
#   'de O',
#   'Projetos O',
#   'da O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Desenvolvimento O',
#   'Urbano O',
#   'e O',
#   'Habitação O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   'e O',
#   'pela O',
#   'Concessionária O',
#   'representada O',
#   'por O',
#   'WELLINGTON O',
#   'LUIZ O',
#   'DE O',
#   'SOUZA O',
#   'SILVA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Diretor O',
#   'Presidente O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'DE O',
#   'PRESTACAO O',
#   'DE O',
#   'SERVICOS O',
#   'No O',
#   '15/2019 B-numero_contrato',
#   'PROCESSO O',
#   ': O',
#   '00070-00014429/ B-processo_gdf',
#   '2018-61 I-processo_gdf',
#   '. O',
#   'Partes O',
#   ': O',
#   'SEAGRI O',
#   '/ O',
#   'DF O',
#   'e O',
#   'TL O',
#   'PUBLICIDADE O',
#   'E O',
#   'ASSESSORIA O',
#   'LTDA O',
#   '. O',
#   'Objeto O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'contratacao O',
#   'de O',
#   'empresa O',
#   'especializada O',
#   'na O',
#   'prestacao O',
#   'de O',
#   'servicos O',
#   'de O',
#   'diagramacao O',
#   ', O',
#   'impressao O',
#   ', O',
#   'instalacao O',
#   'e O',
#   'veiculacao O',
#   'de O',
#   'outdoors O',
#   ', O',
#   'formato O',
#   ': O',
#   '9x3 O',
#   'm O',
#   ', O',
#   'impresso O',
#   'digitalmente O',
#   'em O',
#   'lona O',
#   'com O',
#   'gramatura O',
#   'minima O',
#   'de O',
#   '300GR O',
#   ', O',
#   'cores O',
#   '4x0 O',
#   ', O',
#   'fixacao O',
#   'por O',
#   'meio O',
#   'de O',
#   'ilhoses O',
#   ', O',
#   'aplicado O',
#   'no O',
#   'local O',
#   'e O',
#   'na O',
#   'quantidade O',
#   'necessaria O',
#   'para O',
#   'sua O',
#   'correta O',
#   'instalacao O',
#   ', O',
#   'consoante O',
#   'especifica O',
#   'o O',
#   'Edital O',
#   'de O',
#   'Pregao O',
#   'Eletronico O',
#   '03/2019 O',
#   '( O',
#   '22203290 O',
#   ') O',
#   'e O',
#   'da O',
#   'Proposta(Doc O',
#   '. O',
#   'Sei O',
#   'id O',
#   '23183168 O',
#   ') O',
#   ', O',
#   'que O',
#   'passa O',
#   'a O',
#   'integrar O',
#   'o O',
#   'presente O',
#   'Termo O',
#   '. O',
#   'Valor O',
#   ': O',
#   'O O',
#   'valor O',
#   'total O',
#   'do O',
#   'Contrato O',
#   'e O',
#   'de O',
#   'R$ O',
#   '6.800,00 O',
#   '( O',
#   'seis O',
#   'mil O',
#   'e O',
#   'oitocentos O',
#   'reais O',
#   ') O',
#   '. O',
#   'O O',
#   'empenho O',
#   'e O',
#   'de O',
#   'R$ O',
#   '6.800,00 O',
#   '( O',
#   'seis O',
#   'mil O',
#   'e O',
#   'oitocentos O',
#   'reais O',
#   ') O',
#   ', O',
#   'conforme O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   'no O',
#   '2019NE00421 O',
#   'emitida O',
#   'em O',
#   '05/08/2019 O',
#   ', O',
#   'sob O',
#   'o O',
#   'evento O',
#   'No O',
#   '400091 O',
#   ', O',
#   'na O',
#   'modalidade O',
#   'global O',
#   ', O',
#   'Unidade O',
#   'Orcamentaria:14101 O',
#   ', O',
#   'Programa O',
#   'de O',
#   'Tr O',
#   'a O',
#   'b O',
#   'a O',
#   'l O',
#   'h O',
#   'o O',
#   ': O',
#   '20.304.6207.2612.0001 O',
#   ', O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   '339039 O',
#   ', O',
#   'Fonte O',
#   'de O',
#   'Recurso O',
#   ': O',
#   '332011195 O',
#   '. O',
#   'Prazo O',
#   'de O',
#   'Vigencia O',
#   ': O',
#   'O O',
#   'contrato O',
#   'tera O',
#   'vigencia O',
#   'desde O',
#   'a O',
#   'sua O',
#   'assinatura O',
#   'por O',
#   'ate O',
#   '60 O',
#   'dias O',
#   '. O',
#   'Data O',
#   'de O',
#   'assinatura O',
#   ': O',
#   '08/08/2019 B-data_assinatura_contrato',
#   '. O',
#   'Signatarios O',
#   ': O',
#   'Pela O',
#   'SEAGRI O',
#   '/ O',
#   'DF O',
#   ': O',
#   'DILSON O',
#   'RESENDE O',
#   'DE O',
#   'ALMEIDA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Secretario O',
#   'de O',
#   'Estado O',
#   '. O',
#   'Pela O',
#   'Contratada O',
#   ': O',
#   'ANDREA O',
#   'MARIA O',
#   'LEAL O',
#   'MENDONCA O',
#   'na O',
#   'qualidade O',
#   'Representante O',
#   'Legal O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'DE O',
#   'AQUISIÇÃO O',
#   'DE O',
#   'BENS O',
#   'E O',
#   'PRESTAÇÃO O',
#   'DE O',
#   'SERVIÇOS O',
#   'Nº O',
#   '18/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '00390-00008446/ B-processo_gdf',
#   '2021-51 I-processo_gdf',
#   '. O',
#   'ESPÉCIE O',
#   ': O',
#   'Contrato O',
#   'de O',
#   'Aquisição O',
#   'de O',
#   'Bens O',
#   'e O',
#   'Prestação O',
#   'de O',
#   'Serviços O',
#   'nº O',
#   '18/2021 O',
#   '( O',
#   'SIGGO O',
#   'nº O',
#   '45109 O',
#   ') O',
#   '. O',
#   'PARTES O',
#   ': O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Desenvolvimento O',
#   'Urbano O',
#   'e O',
#   'Habitação O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   '- O',
#   'SEDUH O',
#   '/ O',
#   'DF O',
#   'e O',
#   'FISON O',
#   'Comércio O',
#   'e O',
#   'Representação O',
#   'de O',
#   'Móveis O',
#   'LTDA O',
#   ', O',
#   'inscrita O',
#   'no O',
#   'CNPJ O',
#   'nº O',
#   '01.447.406/ O',
#   '0001-80 O',
#   '. O',
#   'DO O',
#   'OBJETO O',
#   ': O',
#   'fornecimento O',
#   'e O',
#   'serviço O',
#   'de O',
#   'montagem O',
#   '/ O',
#   'desmontagem O',
#   'de O',
#   'divisórias O',
#   'do O',
#   'tipo O',
#   'cega O',
#   'e O',
#   'instalação O',
#   'de O',
#   'portas O',
#   ', O',
#   'mão-de-obra O',
#   ', O',
#   'com O',
#   'disponibilização O',
#   'de O',
#   'materiais O',
#   ', O',
#   'equipamentos O',
#   'e O',
#   'ferramentas O',
#   'necessárias O',
#   'para O',
#   'a O',
#   'execução O',
#   'do O',
#   'serviço O',
#   ', O',
#   'conforme O',
#   'condições O',
#   'e O',
#   'especificações O',
#   'constantes O',
#   'no O',
#   'Projeto O',
#   'Básico O',
#   '( O',
#   '4053448 O',
#   ') O',
#   ', O',
#   'de O',
#   'modo O',
#   'a O',
#   'atender O',
#   'as O',
#   'necessidades O',
#   'desta O',
#   'Pasta O',
#   '. O',
#   'DO O',
#   'VALOR O',
#   ': O',
#   'R$ O',
#   '14.702,90 O',
#   '( O',
#   'quatorze O',
#   'mil O',
#   ', O',
#   'setecentos O',
#   'e O',
#   'dois O',
#   'reais O',
#   'e O',
#   'noventa O',
#   'centavos O',
#   ') O',
#   ', O',
#   'conforme O',
#   'Notas O',
#   'de O',
#   'Empenhos O',
#   '2021NE0292 O',
#   ', O',
#   '2020NE00293 O',
#   'e O',
#   '2020NE00294 O',
#   ', O',
#   'emitidas O',
#   'em O',
#   '29/10/2021 O',
#   '. O',
#   'Dotação O',
#   'Orçamentária O',
#   ': O',
#   'I O',
#   '- O',
#   'Unidade O',
#   'Orçamentária O',
#   ': O',
#   '28.101 O',
#   '- O',
#   'SEDUH O',
#   '/ O',
#   'DF O',
#   ', O',
#   'II O',
#   '- O',
#   'P.T O',
#   '15.122.8208.8517.0131 O',
#   ', O',
#   'III O',
#   '- O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   ': O',
#   '33.90.30 O',
#   '/ O',
#   '33.90.39 O',
#   '/ O',
#   '44.90.52 O',
#   ', O',
#   'IV O',
#   '- O',
#   'Fonte O',
#   ': O',
#   '100 O',
#   '. O',
#   'Lei O',
#   'Orçamentária O',
#   'Anual O',
#   'LOA O',
#   'nº O',
#   '6.778 O',
#   ', O',
#   'de O',
#   '06 O',
#   'de O',
#   'janeiro O',
#   'de O',
#   '2021 O',
#   '. O',
#   'DO O',
#   'PRAZO O',
#   'DE O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'terá O',
#   'vigência O',
#   'de O',
#   '12 O',
#   '( O',
#   'doze O',
#   ') O',
#   'meses O',
#   ', O',
#   'persistindo O',
#   'as O',
#   'obrigações O',
#   'decorrentes O',
#   'da O',
#   'garantia O',
#   'dos O',
#   'bens O',
#   ', O',
#   'contados O',
#   'a O',
#   'partir O',
#   'da O',
#   'data O',
#   'de O',
#   'sua O',
#   'assinatura O',
#   '; O',
#   'data B-data_assinatura_contrato',
#   'inicial I-data_assinatura_contrato',
#   '24/11/2021 I-data_assinatura_contrato',
#   'e O',
#   'data O',
#   'final O',
#   '24/11/2022 O',
#   '. O',
#   'DATA O',
#   'DE O',
#   'ASSINATURA O',
#   ': O',
#   '24/11/2021 B-data_assinatura_contrato',
#   '. O',
#   'SIGNATÁRIOS O',
#   ': O',
#   'Pelo O',
#   'Distrito O',
#   'Federal O',
#   ': O',
#   'Mateus O',
#   'Leandro O',
#   'de O',
#   'Oliveira O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Secretário O',
#   'de O',
#   'Estado O',
#   '. O',
#   'Pela O',
#   'Contratada O',
#   ': O',
#   'Ricardo O',
#   'Pina O',
#   'Pinheiro O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'sócio O',
#   'administrador O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'No O',
#   '11/2019 B-numero_contrato',
#   'PROCESSO O',
#   ': O',
#   '00390-00003006/ B-processo_gdf',
#   '2019-92 I-processo_gdf',
#   '. O',
#   'ESPECIE O',
#   ': O',
#   'Contrato O',
#   'de O',
#   'Aquisicao O',
#   'de O',
#   'Bens O',
#   'pelo O',
#   'Distrito O',
#   'Federal O',
#   'no O',
#   '11/2019 O',
#   '. O',
#   'PARTES O',
#   ': O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Desenvolvimento O',
#   'Urbano O',
#   'e O',
#   'Habitacao O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   '- O',
#   'SEDUH O',
#   '/ O',
#   'DF O',
#   'e O',
#   'INDUSTRIA O',
#   'DE O',
#   'AGUA O',
#   'MINERAL O',
#   'IBIA O',
#   'LTDA O',
#   '. O',
#   'DO O',
#   'OBJETO O',
#   ': O',
#   'Aquisicao O',
#   'de O',
#   'agua O',
#   'potavel O',
#   'de O',
#   'mesa O',
#   'sem O',
#   'gas O',
#   'e O',
#   'garrafao O',
#   'retornavel O',
#   ', O',
#   'destinados O',
#   'ao O',
#   'atendimento O',
#   'desta O',
#   'pasta O',
#   ', O',
#   'conforme O',
#   'demais O',
#   'especiGcacoes O',
#   'e O',
#   'condicoes O',
#   'estabelecidas O',
#   'no O',
#   'Termo O',
#   'de O',
#   'Referencia O',
#   'Anexo O',
#   'I O',
#   'do O',
#   'Edital O',
#   'de O',
#   'Pregao O',
#   'Eletronico O',
#   'no O',
#   '0058/2018 O',
#   '- O',
#   'SCG O',
#   '/ O',
#   'SEPLAG O',
#   ', O',
#   'da O',
#   'Proposta O',
#   'da O',
#   'empresa O',
#   'INDUSTRIA O',
#   'DE O',
#   'AGUA O',
#   'MINERAL O',
#   'IBIA O',
#   'LTDA O',
#   'de O',
#   '11/06/2018 O',
#   'e O',
#   'da O',
#   'Lei O',
#   'no O',
#   '8.666 O',
#   ', O',
#   'de O',
#   '21 O',
#   'de O',
#   'junho O',
#   'de O',
#   '1993 O',
#   ', O',
#   'que O',
#   'passam O',
#   'a O',
#   'integrar O',
#   'o O',
#   'presente O',
#   'Termo O',
#   '. O',
#   'DO O',
#   'VALOR O',
#   ': O',
#   'R$ O',
#   '11.661,00 O',
#   '( O',
#   'onze O',
#   'mil O',
#   ', O',
#   'seiscentos O',
#   'e O',
#   'sessenta O',
#   'e O',
#   'um O',
#   'reais O',
#   ') O',
#   'conforme O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   'no O',
#   '2019NE00180 O',
#   ', O',
#   'emitida O',
#   'em O',
#   '18/07/2019 O',
#   '. O',
#   'Dotacao O',
#   'Orcamentaria O',
#   'P.T O',
#   '15.122.6001.8517.0131 O',
#   '- O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   ': O',
#   '3390.30 O',
#   '- O',
#   'Fonte O',
#   'de O',
#   'Recursos O',
#   ': O',
#   '100 O',
#   '. O',
#   'DO O',
#   'PRAZO O',
#   'DE O',
#   'VIGENCIA O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'tera O',
#   'vigencia O',
#   'de O',
#   '06 O',
#   '( O',
#   'seis O',
#   ') O',
#   'meses O',
#   'a O',
#   'contar O',
#   'do O',
#   'dia O',
#   '07/08/2019 O',
#   '. O',
#   'DATA O',
#   'DE O',
#   'ASSINATURA O',
#   ': O',
#   '22/07/2019 B-data_assinatura_contrato',
#   '. O',
#   'SIGNATARIOS O',
#   ': O',
#   'Pelo O',
#   'Distrito O',
#   'Federal O',
#   ': O',
#   'Mateus O',
#   'Leandro O',
#   'de O',
#   'Oliveira O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Secretario O',
#   'de O',
#   'Estado O',
#   '. O',
#   'Pela O',
#   'Contratada O',
#   ': O',
#   'Eduardo O',
#   'Barros O',
#   'de O',
#   'Queiroz O',
#   'Rodrigues O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Socio O',
#   'Administrador O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'CUSD O',
#   'CEB O',
#   'Nº O',
#   '177/2021 B-numero_contrato',
#   '- O',
#   'GRUPO O',
#   'A O',
#   'PRESTAÇÃO O',
#   'DE O',
#   'SERVIÇOS O',
#   'Processo O',
#   ': O',
#   '00053-00084410/ B-processo_gdf',
#   '2021-77 I-processo_gdf',
#   '. O',
#   'Inexigibilidade O',
#   'de O',
#   'licitação O',
#   'nº O',
#   '89/2021 O',
#   '. O',
#   'Partes O',
#   ': O',
#   'CBMDF O',
#   'X O',
#   'CEB O',
#   'DISTRIBUIÇÃO O',
#   'S/A O',
#   '( O',
#   'NEOENERGIA O',
#   'DISTRIBUIÇÃO O',
#   'BRASÍLIA O',
#   ') O',
#   '. O',
#   ', O',
#   'CNPJ O',
#   'nº O',
#   '07.522.669/ O',
#   '0001-92 O',
#   '. O',
#   'Objeto O',
#   ': O',
#   'regular O',
#   'as O',
#   'condições O',
#   ', O',
#   'procedimentos O',
#   ', O',
#   'direitos O',
#   'e O',
#   'obrigações O',
#   'das O',
#   'PARTES O',
#   'em O',
#   'relação O',
#   'ao O',
#   'uso O',
#   'do O',
#   'SISTEMA O',
#   'DE O',
#   'DISTRIBUIÇÃO O',
#   'pelo O',
#   'CONSUMIDOR O',
#   'para O',
#   'a O',
#   'UNIDADE O',
#   'CONSUMIDORA O',
#   'e O',
#   'o O',
#   'pagamento O',
#   'dos O',
#   'ENCARGOS O',
#   'DE O',
#   'USO O',
#   ', O',
#   'segundo O',
#   'as O',
#   'características O',
#   'contratuais O',
#   'definidas O',
#   'neste O',
#   'CONTRATO O',
#   ', O',
#   'além O',
#   'de O',
#   'regular O',
#   'as O',
#   'condições O',
#   ', O',
#   'procedimentos O',
#   ', O',
#   'direitos O',
#   'e O',
#   'obrigações O',
#   'das O',
#   'PARTES O',
#   'em O',
#   'relação O',
#   'à O',
#   'conexão O',
#   'das O',
#   'instalações O',
#   'do O',
#   'CONSUMIDOR O',
#   'ao O',
#   'SISTEMA O',
#   'DE O',
#   'DISTRIBUIÇÃO O',
#   'por O',
#   'meio O',
#   'do O',
#   'PONTO O',
#   'DE O',
#   'ENTREGA O',
#   '. O',
#   'Dotação O',
#   'Orçamentária O',
#   ': O',
#   'Unidade O',
#   'Orçamentária:73901 O',
#   '. O',
#   'PTRES O',
#   ': O',
#   '89302 O',
#   '. O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   ': O',
#   '339039 O',
#   '. O',
#   'Fonte O',
#   'de O',
#   'Recurso O',
#   ': O',
#   '100 O',
#   '- O',
#   '( O',
#   'FCDF O',
#   ') O',
#   '. O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   'nº390 O',
#   ', O',
#   'emitida O',
#   'em O',
#   '27/08/2021 O',
#   '. O',
#   'Valor O',
#   'Estimado O',
#   'do O',
#   'Contrato O',
#   ': O',
#   'R$ O',
#   '180.000,00 O',
#   '( O',
#   'cento O',
#   'e O',
#   'oitenta O',
#   'mil O',
#   'reais O',
#   ') O',
#   '. O',
#   'Data O',
#   'de O',
#   'Assinatura O',
#   ': O',
#   '13/11/2021 B-data_assinatura_contrato',
#   '. O',
#   'Prazo O',
#   'de O',
#   'vigência O',
#   ': O',
#   '60 O',
#   '( O',
#   'sessenta O',
#   ') O',
#   'meses O',
#   '. O',
#   'Signatários O',
#   ': O',
#   'Pela O',
#   'Contratante O',
#   ': O',
#   'Te O',
#   'n O',
#   '- O',
#   'C O',
#   'e O',
#   'l. O',
#   'QOBM O',
#   '/ O',
#   'Comb O',
#   '. O',
#   'Hélio O',
#   'Pereira O',
#   'Lima O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Diretor O',
#   'de O',
#   'Contratações O',
#   'e O',
#   'Aquisições O',
#   'e O',
#   'pela O',
#   'Contratada O',
#   ': O',
#   'Fabiola O',
#   'Maria O',
#   'Da O',
#   'Cruz O',
#   'De O',
#   'Almeida O',
#   'e O',
#   'Antonio O',
#   'Carlos O',
#   'Morais O',
#   'De O',
#   'Queiroz O',
#   ', O',
#   'ambos O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'representantes O',
#   'legais O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '66/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '00150-00003798/ B-processo_gdf',
#   '2021-51 I-processo_gdf',
#   '. O',
#   'Das O',
#   'Partes O',
#   ': O',
#   'DF O',
#   '/ O',
#   'SECEC O',
#   '/ O',
#   'FAC O',
#   'X O',
#   'MÁRCIO O',
#   'WESTPHALEN O',
#   'BURTET O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   '. O',
#   'Espécie O',
#   ': O',
#   'Contrato O',
#   'nº O',
#   '66/2021 O',
#   '. O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   ': O',
#   '00296/2021 O',
#   '. O',
#   'Do O',
#   'Objeto O',
#   ': O',
#   'O O',
#   'presente O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'prestação O',
#   'de O',
#   'serviços O',
#   'de O',
#   'emissão O',
#   'de O',
#   'análise O',
#   'técnica O',
#   'e O',
#   'de O',
#   'mérito O',
#   'cultural O',
#   'nos O',
#   'projetos O',
#   'a O',
#   'que O',
#   'lhe O',
#   'forem O',
#   'designados O',
#   '; O',
#   'DO O',
#   'VALOR O',
#   'ESTIMADO O',
#   ': O',
#   '10.200,00 O',
#   '( O',
#   'dez O',
#   'mil O',
#   ', O',
#   'duzentos O',
#   'reais O',
#   ') O',
#   'que O',
#   'serão O',
#   'liberados O',
#   'em O',
#   'parcela O',
#   'única O',
#   'e O',
#   'transferidos O',
#   'à O',
#   'conta O',
#   'do O',
#   '( O',
#   'a O',
#   ') O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   ', O',
#   'correndo O',
#   'a O',
#   'despesa O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotação O',
#   'orçamentária O',
#   'própria O',
#   'do O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   '13.392.8219.4220. O',
#   '0011-Gestão O',
#   'de O',
#   'Recursos O',
#   'de O',
#   'Fundos-DF O',
#   '- O',
#   'Fonte O',
#   '100 O',
#   '; O',
#   'Natureza O',
#   'de O',
#   'despesa O',
#   '33.90.35 O',
#   '; O',
#   'DA O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'contrato O',
#   'terá O',
#   'início O',
#   'na O',
#   'data O',
#   'de O',
#   'assinatura O',
#   ', O',
#   'com O',
#   'duração O',
#   'de O',
#   '120 O',
#   '( O',
#   'cento O',
#   'e O',
#   'vinte O',
#   'dias O',
#   ') O',
#   '. O',
#   'Pelo O',
#   'FAC O',
#   '/ O',
#   'SECEC O',
#   '/ O',
#   'DF O',
#   ': O',
#   'JOÃO O',
#   'ROBERTO O',
#   'DE O',
#   'OLIVEIRA O',
#   'MORO O',
#   ', O',
#   'Subsecretário O',
#   'de O',
#   'Fomento O',
#   'e O',
#   'Incentivo O',
#   'Cultural O',
#   '; O',
#   'DO O',
#   'EXECUTOR O',
#   ': O',
#   'SUZANA O',
#   'DE O',
#   'BORTOLI O',
#   'LIBRELOTTO O',
#   ', O',
#   'matrícula O',
#   '242. O',
#   '700-1 O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '343/2021 B-numero_contrato',
#   'Contratada O',
#   ': O',
#   'PERTO O',
#   'S/A O',
#   '- O',
#   'PERIFÉRICOS O',
#   'PARA O',
#   'AUTOMAÇÃO O',
#   '. O',
#   'Modalidade O',
#   ': O',
#   'Pregão O',
#   'Eletrônico O',
#   'nº O',
#   '05/2021 O',
#   '. O',
#   'Objeto O',
#   ': O',
#   'Aquisição O',
#   'de O',
#   'terminais O',
#   'de O',
#   'autoatendimento O',
#   '( O',
#   'ATM O',
#   ') O',
#   ', O',
#   'incluindo O',
#   ', O',
#   'hardware O',
#   ', O',
#   'APIs O',
#   'e O',
#   'softwares O',
#   ', O',
#   'serviços O',
#   'de O',
#   'instalação O',
#   ', O',
#   'configuração O',
#   'e O',
#   'suporte O',
#   'com O',
#   'garantia O',
#   ', O',
#   'orientações O',
#   'aos O',
#   'funcionários O',
#   'para O',
#   'a O',
#   'operacionalização O',
#   'dos O',
#   'equipamentos O',
#   ', O',
#   'bem O',
#   'como O',
#   'a O',
#   'manutenção O',
#   'preventiva O',
#   'e O',
#   'corretiva O',
#   '. O',
#   'Vigência O',
#   ': O',
#   '29/12/2021 O',
#   'à O',
#   '28/12/2026 O',
#   '. O',
#   'Valor O',
#   'Total O',
#   ': O',
#   'R$ O',
#   '91.213.809,40 O',
#   '. O',
#   'Gestor O',
#   ': O',
#   'Bráulio O',
#   'Lourenço O',
#   'da O',
#   'Silva O',
#   '. O',
#   'Pelo O',
#   'BRB O',
#   ': O',
#   'Fabiano O',
#   'Pereira O',
#   'Côrtes O',
#   '; O',
#   'e O',
#   'Pela O',
#   'Contratada O',
#   ': O',
#   'José O',
#   'Luis O',
#   'Korman O',
#   'Tenenbaum O',
#   '. O',
#   'Processo O',
#   '041.000.100/2019 B-processo_gdf',
#   '. O',
#   'As O',
#   'despesas O',
#   'decorrentes O',
#   'do O',
#   'presente O',
#   'contrato O',
#   'correrão O',
#   'com O',
#   'base O',
#   'no O',
#   'orçamento O',
#   'de O',
#   'investimentos O',
#   'e O',
#   'dispêndios O',
#   ', O',
#   'natureza O',
#   '4 O',
#   '- O',
#   'Dispêndio O',
#   'das O',
#   'Estatais O',
#   'e O',
#   'Fonte O',
#   '1 O',
#   '- O',
#   'geração O',
#   'própria O',
#   '. O',
#   'Bruno O',
#   'Costa O',
#   'Nunes O',
#   '- O',
#   'Gerente O',
#   'de O',
#   'área O',
#   'e.e O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'PARA O',
#   'AQUISIÇÃO O',
#   'DE O',
#   'BENS O',
#   'PELO O',
#   'DISTRITO O',
#   'FEDERAL O',
#   'Nº O',
#   '45/2021 B-numero_contrato',
#   '- O',
#   'SIGGO O',
#   'Nº O',
#   '044728 O',
#   'Processo O',
#   ': O',
#   '00400-00013181/ B-processo_gdf',
#   '2021-91 I-processo_gdf',
#   '. O',
#   'PARTES O',
#   ': O',
#   'O O',
#   'Distrito O',
#   'Federal O',
#   ', O',
#   'por O',
#   'meio O',
#   'da O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Justiça O',
#   'e O',
#   'Cidadania O',
#   'X O',
#   'POWER O',
#   'COMERCIO O',
#   'DE O',
#   'EQUIPAMENTOS O',
#   'INDUSTRIAIS O',
#   'LTDA O',
#   '. O',
#   'OBJETO O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'aquisição O',
#   'de O',
#   'eletrodomésticos O',
#   '( O',
#   '08 O',
#   'bebedouros O',
#   'elétricos O',
#   ', O',
#   'marca O',
#   'Libell O',
#   '/ O',
#   'Master O',
#   'CGA O',
#   ') O',
#   'para O',
#   'equipar O',
#   'as O',
#   'instalações O',
#   'das O',
#   'unidades O',
#   'de O',
#   'Internação O',
#   'e O',
#   'Semiliberdade O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   'e O',
#   'do O',
#   'Centro O',
#   'Integrado O',
#   '18 O',
#   'de O',
#   'Maio O',
#   ', O',
#   'conforme O',
#   'condições O',
#   'e O',
#   'exigências O',
#   'estabelecidas O',
#   'no O',
#   'Termo O',
#   'de O',
#   'Referência O',
#   '( O',
#   '60843918),no O',
#   'Edital O',
#   'de O',
#   'Pregão O',
#   'Eletrônico O',
#   'nº O',
#   '10/ O',
#   '2021-SEJUS O',
#   '( O',
#   '66416196 O',
#   ') O',
#   'e O',
#   'na O',
#   'Proposta O',
#   'da O',
#   'Contratada O',
#   '( O',
#   '67694358 O',
#   ') O',
#   ', O',
#   'que O',
#   'passam O',
#   'a O',
#   'integrar O',
#   'o O',
#   'presente O',
#   'Termo O',
#   '. O',
#   'VALOR O',
#   ': O',
#   'O O',
#   'valor O',
#   'total O',
#   'do O',
#   'Contrato O',
#   'é O',
#   'de O',
#   'R$ O',
#   '4.095,28 O',
#   '( O',
#   'quatro O',
#   'mil O',
#   'e O',
#   'noventa O',
#   'e O',
#   'cinco O',
#   'reais O',
#   'e O',
#   'vinte O',
#   'e O',
#   'oito O',
#   'centavos O',
#   ') O',
#   ', O',
#   'devendo O',
#   'a O',
#   'importância O',
#   'ser O',
#   'atendida O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotações O',
#   'orçamentárias O',
#   'consignadas O',
#   'no O',
#   'orçamento O',
#   'corrente O',
#   'Lei O',
#   'Orçamentária O',
#   'Anual O',
#   'Lei O',
#   'nº O',
#   '6.778 O',
#   ', O',
#   'de O',
#   '06 O',
#   'de O',
#   'janeiro O',
#   'de O',
#   '2021 O',
#   '. O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   ': O',
#   'A O',
#   'despesa O',
#   'correrá O',
#   'à O',
#   'conta O',
#   'da O',
#   'seguinte O',
#   'Dotação O',
#   'Orçamentária O',
#   ': O',
#   'I O',
#   'Unidade O',
#   'Orçamentária O',
#   ': O',
#   '44.101 O',
#   '; O',
#   'II O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   ': O',
#   '14.243.6211.4217.0003 O',
#   '- O',
#   'MANUTENÇÃO O',
#   'DO O',
#   'SISTEMA O',
#   'SOCIOEDUCATIVO O',
#   '- O',
#   'DISTRITO O',
#   'FEDERAL O',
#   '- O',
#   'OCA O',
#   '; O',
#   'III O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   ': O',
#   '44.90.52 O',
#   '; O',
#   'IV O',
#   'Fonte O',
#   'de O',
#   'Recursos O',
#   ': O',
#   '732 O',
#   '; O',
#   'V O',
#   '- O',
#   'O O',
#   'empenho O',
#   'inicial O',
#   'é O',
#   'de O',
#   'R$ O',
#   '4.095,28 O',
#   '( O',
#   'quatro O',
#   'mil O',
#   'noventa O',
#   'e O',
#   'cinco O',
#   'reais O',
#   'e O',
#   'vinte O',
#   'e O',
#   'oito O',
#   'centavos O',
#   ') O',
#   ', O',
#   'conforme O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   'nº O',
#   '2021NE01111 O',
#   ', O',
#   'emitida O',
#   'em O',
#   '07/10/2021 O',
#   ', O',
#   'sob O',
#   'o O',
#   'evento O',
#   'nº O',
#   '400091 O',
#   ', O',
#   'na O',
#   'modalidade O',
#   '1 O',
#   '- O',
#   'Ordinário O',
#   '; O',
#   'VI O',
#   '- O',
#   'Os O',
#   'itens O',
#   'identificados O',
#   'na O',
#   'coluna O',
#   'Quantidade O',
#   'SUBSIS O',
#   ', O',
#   'no O',
#   'capítulo O',
#   '1 O',
#   'do O',
#   'Termo O',
#   'de O',
#   'Referência O',
#   ', O',
#   'serão O',
#   'adquiridos O',
#   'com O',
#   'recursos O',
#   'provenientes O',
#   'do O',
#   'convênio O',
#   'nº O',
#   '908928/2020 O',
#   '. O',
#   'DA O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'presente O',
#   'termo O',
#   'terá O',
#   'vigência O',
#   'de O',
#   '12 O',
#   '( O',
#   'doze O',
#   ') O',
#   'meses O',
#   'a O',
#   'contar O',
#   'a O',
#   'partir O',
#   'da O',
#   'data O',
#   'da O',
#   'assinatura O',
#   'do O',
#   'contrato O',
#   ', O',
#   'nos O',
#   'termos O',
#   'do O',
#   'artigo B-data_assinatura_contrato',
#   '57 I-data_assinatura_contrato',
#   'da I-data_assinatura_contrato',
#   'Lei I-data_assinatura_contrato',
#   '8666/93 I-data_assinatura_contrato',
#   '. O',
#   'DATA O',
#   'DE O',
#   'ASSINATURA O',
#   ': O',
#   '13/10/2021 B-data_assinatura_contrato',
#   '. O',
#   'SIGNATÁRIOS O',
#   ': O',
#   'Pelo O',
#   'DISTRITO O',
#   'FEDERAL O',
#   ': O',
#   'JAIME O',
#   'SANTANA O',
#   'DE O',
#   'SOUSA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Secretário O',
#   '-Executivo O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Justiça O',
#   'e O',
#   'Cidadania O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   '. O',
#   'Pela O',
#   'CONTRATADA O',
#   ': O',
#   'DEIVIDY O',
#   'GONCALVES O',
#   'DA O',
#   'SILVA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Responsável O',
#   'Legal O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '102/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '00150-00003907/ B-processo_gdf',
#   '2021-31 I-processo_gdf',
#   '. O',
#   'Das O',
#   'Partes O',
#   ': O',
#   'DF O',
#   '/ O',
#   'SECEC O',
#   '/ O',
#   'FAC O',
#   'X O',
#   'MARIA O',
#   'DE O',
#   'FÁTIMA O',
#   'PONTES O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   '. O',
#   'Espécie O',
#   ': O',
#   'Contrato O',
#   'nº O',
#   '102/2021 O',
#   '. O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   ': O',
#   '00332/2021 O',
#   '. O',
#   'Do O',
#   'Objeto O',
#   ': O',
#   'O O',
#   'presente O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'prestação O',
#   'de O',
#   'serviços O',
#   'de O',
#   'emissão O',
#   'de O',
#   'análise O',
#   'técnica O',
#   'e O',
#   'de O',
#   'mérito O',
#   'cultural O',
#   'nos O',
#   'projetos O',
#   'a O',
#   'que O',
#   'lhe O',
#   'forem O',
#   'designados O',
#   '; O',
#   'DO O',
#   'VALOR O',
#   'ESTIMADO O',
#   ': O',
#   '2.625,00 O',
#   '( O',
#   'dois O',
#   'mil O',
#   ', O',
#   'seiscentos O',
#   'e O',
#   'vinte O',
#   'e O',
#   'cinco O',
#   'reais O',
#   ') O',
#   'que O',
#   'serão O',
#   'liberados O',
#   'em O',
#   'parcela O',
#   'única O',
#   'e O',
#   'transferidos O',
#   'à O',
#   'conta O',
#   'do O',
#   '( O',
#   'a O',
#   ') O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   ', O',
#   'correndo O',
#   'a O',
#   'despesa O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotação O',
#   'orçamentária O',
#   'própria O',
#   'do O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   '13.392.8219.4220. O',
#   '0011-Gestão O',
#   'de O',
#   'Recursos O',
#   'de O',
#   'Fundos-DF O',
#   '- O',
#   'Fonte O',
#   '100 O',
#   '; O',
#   'Natureza O',
#   'de O',
#   'despesa O',
#   '33.90.35 O',
#   '; O',
#   'DA O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'contrato O',
#   'terá O',
#   'início O',
#   'na O',
#   'data O',
#   'de O',
#   'assinatura O',
#   ', O',
#   'com O',
#   'duração O',
# ...
#   'PE O',
#   'nº O',
#   '01/2020 O',
#   '( O',
#   '42610014 O',
#   ') O',
#   ', O',
#   'a O',
#   'Proposta O',
#   '( O',
#   '66764883 O',
#   ') O',
#   ', O',
#   'Ata O',
#   'de O',
#   'Formação O',
#   'do O',
#   'Cadastro O',
#   'de O',
#   'Reserva O',
#   '( O',
#   '44934543 O',
#   ') O',
#   'e O',
#   'a O',
#   'Justificativa O',
#   'de O',
#   'Dispensa O',
#   'de O',
#   'Licitação O',
#   '( O',
#   '67078065 O',
#   ') O',
#   ', O',
#   'que O',
#   'passam O',
#   'a O',
#   'integrar O',
#   'o O',
#   'presente O',
#   'Contrato O',
#   '. O',
#   'Valor O',
#   'total O',
#   'em O',
#   'Reais O',
#   'da O',
#   'Contratação O',
#   ': O',
#   'R$ O',
#   '8.979.030,00 O',
#   '( O',
#   'oito O',
#   'milhões O',
#   ', O',
#   'novecentos O',
#   'e O',
#   'setenta O',
#   'e O',
#   'nove O',
#   'mil O',
#   'trinta O',
#   'reais O',
#   ') O',
#   ', O',
#   'devendo O',
#   'o O',
#   'valor O',
#   'de O',
#   'R$ O',
#   '174.000,00 O',
#   '( O',
#   'cento O',
#   'e O',
#   'setenta O',
#   'e O',
#   'quatro O',
#   'mil O',
#   'reais O',
#   ') O',
#   'ser O',
#   'atendido O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotações O',
#   'orçamentárias O',
#   'consignadas O',
#   'no O',
#   'orçamento O',
#   'corrente O',
#   'e O',
#   'o O',
#   'valor O',
#   'de O',
#   'R$ O',
#   '8.805.030,00 O',
#   '( O',
#   'oito O',
#   'milhões O',
#   ', O',
#   'oitocentos O',
#   'e O',
#   'cinco O',
#   'mil O',
#   'trinta O',
#   'reais O',
#   ') O',
#   'ser O',
#   'atendido O',
#   'com O',
#   'o O',
#   'orçamento O',
#   'do O',
#   'próximo O',
#   'exercício O',
#   '. O',
#   '- O',
#   'A O',
#   'despesa O',
#   'correrá O',
#   'à O',
#   'conta O',
#   'da O',
#   'seguinte O',
#   'Dotação O',
#   'Orçamentária O',
#   ': O',
#   'Unidade O',
#   'Orçamentária O',
#   ': O',
#   '200101 O',
#   '- O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   ': O',
#   '26.451.6216.1506.0011 O',
#   '- O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   ': O',
#   '33.90.39 O',
#   '-Obras O',
#   'e O',
#   'Instalações O',
#   '- O',
#   'Fonte O',
#   'de O',
#   'Recursos O',
#   ': O',
#   '100 O',
#   '- O',
#   'Ordinária O',
#   'não O',
#   'vinculada O',
#   ', O',
#   'O O',
#   'empenho O',
#   'inicial O',
#   'é O',
#   'de O',
#   'R$ O',
#   '174.000,00 O',
#   '( O',
#   'cento O',
#   'e O',
#   'setenta O',
#   'e O',
#   'quatro O',
#   'mil O',
#   'reais O',
#   ') O',
#   ', O',
#   'conforme O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   '2020NE00848 O',
#   ', O',
#   'emitida O',
#   'em O',
#   '03/08/2021 O',
#   ', O',
#   'na O',
#   'modalidade O',
#   'Estimativo O',
#   '. O',
#   'Prazo O',
#   'de O',
#   'Vigência O',
#   ': O',
#   'O O',
#   'Contrato O',
#   'terá O',
#   'vigência O',
#   'de O',
#   '12 O',
#   '( O',
#   'doze O',
#   ') O',
#   'meses O',
#   ', O',
#   'a O',
#   'contar O',
#   'de O',
#   'sua O',
#   'assinatura O',
#   ', O',
#   'podendo O',
#   'ser O',
#   'prorrogado O',
#   'nos O',
#   'termos O',
#   'da O',
#   'Lei O',
#   'nº O',
#   '8.666/93 O',
#   '. O',
#   'Data O',
#   'de O',
#   'Assinatura O',
#   ': O',
#   '03/08/2021 B-data_assinatura_contrato',
#   '. O',
#   'Signatários O',
#   ': O',
#   'Pelo O',
#   'Distrito O',
#   'Federal O',
#   ': O',
#   'VALTER O',
#   'CASIMIRO O',
#   'SILVEIRA O',
#   ', O',
#   'Secretário O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Transporte O',
#   'e O',
#   'Mobilidade O',
#   'e O',
#   'pela O',
#   'Contratada O',
#   ': O',
#   'JOÃO O',
#   'CARLOS O',
#   'PIMENTA O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '158/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '00150-00003939/ B-processo_gdf',
#   '2021-36 I-processo_gdf',
#   '. O',
#   'Das O',
#   'Partes O',
#   ': O',
#   'DF O',
#   '/ O',
#   'SECEC O',
#   '/ O',
#   'FAC O',
#   'X O',
#   'DEBORA O',
#   'FERNANDES O',
#   'HERSZENHUT O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   '. O',
#   'Espécie O',
#   ': O',
#   'Contrato O',
#   'nº O',
#   '158/2021 O',
#   '. O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   ': O',
#   '00388/2021 O',
#   '. O',
#   'Do O',
#   'Objeto O',
#   ': O',
#   'O O',
#   'presente O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'prestação O',
#   'de O',
#   'serviços O',
#   'de O',
#   'emissão O',
#   'de O',
#   'análise O',
#   'técnica O',
#   'e O',
#   'de O',
#   'mérito O',
#   'cultural O',
#   'nos O',
#   'projetos O',
#   'a O',
#   'que O',
#   'lhe O',
#   'forem O',
#   'designados O',
#   '; O',
#   'DO O',
#   'VALOR O',
#   'ESTIMADO O',
#   ': O',
#   '5.275,00 O',
#   '( O',
#   'cinco O',
#   'mil O',
#   ', O',
#   'duzentos O',
#   'e O',
#   'setenta O',
#   'e O',
#   'cinco O',
#   'reais O',
#   ') O',
#   'que O',
#   'serão O',
#   'liberados O',
#   'em O',
#   'parcela O',
#   'única O',
#   'e O',
#   'transferidos O',
#   'à O',
#   'conta O',
#   'do O',
#   '( O',
#   'a O',
#   ') O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   ', O',
#   'correndo O',
#   'a O',
#   'despesa O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotação O',
#   'orçamentária O',
#   'própria O',
#   'do O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   '13.392.8219.4220. O',
#   '0011-Gestão O',
#   'de O',
#   'Recursos O',
#   'de O',
#   'Fundos-DF O',
#   '- O',
#   'Fonte O',
#   '100 O',
#   '; O',
#   'Natureza O',
#   'de O',
#   'despesa O',
#   '33.90.35 O',
#   '; O',
#   'DA O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'contrato O',
#   'terá O',
#   'início O',
#   'na O',
#   'data O',
#   'de O',
#   'assinatura O',
#   ', O',
#   'com O',
#   'duração O',
#   'de O',
#   '120 O',
#   '( O',
#   'cento O',
#   'e O',
#   'vinte O',
#   'dias O',
#   ') O',
#   '. O',
#   'Pelo O',
#   'FAC O',
#   '/ O',
#   'SECEC O',
#   '/ O',
#   'DF O',
#   ': O',
#   'JOÃO O',
#   'ROBERTO O',
#   'DE O',
#   'OLIVEIRA O',
#   'MORO O',
#   ', O',
#   'Subsecretário O',
#   'de O',
#   'Fomento O',
#   'e O',
#   'Incentivo O',
#   'Cultural O',
#   '; O',
#   'DO O',
#   'EXECUTOR O',
#   ': O',
#   'SUZANA O',
#   'DE O',
#   'BORTOLI O',
#   'LIBRELOTTO O',
#   ', O',
#   'matrícula O',
#   '242. O',
#   '700-1 O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'DE O',
#   'PRESTAÇÃO O',
#   'DE O',
#   'SERVIÇOS O',
#   'Nº O',
#   '05/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '04017-00013410/ B-processo_gdf',
#   '2021-15 I-processo_gdf',
#   '. O',
#   'SIGGO O',
#   'Nº O',
#   '044006 O',
#   '. O',
#   'DAS O',
#   'PARTES O',
#   ': O',
#   'SECRETARIA O',
#   'DE O',
#   'ESTADO O',
#   'DE O',
#   'PROTEÇÃO O',
#   'DA O',
#   'ORDEM O',
#   'URBANÍSTICA O',
#   'DO O',
#   'DISTRITO O',
#   'FEDERAL-DF O',
#   'LEGAL O',
#   'e O',
#   'AMC O',
#   'INFORMÁTICA O',
#   'LTDA O',
#   ', O',
#   'CNPJ O',
#   'Nº O',
#   '62.541.735/ O',
#   '0001-80 O',
#   '. O',
#   'DO O',
#   'OBJETO O',
#   ': O',
#   'Contratação O',
#   'emergencial O',
#   'para O',
#   'prestação O',
#   'de O',
#   'serviços O',
#   'de O',
#   'outsourcing O',
#   'de O',
#   'impressão O',
#   'na O',
#   'modalidade O',
#   '" O',
#   'franquia O',
#   'de O',
#   'página O',
#   'mais O',
#   'excedente O',
#   '" O',
#   ', O',
#   'contemplando O',
#   'o O',
#   'fornecimento O',
#   'de O',
#   'equipamentos O',
#   'e O',
#   'todos O',
#   'os O',
#   'insumos O',
#   ', O',
#   'exceto O',
#   'o O',
#   'papel O',
#   ', O',
#   'bem O',
#   'como O',
#   'serviços O',
#   'de O',
#   'instalação O',
#   ', O',
#   'manutenção O',
#   ', O',
#   'assistência O',
#   'técnica O',
#   'especializada O',
#   'com O',
#   'reposição O',
#   'de O',
#   'peças O',
#   'originais O',
#   ', O',
#   'para O',
#   'atender O',
#   'as O',
#   'necessidades O',
#   'da O',
#   'Secretaria O',
#   'de O',
#   'Estado O',
#   'de O',
#   'Proteção O',
#   'da O',
#   'Ordem O',
#   'Urbanística O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   '( O',
#   'DF O',
#   'LEGAL O',
#   ') O',
#   ', O',
#   'consoante O',
#   'especifica O',
#   'o O',
#   'Termo O',
#   'de O',
#   'Referência O',
#   '03/2021 O',
#   '( O',
#   '63194694 O',
#   ') O',
#   'e O',
#   'a O',
#   'Proposta O',
#   '( O',
#   '65120043 O',
#   ') O',
#   'que O',
#   'integram O',
#   'o O',
#   'Contrato O',
#   '. O',
#   'DO O',
#   'VALOR O',
#   ': O',
#   'O O',
#   'valor O',
#   'total O',
#   'estimativo O',
#   'do O',
#   'Contrato O',
#   'corresponde O',
#   'a O',
#   'R$ O',
#   '73.831,78 O',
#   '( O',
#   'setenta O',
#   'e O',
#   'três O',
#   'mil O',
#   'oitocentos O',
#   'e O',
#   'trinta O',
#   'e O',
#   'um O',
#   'reais O',
#   'e O',
#   'setenta O',
#   'e O',
#   'oito O',
#   'centavos O',
#   ') O',
#   ', O',
#   'procedente O',
#   'do O',
#   'Orçamento O',
#   'do O',
#   'Distrito O',
#   'Federal O',
#   'para O',
#   'o O',
#   'corrente O',
#   'exercício O',
#   ', O',
#   'nos O',
#   'termos O',
#   'da O',
#   'correspondente O',
#   'Lei O',
#   'Orçamentária O',
#   'Anual O',
#   '. O',
#   'DA O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   ': O',
#   'I O',
#   'Unidade O',
#   'Orçamentária O',
#   ': O',
#   '63101 O',
#   '; O',
#   'II O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   ': O',
#   '04.122.8208.8517.0125 O',
#   '; O',
#   'III O',
#   'Natureza O',
#   'da O',
#   'Despesa O',
#   ': O',
#   '33.90.39 O',
#   ', O',
#   'e O',
#   'IV O',
#   'Fonte O',
#   'de O',
#   'Recursos O',
#   ': O',
#   '183 O',
#   '. O',
#   'DO O',
#   'EMPENHO O',
#   ': O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   'nº O',
#   '2021NE00266 O',
#   ', O',
#   'emitida O',
#   'em O',
#   '9 O',
#   'de O',
#   'julho O',
#   'de O',
#   '2021 O',
#   ', O',
#   'sob O',
#   'o O',
#   'Evento O',
#   'nº O',
#   '400091 O',
#   ', O',
#   'na O',
#   'modalidade O',
#   'Estimativo O',
#   '. O',
#   'DA O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'contrato O',
#   'terá O',
#   'vigência O',
#   'de O',
#   '180 O',
#   '( O',
#   'cento O',
#   'e O',
#   'oitenta O',
#   ') O',
#   'dias O',
#   ', O',
#   'consecutivos O',
#   'e O',
#   'ininterruptos O',
#   ', O',
#   'a O',
#   'contar O',
#   'da O',
#   'data O',
#   'de O',
#   'sua O',
#   'assinatura O',
#   ', O',
#   'sendo O',
#   'vedada O',
#   'a O',
#   'sua O',
#   'prorrogação O',
#   ', O',
#   'nos O',
#   'termos O',
#   'do O',
#   'art. O',
#   '24 O',
#   ', O',
#   'inciso O',
#   'IV O',
#   ', O',
#   'da O',
#   'Lei O',
#   'nº O',
#   '8.666/93 O',
#   ', O',
#   'ou O',
#   'até O',
#   'que O',
#   'se O',
#   'conclua O',
#   'o O',
#   'novo O',
#   'procedimento O',
#   'licitatório O',
#   'em O',
#   'andamento B-data_assinatura_contrato',
#   'sob I-data_assinatura_contrato',
#   'o I-data_assinatura_contrato',
#   'processo I-data_assinatura_contrato',
#   '04017-00015539/ I-data_assinatura_contrato',
#   '2020-79 O',
#   ', O',
#   'impondo-se O',
#   'a O',
#   'rescisão O',
#   'unilateral O',
#   'do O',
#   'contrato O',
#   ', O',
#   'por O',
#   'parte O',
#   'da O',
#   'CONTRATANTE O',
#   ', O',
#   'tão O',
#   'logo O',
#   'seja O',
#   'concluído O',
#   'o O',
#   'mencionado O',
#   'procedimento O',
#   'licitatório O',
#   '. O',
#   'DOS O',
#   'SIGNATÁRIOS O',
#   ': O',
#   'Pelo O',
#   'DISTRITO O',
#   'FEDERAL O',
#   ': O',
#   'CRISTIANO O',
#   'MANGUEIRA O',
#   'DE O',
#   'SOUZA O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Secretário O',
#   'de O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '173/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '00150-00003810/ B-processo_gdf',
#   '2021-28 I-processo_gdf',
#   '. O',
#   'Das O',
#   'Partes O',
#   ': O',
#   'DF O',
#   '/ O',
#   'SECEC O',
#   '/ O',
#   'FAC O',
#   'X O',
#   'ZILDA O',
#   'BARRADAS O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   '. O',
#   'Espécie O',
#   ': O',
#   'Contrato O',
#   'nº O',
#   '173/2021 O',
#   '. O',
#   'Nota O',
#   'de O',
#   'Empenho O',
#   ': O',
#   '00403/2021 O',
#   '. O',
#   'Do O',
#   'Objeto O',
#   ': O',
#   'O O',
#   'presente O',
#   'Contrato O',
#   'tem O',
#   'por O',
#   'objeto O',
#   'a O',
#   'prestação O',
#   'de O',
#   'serviços O',
#   'de O',
#   'emissão O',
#   'de O',
#   'análise O',
#   'técnica O',
#   'e O',
#   'de O',
#   'mérito O',
#   'cultural O',
#   'nos O',
#   'projetos O',
#   'a O',
#   'que O',
#   'lhe O',
#   'forem O',
#   'designados O',
#   '; O',
#   'DO O',
#   'VALOR O',
#   'ESTIMADO O',
#   ': O',
#   '3.750,00 O',
#   '( O',
#   'três O',
#   'mil O',
#   ', O',
#   'setecentos O',
#   'e O',
#   'cinquenta O',
#   'reais O',
#   ') O',
#   'que O',
#   'serão O',
#   'liberados O',
#   'em O',
#   'parcela O',
#   'única O',
#   'e O',
#   'transferidos O',
#   'à O',
#   'conta O',
#   'do O',
#   '( O',
#   'a O',
#   ') O',
#   'Contratado O',
#   '( O',
#   'a O',
#   ') O',
#   ', O',
#   'correndo O',
#   'a O',
#   'despesa O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotação O',
#   'orçamentária O',
#   'própria O',
#   'do O',
#   'Programa O',
#   'de O',
#   'Trabalho O',
#   '13.392.8219.4220. O',
#   '0011-Gestão O',
#   'de O',
#   'Recursos O',
#   'de O',
#   'Fundos-DF O',
#   '- O',
#   'Fonte O',
#   '100 O',
#   '; O',
#   'Natureza O',
#   'de O',
#   'despesa O',
#   '33.90.35 O',
#   '; O',
#   'DA O',
#   'VIGÊNCIA O',
#   ': O',
#   'O O',
#   'contrato O',
#   'terá O',
#   'início O',
#   'na O',
#   'data O',
#   'de O',
#   'assinatura O',
#   ', O',
#   'com O',
#   'duração O',
#   'de O',
#   '120 O',
#   '( O',
#   'cento O',
#   'e O',
#   'vinte O',
#   'dias O',
#   ') O',
#   '. O',
#   'Pelo O',
#   'FAC O',
#   '/ O',
#   'SECEC O',
#   '/ O',
#   'DF O',
#   ': O',
#   'JOÃO O',
#   'ROBERTO O',
#   'DE O',
#   'OLIVEIRA O',
#   'MORO O',
#   ', O',
#   'Subsecretário O',
#   'de O',
#   'Fomento O',
#   'e O',
#   'Incentivo O',
#   'Cultural O',
#   '; O',
#   'DO O',
#   'EXECUTOR O',
#   ': O',
#   'SUZANA O',
#   'DE O',
#   'BORTOLI O',
#   'LIBRELOTTO O',
#   ', O',
#   'matrícula O',
#   '242. O',
#   '700-1 O',
#   '. O'],
#  ['EXTRATO O',
#   'DO O',
#   'CONTRATO O',
#   'Nº O',
#   '43721/2021 B-numero_contrato',
#   'Processo O',
#   ': O',
#   '04001-0000000272/ B-processo_gdf',
#   '2021-01 I-processo_gdf',
#   '- O',
#   'DAS O',
#   'PARTES O',
#   ': O',
#   'INSTITUTO O',
#   'DE O',
#   'ASSIST O',
#   '. O',
#   'À O',
#   'SAÚDE O',
#   'DOS O',
#   'SERV O',
#   '. O',
#   'DO O',
#   'DF-INAS O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'CONTRATANTE O',
#   ', O',
#   'CEON-CENTRO O',
#   'ESPECIALIZADO O',
#   'EM O',
#   'ONCOLOGIA O',
#   '. O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'CONTRATADA O',
#   '. O',
#   'DO O',
#   'OBJETO O',
#   ': O',
#   'CREDECIAMENTO O',
#   'DE O',
#   'PESSOAS O',
#   'JURIDICAS O',
#   'PARA O',
#   'PRESTAÇÃO O',
#   'DE O',
#   'SERVIÇOS O',
#   'DE O',
#   'SAÚDE O',
#   'AOS O',
#   'BENEFICIÁRIOS O',
#   'DO O',
#   'PLANO O',
#   'DE O',
#   'ASSISTÊNCIA O',
#   'SUPLEMENTAR O',
#   'À O',
#   'SAÚDE O',
#   '- O',
#   'GDF-SAÚDE-DF O',
#   ', O',
#   'COMPREENDENDO O',
#   'ASSISTÊNCIA O',
#   'MÉDICA O',
#   'E O',
#   'SERVIÇOS O',
#   'AUXILIARES O',
#   'DE O',
#   'DIAGNÓSTICO O',
#   'E O',
#   'TERAPIA O',
#   '; O',
#   'CONFORME O',
#   'CONTRATO O',
#   '. O',
#   'DO O',
#   'VALOR O',
#   ': O',
#   'R$ O',
#   '87.322,72 O',
#   '( O',
#   'oitenta O',
#   'e O',
#   'sete O',
#   'mil O',
#   'e O',
#   'trezentos O',
#   'e O',
#   'vinte O',
#   'e O',
#   'dois O',
#   'reais O',
#   'e O',
#   'setenta O',
#   'e O',
#   'dois O',
#   'centavos O',
#   ') O',
#   'e O',
#   'correrá O',
#   'à O',
#   'conta O',
#   'de O',
#   'dotações O',
#   'orçamentárias O',
#   'consignadas O',
#   'no O',
#   'orçamento O',
#   'corrente O',
#   '- O',
#   'Lei O',
#   'Orçamentária O',
#   'Anual O',
#   '. O',
#   'DA O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   ': O',
#   'A O',
#   'despesa O',
#   'correrá O',
#   'à O',
#   'conta O',
#   'da O',
#   'seguinte O',
#   'Dotação O',
#   'Orçamentária O',
#   ': O',
#   'DOTAÇÃO O',
#   'ORÇAMENTÁRIA O',
#   ': O',
#   'UO:19212 O',
#   '; O',
#   'PROGRAMA O',
#   'DE O',
#   'TRABALHO O',
#   ': O',
#   '10122620361957 O',
#   ', O',
#   'FONTE O',
#   'DE O',
#   'RECURSO O',
#   ': O',
#   '220000000 O',
#   '; O',
#   'UG O',
#   ': O',
#   '140202 O',
#   '; O',
#   'GESTÃO O',
#   ': O',
#   '14202 O',
#   '; O',
#   'EMPENHO O',
#   '2021NE0/0518 O',
#   ', O',
#   'DATADO O',
#   'DE O',
#   ': O',
#   '28/10/2021 O',
#   ', O',
#   'VALOR O',
#   'DO O',
#   'EMPENHO O',
#   ': O',
#   'R$ O',
#   '87.322,72 O',
#   '( O',
#   'oitenta O',
#   'e O',
#   'sete O',
#   'mil O',
#   'e O',
#   'trezentos O',
#   'e O',
#   'vinte O',
#   'e O',
#   'dois O',
#   'reais O',
#   'e O',
#   'setenta O',
#   'e O',
#   'dois O',
#   'centavos).DO O',
#   'PRAZO O',
#   'EXECUÇÃO O',
#   '/ O',
#   'VIGÊNCIA O',
#   ': O',
#   '12(doze O',
#   ') O',
#   'mês(es O',
#   ') O',
#   'consecutivos O',
#   'e O',
#   '12 O',
#   '( O',
#   'doze O',
#   ') O',
#   'mês(es O',
#   ') O',
#   'consecutivos O',
#   ', O',
#   'respectivamente O',
#   '. O',
#   'Observado O',
#   'o O',
#   'disposto O',
#   'no O',
#   'art. O',
#   '57 O',
#   'da O',
#   'Lei O',
#   'nº O',
#   '8666/93 O',
#   '. O',
#   'DA O',
#   'ASSINATURA:05/04/2021 B-data_assinatura_contrato',
#   '. B-data_assinatura_contrato',
#   'DOS I-data_assinatura_contrato',
#   'SIGNATÁRIOS O',
#   ': O',
#   'Pela O',
#   'INSTITUTO O',
#   'DE O',
#   'ASSIST O',
#   '. O',
#   'À O',
#   'SAÚDE O',
#   'DOS O',
#   'SERV O',
#   '. O',
#   'DO O',
#   'DF-INAS O',
#   ': O',
#   'NEY O',
#   'FERRAZ O',
#   'JUNIOR O',
#   '- O',
#   'Presidente O',
#   'Interino O',
#   'e O',
#   'pela O',
#   'CONTRATADA O',
#   ': O',
#   'CARLOS O',
#   'ALBERTO O',
#   'DA O',
#   'SILVA O',
#   'LOURES O',
#   ', O',
#   'na O',
#   'qualidade O',
#   'de O',
#   'Representante O',
#   'da O',
#   'Empresa O',
#   '. O']]

# %%
termos_skweak = []
debug=set()
labels_skweak = []
for ato in corpus:
    x = []
    y = []
    for termo in ato:
        termo_label = termo.split()
        x.append(termo_label[0])
        y.append(termo_label[1])
        debug.add(termo_label[1])
    termos_skweak.append(x)
    labels_skweak.append(y)

# %%
debug
# Out:
# {'B-data_assinatura_contrato',
#  'B-natureza_despesa',
#  'B-nota_empenho',
#  'B-numero_contrato',
#  'B-processo_gdf',
#  'B-programa_trabalho',
#  'B-unidade_orcamentaria',
#  'B-valor_contrato',
#  'I-data_assinatura_contrato',
#  'I-natureza_despesa',
#  'I-nota_empenho',
#  'I-numero_contrato',
#  'I-processo_gdf',
#  'I-programa_trabalho',
#  'I-unidade_orcamentaria',
#  'O'}

# %%
len(termos_skweak)
# Out:
# 308

# %%
termos_skweak_list = []
for i in termos_skweak:
   if not isinstance(i, list):
      termos_skweak_list .append(i)
   else:
      for j in i:
       termos_skweak_list .append(j)

len(termos_skweak_list )
# Out:
# 72220

# %%
termos_skweak_list
# Out:
# ['EXTRATO',
#  'DO',
#  'CONTRATO',
#  'DE',
#  'PRESTAÇÃO',
#  'DE',
#  'SERVIÇOS',
#  'Nº',
#  '25/2021',
#  'Processo',
#  ':',
#  '00094-00005321/',
#  '2019-81',
#  '.',
#  'PARTES',
#  ':',
#  'SERVIÇO',
#  'DE',
#  'LIMPEZA',
#  'URBANA',
#  'DO',
#  'DISTRITO',
#  'FEDERAL',
#  '-',
#  'SLU',
#  '/',
#  'DF',
#  'e',
#  'a',
#  'empresa',
#  'CONÁGUA',
#  'AMBIENTAL',
#  'LTDA',
#  ',',
#  'inscrita',
#  'no',
#  'CNPJ',
#  '/',
#  'MF',
#  'sob',
#  'o',
#  'nº',
#  '01.615.998/',
#  '0001-00',
#  '.',
#  'OBJETO',
#  ':',
#  'O',
#  'Contrato',
#  'tem',
#  'por',
#  'objeto',
#  'a',
#  'prestação',
#  'de',
#  'serviços',
#  'de',
#  'laboratório',
#  'acreditado',
#  'pelo',
#  'INMETRO',
#  'para',
#  'avaliar',
#  'os',
#  'parâmetros',
#  'e',
#  'indicadores',
#  'da',
#  'eficácia',
#  'do',
#  'tratamento',
#  'do',
#  'efluente',
#  'na',
#  'Usina',
#  'de',
#  'Tratamento',
#  'de',
#  'Chorume',
#  '-',
#  'UTC',
#  ',',
#  'localizada',
#  'no',
#  'Aterro',
#  'Sanitário',
#  'de',
#  'Brasília',
#  '-',
#  'ASB',
#  ',',
#  'conforme',
#  'especificações',
#  'e',
#  'condições',
#  'estabelecidas',
#  'no',
#  'Edital',
#  'e',
#  'seus',
#  'Anexos',
#  ',',
#  'consoante',
#  'especifica',
#  'o',
#  'Edital',
#  'de',
#  'Licitação',
#  'do',
#  'Pregão',
#  'Eletrônico',
#  'nº',
#  '15/2021',
#  'CPL',
#  '/',
#  'SLU-DF',
#  'e',
#  'da',
#  'Proposta',
#  'de',
#  'Preços',
#  ',',
#  'que',
#  'passam',
#  'a',
#  'integrar',
#  'o',
#  'presente',
#  'Termo',
#  'sem',
#  'necessidade',
#  'de',
#  'transcrição',
#  'na',
#  'íntegra',
#  '.',
#  'FUNDAMENTAÇÃO',
#  'LEGAL',
#  ':',
#  'O',
#  'presente',
#  'Contrato',
#  'obedece',
#  'aos',
#  'termos',
#  'do',
#  'Edital',
#  'de',
#  'Licitação',
#  'do',
#  'Pregão',
#  'Eletrônico',
#  'nº',
#  '15/2021',
#  'CPL',
#  '/',
#  'SLU-DF',
#  ',',
#  'da',
#  'Proposta',
#  'de',
#  'Preços',
#  'e',
#  'da',
#  'Lei',
#  'nº',
#  '8.666',
#  ',',
#  'de',
#  '21.06.93',
#  '.',
#  'VALOR',
#  ':',
#  'O',
#  'valor',
#  'total',
#  'do',
#  'Contrato',
#  'é',
#  'de',
#  'R$',
#  '84.240,00',
#  '(',
#  'oitenta',
#  'e',
#  'quatro',
#  'mil',
#  'e',
#  'duzentos',
#  'e',
#  'quarenta',
#  'reais',
#  ')',
#  ',',
#  'devendo',
#  'a',
#  'importância',
#  'ser',
#  'atendida',
#  'à',
#  'conta',
#  'de',
#  'dotações',
#  'orçamentárias',
#  'consignadas',
#  'no',
#  'orçamento',
#  'corrente',
#  'Lei',
#  'Orçamentária',
#  'Anual',
#  'nº',
#  '6.778',
#  'de',
#  '06/01/2021',
#  ',',
#  'enquanto',
#  'a',
#  'parcela',
#  'remanescente',
#  'será',
#  'custeada',
#  'à',
#  'conta',
#  'de',
#  'dotações',
#  'a',
#  'serem',
#  'alocadas',
#  'no(s',
#  ')',
#  'orçamento(s',
#  ')',
#  'seguinte(s',
#  ')',
#  '.',
#  'DOTAÇÃO',
#  'ORÇAMENTÁRIA',
#  ';',
#  'UO',
#  ':',
#  '22214',
#  ';',
#  'PT',
#  ':',
#  '15.452.6209.2079.6118',
#  ';',
#  'NATUREZA',
#  'DA',
#  'DESPESA',
#  ':',
#  '33.90.',
#  '39-51',
#  ';',
#  'FONTE',
#  'DE',
#  'RECURSOS',
#  ':',
#  '100',
#  '.',
#  'DATA',
#  'DE',
#  'ASSINATURA',
#  ':',
#  '05',
#  'de',
#  'novembro',
#  'de',
#  '2021',
#  '.',
#  'DA',
#  'VIGÊNCIA',
#  ':',
#  'O',
#  'contrato',
#  'terá',
#  'vigência',
#  'de',
#  '12',
#  '(',
#  'doze',
#  ')',
#  'meses',
#  ',',
#  'de',
#  'acordo',
#  'com',
#  'o',
#  'item',
#  '17.1',
#  '.',
#  'do',
#  'Termo',
#  'de',
#  'Referência',
#  'a',
#  'contar',
#  'da',
#  'data',
#  'de',
#  'sua',
#  'assinatura',
#  ',',
#  'persistindo',
#  'as',
#  'obrigações',
#  'decorrentes',
#  'da',
#  'garantia',
#  ',',
#  'quando',
#  'houver',
#  ',',
#  'sendo',
#  'seu',
#  'extrato',
#  'publicado',
#  'no',
#  'DODF',
#  '.',
#  'SIGNATÁRIOS',
#  ':',
#  'pelo',
#  'SLU',
#  '/',
#  'DF',
#  ',',
#  'SILVIO',
#  'DE',
#  'MORAIS',
#  'VIEIRA',
#  ',',
#  'Diretor-Presidente',
#  'e',
#  'DARLEY',
#  'BRAZ',
#  'DE',
#  'QUEIROZ',
#  ',',
#  'Diretor',
#  'de',
#  'Administração',
#  'e',
#  'Finanças',
#  'e',
#  ',',
#  'pela',
#  'CONTRATADA',
#  ':',
#  'WILMA',
#  'MARIA',
#  'COELHO',
#  ',',
#  'Representante',
#  'Legal',
#  '.',
#  'EXTRATO',
#  'DO',
#  'CONTRATO',
#  'DE',
#  'PRESTAÇÃO',
#  'DE',
#  'SERVIÇOS',
#  'Nº',
#  '67/2021',
#  '-',
#  'SIGGO',
#  'Nº',
#  '045035',
#  'Processo',
#  ':',
#  '0417-000507/2017',
#  '.',
#  'PARTES',
#  ':',
#  'DISTRITO',
#  'FEDERAL',
#  '/',
#  'SECRETARIA',
#  'DE',
#  'ESTADO',
#  'DE',
#  'JUSTIÇA',
#  'E',
#  'CIDADANIA',
#  'X',
#  'DOUGLAS',
#  'CORDEIRO',
#  'EIRELI',
#  '.',
#  'OBJETO',
#  ':',
#  'O',
#  'Contrato',
#  'tem',
#  'por',
#  'objeto',
#  'a',
#  'aquisição',
#  'de',
#  'equipamentos',
#  'de',
#  'saúde',
#  'para',
#  'qualificar',
#  'os',
#  'atendimentos',
#  'realizados',
#  'aos',
#  'adolescentes',
#  'do',
#  'sistema',
#  'socioeducativo',
#  'que',
#  'se',
#  'encontram',
#  'nas',
#  'Unidades',
#  'de',
#  'Atendimento',
#  'Inicial',
#  ',',
#  'Unidades',
#  'de',
#  'Internação',
#  'e',
#  'Unidade',
#  'de',
#  'Internação',
#  'Provisória',
#  ',',
#  'a',
#  'saber',
#  ':',
#  'VENOSCÓPIO',
#  '(',
#  'localizador',
#  'de',
#  'veias',
#  ')',
#  ',',
#  'Marca',
#  '/',
#  'Modelo',
#  ':',
#  'DUAN',
#  '/',
#  'IV',
#  'PLUS',
#  '.',
#  'VALOR',
#  'DO',
#  'CONTRATO',
#  ':',
#  'O',
#  'valor',
#  'total',
#  'do',
#  'Contrato',
#  'é',
#  'de',
#  'R$',
#  '12.881,99',
#  '(',
#  'doze',
#  'mil',
#  'oitocentos',
#  'e',
#  'oitenta',
#  'e',
#  'um',
#  'reais',
#  'e',
#  'noventa',
#  'e',
#  'nove',
#  'centavos',
#  ')',
#  ',',
#  'devendo',
#  'a',
#  'importância',
#  'ser',
#  'atendida',
#  'à',
#  'conta',
#  'de',
#  'dotações',
#  'orçamentárias',
#  'consignadas',
#  'no',
#  'orçamento',
#  'corrente',
#  'Lei',
#  'Orçamentária',
#  'nº',
#  '6.778',
#  ',',
#  'de',
#  '06',
#  'de',
#  'Janeiro',
#  'de',
#  '2021',
#  '.',
#  'DOTAÇÃO',
#  'ORÇAMENTÁRIA',
#  ':',
#  'Unidade',
#  'Orçamentária',
#  ':',
#  '44.101',
#  ',',
#  'sob',
#  'o',
#  'Programa',
#  'de',
#  'Trabalho',
#  '14.243.6211.2461.0004',
#  '-',
#  'Apoio',
#  'às',
#  'Ações',
#  'Intersetoriais',
#  'de',
#  'Proteção',
#  'Especial',
#  'de',
#  'Crianças',
#  'e',
#  'Adolescentes',
#  '-',
#  'FDCA',
#  'Fonte',
#  'de',
#  'Recursos',
#  ':',
#  '100',
#  ',',
#  'Natureza',
#  'da',
#  'Despesa',
#  ':',
#  '44.90.52',
#  '.',
#  'O',
#  'empenho',
#  'é',
#  'de',
#  'R$',
#  '12.881,99',
#  '(',
#  'doze',
#  'mil',
#  'oitocentos',
#  'e',
#  'oitenta',
#  'e',
#  'um',
#  'reais',
#  'e',
#  'noventa',
#  'e',
#  'nove',
#  'centavos',
#  ')',
#  ',',
#  'conforme',
#  'Nota',
#  'de',
#  'Empenho',
#  'nº',
#  '2021NE01213',
#  ',',
#  'emitida',
#  'em',
#  '29/10/2021',
#  ',',
#  'sob',
#  'o',
#  'evento',
#  'nº',
#  '400091',
#  ',',
#  'na',
#  'modalidade',
#  'Ordinário',
#  '.',
#  'VIGÊNCIA',
#  ':',
#  'O',
#  'contrato',
#  'terá',
#  'vigência',
#  '6',
#  '(',
#  'seis',
#  ')',
#  'meses',
#  ',',
#  'contados',
#  'a',
#  'partir',
#  'da',
#  'data',
#  'de',
#  'sua',
#  'assinatura',
#  '.',
#  'DATA',
#  'DE',
#  'ASSINATURA',
#  ':',
#  '08/11/2021',
#  '.',
#  'SIGNATÁRIOS',
#  ':',
#  'Pelo',
#  'DISTRITO',
#  'FEDERAL',
#  ':',
#  'JAIME',
#  'SANTANA',
#  'DE',
#  'SOUSA',
#  ',',
#  'na',
#  'qualidade',
#  'de',
#  'Secretário-Executivo',
#  'de',
#  'Estado',
#  '.',
#  'Pela',
#  'CONTRATADA',
#  ':',
#  'DOUGLAS',
#  'CORDEIRO',
#  ',',
#  'na',
#  'qualidade',
#  'de',
#  'Responsável',
#  'Legal',
#  '.',
#  'EXTRATO',
#  'DO',
#  'CONTRATO',
#  'Nº',
#  '09/2022',
#  'Contratante',
#  ':',
#  'Tribunal',
#  'de',
#  'Contas',
#  'do',
#  'Distrito',
#  'Federal',
#  '-',
#  'CNPJ',
#  'Nº',
#  '00.534.560/',
#  '0001-26',
#  '-',
#  'Contratada',
#  ':',
#  'SOLETRA',
#  'LIVROS',
#  'E',
#  'BRINQUEDOS',
#  'LTDA',
#  '.',
#  '-',
#  'CNPJ',
#  'Nº',
#  '31.507.729/',
#  '0001-82',
#  '-',
#  'Objeto',
#  ':',
#  'fornecimento',
#  'de',
#  'materiais',
#  'bibliográficos',
#  ',',
#  'durante',
#  'o',
#  'exercício',
#  'de',
#  '2022',
#  ',',
#  'a',
#  'fim',
#  'de',
#  'atender',
#  'à',
#  'demanda',
#  'da',
#  'Biblioteca',
#  'Cyro',
#  'dos',
#  'Anjos',
#  'do',
#  'TCDF',
#  '-',
#  'Processo',
#  '00600-',
#  '00010859/',
#  '2021-91',
#  '-',
#  'Licitação',
#  ':',
#  'Pregão',
#  'Eletrônico',
#  'n',
#  '°',
#  '2/2022',
#  ',',
#  'regido',
#  'pela',
#  'Lei',
#  'nº',
#  '10.520/2002',
#  ',',
#  'Lei',
#  'Complementar',
#  'nº',
#  '123/2006',
#  'e',
#  ',',
#  'subsidiariamente',
#  ',',
#  'pela',
#  'Lei',
#  'nº',
#  '8.666/1993',
#  ',',
#  'bem',
#  'como',
#  'pelas',
#  'Leis',
#  'Distritais',
#  'nº',
#  '4.611/2011',
#  'e',
#  '4.770/2012',
#  ',',
#  'pelos',
#  'Decretos',
#  'Distritais',
#  'nºs',
#  '23.460/2002',
#  'e',
#  '35.592/2014',
#  ',',
#  'pelo',
#  'Decreto',
#  'Federal',
#  'nº',
#  '10.024/2019',
#  ',',
#  'recepcionado',
#  'pelo',
#  'Distrito',
#  'Federal',
#  'pelo',
#  'Decreto',
#  'Distrital',
#  'nº',
#  '40.205/2019',
#  ',',
#  'e',
#  'pelas',
#  'demais',
#  'legislações',
#  'aplicáveis',
#  'Vigência',
#  'e',
#  'Execução',
#  ':',
#  'de',
#  '22/02/2022',
#  'a',
#  '31/12/2022',
#  '-',
#  'Valor',
#  'Estimado',
#  ':',
#  'R$',
#  '78.715,00',
#  '(',
#  'setenta',
#  'e',
#  'oito',
#  'mil',
#  'e',
#  'setecentos',
#  'e',
#  'quinze',
#  'reais',
#  ')',
#  '-',
#  'Unidade',
#  'Gestora',
#  ':',
#  '20101',
#  '-',
#  'Gestão',
#  ':',
#  '1',
#  '-',
#  'Classificação',
#  'Orçamentária',
#  ':',
#  '449052',
#  '-',
#  'EQUIPAMENTOS',
#  'E',
#  'MATERIAL',
#  'PERMANENTE',
#  'Programa',
#  'de',
#  'Trabalho',
#  ':',
#  '01122823185170019',
#  '-',
#  'Fonte',
#  'de',
#  'Recursos',
#  ':',
#  '100',
#  '-',
#  'ORDINÁRIO',
#  'NÃO',
#  'VINCULADO',
#  '-',
#  'Nota',
#  'de',
#  'Empenho',
#  ':',
#  '2022NE00194',
#  '-',
#  'Data',
#  'de',
#  'Emissão',
#  'da',
#  'NE',
#  ':',
#  '09/02/2022',
#  '-',
#  'Valor',
#  'da',
#  'NE',
#  ':',
#  'R$',
#  '78.715,00',
#  '(',
#  'setenta',
#  'e',
#  'oito',
#  'mil',
#  'e',
#  'setecentos',
#  'e',
#  'quinze',
#  'reais',
#  ')',
#  '-',
#  'Data',
#  'da',
#  'Assinatura',
#  ':',
#  '22/02/2022',
#  '-',
#  'Assinam',
#  ':',
#  'pelo',
#  'Contratante',
#  ',',
#  'PAULO',
#  'CAVALCANTI',
#  'DE',
#  'OLIVEIRA',
#  ';',
#  'e',
#  ',',
#  'pela',
#  'Contratada',
#  ',',
#  'RENAN',
#  'MAIA',
#  'AMARAL',
#  '.',
#  'EXTRATO',
#  'DO',
#  'CONTRATO',
#  'Nº',
#  '43845/2021',
#  'Processo',
#  ':',
#  '04001-0000000284/',
#  '2021-27',
#  '.',
#  'Das',
#  'Partes',
#  ':',
#  'INSTITUTO',
#  'DE',
#  'ASSIST',
#  '.',
#  'À',
#  'SAÚDE',
#  'DOS',
#  'SERV',
#  '.',
#  'DO',
#  'DF-INAS',
#  'na',
#  'qualidade',
#  'de',
#  'CONTRATANTE',
#  ',',
#  'CLIAOD-CLIN',
#  '.',
#  'DE',
#  'OTORR',
#  '.',
#  'E',
#  'AUDIOLOGIA',
#  'LTDA',
#  '.',
#  'na',
#  'qualidade',
#  'de',
#  'CONTRATADA',
#  '.',
#  'DO',
#  'OBJETO',
#  ':',
#  'CREDECIAMENTO',
#  'DE',
#  'PESSOAS',
#  'JURIDICAS',
#  'PARA',
#  'PRESTAÇÃO',
#  'DE',
#  'SERVIÇOS',
#  'DE',
#  'SAÚDE',
#  'AOS',
#  'BENEFICIÁRIOS',
#  'DO',
#  'PLANO',
#  'DE',
#  'ASSISTÊNCIA',
#  'SUPLEMENTAR',
#  'À',
#  'SAÚDE',
#  '-',
#  'GDF-SAÚDE-DF',
#  ',',
#  'COMPREENDENDO',
#  'ASSISTÊNCIA',
#  'MÉDICA',
#  'E',
#  'SERVIÇOS',
#  'AUXILIARES',
#  'DE',
#  'DIAGNÓSTICO',
#  'E',
#  'TERAPIA',
#  ';',
#  'CONFORME',
#  'CONTRATO',
#  '.',
#  'Do',
#  'Valor',
#  ':',
#  'R$',
#  '1.482,56',
#  '(',
#  'hum',
#  'mil',
#  'e',
#  'quatrocentos',
#  'e',
#  'oitenta',
#  'e',
#  'dois',
#  'reais',
#  'e',
#  'cinqüenta',
#  'e',
#  'seis',
#  'centavos',
#  ')',
#  'e',
#  'correrá',
#  'à',
#  'conta',
#  ...]

# %%
#apenas para conferencia
#df = pd.DataFrame(termos_skweak_list, columns=['Texto']) 
#df.to_csv('/home/lucelia_vieira/Experimentos/ner/CSVs/termos_skweak_list.csv')

# %%
labels_skweak_list = []
for i in labels_skweak:
   if not isinstance(i, list):
      labels_skweak_list.append(i)
   else:
      for j in i:
        labels_skweak_list.append(j)

len(labels_skweak_list)
# Out:
# 72220

# %% [markdown]
# ## Preparando o test da base ouro para fazer a validação

# %%
#Carrega o dataset de teste da base ouro para aplicar a validação
#df_gold_ato= pd.read_csv('./CSVs/Extrato_Contrato_Split_1_x_test.csv', dtype=str)
#df_gold_ato

# %%
#Carrega os atos do dataset de teste da base ouro (Lista dentro de lista)
#https://pt.stackoverflow.com/questions/232208/ler-uma-lista-de-listas-em-txt-python-3
import pickle
with open("./CSVs/Extrato_Contrato_Split_V1_0_x_test.txt", "rb") as file:
    gold_x_test = pickle.load(file)

# %%
# Retira uma nível da lista dos atos do dataset de teste da base ouro
gold_x_test_list = []
for i in gold_x_test:
   if not isinstance(i, list):
      gold_x_test_list.append(i)
   else:
      for j in i:
        gold_x_test_list.append(j)

len(gold_x_test_list)
# Out:
# 72220

# %%
#Carrega os labels do dataset de teste da base ouro (Lista dentro de lista)
import pickle
with open("./CSVs/Extrato_Contrato_Split_V1_0_y_test.txt", "rb") as file:
    gold_y_test = pickle.load(file)

# %%
#  Retira uma nível da lista dos labels do dataset de teste da base ouro

gold_y_test_list = []
for i in gold_y_test:
   if not isinstance(i, list):
      gold_y_test_list.append(i)
   else:
      for j in i:
       gold_y_test_list.append(j)

len(gold_y_test_list)
# Out:
# 72220

# %%
len(termos_skweak_list)
# Out:
# 72220

# %%
#Apenas checa se os tokens estão batento
resultados = []
for sk_ato , gold_ato in zip(termos_skweak_list, gold_x_test_list):
    tupla=(sk_ato , gold_ato) 
    resultados.append(tupla)
    if sk_ato != gold_ato:
        print(sk_ato, gold_ato)

#for item in resultados:
#    print(item)

# %%
#labels_skweak = labels
numero_contrato = 0
numero_contrato_total = 0
B_numero_contrato = 0
numero_contrato_gold=[]
obj_sk=[]


data_assinatura_contrato = 0
data_assinatura_contrato_total = 0
B_data_assinatura_contrato = 0
data_assinatura_contrato_gold = []

unidade_orcamentaria = 0
unidade_orcamentaria_total = 0
B_unidade_orcamentaria = 0
unidade_orcamentaria_gold = []
teste=[]

programa_trabalho = 0
programa_trabalho_total = 0
B_programa_trabalho = 0
programa_trabalho_gold = []

for ato_sk , label_sk, ato_gold, label_gold in zip(termos_skweak_list, labels_skweak_list,  gold_x_test_list, gold_y_test_list):    
    if label_gold == "B-numero_contrato":
           #print("Teste")
        numero_contrato_total+=1
        B_numero_contrato=label_gold
        if label_gold == label_sk:
               numero_contrato+=1
        else:
            numero_contrato_gold.append(ato_gold)

    elif label_gold == "B-data_assinatura_contrato":
                
        data_assinatura_contrato_total+=1
        B_data_assinatura_contrato=label_gold
        if label_gold == label_sk:
            data_assinatura_contrato+=1
        else:
            data_assinatura_contrato_gold.append(ato_gold)    
    elif label_gold == "B-unidade_orcamentaria":    
        unidade_orcamentaria_total+=1
        B_unidade_orcamentaria=label_gold
        if label_gold == label_sk:
            unidade_orcamentaria+=1        
        else:
            unidade_orcamentaria_gold.append(ato_gold) 
                 
    elif label_gold == "B-programa_trabalho":      
        programa_trabalho_total+=1
        B_programa_trabalho=label_gold
        if label_gold == label_sk:
            programa_trabalho+=1
        else:
            programa_trabalho_gold.append(ato_gold)                
print("Tipo da entidade             Total Entidade Gold                 Total Entidade Skweak")                
print("B-numero_contrato",              "   ",numero_contrato_total,         "   ",numero_contrato)#,"      ","       ",numero_contrato_gold)
print("B-data_assinatura_contrato"," ",data_assinatura_contrato_total,"   ",data_assinatura_contrato)#,"      ",data_assinatura_contrato_gold)
print("B-unidade_orcamentaria",      "  ",unidade_orcamentaria_total,    "   ",unidade_orcamentaria)#,"          ",unidade_orcamentaria_gold)
print( "B-programa_trabalho",       "  ",programa_trabalho_total,       "   ",programa_trabalho)#,"             ",programa_trabalho_gold)

#print(programa_trabalho_gold)
#print(programa_trabalho_gold)
# Out:
# Tipo da entidade             Total Entidade Gold                 Total Entidade Skweak
# B-numero_contrato     340     289
# B-data_assinatura_contrato   185     172
# B-unidade_orcamentaria    150     144
# B-programa_trabalho    221     214

# %%
classes = ['B-numero_contrato',
 'B-processo_gdf',
 'I-processo_gdf',
 'B-data_assinatura_contrato',
 'B-unidade_orcamentaria',
 'B-programa_trabalho',
 'B-natureza_despesa',
 'B-nota_empenho',
 'B-valor_contrato',
 'I-programa_trabalho',
 'I-natureza_despesa',
 'I-nota_empenho',
 'I-numero_contrato',
 'I-data_assinatura_contrato',
 'I-unidade_orcamentaria']

# %%
len(labels_skweak_list)
# Out:
# 72220

# %%
classes
# Out:
# ['B-numero_contrato',
#  'B-processo_gdf',
#  'I-processo_gdf',
#  'B-data_assinatura_contrato',
#  'B-unidade_orcamentaria',
#  'B-programa_trabalho',
#  'B-natureza_despesa',
#  'B-nota_empenho',
#  'B-valor_contrato',
#  'I-programa_trabalho',
#  'I-natureza_despesa',
#  'I-nota_empenho',
#  'I-numero_contrato',
#  'I-data_assinatura_contrato',
#  'I-unidade_orcamentaria']

# %%
#Rotulação baseada no modelo treinado com supervisão fraca
y_pred = crf.predict(x_test_gold)
# Out:
# 0.8661207795081473

# %%
#Validação com sklearn
classes = list(crf.classes_)
classes.remove('O')
metrics.flat_f1_score(gold_y_test, labels_skweak, average='weighted', labels=classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [198], line 2
#       1 #Validação com sklearn
# ----> 2 classes = list(crf.classes_)
#       3 classes.remove('O')
#       4 metrics.flat_f1_score(gold_y_test, labels_skweak, average='weighted', labels=classes)
#
# NameError: name 'crf' is not defined

# %%
#Validação com seqeval
from seqeval.metrics import f1_score
f1_score(gold_y_test, labels_skweak, average='weighted')
# Out:
# 0.4572283878431754

# %%
# classification_report Seqeval
import numpy as np
from seqeval.metrics import classification_report
from seqeval.scheme import IOB2

report = classification_report(gold_y_test, labels_skweak, output_dict=False, mode='strict', scheme=IOB2)
print(report)
np.save("./Results/METRICA_EXTRATO_CONTRATO_DIRETO_V1_0_sq.npy", report)
# Out:
#                           precision    recall  f1-score   support
#
# cnpj_entidade_contratada       0.00      0.00      0.00        73
#   cnpj_orgao_contratante       0.00      0.00      0.00        13
#             codigo_siggo       0.00      0.00      0.00        34
# data_assinatura_contrato       0.59      0.92      0.72       185
#      entidade_contratada       0.00      0.00      0.00       323
#            fonte_recurso       0.00      0.00      0.00       263
#         natureza_despesa       0.94      0.82      0.87       222
#         nome_responsavel       0.00      0.00      0.00        41
#             nota_empenho       0.96      0.95      0.95       258
#          numero_contrato       0.93      0.84      0.88       340
#          objeto_contrato       0.00      0.00      0.00       304
#        orgao_contratante       0.00      0.00      0.00       444
#             processo_gdf       0.96      0.96      0.96       298
#        programa_trabalho       0.74      0.86      0.79       221
#     unidade_orcamentaria       0.68      0.94      0.79       150
#           valor_contrato       0.94      0.72      0.81       381
#        vigencia_contrato       0.00      0.00      0.00       292
#
#                micro avg       0.84      0.46      0.60      3842
#                macro avg       0.40      0.41      0.40      3842
#             weighted avg       0.47      0.46      0.46      3842

# %%
#classification_report sklearn
report = metrics.flat_classification_report(
    #y_test[:200], y_pred[:200], labels=classes, digits=3))
   gold_y_test, labels_skweak, labels=classes, digits=3, output_dict=False)
print(report)
# Out:
# /home/lucelia_vieira/experiments/members/lucelia/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                             precision    recall  f1-score   support
#
#          B-numero_contrato      0.941     0.850     0.893       340
#             B-processo_gdf      0.966     0.966     0.966       298
#             I-processo_gdf      0.976     0.839     0.902       285
# B-data_assinatura_contrato      0.593     0.930     0.724       185
#     B-unidade_orcamentaria      0.699     0.960     0.809       150
#        B-programa_trabalho      0.836     0.968     0.897       221
#         B-natureza_despesa      0.990     0.860     0.920       222
#             B-nota_empenho      0.984     0.973     0.979       258
#           B-valor_contrato      0.941     0.717     0.814       381
#        I-programa_trabalho      0.044     1.000     0.085         3
#         I-natureza_despesa      0.167     1.000     0.286         3
#             I-nota_empenho      0.000     0.000     0.000         4
#          I-numero_contrato      0.312     0.833     0.455        12
# I-data_assinatura_contrato      0.231     0.984     0.374        61
#     I-unidade_orcamentaria      0.000     0.000     0.000         0
#
#                  micro avg      0.782     0.882     0.829      2423
#                  macro avg      0.579     0.792     0.607      2423
#               weighted avg      0.882     0.882     0.866      2423

# %%
import numpy as np
report = metrics.flat_classification_report(
    #y_test[:200], y_pred[:200], labels=classes, digits=3))
    gold_y_test, labels_skweak, labels=classes, digits=3, output_dict=True)
print(report)
np.save("./Results/METRICA_EXTRATO_CONTRATO_LB_DIRETO_V1_0.npy", report)
# Out:
# {'B-numero_contrato': {'precision': 0.9413680781758957, 'recall': 0.85, 'f1-score': 0.8933539412673879, 'support': 340}, 'B-processo_gdf': {'precision': 0.9664429530201343, 'recall': 0.9664429530201343, 'f1-score': 0.9664429530201343, 'support': 298}, 'I-processo_gdf': {'precision': 0.9755102040816327, 'recall': 0.8385964912280702, 'f1-score': 0.9018867924528302, 'support': 285}, 'B-data_assinatura_contrato': {'precision': 0.593103448275862, 'recall': 0.9297297297297298, 'f1-score': 0.7242105263157895, 'support': 185}, 'B-unidade_orcamentaria': {'precision': 0.6990291262135923, 'recall': 0.96, 'f1-score': 0.8089887640449438, 'support': 150}, 'B-programa_trabalho': {'precision': 0.8359375, 'recall': 0.9683257918552036, 'f1-score': 0.8972746331236896, 'support': 221}, 'B-natureza_despesa': {'precision': 0.9896373056994818, 'recall': 0.8603603603603603, 'f1-score': 0.9204819277108434, 'support': 222}, 'B-nota_empenho': {'precision': 0.984313725490196, 'recall': 0.9728682170542635, 'f1-score': 0.9785575048732942, 'support': 258}, 'B-valor_contrato': {'precision': 0.9413793103448276, 'recall': 0.7165354330708661, 'f1-score': 0.8137108792846497, 'support': 381}, 'I-programa_trabalho': {'precision': 0.04411764705882353, 'recall': 1.0, 'f1-score': 0.08450704225352113, 'support': 3}, 'I-natureza_despesa': {'precision': 0.16666666666666666, 'recall': 1.0, 'f1-score': 0.2857142857142857, 'support': 3}, 'I-nota_empenho': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4}, 'I-numero_contrato': {'precision': 0.3125, 'recall': 0.8333333333333334, 'f1-score': 0.45454545454545453, 'support': 12}, 'I-data_assinatura_contrato': {'precision': 0.23076923076923078, 'recall': 0.9836065573770492, 'f1-score': 0.37383177570093457, 'support': 61}, 'I-unidade_orcamentaria': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'micro avg': {'precision': 0.7819246249542627, 'recall': 0.88196450680974, 'f1-score': 0.8289371605896043, 'support': 2423}, 'macro avg': {'precision': 0.5787183463864227, 'recall': 0.7919865911352674, 'f1-score': 0.6069004320205172, 'support': 2423}, 'weighted avg': {'precision': 0.8816275135812536, 'recall': 0.88196450680974, 'f1-score': 0.8661207795081473, 'support': 2423}}
