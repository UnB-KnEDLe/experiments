# %% [markdown]
# # Métricas de concordância
# Notebook resumido

# %%
from utils import *

# %% [markdown]
# ## Obter CSV
# Obtendo arquivo CSV com anotações:

# %%
path = get_csv('/home/mstauffer/Documentos/UnB/KnEDle/agreement_study/xmls', 'agreement_soft.csv')

# %%
import pandas as pd

df = pd.read_csv(path)
df
# Out:
#                  id_dodf                     tipo_rel id_rel  \
# 0       17_133.28.6.2013  Ato_Exoneracao_Comissionado     R3
# 1       17_133.28.6.2013  Ato_Exoneracao_Comissionado     R3
# 2       17_133.28.6.2013  Ato_Exoneracao_Comissionado     R3
# 3       17_133.28.6.2013  Ato_Exoneracao_Comissionado     R3
# 4       17_133.28.6.2013  Ato_Exoneracao_Comissionado     R3
# ...                  ...                          ...    ...
# 19487  13_212.10.10.2013             Ato_Substituicao    R40
# 19488  13_212.10.10.2013             Ato_Substituicao    R40
# 19489  13_212.10.10.2013             Ato_Substituicao    R40
# 19490  13_212.10.10.2013             Ato_Substituicao    R40
# 19491  13_212.10.10.2013             Ato_Substituicao    R40
#
#            anotador_rel                     tipo_ent  id_ent     anotador_ent  \
# 0      matheus_stauffer  Ato_Exoneracao_Comissionado    1178   pedro_henrique
# ...

# %% [markdown]
# ## Obter estruturas auxiliares
# Obtendo dicionário de duplicatas de offsets e dicionário com entidades:

# %%
dupli, data_dict = aux_structures(path)

# %%
dupli
# Out:
# {304: [15160],
#  305: [1494],
#  312: [9320, 9443, 9566, 9677],
#  314: [15161],
#  315: [1500],
#  323: [15162],
#  338: [9321, 9444, 9567, 9678],
#  356: [1495],
#  359: [12575],
#  363: [9322, 9445, 9568, 9679, 15163],
#  364: [9323, 9446, 9569, 9680],
#  369: [12576],
#  378: [12577],
#  407: [9324, 9447, 9570, 9681],
#  414: [15164],
#  424: [15165],
#  430: [1496],
#  435: [9325, 9448, 9571, 9682],
#  439: [12578],
#  440: [1497],
#  443: [15166],
#  445: [9326, 9449, 9572, 9683],
#  446: [9327, 9450, 9573, 9684],
#  449: [12579],
#  451: [1498],
#  465: [12580],
#  466: [1499],
#  468: [9328, 9451, 9574, 9685],
#  502: [1446],
#  508: [1447],
#  522: [9329, 9452, 9575, 9686],
#  556: [9389, 9512, 9746, 9776],
#  566: [1448],
#  577: [9390, 9513, 9747, 9777, 15167],
#  588: [9391, 9514, 9748, 9778],
#  594: [1449],
#  612: [15152],
#  622: [15153],
#  632: [9392, 9515, 9749, 9779],
#  641: [9393, 9516, 9750, 9780],
#  663: [15154],
#  664: [15155],
# ...

# %%
data_dict
# Out:
# {0: (205008,
#   326,
#   'pedro_henrique',
#   'Ato_Exoneracao_Comissionado',
#   'EXONERAR SEBASTIAO FRANCISCO DE QUEIROZ do Cargo em Comissao, Simbolo DFA-\n12, de Assessor, da Gerencia Regional do Setor Complementar de Industria e Abastecimento, da \nAdministracao Regional do Setor Complementar de Industria e Abastecimento, da Coordenadoria \ndas Cidades, da Casa Civil, da Governadoria do Distrito Federal.',
#   0,
#   '17_133.28.6.2013'),
#  1: (205016,
#   31,
#   'DODFMiner',
#   'nome',
#   ' SEBASTIAO FRANCISCO DE QUEIROZ',
#   1,
#   '17_133.28.6.2013'),
#  2: (205078, 4, 'DODFMiner', 'simbolo', 'DFA-', 2, '17_133.28.6.2013'),
#  3: (205078,
#   7,
#   'pedro_henrique',
#   'simbolo',
#   'DFA-\n12',
#   2,
#   '17_133.28.6.2013'),
#  4: (205089,
#   9,
#   'DODFMiner',
#   'cargo_comissionado',
#   ' Assessor',
#   3,
#   '17_133.28.6.2013'),
#  5: (205103,
#   193,
#   'DODFMiner',
#   'hierarquia_lotacao',
# ...

# %% [markdown]
# ## Métricas de concordância

# %%
t1 = 'EXONERAR SEBASTIAO FRANCISCO DE QUEIROZ do Cargo em Comissao, Simbolo DFA-\n12, de Assessor, da Gerencia Regional do Setor Complementar de Industria e Abastecimento, da \nAdministracao Regional do Setor Complementar de Industria e Abastecimento, da Coordenadoria \ndas Cidades, da Casa Civil, da Governadoria do Distrito Federal.'
t2 = 'SEBASTIAO FRANCISCO DE QUEIROZ do Cargo em Comissao, Simbolo DFA-\n12, de Assessor, da Gerencia Regional do Setor Complementar de Industria e Abastecimento, da \nAdministracao Regional do Setor Complementar de Industria e Abastecimento, da Coordenadoria \ndas Cidades, da Casa Civil, da Governadoria do Distrito Federal.'

# %% [markdown]
# ### Jaccard
# Cômputo da similaridade entre strings usando o critério de Jaccard:

# %%
jaccard_char(t1, t2)
# Out:
# 0.9723926380368099

# %% [markdown]
# ### Similaridade via representação vetorial
# Cômputo da similaridade de cossenos e distância euclidiana:

# %%
vectors = get_word2vec(path)

# %%
vectors['EXONERAR']
# Out:
# array([ 0.45592782,  0.330456  , -0.7961448 ,  0.70875174,  0.77336806,
#        -0.6903657 , -0.2650824 , -0.77395195, -0.6836054 ,  0.99365616,
#        -0.34543547, -0.82594186, -0.6846429 , -0.43187544,  0.5254813 ,
#        -0.46163464,  0.17954776,  1.4218036 ,  0.45055628, -0.7478577 ,
#        -0.3324256 ,  0.5540718 , -0.5982775 ,  0.03188893,  0.20005582,
#        -0.4453584 ,  0.38104498, -0.9272266 ,  0.04954855, -0.43717942,
#        -0.23468181,  0.5890823 ,  0.00625427, -0.43716165,  0.7201162 ,
#         0.37777877, -0.52582157,  0.53980327,  0.02388224,  0.30350843,
#         0.06804836,  0.45080966, -0.552082  ,  0.7296416 , -0.40408698,
#        -0.54497665,  0.24515456,  0.21217862,  0.4806919 , -0.23603006],
#       dtype=float32)

# %%
cos_sim(get_vector(t1, vectors), get_vector(t2, vectors))
# Out:
# 0.9999011930417704

# %%
euclidean(get_vector(t1, vectors), get_vector(t2, vectors))
# Out:
# 3.929324271531377

# %% [markdown]
# ### Similaridade de dados nominais
# Cômputo do score _alpha_ de Krippendorff para dados nominais:

# %%
krippendorff_score(path, dupli, data_dict)
# Out:
# 0.2025049723421185
