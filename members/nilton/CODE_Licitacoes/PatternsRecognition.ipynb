# %% [markdown]
# # KneDle: Licitações e Contratos
# ## Data Exploration: "AVISO DE VENCEDOR"

# %%
import re
import docx
from sklearn.feature_extraction.text import CountVectorizer
import operator

# %%
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %% [markdown]
# ### Exploring collected data from: <https://www.dodf.df.gov.br/>

# %%
texto = [getText('vencedorALL.docx').lower()]
texto
# Out:
# ['aviso de declaração de vencedor\ncomunicamos aos interessados no procedimento licitatório eletrônico nº 010/2020 –\ndecomp/da - processo nº 00112-00017750/2020-32, após verificada a aceitabilidade\nda proposta de preços e documentação, na forma do instrumento convocatório, fica\ndeclarada vencedora do certame a empresa climática engenharia eireli -\ncnpj 02.604.476/0001-67, com o valor total de r$ 619.500,00. fica aberto o prazo\nrecursal de 05 (cinco) dias úteis, contados a partir do primeiro dia útil após a\npublicação. contatos: (061) 3403-2321 ou (061) 3403- 2322 e email\ndilic@novacap.df.gov.br.\nbrasília/df, 04 de dezembro de 2020\nshirley de faria soares de carvalho\nchefe\n\ndiretoria administrativa departamento de compras \xa0\naviso de declaração de vencedor comunicamos aos interessados no procedimento licitatório eletrônico nº 016/2020 – decomp/da - processo nº 00112-00023131/2019-43, após verificada a aceitabilidade da proposta de preços e documentação, na forma do instrumento convocatório, fica declarada vencedora dos lotes 03 – com o valor total de r$ 10.180.000,01 e lote 05 – com o valor total de\n\ndiretoria administrativa departamento de compras aviso de declaração de vencedor\xa0comunicamos aos interessados no procedimento licitatório eletrônico nº 011/2020 – decomp/da - processo nº 00112-00023724/2018-29, após verificada a aceitabilidade da proposta de preços e documentação, na forma do instrumento convocatório, fica declarada vencedora do certame a empresa conforto ambiental tecnologia em despoluição ambiental eireli – cnpj\n\naviso de declaração de vencedor comunicamos aos interessados no procedimento licitatório eletrônico nº 010/2020 – decomp/da - processo nº 00112-00017750/2020-32, após verificada a aceitabilidade da proposta de preços e documentação, na forma do instrumento convocatório, fica declarada vencedora do certame a empresa climática engenharia eireli - cnpj 02.604.476/0001-67, com o valor\n\ndiretoria administrativa departamento de compras aviso de declaração de vencedor\xa0comunicamos aos interessados no procedimento licitatório eletrônico nº 005/2020 – decomp/da - processo nº 00112-00032836/2018-71, após verificada a aceitabilidade da proposta de preços e documentação, na forma do instrumento convocatório, fica declarada vencedora do certame a empresa concrepoxi engenharia ltda - cnpj 08.064.693/0001-98, com o valor\n\n268 diretoria administrativa departamento de compras aviso de declaração de vencedor\xa0comunicamos aos interessados no procedimento licitatório eletrônico nº 007/2020 – decomp/da - processo nº 00112-00036315/2019-73, após verificada a aceitabilidade da proposta de preços e documentação, na forma do instrumento convocatório, fica declarada vencedora do certame a empresa abtec engenharia ltda - cnpj 12.754.237/0001-47, com o valor total\n\n277 diretoria administrativa departamento de compras aviso de declaração de vencedor\xa0comunicamos aos interessados no procedimento licitatório eletrônico nº 008/2020 – decomp/da - processo nº 00112-00032151/2018-24, após verificada a aceitabilidade da proposta de preços e documentação, na forma do instrumento convocatório, fica declarada vencedora do certame a empresa pentag engenharia ltda – cnpj 02.581.588/0001-40, com o valor total\n\ndiretoria administrativa departamento de compras aviso de declaração de vencedor\xa0comunicamos aos interessados no procedimento licitatório eletrônico nº 009/2020 – decomp/da - processo nº 112-00000800/2019-17, que após finalizado o exame e verificada a aceitabilidade da proposta de preços e documentação, na forma do instrumento convocatório, fica declarada vencedora do certame a empresa over elevadores eireli – cnpj\n\ndiretoria administrativa departamento de compras aviso de declaração de vencedor\xa0comunicamos aos interessados no procedimento licitatório eletrônico nº 003/2020 – ascal/pres - processo nº 00050-00047502/2018-55, que após finalizado o exame e verificada a aceitabilidade da proposta de  ...

# %% [markdown]
# ### BoW: 1-Gram and n-Gram Analysis

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texto)
words = vectorizer.get_feature_names() #Words
countX = X.toarray()[0]
counting = {}
for pind in range(0, len(countX)):
    counting[words[pind]] = countX[pind]
counting = sorted(counting.items(), key=operator.itemgetter(1),reverse=True)

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(5, 5),token_pattern=r'\b\w+\b', min_df=1)
X2 = bigram_vectorizer.fit_transform(texto)
words2 = bigram_vectorizer.get_feature_names() #Words
countX2 = X.toarray()[0]
counting2 = {}
for pind in range(0, len(countX2)):
    counting2[words2[pind]] = countX2[pind]
counting2 = sorted(counting2.items(), key=operator.itemgetter(1),reverse=True)

# %% [markdown]
# ### Visually Selection of Key terms

# %%
counting
# Out:
# [('de', 107),
#  ('do', 46),
#  ('da', 34),
#  ('nº', 33),
#  ('após', 24),
#  ('na', 24),
#  ('no', 24),
#  ('aceitabilidade', 23),
#  ('aos', 23),
#  ('aviso', 23),
#  ('comunicamos', 23),
#  ('convocatório', 23),
#  ('declaração', 23),
#  ('documentação', 23),
#  ('forma', 23),
#  ('instrumento', 23),
#  ('interessados', 23),
#  ('licitatório', 23),
#  ('preços', 23),
#  ('procedimento', 23),
#  ('proposta', 23),
#  ('vencedor', 23),
#  ('verificada', 23),
#  ('eletrônico', 22),
#  ('cnpj', 20),
#  ('declarada', 20),
#  ('fica', 20),
#  ('vencedora', 20),
#  ('empresa', 19),
#  ('2020', 16),
#  ('com', 16),
#  ('exame', 16),
#  ('finalizado', 16),
#  ('que', 16),
#  ('2019', 15),
#  ('ascal', 15),
#  ('certame', 15),
#  ('pres', 15),
#  ('valor', 15),
#  ('0001', 14),
#  ('assessoria', 10),
#  ('cadastro', 10),
#  ('engenharia', 10),
#  ('licitações', 10),
#  ('total', 10),
#  ('ltda', 9),
#  ('processo', 9),
#  ('decomp', 8),
#  ('eireli', 8),
#  ('00112', 7),
#  ('administrativa', 7),
#  ('compras', 7),
#  ('departamento', 7),
#  ('diretoria', 7),
#  ('lote', 7),
#  ('01', 5),
#  ('007', 4),
#  ('2018', 4),
#  ('construtora', 4),
#  ('epp', 4),
#  ('me', 4),
#  ('009', 3),
#  ('016', 3),
#  ('02', 3),
#  ('03', 3),
#  ('06', 3),
#  ('07', 3),
#  ('08', 3),
#  ('10', 3),
#  ('ambiental', 3),
#  ('brasil', 3),
#  ('capital', 3),
#  ('df', 3),
#  ('nova', 3),
#  ('oliveira', 3),
#  ('queiroz', 3),
#  ('00017750', 2),
#  ('005', 2),
#  ('010', 2),
#  ('05', 2),
#  ('061', 2),
#  ('064', 2),
#  ('17', 2),
#  ('20', 2),
#  ('224', 2),
#  ('23', 2),
#  ('32', 2),
#  ('3403', 2),
#  ('476', 2),
#  ('599', 2),
#  ('604', 2),
#  ('67', 2),
#  ('693', 2),
#  ('830', 2),
#  ('895', 2),
#  ('98', 2),
#  ('astoke', 2),
#  ('brasília', 2),
#  ('chefe', 2),
#  ('climática', 2),
#  ('comércio', 2),
#  ('concrepoxi', 2),
#  ('declaradas', 2),
#  ('dos', 2),
#  ('edilson', 2),
#  ('ficam', 2),
#  ('gerais', 2),
#  ('januário', 2),
#  ('lotes', 2),
#  ('paisagismo', 2),
#  ('serviços', 2),
#  ('urbanismo', 2),
#  ('vencedoras', 2),
#  ('wm', 2),
#  ('00', 1),
#  ('000', 1),
#  ('00000800', 1),
#  ('00023131', 1),
#  ('00023724', 1),
#  ('00032151', 1),
#  ('00032836', 1),
#  ('00036315', 1),
#  ('00047502', 1),
#  ('00050', 1),
#  ('001', 1),
#  ('002', 1),
#  ('003', 1),
#  ('008', 1),
#  ('011', 1),
#  ('015', 1),
#  ('021', 1),
#  ('023', 1),
#  ('035', 1),
#  ('04', 1),
#  ('09', 1),
#  ('112', 1),
#  ('12', 1),
#  ('123', 1),
#  ('125', 1),
#  ('15', 1),
#  ('154', 1),
#  ('170', 1),
#  ('180', 1),
#  ('2006', 1),
#  ('22', 1),
#  ('2321', 1),
#  ('2322', 1),
#  ('237', 1),
#  ('24', 1),
#  ('268', 1),
#  ('277', 1),
#  ('29', 1),
#  ('313', 1),
#  ('335', 1),
#  ('40', 1),
#  ('43', 1),
#  ('47', 1),
#  ('50', 1),
#  ('500', 1),
#  ('516', 1),
#  ('55', 1),
#  ('57', 1),
#  ('581', 1),
#  ('585', 1),
#  ('588', 1),
#  ('619', 1),
#  ('71', 1),
#  ('710', 1),
#  ('724', 1),
#  ('73', 1),
#  ('754', 1),
#  ('791', 1),
#  ('84', 1),
#  ('952', 1),
#  ('aberto', 1),
#  ('abril', 1),
#  ('abtec', 1),
#  ('ali', 1),
#  ('alvenaria', 1),
#  ('as', 1),
#  ('base', 1),
#  ('benefícios', 1),
#  ('br', 1),
#  ('carvalho', 1),
#  ('cinco', 1),
#  ('civil', 1),
#  ('companhia', 1),
#  ('complementar', 1),
#  ('conforto', 1),
#  ('conservação', 1),
#  ('construção', 1),
#  ('contados', 1),
#  ('contatos', 1),
#  ('cqo', 1),
#  ('delcimar', 1),
#  ('despoluição', 1),
#  ('dezembro', 1),
#  ('dia', 1),
#  ('dias', 1),
#  ('dilic', 1),
#  ('dr7', 1),
#  ('eirli', 1),
#  ('elevadores', 1),
#  ('em', 1),
#  ('email', 1),
#  ('empresas', 1),
#  ('estabelecido', 1),
#  ('estabelecidos', 1),
#  ('faria', 1),
#  ('foi', 1),
#  ('gov', 1),
#  ('jmd', 1),
#  ('lei', 1),
#  ('leão', 1),
#  ('limpeza', 1),
#  ('martins', 1),
#  ('março', 1),
#  ('novacap', 1),
#  ('obras', 1),
#  ('os', 1),
#  ('ou', 1),
#  ('over', 1),
#  ('partir', 1),
#  ('pentag', 1),
#  ('pequeno', 1),
#  ('pires', 1),
#  ('por', 1),
#  ('prazo', 1),
#  ('premium', 1),
#  ('presencial', 1),
#  ('primeiro', 1),
#  ('publicação', 1),
#  ('recursal', 1),
#  ('se', 1),
#  ('serviço', 1),
#  ('shirley', 1),
#  ('soares', 1),
#  ('tecnologia', 1),
#  ('teixeira', 1),
#  ('tratar', 1),
#  ('urbana', 1),
#  ('urbanizado', 1),
#  ('úteis', 1),
#  ('útil', 1)]

# %%
counting2
# Out:
# [('791 724 assessoria de cadastro', 107),
#  ('a empresa civil engenharia ltda', 46),
#  ('754 237 0001 47 com', 34),
#  ('carvalho chefe diretoria administrativa departamento', 33),
#  ('2322 e email dilic novacap', 24),
#  ('brasília df 10 de março', 24),
#  ('c q o construtora queiroz', 24),
#  ('2020 delcimar pires martins chefe', 23),
#  ('2321 ou 061 3403 2322', 23),
#  ('29 após verificada a aceitabilidade', 23),
#  ('588 0001 40 com o', 23),
#  ('724 assessoria de cadastro e', 23),
#  ('84 com valor da nova', 23),
#  ('a empresa climática engenharia eireli', 23),
#  ('ambiental eireli cnpj aviso de', 23),
#  ('após a publicação contatos 061', 23),
#  ('após finalizado o exame e', 23),
#  ('assessoria de cadastro e licitações', 23),
#  ('cinco dias úteis contados a', 23),
#  ('climática engenharia eireli cnpj 02', 23),
#  ('cnpj 01 710 170 0001', 23),
#  ('com o valor total 277', 23),
#  ('com o valor total diretoria', 23),
#  ('a empresa jmd engenharia eirli', 22),
#  ('516 0001 50 dos lotes', 20),
#  ('830 895 0001 07 com', 20),
#  ('administrativa departamento de compras aviso', 20),
#  ('com o valor total da', 20),
#  ('a empresa wm paisagismo urbanismo', 19),
#  ('03 a empresa wm paisagismo', 16),
#  ('55 que após finalizado o', 16),
#  ('abtec engenharia ltda cnpj 12', 16),
#  ('alvenaria ltda cnpj 01 335', 16),
#  ('cnpj 02 604 476 0001', 16),
#  ('023 2019 ascal pres que', 15),
#  ('24 após verificada a aceitabilidade', 15),
#  ('43 após verificada a aceitabilidade', 15),
#  ('chefe aviso de declaração de', 15),
#  ('com o valor diretoria administrativa', 15),
#  ('0001 07 com valor assessoria', 14),
#  ('268 diretoria administrativa departamento de', 10),
#  ('3403 2321 ou 061 3403', 10),
#  ('a partir do primeiro dia', 10),
#  ('astoke engenharia edilson januário assessoria', 10),
#  ('cnpj companhia urbanizado brasília df', 10),
#  ('benefícios ali estabelecidos por tratar', 9),
#  ('cnpj 01 335 516 0001', 9),
#  ('895 0001 07 com valor', 8),
#  ('a empresa cqo construtora queiroz', 8),
#  ('0001 98 com o valor', 7),
#  ('2020 shirley de faria soares', 7),
#  ('585 0001 15 com o', 7),
#  ('952 035 0001 84 com', 7),
#  ('a empresa c q o', 7),
#  ('aviso de declaração de vencedor', 7),
#  ('00047502 2018 55 que após', 5),
#  ('00032151 2018 24 após verificada', 4),
#  ('021 2019 ascal pres que', 4),
#  ('67 com o valor total', 4),
#  ('a publicação contatos 061 3403', 4),
#  ('brasília df 04 de dezembro', 4),
#  ('00036315 2019 73 após verificada', 3),
#  ('00112 00023131 2019 43 após', 3),
#  ('00112 00023724 2018 29 após', 3),
#  ('00112 00036315 2019 73 após', 3),
#  ('005 2020 decomp da processo', 3),
#  ('008 2020 decomp da processo', 3),
#  ('009 2019 ascal pres que', 3),
#  ('01 335 516 0001 50', 3),
#  ('23 com o valor total', 3),
#  ('32 após verificada a aceitabilidade', 3),
#  ('3403 2322 e email dilic', 3),
#  ('a aceitabilidade da proposta de', 3),
#  ('cadastro e licitações aviso de', 3),
#  ('certame a empresa abtec engenharia', 3),
#  ('cnpj 03 de abril de', 3),
#  ('0001 07 lote assessoria de', 2),
#  ('00023724 2018 29 após verificada', 2),
#  ('00050 00047502 2018 55 que', 2),
#  ('005 2019 ascal pres que', 2),
#  ('007 2019 ascal pres que', 2),
#  ('007 2020 decomp da processo', 2),
#  ('015 2019 ascal pres que', 2),
#  ('02 581 588 0001 40', 2),
#  ('03 de abril de 2020', 2),
#  ('035 0001 84 com valor', 2),
#  ('07 125 585 0001 15', 2),
#  ('07 lote assessoria de cadastro', 2),
#  ('10 180 000 01 e', 2),
#  ('17 2019 ascal pres que', 2),
#  ('17 que após finalizado o', 2),
#  ('180 000 01 e lote', 2),
#  ('20 830 895 0001 07', 2),
#  ('2019 43 após verificada a', 2),
#  ('2019 ascal pres que após', 2),
#  ('2020 ascal pres processo nº', 2),
#  ('277 diretoria administrativa departamento de', 2),
#  ('335 516 0001 50 dos', 2),
#  ('47 com o valor total', 2),
#  ('500 00 fica aberto o', 2),
#  ('599 0001 23 com o', 2),
#  ('604 476 0001 67 com', 2),
#  ('830 895 0001 07 lote', 2),
#  ('a empresa concrepoxi engenharia ltda', 2),
#  ('a empresa construtora premium e', 2),
#  ('ali estabelecidos por tratar se', 2),
#  ('ambiental tecnologia em despoluição ambiental', 2),
#  ('após verificada a aceitabilidade da', 2),
#  ('base no estabelecido na lei', 2),
#  ('certame a empresa concrepoxi engenharia', 2),
#  ('cnpj 10 952 035 0001', 2),
#  ('com o valor 268 diretoria', 2),
#  ('com o valor total de', 2),
#  ('com valor assessoria de cadastro', 2),
#  ('00 fica aberto o prazo', 1),
#  ('000 01 e lote 05', 1),
#  ('00000800 2019 17 que após', 1),
#  ('0001 15 com o valor', 1),
#  ('0001 22 com valor total', 1),
#  ('0001 23 com o valor', 1),
#  ('0001 40 com o valor', 1),
#  ('0001 47 com o valor', 1),
#  ('0001 50 dos lotes 01', 1),
#  ('0001 67 com o valor', 1),
#  ('0001 84 com valor da', 1),
#  ('00017750 2020 32 após verificada', 1),
#  ('00023131 2019 43 após verificada', 1),
#  ('00032836 2018 71 após verificada', 1),
#  ('001 2020 ascal pres que', 1),
#  ('00112 00017750 2020 32 após', 1),
#  ('00112 00032151 2018 24 após', 1),
#  ('00112 00032836 2018 71 após', 1),
#  ('002 2020 ascal pres que', 1),
#  ('003 2020 ascal pres processo', 1),
#  ('009 2020 decomp da processo', 1),
#  ('01 710 170 0001 22', 1),
#  ('01 com o valor total', 1),
#  ('01 e lote 05 com', 1),
#  ('01 r 3 791 724', 1),
#  ('010 2020 decomp da processo', 1),
#  ('011 2020 decomp da processo', 1),
#  ('016 2019 ascal pres que', 1),
#  ('016 2020 decomp da processo', 1),
#  ('02 604 476 0001 67', 1),
#  ('03 com o valor total', 1),
#  ('04 de dezembro de 2020', 1),
#  ('05 cinco dias úteis contados', 1),
#  ('05 com o valor total', 1),
#  ('06 224 599 0001 23', 1),
#  ('06 a leão serviços gerais', 1),
#  ('061 3403 2321 ou 061', 1),
#  ('061 3403 2322 e email', 1),
#  ('064 693 0001 98 com', 1),
#  ('07 com valor assessoria de', 1),
#  ('08 064 693 0001 98', 1),
#  ('08 a empresa civil engenharia', 1),
#  ('09 a empresa urbana ambiental', 1),
#  ('10 952 035 0001 84', 1),
#  ('10 de março de 2020', 1),
#  ('112 00000800 2019 17 que', 1),
#  ('12 754 237 0001 47', 1),
#  ('123 2006 os benefícios ali', 1),
#  ('125 585 0001 15 com', 1),
#  ('15 com o valor aviso', 1),
#  ('154 57 a empresa astoke', 1),
#  ('170 0001 22 com valor', 1),
#  ('2006 os benefícios ali estabelecidos', 1),
#  ('2018 24 após verificada a', 1),
#  ('2018 29 após verificada a', 1),
#  ('2018 55 que após finalizado', 1),
#  ('2018 71 após verificada a', 1),
#  ('2019 17 que após finalizado', 1),
#  ('2019 73 após verificada a', 1),
#  ('2020 32 após verificada a', 1),
#  ('2020 ascal pres que após', 1),
#  ('2020 assessoria de cadastro e', 1),
#  ('2020 decomp da processo nº', 1),
#  ('22 com valor total de', 1),
#  ('224 599 0001 23 com', 1),
#  ('237 0001 47 com o', 1),
#  ('3 313 154 57 a', 1),
#  ('3 791 724 assessoria de', 1),
#  ('313 154 57 a empresa', 1),
#  ('40 com o valor total', 1),
#  ('476 0001 67 com o', 1),
#  ('50 dos lotes 01 r', 1),
#  ('57 a empresa astoke engenharia', 1),
#  ('581 588 0001 40 com', 1),
#  ('619 500 00 fica aberto', 1),
#  ('67 com o valor diretoria', 1),
#  ('693 0001 98 com o', 1),
#  ('71 após verificada a aceitabilidade', 1),
#  ('710 170 0001 22 com', 1),
#  ('73 após verificada a aceitabilidade', 1),
#  ('895 0001 07 lote assessoria', 1),
#  ('98 com o valor 268', 1),
#  ('98 com o valor total', 1),
#  ('a concrepoxi engenharia ltda cnpj', 1),
#  ('a empresa abtec engenharia ltda', 1),
#  ('a empresa astoke engenharia edilson', 1),
#  ('a empresa conforto ambiental tecnologia', 1),
#  ('a empresa dr7 serviço de', 1),
#  ('a empresa over elevadores eireli', 1),
#  ('a empresa pentag engenharia ltda', 1),
#  ('a empresa urbana ambiental construção', 1),
#  ('a leão serviços gerais de', 1),
#  ('aberto o prazo recursal de', 1),
#  ('abril de 2020 assessoria de', 1),
#  ('aceitabilidade da proposta de preços', 1),
#  ('ambiental construção eireli epp cnpj', 1),
#  ('aos interessados no procedimento licitatório', 1),
#  ('as empresas wm paisagismo urbanismo', 1),
#  ('ascal pres processo nº 00050', 1),
#  ('ascal pres que após finalizado', 1),
#  ('astoke engenharia edilson januário teixeira', 1),
#  ('br brasília df 04 de', 1),
#  ('brasil assessoria de cadastro e', 1),
#  ('capital do brasil assessoria de', 1),
#  ('certame a concrepoxi engenharia ltda', 1),
#  ('certame a empresa astoke engenharia', 1),
#  ('certame a empresa c q', 1),
#  ('certame a empresa climática engenharia', 1),
#  ('certame a empresa conforto ambiental', 1),
#  ('certame a empresa construtora premium', 1),
#  ('certame a empresa cqo construtora', 1),
#  ('certame a empresa jmd engenharia', 1),
#  ('certame a empresa over elevadores', 1),
#  ('certame a empresa pentag engenharia', 1),
#  ('certame as empresas wm paisagismo', 1),
#  ('chefe diretoria administrativa departamento de', 1),
#  ('civil engenharia ltda cnpj 01', 1),
#  ('cnpj 02 581 588 0001', 1),
#  ('cnpj 06 224 599 0001', 1),
#  ('cnpj 07 125 585 0001', 1),
#  ('cnpj 08 064 693 0001', 1),
#  ('cnpj 12 754 237 0001', 1),
#  ('cnpj 20 830 895 0001', 1),
#  ('cnpj assessoria de cadastro e', 1),
#  ('cnpj aviso de declaração de', 1),
#  ('cnpj diretoria administrativa departamento de', 1),
#  ('com base no estabelecido na', 1),
#  ('com o valor aviso de', 1),
#  ('com valor da nova capital', 1),
#  ('com valor total de r', 1)]

# %%
termosimportantes = ['aviso de declaração de vencedor', 'após verificada a aceitabilidade', 'aceitabilidade', 'aviso', 'convocatório', 'licitatório', 'vencedor', 'vencedora']
