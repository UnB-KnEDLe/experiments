# %% [markdown]
# * Instalando biblioteca

# %%
#!pip install dodfminer

# %% [markdown]
# * Importando classes de extração de textos e atos:

# %%
from dodfminer import ContentExtractor
from dodfminer import ActsExtractor

# %% [markdown]
# * Extraindo texto de um arquivo PDF

# %%
ContentExtractor.extract_text('./pasta/dodf1.pdf', single=True)

# %% [markdown]
# * Recuperando DATA_FRAME com nossas entidades

# %%
data_frame = ActsExtractor.get_act_df('substituicao','./pasta/dodf2.txt', 'ner')

# %%
data_frame
# Out:
#                                 Nome_substituto  \
# 0                          CLAYTON CLAY FURTADO
# 1                            MONICA YUMI HARADA
# 2     ANA PAULA ANTONINO RIBEIRO ROSAES BARBOZA
# 3                           IVAN GOMES CARVALHO
# 4                   ANDERSON ALBUQUERQUE CABRAL
# 5                         JOANA DE ALMEIDA LIMA
# 6               FRANCISCA MARIA SANTOS DA SILVA
# 7                     RAIMUNDO DEODATO DA SILVA
# 8                      ELIANE RODRIGUES DA CRUZ
# 9                   DANIEL REIS DE SOUZA JUNIOR
# 10                            JANE ROCHA DUARTE
# 11       DANIELA ALESSANDRA BARNABE DE OLIVEIRA
# 12                JACKELINE DOMINGUES DE AGUIAR
# 13                       GUTIERRY ZALTUM MERCES
# 14                   DEBORA LONGUINHO DE MORAIS
# 15                    CRISTYANNE BARBOSA TAQUES
# 16                   DANIELE DA HORA DOS SANTOS
# 17                       ALESSANDRO ALVES ROCHA
# ...

# %% [markdown]
# * Resgatando segmentos de um ato

# %%
segmentos = ActsExtractor.get_act_obj('substituicao','./pasta/dodf2.txt', 'ner')

# %%
segmentos.acts_str
# Out:
# ['DESIGNAR CLAYTON CLAY FURTADO, matricula 172.729-X, para substituir CHARLISSON NOGUEIRA SILVA, matricula 127.100-8, Chefe da Unidade do Fundo Pro-Gestao, simbolo DFG - 14, da Secretaria Adjunta de Planejamento e Orcamento, da Secretaria de Estado de Planejamento, Orcamento e Gestao do Distrito Federal, no periodo de 05 a 14 de junho de 2017, por motivo de ferias do Titular.',
#  'DESIGNAR MONICA YUMI HARADA, matricula no 269.649-5, para substituir LIGIA MARIA DE SOUZA LOPES REIS, matricula no 267.5099, Chefe da Assessoria de Comunicacao, Simbolo CNE-03, da Secretaria de Estado de Planejamento, Orcamento e Gestao do Distrito Federal, no periodo de 19 a 28 de junho de 2017, por motivo de ferias da Titular.',
# ...
