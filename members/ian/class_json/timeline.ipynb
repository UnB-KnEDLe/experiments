# %%
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
df = pd.read_csv("dodf_json.csv")

# %%
df['processo'] = df['raw_txt'].str.extract(r'''(?:(?:(?:P|p)rocesso(?:\s+)?(?:(?:\()?SEI(?:\)?))?(?:\s+)?(?:(?:no|n\.o)?)?)|(?:P|p)rocesso:|(?:P|p)rocesso|Processo.|(?:P|p)rocesso\s+no|(?:P|p)rocesso\s+n.? ?o.?|(?:P|p)rocesso\s+no:|(?:P|p)rocesso\s+SEI\s+no:|(?:P|p)rocesso\s+SEI:|(?:P|p)rocesso\s+SEI-GDF:|(?:P|p)rocesso\s+SEI-GDF|(?:P|p)rocesso\s+SEI\s+no|(?:P|p)rocesso\s+SEI\s+n|(?:P|p)rocesso\s+SEI|(?:P|p)rocesso-\s+SEI|(?:P|p)rocesso\s+SEI\s+no.|(?:P|p)rocesso\s+\(SEI\)\s+no.|(?:P|p)rocesso\s+SEI\.|(?:P|p)rocesso\s+\(SEI-DF\)\s+no.|(?:P|p)rocesso\s+SEI-GDF no|(?:P|p)rocesso\s+n|(?:P|p)rocesso\s+N|(?:P|p)rocesso\s+administrativo no|(?:P|p)rocesso\s+n:|PROCESSO: ?N?o?|PROCES-? ?SO|PROCESSO.|PROCESSO\s+no|PROCESSO\s+No|PROCESSO\s+N.o:?|PROCESSO\s+no.|PROCESSO\s+no:|PROCESSO\s+No:|PROCESSO\s+SEI\s+no:|PROCESSO\s+SEI:|PROCESSO\s+SEI|PROCESSO\s+SEI-GDF:|PROCESSO\s+SEI-GDF|PROCESSO\s+SEI\s+no|PROCESSO\s+SEI\s+No|PROCESSO\s+SEI\s+no.|PROCESSO\s+SEI.)((?:(?!\s\d{2}.\d{3}.\d{3}/\d{4}-\d{2}))(?:(?:\s)(?:(?:[\d.]+)|(?:[\d\s]+))[.-]?(?:(?:\d)|(?:[.\d\sSEI-|]+))(?:/|-
\b)(?:(?:(?:\d)+|(?:[\d\s]+)))?(?:-(?:(?:\d)+|(?:[\d\s]+)))?(?:-SECOM/DF|-?CEB|/CBMDF|F J Z B / D F)?))''').replace(r'[^0-9]', '', regex=True)

# %%
df
# Out:
#                       link_dodf        date  nro  \
# 0      do.df.gov.br/220104NO002  2022-01-04    2
# 1      do.df.gov.br/220104NO002  2022-01-04    2
# 2      do.df.gov.br/220104NO002  2022-01-04    2
# 3      do.df.gov.br/220104NO002  2022-01-04    2
# 4      do.df.gov.br/220104NO002  2022-01-04    2
# ...                         ...         ...  ...
# 40257  do.df.gov.br/211228NO242  2021-12-28  242
# 40258  do.df.gov.br/211228NO242  2021-12-28  242
# 40259  do.df.gov.br/211228NO242  2021-12-28  242
# 40260  do.df.gov.br/211228NO242  2021-12-28  242
# 40261  do.df.gov.br/211228NO242  2021-12-28  242
#
#                                   orgao    section  \
# 0                     Poder Legislativo  Seção III
# 1       Secretaria de Estado de Governo  Seção III
# 2       Secretaria de Estado de Governo  Seção III
# 3      Secretaria de Estado de Economia  Seção III
# 4      Secretaria de Estado de Economia  Seção III
# ...                                 ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# link_dodf       0
# date            0
# nro             0
# orgao           0
# section         0
# name            0
# type_act        0
# raw_txt        40
# processo     7701
# dtype: int64

# %%
timeline = Counter(list(df['processo'])).most_common()

# %%
timeline
# Out:
# 21409

# %%
# [143, 109, 53, 72, 276, 214, 218, 72, 276, 160, 56, 297, 163, 298, 296, 27, 305, 46, 168, 107, 27, 147, 314, 87, 172, 172, 298, 325]

# %%
df.loc[df['processo'] == timeline[109][0]].sort_values(by=['date'], ascending=False)
# Out:
#                       link_dodf        date  nro  \
# 17813  do.df.gov.br/220714NO131  2022-07-14  131
# 12237  do.df.gov.br/220520NO094  2022-05-20   94
# 5224   do.df.gov.br/220307NO044  2022-03-07   44
# 3510   do.df.gov.br/220214NO031  2022-02-14   31
# 706    do.df.gov.br/220112NO008  2022-01-12    8
# 502    do.df.gov.br/220107NO005  2022-01-07    5
# 503    do.df.gov.br/220107NO005  2022-01-07    5
# 35346  do.df.gov.br/211118NO215  2021-11-18  215
# 31935  do.df.gov.br/211014NO193  2021-10-14  193
#
#                                                 orgao    section  \
# 17813  Secretaria de Estado de Obras e Infraestrutura  Seção III
# 12237  Secretaria de Estado de Obras e Infraestrutura  Seção III
# 5224   Secretaria de Estado de Obras e Infraestrutura  Seção III
# 3510   Secretaria de Estado de Obras e Infraestrutura  Seção III
# 706    Secretaria de Estado de Obras e Infraestrutura  Seção III
# 502    Secretaria de Estado de Obras e Infraestrutura  Seção III
# ...

# %%
df['raw_txt'][502], df['raw_txt'][503]
# Out:
# ('Concorrencia no 001/2022 - DECOMP/DA - do tipo menor preco - objetivando a contratacao pelo Distrito Federal, por meio da Secretaria de Estado de Obras e Infraestrutura do Distrito Federal, de empresa especializada para a execucao dos servicos de requalificacao urbana, incluindo execucao de obras de drenagem pluvial, lagoa de detencao, pavimentacao, sinalizacao, paisagismo, implantacao de mobiliario urbano, calcadas e estacionamentos publicos do Setor de Oficinas Sul - SOF SUL, Regiao Administrativa do Guara (RA-X), devidamente especificado no Termo de Referencia e no Edital e seus anexos processo 00110-00000583/2021-28 - Valor estimado R$ 49.077.758,24 - Data e horario da licitacao: 09 de fevereiro de 2022 - as 09:00h. A NOVACAP realizara o certame na Sala de Licitacoes do DECOMP/DA, sito no Setor de Areas Publicas, Lote "B", Bloco "A" 1o andar - Sede da Companhia em Brasilia - DF. O Edital e seus anexos poderao ser retirados exclusivamente no site www.novacap.df.gov.br. Contatos:
# ...
