# %%
from acts_extract_json import *

# %%
DODFCorpus('DODF 002 04-01-2022.json').read()
# Out:
#                    link_dodf        date nro  \
# 0   do.df.gov.br/220104NO002  2022-01-04   2
# 1   do.df.gov.br/220104NO002  2022-01-04   2
# 2   do.df.gov.br/220104NO002  2022-01-04   2
# 3   do.df.gov.br/220104NO002  2022-01-04   2
# 4   do.df.gov.br/220104NO002  2022-01-04   2
# ..                       ...         ...  ..
# 66  do.df.gov.br/220104NO002  2022-01-04   2
# 67  do.df.gov.br/220104NO002  2022-01-04   2
# 68  do.df.gov.br/220104NO002  2022-01-04   2
# 69  do.df.gov.br/220104NO002  2022-01-04   2
# 70  do.df.gov.br/220104NO002  2022-01-04   2
#
#                                orgao    section  \
# 0                  Poder Legislativo  Seção III
# 1    Secretaria de Estado de Governo  Seção III
# 2    Secretaria de Estado de Governo  Seção III
# 3   Secretaria de Estado de Economia  Seção III
# 4   Secretaria de Estado de Economia  Seção III
# ..                               ...        ...
# 66  Secretaria de Estado de Trabalho  Seção III
# ...
