# %%
from acts_extract_json import *

# %%
page = requests.get("http://164.41.76.30/dodf_watcher/")
html = page.content.decode("utf-8")

soup = BeautifulSoup(html, 'html.parser')

url_paths = soup.findAll('a')
url_paths = [l.get_text() for l in url_paths]
url_paths = [l.replace("\n", "%0A") for l in url_paths if "DODF" in l]

# %%
DODFCorpus(url_paths[1]).read()
# Out:
#                    linkJornal dt_previsao_publicacao nu_numero  \
# 0    do.df.gov.br/230102NO001             02/01/2023         1
# 1    do.df.gov.br/230102NO001             02/01/2023         1
# 2    do.df.gov.br/230102NO001             02/01/2023         1
# 3    do.df.gov.br/230102NO001             02/01/2023         1
# 4    do.df.gov.br/230102NO001             02/01/2023         1
# ..                        ...                    ...       ...
# 183  do.df.gov.br/230102NO001             02/01/2023         1
# 184  do.df.gov.br/230102NO001             02/01/2023         1
# 185  do.df.gov.br/230102NO001             02/01/2023         1
# 186  do.df.gov.br/230102NO001             02/01/2023         1
# 187  do.df.gov.br/230102NO001             02/01/2023         1
#
#                                 orgao      secao  \
# 0                          Casa Civil  Seção III
# 1                          Casa Civil  Seção III
# 2     Secretaria de Estado de Governo  Seção III
# 3     Secretaria de Estado de Governo  Seção III
# 4     Secretaria de Estado de Governo  Seção III
# ..                                ...        ...
# 183  Secretaria de Estado de Trabalho  Seção III
# 184  Secretaria de Estado de Trabalho  Seção III
# 185                Defensoria Pública  Seção III
# 186                       Ineditorial  Seção III
# 187                       Ineditorial  Seção III
#
#                                                 titulo         tipo  \
# 0                       EXTRATO AO CONTRATO N° 19/2022      Extrato
# 1    EXTRATO AO CONTRATO DE PRESTAÇÃO DE SERVIÇOS N...      Extrato
# 2               EXTRATO DO CONTRATO Nº 02/2022 - RA-NB      Extrato
# 3               EXTRATO DO CONTRATO Nº 03/2022 - RA-NB      Extrato
# 4            EXTRATO DO TERMO DE COOPERAÇÃO Nº 02/2022      Extrato
# ..                                                 ...          ...
# 183            EXTRATO DO TERMO DE FOMENTO Nº 019/2022      Extrato
# 184   EDITAL DE CHAMAMENTO PÚBLICO Nº 53/2022 - SETRAB       Edital
# 185  EXTRATO DO PRIMEIRO TERMO ADITIVO AO TERMO DE ...      Extrato
# 186                                 AVISO DE RESULTADO  Ineditorial
# 187        AVISO DE RECEBIMENTO DE LICENÇA DE OPERAÇÃO  Ineditorial
#
#                                                  texto             processo
# 0    PROCESSO SEI-GDF No: 00010-00000160/2022-35. P...                  NaN
# 1    PROCESSO SEI-GDF No: 00002-00004242/2022-30. P...                  NaN
# 2    Processo: 00136-00000216/2022-71. Partes: DF/A...  0013600000216202271
# 3    Processo: 00136-00000703/2022-34. Partes: DF/A...  0013600000703202234
# 4    PROCESSO: 00146-00000387/2021-82. DAS PARTES: ...  0014600000387202182
# ..                                                 ...                  ...
# 183  Processo SEI no 04012-00002269/2022-39. DAS PA...  0401200002269202239
# 184  O Governo do Distrito Federal, por intermedio ...  0401200001712202254
# 185  Processo: 00401-00012085/2021-06. Partes: DEFE...  0040100012085202106
# 186  CHAMAMENTO No 329/2022O Hospital da Crianca de...  0402400001309202231
# 187  Torna publico que recebeu do Instituto do Meio...  0039100012015201865
#
# [188 rows x 9 columns]
