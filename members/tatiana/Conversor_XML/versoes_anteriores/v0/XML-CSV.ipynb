# %% [markdown]
# # Convertendo de XML para CSV

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('exemplo.xml')
root = tree.getroot()

# one specific item attribute
print('Item #2 attribute:')
print(root[0][1].attrib)

# all item attributes
print('\nAll attributes:')
for elem in root:
    for subelem in elem:
        print(subelem.attrib)

# one specific item's data
print('\nItem #2 data:')
print(root[0][1].text)

# all items data
print('\nAll item data:')
for elem in root:
    for subelem in elem:
        print(subelem.text)
# Out:
# Item #2 attribute:
# {'name': 'item2'}
#
# All attributes:
# {'name': 'item1'}
# {'name': 'item2'}
#
# Item #2 data:
# item2abc
#
# All item data:
# item1abc
# item2abc

# %%
# find the first 'item' object
for elem in root:
    print(elem.find('item').get('name'))

# find all "item" objects and print their "name" attribute
for elem in root:
    for subelem in elem.findall('item'):
    
        # if we don't need to know the name of the attribute(s), get the dict
        print(subelem.attrib)      
    
        # if we know the name of the attribute, access it directly
        print(subelem.get('name'))
# Out:
# item1
# {'name': 'item1'}
# item1
# {'name': 'item2'}
# item2

# %%
tree = ET.parse('DODF7_nomeacoes_completo.xml')
root = tree.getroot()

# all item attributes
print('\nAll attributes:')
print('passei por aqui1')
for documento in root.findall('document'):
    #print('passei por aqui2')
    for paragrafo in documento.findall('passage'):
        #print('passei por aqui3')
        for anno in paragrafo.findall('annotation'):
            anno_data = []
            print('\nAnnotation')
            print('ID = ' + anno.get('id'))
            for infon in anno.findall('infon'):
                #print('passei por aqui 5.1')
                #print(infon.attrib)
                #print(infon.get('key'))
                if infon.get('key') == 'type':
                    #print('passei por aqui 5.2')
                    anno_type = infon.text
                    print('Type = ' + anno_type)
                    #anno_data.append(anno_type)
                    
            text = anno.find('text').text
            print('Text = ' + text)
    
print('passei por aqui6')
# Out:
# All attributes:
# passei por aqui1
#
# Annotation
# ID = 632
# Type = NomeacaoComissionado
# Text = NOMEAR RICARDO TERENZI CARDOSO para exercer o Cargo de Natureza Especial, Símbolo CNE02, de Subsecretário, da Subsecretaria de Acompanhamento e Fiscalização, da Secretaria de Estado de
# Obras e Infraestrutura do Distrito Federal.
#
# Annotation
# ID = 592
# Type = NomeServidor
# Text = RICARDO TERENZI CARDOSO
#
# Annotation
# ID = 601
# Type = Simbolo
# Text = CNE02
#
# Annotation
# ID = 19
# Type = Cargo
# Text = Subsecretário
#
# Annotation
# ID = 628
# Type = Hierarquia_da_Lotacao
# Text = Subsecretaria de Acompanhamento e Fiscalização
#
# Annotation
# ID = 621
# Type = Orgao
# Text = da Secretaria de Estado de
# Obras e Infraestrutura do Distrito Federal
#
# Annotation
# ID = 43
# Type = NomeacaoComissionado
# ...

# %%
for documento in root.findall('document'):
    #dentro do documento
    for paragrafo in documento.findall('passage'):
        #dentro de cada parágrafo
        nome = 0
        cargoefetivo = 0
        matricula = 0
        matriculasiape = 0
        simbolo = 0
        cargo = 0
        hierarquia = 0
        orgao = 0
        for anno in paragrafo.findall('annotation'):
            #dentro de cada anotação
            anno_data = []
            
            #encontra o tipo de anotação
            for infon in anno.findall('infon'):
                if infon.get('key') == 'type':
                    anno_type = infon.text
                    print(anno_type)
                    
                    #confere se é o sobre o ato ou sobre entidade dentro do ato
                    if anno_type == 'NomeacaoComissionado':
                        dentro = 0
                    
                    elif anno_type != 'NomeacaoComissionado':
                        dentro = 1
                        
                    #anno_data.append(anno_type)
            naoTem = 'None'        
            if dentro == 0:
                print('\n\n NOVO ATO')
                print('Type = ' + anno_type)
                text = anno.find('text').text
                print('Texto = ' + text)
                nome = 0
                cargoefetivo = 0
                matricula = 0
                matriculasiape = 0
                simbolo = 0
                cargo = 0
                hierarquia = 0
                orgao = 0
                
            
            
            if dentro == 1:
                #print('Type = ' + anno_type)
                if anno_type == 'NomeServidor': 
                        print('  Nome = ' + anno.find('text').text)
                        nome = 1
                else: 
                    if nome == 0:
                        nome = 1
                        print('  Nome = ' + naoTem)  
                    if anno_type == 'CargoEfetivo': 
                        print('  CargoEfetivo = ' + anno.find('text').text)
                        cargoefetivo = 1
                    else:
                        if cargoefetivo == 0:
                            cargoefetivo = 1
                            print('  CargoEfetivo = ' + naoTem)    
                        if anno_type == 'Matricula': 
                            print('  Matricula = ' + anno.find('text').text)
                            matricula = 1
                        else: 
                            if matricula == 0:
                                print('  Matricula = ' + naoTem) 
                                matricula = 1
                            if anno_type == 'MatriculaSiape': 
                                print('  MatriculaSiape = ' + anno.find('text').text)
                                matriculasiape = 1
                            else: 
                                if matriculasiape == 0:
                                    print('  MatriculaSiape = ' + naoTem)
                                    matriculasiape = 1
                                if anno_type == 'Simbolo': 
                                    print('  Simbolo = ' + anno.find('text').text)
                                    simbolo = 1
                                else: 
                                    if simbolo == 0:
                                        print('  Simbolo = ' + naoTem) 
                                        simbolo = 1
                                    if anno_type == 'Cargo': 
                                        print('  Cargo = ' + anno.find('text').text)
                                        cargo = 1
                                    else: 
                                        if cargo == 0:
                                            print('  Cargo = ' + naoTem)
                                            cargo = 1
                                        if anno_type == 'Hierarquia_da_Lotacao': 
                                            print('  Hierarquia_da_Lotacao = ' + anno.find('text').text)
                                            hierarquia = 1
                                        else: 
                                            if hierarquia == 0:
                                                print('  Hierarquia_da_Lotacao = ' + naoTem)
                                                hierarquia = 1
                                            if anno_type == 'Orgao': 
                                                print('  Orgao = ' + anno.find('text').text)
                                            else: 
                                                print('  Orgao = ' + naoTem)  

                
'''
            if dentro == 3:
                #print('Type = ' + anno_type)
                if anno_type == 'Matricula': 
                    print('  Matricula = ' + anno.find('text').text)
                else: 
                    print('  Matricula = ' + naoTem)    
            
                          
            if dentro == 4:
                #print('Type = ' + anno_type)
                if anno_type == 'MatriculaSiape': 
                    print('  MatriculaSiape = ' + anno.find('text').text)
                else: 
                    print('  MatriculaSiape = ' + naoTem)    
            
                          
            if dentro == 5:
                #print('Type = ' + anno_type)
                if anno_type == 'Simbolo': 
                    print('  Simbolo = ' + anno.find('text').text)
                else: 
                    print('  Simbolo = ' + naoTem)    
               
                          
            if dentro == 6:
                #print('Type = ' + anno_type)
                if anno_type == 'Cargo': 
                    print('  Cargo = ' + anno.find('text').text)
                else: 
                    print('  Cargo = ' + naoTem)    
               
                          
            if dentro == 7:
                #print('Type = ' + anno_type)
                if anno_type == 'Hierarquia_da_Loatacao': 
                    print('  Hierarquia_da_Loatacao = ' + anno.find('text').text)
                else: 
                    print('  Hierarquia_da_Loatacao = ' + naoTem)    
                
                          
            if dentro == 8:
                #print('Type = ' + anno_type)
                if anno_type == 'Orgao': 
                    print('  Orgao = ' + anno.find('text').text)
                else: 
                    print('  Orgao = ' + naoTem)    
        
            
'''
# Out:
# NomeacaoComissionado
#
#
#  NOVO ATO
# Type = NomeacaoComissionado
# Texto = NOMEAR RICARDO TERENZI CARDOSO para exercer o Cargo de Natureza Especial, Símbolo CNE02, de Subsecretário, da Subsecretaria de Acompanhamento e Fiscalização, da Secretaria de Estado de
# Obras e Infraestrutura do Distrito Federal.
# NomeServidor
#   Nome = RICARDO TERENZI CARDOSO
# Simbolo
#   CargoEfetivo = None
#   Matricula = None
#   MatriculaSiape = None
#   Simbolo = CNE02
# Cargo
#   Cargo = Subsecretário
# Hierarquia_da_Lotacao
#   Hierarquia_da_Lotacao = Subsecretaria de Acompanhamento e Fiscalização
# Orgao
#   Orgao = da Secretaria de Estado de
# Obras e Infraestrutura do Distrito Federal
# NomeacaoComissionado
#
#
#  NOVO ATO
# Type = NomeacaoComissionado
# Texto = NOMEAR LEONARDO RODRIGUES FACÓ para exercer o Cargo de Natureza Especial, Símbolo CNE05, de Chefe, da Assessoria Especial, da Subsecretaria de Acompanhamento e Fiscalização, da Secretaria
# ...

# %%
import os
import csv

csvFile = open('dodf7_nomeacoes3.csv', 'w', encoding='utf-8')
csvWriter = csv.writer(csvFile)

#colNames = ['tipo', 'texto', 'NomeServidor', 'CargoEfetivo', 'Matricula', 'MatriculaSiape', 'Simbolo', 'Cargo', 'Hierarquia_da_Lotacao', 'Orgao']
#csvWriter.writerow(colNames)
anno_data = ['tipo', 'texto', 'NomeServidor', 'CargoEfetivo', 'Matricula', 'MatriculaSiape', 'Simbolo', 'Cargo', 'Hierarquia_da_Lotacao', 'Orgao', 'outro']

for documento in root.findall('document'):
    #dentro do documento
    for paragrafo in documento.findall('passage'):
        #dentro de cada parágrafo
        nome = 0
        cargoefetivo = 0
        matricula = 0
        matriculasiape = 0
        simbolo = 0
        cargo = 0
        hierarquia = 0
        orgao = 0
        for anno in paragrafo.findall('annotation'):
            #dentro de cada anotação
            
            #encontra o tipo de anotação
            for infon in anno.findall('infon'):
                if infon.get('key') == 'type':
                    anno_type = infon.text
                    print(anno_type)
                    
                    #confere se é o sobre o ato ou sobre entidade dentro do ato
                    if anno_type == 'NomeacaoComissionado':
                        dentro = 0
                    
                    elif anno_type != 'NomeacaoComissionado':
                        dentro = 1
                        
                    #anno_data.append(anno_type)
            naoTem = 'None'        
            if dentro == 0:
                print("\nNOVO ATO")
                csvWriter.writerow(anno_data)
                anno_data = []
                print('Type = ' + anno_type)
                anno_data.append(anno_type)
                text = anno.find('text').text
                print('Texto = ' + text)
                anno_data.append(text)
                nome = 0
                cargoefetivo = 0
                matricula = 0
                matriculasiape = 0
                simbolo = 0
                cargo = 0
                hierarquia = 0
                orgao = 0
                
            
            
            if dentro == 1:
                #print('Type = ' + anno_type)
                if anno_type == 'NomeServidor': 
                        print('  Nome = ' + anno.find('text').text)
                        anno_data.append(anno.find('text').text)
                        nome = 1
                else: 
                    if nome == 0:
                        nome = 1
                        print('  Nome = ' + naoTem) 
                        anno_data.append(naoTem)
                    if anno_type == 'CargoEfetivo': 
                        print('  CargoEfetivo = ' + anno.find('text').text)
                        anno_data.append(anno.find('text').text)
                        cargoefetivo = 1
                    else:
                        if cargoefetivo == 0:
                            cargoefetivo = 1
                            print('  CargoEfetivo = ' + naoTem) 
                            anno_data.append(naoTem)
                        if anno_type == 'Matricula': 
                            print('  Matricula = ' + anno.find('text').text)
                            anno_data.append(anno.find('text').text)
                            matricula = 1
                        else: 
                            if matricula == 0:
                                print('  Matricula = ' + naoTem)
                                anno_data.append(naoTem)
                                matricula = 1
                            if anno_type == 'MatriculaSiape': 
                                print('  MatriculaSiape = ' + anno.find('text').text)
                                anno_data.append(anno.find('text').text)
                                matriculasiape = 1
                            else: 
                                if matriculasiape == 0:
                                    print('  MatriculaSiape = ' + naoTem)
                                    anno_data.append(naoTem)
                                    matriculasiape = 1
                                if anno_type == 'Simbolo': 
                                    print('  Simbolo = ' + anno.find('text').text)
                                    anno_data.append(anno.find('text').text)
                                    simbolo = 1
                                else: 
                                    if simbolo == 0:
                                        print('  Simbolo = ' + naoTem)
                                        anno_data.append(naoTem)
                                        simbolo = 1
                                    if anno_type == 'Cargo': 
                                        print('  Cargo = ' + anno.find('text').text)
                                        anno_data.append(anno.find('text').text)
                                        cargo = 1
                                    else: 
                                        if cargo == 0:
                                            print('  Cargo = ' + naoTem)
                                            anno_data.append(naoTem)
                                            cargo = 1
                                        if anno_type == 'Hierarquia_da_Lotacao': 
                                            print('  Hierarquia_da_Lotacao = ' + anno.find('text').text)
                                            anno_data.append(anno.find('text').text)
                                            hierarquia = 1
                                        else: 
                                            if hierarquia == 0:
                                                print('  Hierarquia_da_Lotacao = ' + naoTem)
                                                anno_data.append(naoTem)
                                                hierarquia = 1
                                            if anno_type == 'Orgao': 
                                                print('  Orgao = ' + anno.find('text').text)
                                                anno_data.append(anno.find('text').text)
                                            else: 
                                                print('  Orgao = ' + naoTem)
                                                anno_data.append(naoTem)

csvWriter.writerow(anno_data)
csvFile.close()
# Out:
# NomeacaoComissionado
#
# NOVO ATO
# Type = NomeacaoComissionado
# Texto = NOMEAR RICARDO TERENZI CARDOSO para exercer o Cargo de Natureza Especial, Símbolo CNE02, de Subsecretário, da Subsecretaria de Acompanhamento e Fiscalização, da Secretaria de Estado de
# Obras e Infraestrutura do Distrito Federal.
# NomeServidor
#   Nome = RICARDO TERENZI CARDOSO
# Simbolo
#   CargoEfetivo = None
#   Matricula = None
#   MatriculaSiape = None
#   Simbolo = CNE02
# Cargo
#   Cargo = Subsecretário
# Hierarquia_da_Lotacao
#   Hierarquia_da_Lotacao = Subsecretaria de Acompanhamento e Fiscalização
# Orgao
#   Orgao = da Secretaria de Estado de
# Obras e Infraestrutura do Distrito Federal
# NomeacaoComissionado
#
# NOVO ATO
# Type = NomeacaoComissionado
# Texto = NOMEAR LEONARDO RODRIGUES FACÓ para exercer o Cargo de Natureza Especial, Símbolo CNE05, de Chefe, da Assessoria Especial, da Subsecretaria de Acompanhamento e Fiscalização, da Secretaria
# ...

# %%
import pandas as pd

dataset = pd.read_csv("dodf7_nomeacoes3.csv")

dataset
# Out:
#                      tipo                                              texto  \
# 0    NomeacaoComissionado  NOMEAR RICARDO TERENZI CARDOSO para exercer o ...
# 1    NomeacaoComissionado  NOMEAR LEONARDO RODRIGUES FACÓ para exercer o ...
# 2    NomeacaoComissionado  NOMEAR CARLOS MAGNO RODRIGUES BARROS para exer...
# 3    NomeacaoComissionado  NOMEAR ARYADNE BEZERRA PORCIUNCULA, Assessora ...
# 4    NomeacaoComissionado  NOMEAR AMANDA CRISTINA MARQUES MONTEIRO para e...
# ..                    ...                                                ...
# 243  NomeacaoComissionado  NOMEAR ENIVALDO ERILANY FELIPE DOS SANTOS, mat...
# 244  NomeacaoComissionado  NOMEAR PAULO DA SILVA MIRANDA JUNIOR, matrícul...
# 245  NomeacaoComissionado  NOMEAR WILLIAM DA SILVA GANZELA, matrícula nº ...
# 246  NomeacaoComissionado  NOMEAR ROGÉRIO DE SOUZA LEITÃO, matrícula nº 2...
# 247  NomeacaoComissionado  NOMEAR RAYANE SITONIO VELASCO, para o Cargo em...
#
# ...
