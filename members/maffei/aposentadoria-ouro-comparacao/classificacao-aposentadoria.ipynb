# %%
ls
# Out:
# data@                               extract-dodfminer-dodfs_flat-plot.ipynb
# data_anotada/                       extract-dodfminer.ipynb
# date-num-plot.csv                   generate-ouro-counter.ipynb
# extract_compare.csv                 plot-aposentadoria-diff.ipynb
# extract-dodfminer-dodfs_flat.ipynb  Untitled.ipynb

# %%
from dodfminer.extract.polished.acts.aposentadoria import Retirements
import pandas as pd
import numpy as np
import fitz
from drawBoxes import drawBoxes
from itertools import chain

from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
# from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.naive_bayes import MultinomialNB as MNB
from sklearn.naive_bayes import ComplementNB
from catboost import CatBoostClassifier


import glob

def get_doc_blocks(doc):
    return list(chain(*[i.getTextBlocks() for i in doc]))
def get_dodfs_path():
    return glob.glob('data/aposentadoria-ouro/pdfs/*.pdf')

# %%
get_dodfs_path()
# Out:
# ['data/aposentadoria-ouro/pdfs/DODF 155 16-08-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 123 29-06-2018 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 047 12-03-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 104 04-06-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 163 28-08-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 156 19-08-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 108 10-06-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 177 17-09-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 091 14-05-2018 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 175 13-09-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 149 08-08-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 238 17-12-2018 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 059 28-03-2019 INTEGRA.pdf',
#  'data/aposentadoria-ouro/pdfs/DODF 131 12-07-2018 INTEGRA.pdf',
# ...

# %%
doc = fitz.open(
    'data/aposentadoria-ouro/pdfs/DODF 004 07-01-2019 INTEGRA.pdf'
)

# %%
blocks = get_doc_blocks(doc)

    print(i)
    input('\n')
# Out:
# ANO XLVIII EDIÇÃO No- 4
# BRASÍLIA - DF, SEGUNDA-FEIRA, 7 DE JANEIRO DE 2019
#
#
# Este documento pode ser verificado no endereço eletrônico h t t p : / / w w w. i n . g o v. b r / a u t e n t i c i d a d e . h t m l
# pelo código 50012019010700001
# Documento assinado digitalmente conforme MP nº 2.200-2 de 24/08/2001, que institui a
# Infraestrutura de Chaves Públicas Brasileira - ICP-Brasil.
#
#
# SEÇÃO I
#
#
# SUMÁRIO
# SEÇÃO I
# PÁG.
# SEÇÃO II
# PÁG.
# SEÇÃO III
# PÁG.
#
#
# Casa Civil .............................................................................................. . 1 5
#
#
# Secretaria de Estado de Fazenda, Planejamento, Orçamento e
# Gestão .................................................................................................... .
#
#
# 1 14
#
#
# Secretaria de Estado de Saúde ............................................................. . 5
#
#
# Secretaria de Estado de Educação ....................................................... . 14
#
#
# ...

# %%
doc2 = fitz.open(doc.name)
doc2 = drawBoxes.draw2(doc, img=False, line=False)
doc2.save('temp_color.pdf')
