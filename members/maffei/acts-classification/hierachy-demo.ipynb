# %%
import pandas as pd
import numpy as np
import os
import glob

import fitz
import hierarchy
import core

# %%
pdf_lis = glob.glob('pdf/*.pdf')
pdf_lis
# Out:
# ['pdf/DODF 009 14-01-2019 INTEGRA_canvas.pdf',
#  'pdf/2018_12_03.pdf',
#  'pdf/2_5_2019_extra.pdf',
#  'pdf/2_text.pdf',
#  'pdf/2_jan_2019.pdf',
#  'pdf/25_marked.pdf',
#  'pdf/2020_04_30_canvas.pdf',
#  'pdf/2020_marked.pdf',
#  'pdf/02-04-2019_canvas.pdf',
#  'pdf/2002_11_04.pdf',
#  'pdf/2020_04_30.pdf',
#  'pdf/29_10_2001_secao1_canvas_i0_w0_l1_t1.pdf',
#  'pdf/2001_canvas.pdf',
#  'pdf/2020_canvas_i0_w0_l1_t1.pdf',
#  'pdf/2001_11_01.pdf',
#  'pdf/2019_01_22.pdf']

# %%
p  = 'pdf/25_marked.pdf'
doc = fitz.open(p)

# %%
h = hierarchy.mount_hierarchy(doc)
hierarchy.post_process_hierarchy(h);
# hierarchy.show_post_hier(h)
# Out:
# 	[init_hier] first_title of pdf/25_marked.pdf: PODER EXECUTIVO - Size: 12.951430320739746

# %%
h_texts = hierarchy.hierarchy_text(h)

# %%
for t in h_texts['SEÇÃO II'][:15]:
    print(t)
    print('\n\n\n')
# Out:
# RETIFICAÇÃO
# No Decreto de 21 de janeiro de 2019, publicado na Edição Extra nº 7, de 21 de janeiro de 2019, página
# 4, o ato que nomeou VIVIANE PEREIRA ALMEIDA, da Administração Regional de Águas Claras do
# Distrito Federal, ONDE SE LÊ: "...VIVIANE PEREIRA ALMEIDA...", LEIA-SE: "...VIVIANE
# PEREIRA DA SILVA...
#
#
#
#
# PORTARIA N° 2, DE 21 DE JANEIRO DE 2019
# O SECRETÁRIO DE ESTADO-CHEFE DA CASA CIVIL, no uso das atribuições que lhe conferem os
# incisos V e VII do parágrafo único do art. 105 da Lei Orgânica do Distrito Federal e o art. 2º do Decreto
# nº 37.096, de 02 de fevereiro de 2016, e na Instrução Normativa nº 04/2016 da Controladoria Geral do
# Distrito Federal - CGDF, R E S O LV E :
# Art. 1º Designar CECÍLIA TEIXEIRA DE CASTRO, matrícula nº 1.682.396-6, para substituir LUCIANA
# RANGEL SANTOS DITTBERNER, matrícula nº 125.114-7, nas Tomadas de Contas Especiais,
# instauradas pela Portaria nº 64, de 27 de julho de 2017, publicada no DODF nº 144, de 28 de julho de
# ...

# %%
exo = core.Exoneracao('pdf/results/json/25_marked.json')
exo.data_frame
# Out:
#          tipo                    nome matricula simbolo  \
# 0  Exoneração   BRUNA GOMES GUIMARAES       nan     nan
#
#                                       cargo_comissao lotacao orgao vigencia  \
# 0   Tecnico de Gestao Educacional-\nApoio Adminis...     nan   nan      nan
#
#      pedido cargo_efetivo siape motivo
# 0  a pedido           nan   nan    nan

# %%
exo.acts_str
# Out:
# ['EXONERAR, a pedido, BRUNA GOMES GUIMARAES do Cargo de Tecnico de Gestao Educacional-\\nApoio Administrativo, matricula 240']
